# %%
import pandas as pd
import requests as r

# %%
data = [
     ['Optimism Goerli, optimism_goerli.csv']
#     ,['Optimism Mainnet, optimism_mainnet.csv']
#     ,['Base Goerli, base_goerli.csv']
#     ,['Base Mainnet, base_mainnet.csv']
    ]
cols = ['chain_name', 'file_name']
datasets = pd.DataFrame(data, columns=cols)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/opt/anaconda3/envs/new-env/lib/python3.10/site-packages/pandas/core/internals/construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File ~/opt/anaconda3/envs/new-env/lib/python3.10/site-packages/pandas/core/internals/construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
# ...

# %%
# for ds in datasets:
#     pd.read_csv)
display(datasets)
# Out:
#                                                0
# chain_name  Optimism Goerli, optimism_goerli.csv
# file_name   Optimism Goerli, optimism_goerli.csv
