# %%
import coingecko_utils as cg

slug = 'optimism'
granularity = 'hourly'

# %%
df = cg.get_token_data_by_granularity(slug, granularity)
df.to_csv(slug + '.csv')
display(df)
# Out:
#                         date    prices   market_caps  total_volumes     cg_id  \
# 0    2023-01-12 14:02:28.580  1.321830  2.795312e+08   2.242304e+08  optimism
# 1    2023-01-12 15:02:03.160  1.248298  2.704065e+08   2.417343e+08  optimism
# 2    2023-01-12 16:02:17.855  1.269605  2.721672e+08   2.455573e+08  optimism
# 3    2023-01-12 17:01:49.149  1.267675  2.725269e+08   2.439728e+08  optimism
# 4    2023-01-12 18:00:10.337  1.340265  2.772324e+08   2.594847e+08  optimism
# ...                      ...       ...           ...            ...       ...
# 2162 2023-04-12 10:00:51.147  2.222689  6.989397e+08   1.437122e+08  optimism
# 2163 2023-04-12 11:01:13.248  2.225307  7.012389e+08   1.411532e+08  optimism
# 2164 2023-04-12 12:01:21.515  2.220476  6.983250e+08   1.391548e+08  optimism
# 2165 2023-04-12 13:01:10.481  2.248133  7.065046e+08   1.470623e+08  optimism
# 2166 2023-04-12 13:32:25.000  2.257319  7.103218e+08   1.495987e+08  optimism
#
# ...
