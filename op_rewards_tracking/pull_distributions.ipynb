# %%
# Based off of Cow Protocol's Dune Client: https://github.com/cowprotocol/dune-client
import pandas as pd
import dotenv
import os

from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import Query

# %%
# https://dune.com/queries/1900056/3127874
query = Query(
    name="Latest OP Distributions by Project",
    query_id=1900056,
)
print("Results available at", query.url())
# Out:
# Results available at https://dune.com/queries/1900056

# %%
dotenv.load_dotenv()
dune = DuneClient(os.environ["DUNE_API_KEY"])
results = dune.refresh(query)
# Out:
# 2023-03-08 14:48:50,739 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:48:56,176 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:01,686 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:07,187 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:12,755 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:18,262 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:23,840 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:29,350 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:34,825 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:40,327 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:45,814 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:51,539 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:49:57,061 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:02,547 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:08,053 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:13,538 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:18,993 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:24,477 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:29,968 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:35,514 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:41,035 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:46,514 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:51,980 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:50:57,438 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:02,916 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:08,395 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:13,870 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:19,354 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:24,831 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:30,329 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:35,801 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:41,273 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:46,936 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:52,441 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:51:57,938 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:03,443 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:08,931 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:14,428 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:19,992 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:25,500 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:30,983 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:36,496 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:42,000 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:47,491 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:52,962 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:52:58,450 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:04,015 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:09,514 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:15,060 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:20,660 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:26,671 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:32,152 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:37,667 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:43,146 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:48,636 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:54,216 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:53:59,720 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:54:05,259 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:54:10,761 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:54:16,269 INFO dune_client.base_client waiting for query execution 01GV1C9TDYEC5XG7XFWMPHZDZM to complete: ExecutionState.EXECUTING
# 2023-03-08 14:54:22,417 ERROR dune_client.base_client ExecutionState.FAILED: execution_id=01GV1C9TDYEC5XG7XFWMPHZDZM, query_id=1900056, times=TimeData(submitted_at=datetime.datetime(2023, 3, 8, 19, 48, 50, 240355, tzinfo=tzutc()), execution_started_at=datetime.datetime(2023, 3, 8, 19, 48, 50, 280518, tzinfo=tzutc()), execution_ended_at=datetime.datetime(2023, 3, 8, 19, 54, 17, 200102, tzinfo=tzutc()), expires_at=datetime.datetime(2025, 3, 7, 19, 54, 17, 200103, tzinfo=tzutc()), cancelled_at=None)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 dotenv.load_dotenv()
#       2 dune = DuneClient(os.environ["DUNE_API_KEY"])
# ----> 3 results = dune.refresh(query)
#
# File ~/opt/anaconda3/envs/new-env/lib/python3.10/site-packages/dune_client/client.py:132, in DuneClient.refresh(self, query, ping_frequency)
#     130 if status.state == ExecutionState.FAILED:
#     131     self.logger.error(status)
# --> 132     raise Exception(f"{status}. Perhaps your query took too long to run!")
#     133 return full_response
#
# Exception: ExecutionState.FAILED: execution_id=01GV1C9TDYEC5XG7XFWMPHZDZM, query_id=1900056, times=TimeData(submitted_at=datetime.datetime(2023, 3, 8, 19, 48, 50, 240355, tzinfo=tzutc()), execution_started_at=datetime.datetime(2023, 3, 8, 19, 48, 50, 280518, tzinfo=tzutc()), execution_ended_at=datetime.datetime(2023, 3, 8, 19, 54, 17, 200102, tzinfo=tzutc()), expires_at=datetime.datetime(2025, 3, 7, 19, 54, 17, 200103, tzinfo=tzutc()), cancelled_at=None). Perhaps your query took too long to run!

# %%
df = pd.DataFrame(results.result.rows)
df['last_updated'] = results.times.submitted_at
if not os.path.exists('csv_output'):
    os.makedirs('csv_output')
df.to_csv('csv_output/dune_op_distribution.csv')
display(df)
# Out:
#                                             from_link           from_name  \
# 0   <a href="https://dune.com/optimismfnd/optimism...  Perpetual Protocol
# 1   <a href="https://dune.com/optimismfnd/optimism...           Synthetix
# 2   <a href="https://dune.com/optimismfnd/optimism...           Velodrome
# 3   <a href="https://dune.com/optimismfnd/optimism...                Aave
# 4   <a href="https://dune.com/optimismfnd/optimism...                Lyra
# ..                                                ...                 ...
# 66  <a href="https://dune.com/optimismfnd/optimism...          Otterspace
# 67  <a href="https://dune.com/optimismfnd/optimism...               Agora
# 68  <a href="https://dune.com/optimismfnd/optimism...               Karma
# 69  <a href="https://dune.com/optimismfnd/optimism...            Bankless
# 70  <a href="https://dune.com/optimismfnd/optimism...   Interest Protocol
#
#                         funding_sources  op_approved_to_project op_claimed  \
# 0                  Governance - Phase 0               9000000.0    5001210
# 1                  Governance - Phase 0               9000000.0    2607135
# 2   Partner Fund, Governance - Season 2               7000000.0    3924386
# 3    Partner Fund, Governance - Phase 0               5000000.0    4816019
# 4                  Governance - Phase 0               3000000.0    1097624
# ..                                  ...                     ...        ...
# 66                Governance - Season 2                 50000.0       7000
# 67                Governance - Season 2                     0.0          0
# 68                Governance - Season 2                 35000.0      25556
# 69                Governance - Season 2                 33000.0      33000
# 70                Governance - Season 2                 31764.0          0
#
#    op_deployed op_from_other_projects op_incoming_clawback op_to_project p1  \
# 0     10908005                      0                    0       9000000  |
# 1      4745555                      0                    0       9000000  |
# 2      4554899                  47272                    0       7047271  |
# 3      4816019                      0                    0       5300000  |
# 4      1353360                  83570                    0       3083570  |
# ..         ...                    ...                  ...           ... ..
# 66        7000                      0                    0         50000  |
# 67           0                      0                    0             0  |
# 68       25556                      0                    0         25000  |
# 69       33000                      0                    0         33000  |
# 70           0                      0                    0         14630  |
#
#     ... p3 pct_allocated_approved  pct_approved_to_project  \
# 0   ...  |               1.000000                 1.000000
# 1   ...  |               1.000000                 1.000000
# 2   ...  |               1.000000                 1.006753
# 3   ...  |               0.943396                 1.060000
# 4   ...  |               1.000000                 1.027857
# ..  ... ..                    ...                      ...
# 66  ...  |               1.000000                 1.000000
# 67  ...  |                    NaN                      NaN
# 68  ...  |               0.875000                 0.714286
# 69  ...  |               1.000000                 1.000000
# 70  ...  |               1.000000                 0.460584
#
#     pct_claimed_to_project pct_deployed_claimed pct_to_project_deployed  \
# 0                  0.55569              0.45849                1.212001
# 1                 0.289682             0.549385                0.527284
# 2                 0.556866             0.861575                0.646335
# 3                 0.908683                    1                0.908683
# 4                 0.355959             0.811036                0.438894
# ..                     ...                  ...                     ...
# 66                    0.14                    1                    0.14
# 67                    None                 None                    None
# 68                 1.02224                    1                 1.02224
# 69                       1                    1                       1
# 70                       0                  NaN                       0
#
#       program_status                                     proposal_links  \
# 0       Live Program  <a href="https://gov.optimism.io/t/gf-phase-0-...
# 1       Live Program  <a href="https://gov.optimism.io/t/gf-phase-0-...
# 2       Live Program  <a href="https://snapshot.org/#/opcollective.e...
# 3   Between Programs  <a href="https://gov.optimism.io/t/gf-phase-0-...
# 4       Live Program  <a href="https://gov.optimism.io/t/gf-phase-0-...
# ..               ...                                                ...
# 66      Not Launched  <a href="https://snapshot.org/#/opcollective.e...
# 67      Not Launched  <a href="https://snapshot.org/#/opcollective.e...
# 68      Not Launched  <a href="https://snapshot.org/#/opcollective.e...
# 69      Not Launched  <a href="https://snapshot.org/#/opcollective.e...
# 70      Not Launched  <a href="https://snapshot.org/#/opcollective.e...
#
#    total_op_allocated                     last_updated
# 0             9000000 2023-02-14 11:50:30.086732+00:00
# 1             9000000 2023-02-14 11:50:30.086732+00:00
# 2             7000000 2023-02-14 11:50:30.086732+00:00
# 3             5300000 2023-02-14 11:50:30.086732+00:00
# 4             3000000 2023-02-14 11:50:30.086732+00:00
# ..                ...                              ...
# 66              50000 2023-02-14 11:50:30.086732+00:00
# 67              50000 2023-02-14 11:50:30.086732+00:00
# 68              40000 2023-02-14 11:50:30.086732+00:00
# 69              33000 2023-02-14 11:50:30.086732+00:00
# 70              31764 2023-02-14 11:50:30.086732+00:00
#
# [71 rows x 21 columns]
