# %%
# Based off of Cow Protocol's Dune Client: https://github.com/cowprotocol/dune-client
import pandas as pd
import dotenv
import os

from dune_client.types import QueryParameter
from dune_client.client import DuneClient
from dune_client.query import Query

# %%
# https://dune.com/queries/2162007 # OP Distributed - OP Deployed Aggregate
query_aggregate = Query(
    name="Latest OP Deployments by Project",
    query_id=2162007,
)
print("Results available at", query_aggregate.url())

# https://dune.com/queries/1886707 # OP Distributed - OP Deployed By Type
query_type = Query(
    name="Latest OP Deployments by Project and Type",
    query_id=1886707,
)
print("Results available at", query_type.url())
# Out:
# Results available at https://dune.com/queries/2162007
# Results available at https://dune.com/queries/1886707

# %%
dotenv.load_dotenv()
dune = DuneClient(os.environ["DUNE_API_KEY"])
## Don't run aggregate, this is duplicative of by type
# results_aggregate = dune.refresh(query_aggregate)
# print('aggregate done')
results_type = dune.refresh(query_type)
print('type done')
# Out:
# 2023-03-10 15:05:02,547 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:08,007 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:13,541 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:19,031 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:24,519 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:29,994 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:35,475 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:40,931 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:46,385 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:51,903 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:05:57,396 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:02,855 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:08,316 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:13,802 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:19,280 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:24,717 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:30,187 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:35,654 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:41,106 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:46,598 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:52,035 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:06:57,487 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:02,941 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:08,429 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:13,877 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:19,350 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:24,853 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:30,335 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# 2023-03-10 15:07:35,798 INFO dune_client.base_client waiting for query execution 01GV6J0XFSXK3TK05Q6221ZQQE to complete: ExecutionState.EXECUTING
# type done

# %%
## Don't run aggregate, this is duplicative of by type
# df_agg = pd.DataFrame(results_aggregate.result.rows)
# df_agg['last_updated'] = results_aggregate.times.submitted_at

df_type = pd.DataFrame(results_type.result.rows)
df_type['last_updated'] = results_type.times.submitted_at

if not os.path.exists('csv_outputs'):
    os.makedirs('csv_outputs')

# df_agg.to_csv('csv_outputs/dune_op_distribution_agg.csv')
df_type.to_csv('csv_outputs/dune_op_distribution_type.csv')

# %%
display(df_type)
# Out:
#                               from_name op_deployed  to_label  \
# 0                                 1inch      300000  Deployed
# 1                                 Aelin      880175     Other
# 2                                 Aelin       19827   Project
# 3                              Alchemix       20386     Other
# 4                              Alchemix       10000  Deployed
# ..                                  ...         ...       ...
# 144                              dHedge       80000  Deployed
# 145                              dHedge       10219  Deployed
# 146  xToken Terminal / Gamma Strategies      297025  Deployed
# 147  xToken Terminal / Gamma Strategies       61812     Other
# 148  xToken Terminal / Gamma Strategies       25000  Deployed
#
#                    to_type                     last_updated
# 0              Distributor 2023-03-10 20:05:02.077384+00:00
# 1                     None 2023-03-10 20:05:02.077384+00:00
# 2             Intermediate 2023-03-10 20:05:02.077384+00:00
# 3                     None 2023-03-10 20:05:02.077384+00:00
# 4    alETH/WETH: Velodrome 2023-03-10 20:05:02.077384+00:00
# ..                     ...                              ...
# 144            Distributor 2023-03-10 20:05:02.077384+00:00
# 145      DHT/OP: Velodrome 2023-03-10 20:05:02.077384+00:00
# 146        Rewards Program 2023-03-10 20:05:02.077384+00:00
# 147                   None 2023-03-10 20:05:02.077384+00:00
# 148               Rewarder 2023-03-10 20:05:02.077384+00:00
#
# [149 rows x 5 columns]
