# %%
print('start app fees')
import pandas as pd
import sys
import numpy as np
import json
import requests as r

import time


from datetime import datetime, timedelta
sys.path.append("../helper_functions")
import defillama_utils as dfl
import duneapi_utils as du
import opstack_metadata_utils as ops
import csv_utils as cu
import google_bq_utils as bqu
sys.path.pop()

current_utc_date = datetime.utcnow().replace(hour=0, minute=0, second=0, microsecond=0)
# print(current_utc_date)
# Out:
# start app fees
# /var/folders/by/kltjc8yd0yz_7_wrtrzhrm9m0000gn/T/ipykernel_22383/643138684.py:20: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   current_utc_date = datetime.utcnow().replace(hour=0, minute=0, second=0, microsecond=0)

# %%
data_typed = 'dailyRevenue'
df = dfl.get_fees_revenue('optimism', exclude_total_data_chart=False, exclude_total_data_chart_breakdown=False, data_type=data_typed)
display(df)
df.to_csv(f'outputs/defillama_{data_typed}.csv')
# Out:
#    defillamaId                name                slug  disabled  \
# 0          654     Beethoven X DEX     beethoven-x-dex     False
# 1          622             Clipper             clipper     False
# 2            3           Curve DEX           curve-dex     False
# 3         3515       DackieSwap V2       dackieswap-v2     False
# 4          420                 Elk                 elk     False
# 5          127   KyberSwap Classic   kyberswap-classic     False
# 6          127   KyberSwap Elastic   kyberswap-elastic     False
# 7         2361       Mummy Finance       mummy-finance     False
# 8          916                Pika                pika     False
# 9         3281             Pika V4             pika-v4     False
# 10        3481          Solidly V3          solidly-v3     False
# 11         119        SushiSwap V3        sushiswap-v3     False
# 12         115           Synthetix           synthetix     False
# 13        4555         TLX Finance         tlx-finance     False
# 14        1833              UniDex              unidex     False
# 15        1799        Velodrome V1        velodrome-v1     False
# 16        4249        Velodrome V3        velodrome-v3     False
# 17        3302        Velodrome V2        velodrome-v2     False
# 18        1461          WOOFi Swap          woofi-swap     False
# 19         111             AAVE V3             aave-v3     False
# 20         204            Alchemix            alchemix     False
# 21        3944      Allbridge Core      allbridge-core     False
# 22         756               Angle               angle     False
# 23         326               Beefy               beefy     False
# 24        2734           Blast API           blast-api     False
# 25        3675      Chainlink CCIP      chainlink-ccip     False
# 26        2623  Chainlink Requests  chainlink-requests     False
# 27        3846            deBridge            debridge     False
# 28        2974       Extra Finance       extra-finance     False
# 29         742           Furucombo           furucombo     False
# 30         355               Gamma               gamma     False
# 31        2254        MUX Protocol        mux-protocol     False
# 32        2546            NFTEarth            nftearth     False
# 33        3951                ODOS                odos     False
# 34       11840            Optimism            optimism     False
# 35         894            Paraswap            paraswap     False
# 36         382              Pendle              pendle     False
# 37         362  Perpetual Protocol  perpetual-protocol     False
# 38         381           Premia V2           premia-v2     False
# 39         449               QiDao               qidao     False
# 40        3038             Rainbow             rainbow     False
# 41        2142       Sonne Finance       sonne-finance     False
# 42        1571         Stargate V1         stargate-v1     False
# 43        4741           Summer.fi           summer.fi     False
# 44         657             Synapse             synapse     False
# 45         434               Tarot               tarot     False
# 46        3657        Uniswap Labs        uniswap-labs     False
# 47        4602             vfat.io             vfat.io     False
# 48        4049       Zerion Wallet       zerion-wallet     False
# 49        2532               Zonic               zonic     False
# 50           1          Uniswap V3          uniswap-v3     False
#
#             displayName                module           category  \
# 0       Beethoven X DEX           beethoven-x              Dexes
# 1               Clipper               clipper              Dexes
# 2             Curve DEX                 curve              Dexes
# 3         DackieSwap V2         dackieswap-v2              Dexes
# 4                   Elk                   elk              Dexes
# 5   KyberSwap - Classic             kyberswap              Dexes
# 6   KyberSwap - Elastic             kyberswap              Dexes
# 7         Mummy Finance         mummy-finance        Derivatives
# 8                  Pika         pika-protocol        Derivatives
# 9               Pika V4      pika-protocol-v4        Derivatives
# 10           Solidly V3            solidly-v3              Dexes
# 11         SushiSwap V3             sushiswap              Dexes
# 12            Synthetix             synthetix         Synthetics
# 13          TLX Finance           tlx-finance        Derivatives
# 14               UniDex                unidex        Derivatives
# 15         Velodrome V1             velodrome              Dexes
# 16         Velodrome V3  velodrome-slipstream              Dexes
# 17         Velodrome V2          velodrome-v2              Dexes
# 18           WOOFi Swap                 woofi              Dexes
# 19              AAVE V3                  aave            Lending
# 20             Alchemix              alchemix         Synthetics
# 21       Allbridge Core        allbridge-core             Bridge
# 22                Angle                 angle                CDP
# 23                Beefy                 beefy   Yield Aggregator
# 24            Blast API              blastapi           Services
# 25       Chainlink CCIP        chainlink-ccip           Services
# 26   Chainlink Requests    chainlink-requests             Oracle
# 27             deBridge                   dln           Services
# 28        Extra Finance                 extra  Leveraged Farming
# 29            Furucombo             furucombo           Services
# 30                Gamma                 gamma  Liquidity manager
# 31         MUX Protocol                   mux        Derivatives
# 32             NFTEarth              nftearth    NFT Marketplace
# 33                 ODOS                  odos     DEX Aggregator
# 34             Optimism              optimism             Rollup
# 35             Paraswap              paraswap     DEX Aggregator
# 36               Pendle                pendle              Yield
# 37   Perpetual Protocol    perpetual-protocol        Derivatives
# 38            Premia V2                premia            Options
# 39                QiDao                 qidao                CDP
# 40              Rainbow        rainbow-wallet            Wallets
# 41        Sonne Finance         sonne-finance            Lending
# 42          Stargate V1              stargate        Cross Chain
# 43            Summer.fi             summer.fi           Services
# 44              Synapse               synapse        Cross Chain
# 45                Tarot                 tarot            Lending
# 46         Uniswap Labs           uniswap-lab           Services
# 47              vfat.io                  vfat   Yield Aggregator
# 48        Zerion Wallet         zerion-wallet            Wallets
# 49                Zonic                 zonic    NFT Marketplace
# 50           Uniswap V3               uniswap              Dexes
#
#                                                  logo  change_1d  change_7d  \
# 0   https://icons.llamao.fi/icons/protocols/beetho...      38.89      -4.37
# 1   https://icons.llamao.fi/icons/protocols/clippe...        NaN        NaN
# 2   https://icons.llamao.fi/icons/protocols/curve.png     -53.27     -11.17
# 3   https://icons.llamao.fi/icons/protocols/dackie...        NaN        NaN
# 4     https://icons.llamao.fi/icons/protocols/elk.jpg        NaN        NaN
# 5   https://icons.llamao.fi/icons/protocols/kybers...        NaN        NaN
# 6   https://icons.llamao.fi/icons/protocols/kybers...        NaN        NaN
# 7   https://icons.llamao.fi/icons/protocols/mummy-...     -80.43     -21.58
# 8    https://icons.llamao.fi/icons/protocols/pika.png        NaN        NaN
# 50  https://icons.llamao.fi/icons/protocols/uniswa...        NaN        NaN
#
#     ...  holdersRevenue30d  bribesRevenue30d  dailyUserFees  dailyFees  \
# 0   ...                NaN               NaN            NaN        NaN
# 1   ...                NaN               NaN            NaN        NaN
# 2   ...            10095.0               0.0            NaN        NaN
# 3   ...                NaN               NaN            0.0        0.0
# 4   ...                0.0               NaN            0.0        0.0
# 5   ...                NaN               NaN            NaN        NaN
# 6   ...                NaN               NaN            NaN        NaN
# 7   ...                NaN               NaN          271.0      109.0
# 8   ...                NaN               NaN            NaN        0.0
# 9   ...                NaN               NaN            NaN        0.0
# 10  ...             2098.0               NaN          395.0      395.0
# 11  ...                0.0               NaN           65.0       65.0
# 12  ...           622825.0               NaN        19186.0    19186.0
# 13  ...           195133.0               NaN            NaN     2381.0
# 14  ...                NaN               NaN            NaN        NaN
# 15  ...             1072.0               0.0            NaN        NaN
# 16  ...           640339.0               NaN            NaN        NaN
# 17  ...           418767.0         1684346.0            NaN        NaN
# 18  ...            31915.0               NaN            NaN        NaN
# 19  ...                NaN               NaN            NaN        NaN
# 20  ...                NaN               NaN            NaN        NaN
# 21  ...                NaN               NaN            NaN       98.0
# 22  ...                NaN               NaN            NaN        NaN
# 23  ...             1863.0               NaN            NaN        0.0
# 24  ...                NaN               NaN            NaN        0.0
# 25  ...                NaN               NaN            NaN        0.0
# 26  ...                NaN               NaN            NaN        NaN
# 27  ...                NaN               NaN            NaN     5171.0
# 28  ...                NaN               NaN            NaN        NaN
# 29  ...                NaN               NaN            NaN        0.0
# 30  ...                NaN               NaN            NaN     3432.0
# 31  ...             2796.0               NaN            NaN      138.0
# 32  ...                NaN               NaN            NaN        NaN
# 33  ...                0.0               NaN            NaN       71.0
# 34  ...                NaN               NaN            NaN        NaN
# 35  ...                NaN               NaN            NaN       83.0
# 36  ...              970.0               NaN            0.0        0.0
# 37  ...                NaN               NaN            NaN     1130.0
# 38  ...                0.0               NaN            0.0        0.0
# 39  ...                0.0               NaN            NaN        NaN
# 40  ...                NaN               NaN            NaN      320.0
# 41  ...                NaN               NaN            NaN        NaN
# 42  ...                NaN               NaN            NaN      448.0
# 43  ...                NaN               NaN            NaN      110.0
# 44  ...                NaN               NaN          100.0      100.0
# 45  ...                NaN               NaN            NaN        NaN
# 46  ...                NaN               NaN            NaN     1848.0
# 47  ...                NaN               NaN            NaN      406.0
# 48  ...                NaN               NaN            NaN       17.0
# 49  ...                NaN               NaN            NaN        NaN
# 50  ...                0.0               NaN        80757.0    80757.0
#
#     versionKey  totalUserFees  totalFees  tokenTaxes30d  totalRevenue  \
# 0          NaN            NaN        NaN            NaN           NaN
# 1          NaN            NaN        NaN            NaN           NaN
# 2          NaN            NaN        NaN            NaN           NaN
# 3          NaN            NaN        NaN            NaN           NaN
# 4          NaN            NaN        NaN            NaN           NaN
# 5      classic            NaN        NaN            NaN           NaN
# 6      elastic            NaN        NaN            NaN           NaN
# 7          NaN            NaN        NaN            NaN           NaN
# 8          NaN            NaN        NaN            NaN           NaN
# 9          NaN            NaN        NaN            NaN           NaN
# 10         NaN            NaN        NaN            NaN           NaN
# 11          v3            NaN        NaN            NaN           NaN
# 12         NaN            NaN        NaN            NaN           NaN
# 13         NaN            NaN        NaN            NaN           NaN
# 14         NaN            NaN        NaN            NaN           NaN
# 15         NaN            NaN        NaN            NaN           NaN
# 16         NaN            NaN        NaN            NaN           NaN
# 17         NaN            NaN        NaN            NaN           NaN
# 18         NaN            NaN        NaN            NaN           NaN
# 19          v3            NaN        NaN            NaN           NaN
# 20         NaN            NaN        NaN            NaN           NaN
# 21         NaN            NaN        NaN            NaN           NaN
# 22         NaN            NaN        NaN            NaN           NaN
# 23         NaN            NaN        NaN            NaN           NaN
# 24         NaN            NaN        NaN            NaN           NaN
# 25         NaN            NaN        NaN            NaN           NaN
# 26         NaN            NaN        NaN            NaN           NaN
# 27         NaN            NaN        NaN            NaN           NaN
# 28         NaN            NaN        NaN            NaN           NaN
# 29         NaN            NaN        NaN            NaN           NaN
# 30         NaN            NaN        NaN            NaN           NaN
# 31         NaN            NaN        NaN            NaN           NaN
# 32         NaN            NaN        NaN            NaN           NaN
# 33         NaN            NaN        NaN            NaN           NaN
# 34         NaN            NaN        NaN            NaN           NaN
# 35         NaN            NaN        NaN            NaN           NaN
# 36         NaN            NaN        NaN            NaN           NaN
# 37         NaN            NaN        NaN            NaN           NaN
# 38          v2            NaN        NaN            NaN           NaN
# 39         NaN            NaN        NaN            NaN           NaN
# 40         NaN            NaN        NaN            NaN           NaN
# 41         NaN            NaN        NaN            NaN           NaN
# 42         NaN            NaN        NaN            NaN           NaN
# 43         NaN            NaN        NaN            NaN           NaN
# 44         NaN            NaN        NaN            NaN           NaN
# 45         NaN            NaN        NaN            NaN           NaN
# 46         NaN            NaN        NaN            NaN           NaN
# 47         NaN            NaN        NaN            NaN           NaN
# 48         NaN            NaN        NaN            NaN           NaN
# 49         NaN            NaN        NaN            NaN           NaN
# 50          v3            NaN        NaN            NaN           NaN
#
#     totalProtocolRevenue
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
#
# [51 rows x 48 columns]

# %%
# df.head()
df.columns
df_filter = df[['defillamaId','name','slug','chains','protocolType','totalFees','totalSupplySideRevenue','totalAllTime']]
df_filter.sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 # df.head()
#       2 df.columns
# ----> 3 df_filter = df[['defillamaId','name','slug','chains','protocolType','totalFees','totalSupplySideRevenue','totalAllTime']]
#       4 df_filter.sample(5)
#
# File ~/opt/anaconda3/envs/gcp-env/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/gcp-env/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/gcp-env/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['totalSupplySideRevenue'] not in index"
