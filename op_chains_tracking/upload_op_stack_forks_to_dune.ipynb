# %%
import pandas as pd

import sys
sys.path.append("../helper_functions")
import duneapi_utils as d
import pandas_utils as p
sys.path.pop()

import dotenv
import os
dotenv.load_dotenv()
# Out:
# True

# %%
df = pd.read_csv('inputs/chain_metadata.csv')
print(df.head(5))
# Out:
#                         chain_name mainnet_chain_id op_based_version  \
# 0                       op mainnet               10          bedrock
# 1                             base             8453          bedrock
# 2                             zora          7777777          bedrock
# 3             public goods network              424          bedrock
# 4                     aevo network                    legacy bedrock
# 5                            opbnb              204          bedrock
# 6                    manta pacific              169          bedrock
# 7                       loot chain                           bedrock
# 8                    kroma network              255          bedrock
# 9                           vienna                           bedrock
# 10                 orderly network              291          bedrock
# 11                  mantle network             5000       legacy ovm
# 12                 metis andromeda             1088       legacy ovm
# 13                    boba network              288       legacy ovm
# 14                           curio                           unknown
# 15  giant leap gaming / underverse                           unknown
# 16                            lyra              957          bedrock
# 17                    mode network            34443          bedrock
# 18                 ancient 8 chain                           bedrock
# 19                    debank chain              116          bedrock
# 20                          rollux              570          bedrock
# 21                    unidex magma                           unknown
# 22                    stealthchain                           unknown
# 23                        redstone                           bedrock
# 24                            celo                           bedrock
# 25                       swanchain                           bedrock
# 26                    hypr network                           unknown
# 27                           metal                           bedrock
#
#     has_mods is_law_of_chains raas_deployer  \
# 0         no              yes
# 1         no              yes
# 2         no                        conduit
# 3         no                        conduit
# 4        yes                        conduit
# 5        yes
# 6        yes                        caldera
# 7        yes                        caldera
# 8        yes
# 9        yes                        caldera
# 10        no                        conduit
# 11       yes
# 12       yes
# 13       yes
# 14       yes                        caldera
# 15       yes                        caldera
# 16        no                        conduit
# 17        no                        conduit
# 18        no                        conduit
# 19       yes
# 20       yes
# 21   unknown
# 22   unknown
# 23       yes
# 24       yes               no
# 25   unknown               no
# 26       yes               no
# 27   unknown               no
#
#                                     rpc_url                   product_website  \
# 0               https://mainnet.optimism.io               https://optimism.io
# 1                 https://mainnet.base.org/                  https://base.org
# 2                  https://rpc.zora.energy/               https://zora.energy
# 3          https://rpc.publicgoods.network/      https://publicgoods.network/
# 4                      https://api.aevo.xyz             https://www.aevo.xyz/
# 5    https://opbnb-mainnet-rpc.bnbchain.org     https://opbnb.bnbchain.org/en
# 6    https://pacific-rpc.manta.network/http    https://pacific.manta.network/
# 7            https://rpc.lootchain.com/http        https://adventuregold.org/
# 8                https://api.kroma.network/            https://kroma.network/
# 9      https://vienna.calderachain.xyz/http       https://vienna.caldera.dev/
# 10              https://rpc.orderly.network          https://orderly.network/
# 11                   https://rpc.mantle.xyz                https://mantle.xyz
# 12   https://andromeda.metis.io/?owner=1088             https://www.metis.io/
# 13             https://mainnet.boba.network             https://boba.network/
# 14                                                      https://www.curio.gg/
# 15                                            https://giantleap.gg/underverse
# 16                https://rpc.lyra.finance/         https://www.lyra.finance/
# 17             https://mainnet.mode.network         https://www.mode.network/
# 18                                                       https://ancient8.gg/
# 19                                                        https://debank.com/
# 20                   https://rpc.rollux.com               https://rollux.com/
# 21                                               https://www.unidex.exchange/
# 22                                                           stealthchain.org
# 23                                                      https://redstone.xyz/
# 24                                                          https://celo.org/
# 25                                                      https://swanchain.io/
# 26                                                  https://www.hypr.network/
# 27                                                       https://metall2.com/
#
#      defillama_slug          l2beat_slug       growthepie_alias gas_token  \
# 0          Optimism             optimism             OP Mainnet       ETH
# 1              Base                 base                   Base       ETH
# 2              Zora                 zora                   Zora       ETH
# 3                     publicgoodsnetwork   Public Goods Network       ETH
# 4    protocols/Aevo                 aevo                              ETH
# 5             opBNB                opbnb                              BNB
# 6             Manta         mantapacific                              ETH
# 7                                                                     ETH
# 8             Kroma                kroma                              ETH
# 9                                                                     ETH
# 10                                                                    ETH
# 11          Mantle                mantle                              MNT
# 12            Metis                metis                              ETH
# 13             Boba          bobanetwork                              ETH
# 14                                                                unknown
# 15                                                                unknown
# 16                           lyrafinance                              ETH
# 17             Mode                 mode                              ETH
# 18                                                                    ETH
# 19                                                                unknown
# 20           Rollux                                                   SYS
# 21                                                                unknown
# 22                          stealthchain                          unknown
# 23                                                                unknown
# 24                                                                   CELO
# 25                                                                unknown
# 26                                                                unknown
# 27                                 metal                          unknown
#
#      da_layer is_in_superchain_registry_repo
# 0    ethereum                            yes
# 1    ethereum                            yes
# 2    ethereum                            yes
# 3    ethereum                            yes
# 4    ethereum                             no
# 5         bnb                             no
# 6    celestia                             no
# 7     polygon                             no
# 8    ethereum                             no
# 9     unknown                             no
# 10   ethereum                             no
# 11    eigenda                             no
# 12     alt-da                             no
# 13   ethereum                             no
# 14    unknown                             no
# 15    unknown                             no
# 16   ethereum                             no
# 17   ethereum                             no
# 18   ethereum                             no
# 19    unknown                             no
# 20    bitcoin                             no
# 21    unknown                             no
# 22    unknown                             no
# 23     plasma                             no
# 24    eigenda                             no
# 25    unknown                             no
# 26   celestia                             no
# 27    unknown                             no

# %%
# Post to Dune API
d.write_dune_api_from_pandas(df, 'op_stack_chain_metadata_info_tracking',\
                             'Basic Info & Metadata about OP Stack Chains, including forks')
