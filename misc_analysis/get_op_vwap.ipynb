# %%
import pandas as pd

import sys
sys.path.append("../helper_functions")
import coingecko_utils as cg
sys.path.pop()


df = cg.get_token_data_by_granularity('optimism','daily',False)
# Out:
# https://api.coingecko.com/api/v3/coins/optimism/market_chart?vs_currency=usd&days=365&interval=daily

# %%
print('Total Days :' + str(len(df)) )

df['price_x_volume'] = df['prices'] * df['total_volumes']

display(df)

total_volume = df['total_volumes'].sum()
total_price_x_volume = df['price_x_volume'].sum()

vwap = total_price_x_volume / total_volume

print('OP VWAP T' + str(len(df)) + ' Days: ' + str(vwap) )
# Out:
# Total Days :365
#           date    prices   market_caps  total_volumes     cg_id symbol  \
# 0   2022-07-15  0.492482  1.061513e+08   4.098120e+07  optimism     op
# 1   2022-07-16  0.481153  1.034083e+08   4.300690e+07  optimism     op
# 2   2022-07-17  0.520623  1.119864e+08   4.091435e+07  optimism     op
# 3   2022-07-18  0.580016  1.252065e+08   1.319303e+08  optimism     op
# 4   2022-07-19  0.816466  1.744403e+08   3.481879e+08  optimism     op
# ..         ...       ...           ...            ...       ...    ...
# 360 2023-07-10  1.213633  7.813656e+08   3.424276e+07  optimism     op
# 361 2023-07-11  1.199195  7.725126e+08   6.649549e+07  optimism     op
# 362 2023-07-12  1.222113  7.874422e+08   4.766549e+07  optimism     op
# 363 2023-07-13  1.217410  7.859625e+08   6.541169e+07  optimism     op
# 364 2023-07-14  1.367162  8.794500e+08   1.654131e+08  optimism     op
#
#          name                                            details  \
# 0    Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 1    Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 2    Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 3    Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 4    Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# ..        ...                                                ...
# 360  Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 361  Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 362  Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 363  Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
# 364  Optimism  {'optimistic-ethereum': {'decimal_place': 18, ...
#
#      price_x_volume
# 0      2.018249e+07
# 1      2.069289e+07
# 2      2.130095e+07
# 3      7.652169e+07
# 4      2.842835e+08
# ..              ...
# 360    4.155816e+07
# 361    7.974105e+07
# 362    5.825263e+07
# 363    7.963284e+07
# 364    2.261466e+08
#
# [365 rows x 9 columns]
# OP VWAP T365 Days: 1.853120686135792
