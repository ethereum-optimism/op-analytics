# %%
from op_analytics.datapipeline.etl.blockbatchloaddaily.main import (
    daily_to_clickhouse,
)

from op_analytics.datapipeline.etl.blockbatchloaddaily.datasets import (
    DAILY_SEGMENTS,
)

result = daily_to_clickhouse(
    dataset=DAILY_SEGMENTS,
    range_spec="@20250301:20250403",
    dry_run=True,
    chains=['base']
)
# Out:
# 2025-04-07 14:40:33 [debug    ] connecting to OPLABS Clickhouse client... filename=client.py lineno=56 process=79341
# 2025-04-07 14:40:33 [info     ] loaded vault from .env file    filename=vault.py lineno=32 process=79341
# 2025-04-07 14:40:33 [debug    ] loaded vault: 21 items         filename=vault.py lineno=79 process=79341
# 2025-04-07 14:40:33 [debug    ] initialized OPLABS Clickhouse client. filename=client.py lineno=61 process=79341
# 2025-04-07 14:40:33 [info     ] 33 are ready to process across 33 dates filename=readers.py lineno=81 process=79341
# 2025-04-07 14:40:33 [info     ] 33/33 pending dt,chain insert tasks. filename=main.py lineno=53 process=79341
# INSERT INTO blockbatch_daily.aggtxs__daily_segments_v1
# WITH
# DailyWalletActivity AS (
#
#   SELECT
#     dt, chain, chain_id, network, from_address,
#     count_transactions, count_success_transactions, count_distinct_blocks,
#     count_distinct_success_blocks, count_distinct_active_hours,
# ...
