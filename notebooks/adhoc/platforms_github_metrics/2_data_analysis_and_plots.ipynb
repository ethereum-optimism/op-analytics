# %%
"""
Part 2: Analysis & Plotting
---------------------------
Reads CSVs from 'data/' for one or more repositories,
performs baseline analysis, and creates visual charts.
"""

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Repositories you'd like to analyze
repos = [
    "optimism",
    "supersim",
    "superchainerc20-starter",
    "superchain-registry",
    "superchain-ops",
    "docs",
    "specs",
    "design-docs",
    "infra",
]

# ---------------------------
# Example: read single timeseries CSV, plot
# ---------------------------
for repo in repos:
    ts_path = f"data/{repo}_timeseries.csv"
    print(f"Reading {ts_path} ...")
    timeseries_df = pd.read_csv(ts_path)
    if timeseries_df.empty:
        print(f"No data found for {repo}, skipping plots.")
        continue

    timeseries_df.set_index("date", inplace=True)
    timeseries_df.sort_index(inplace=True)
    timeseries_df.index = pd.to_datetime(timeseries_df.index)
    timeseries_df.fillna(0, inplace=True)
    print(f"{repo} timeseries_df shape => {timeseries_df.shape}")

    # Some rolling window line plots
    metrics_to_plot = {
        "avg_time_to_approval_days": "Average Time to Approval",
        "avg_time_to_first_non_bot_comment_days": "Average Time to First Non-Bot Comment",
        "avg_time_to_merge_days": "Average Time to Merge",
        "approval_ratio": "Approval Ratio",
        "number_of_prs": "Number of PRs",
        "avg_comments_per_pr": "Average Comments per PR"
    }

    # for metric, title in metrics_to_plot.items():
    #     # We'll do a simple rolling-30-day average
    #     plt.figure(figsize=(12, 6))
    #     timeseries_df[metric].rolling(window=30, min_periods=1).mean().plot(kind="line")
    #     plt.title(f"{repo} - {title} (30-Day Rolling Avg)")
    #     plt.xlabel("Date")
    #     plt.ylabel(title)
    #     plt.grid(True)
    #     plt.tight_layout()
    #     plt.show()


# Iterate over each repository and sample the CSV files
for repo in repos:
    ts_path = f"data/{repo}_timeseries.csv"
    print(f"Reading {ts_path} ...")
    try:
        timeseries_df = pd.read_csv(ts_path)
    except FileNotFoundError:
        print(f"No CSV file found for {repo}, skipping.")
        continue

    if timeseries_df.empty:
        print(f"No data found in {ts_path}, skipping.")
        continue

    # Sample the first few rows
    print(f"\nSample data from {ts_path}:")
    print(timeseries_df.head())

    # Print a summary of the DataFrame
    print(f"\nSummary statistics for {repo}:")
    print(timeseries_df.describe(include='all'))

    # Print the columns and data types
    print(f"\nColumns and data types for {repo}:")
    print(timeseries_df.dtypes)
    print("\n" + "-"*50 + "\n")
# Out:
# Reading data/optimism_timeseries.csv ...
# optimism timeseries_df shape => (346, 12)
# Reading data/supersim_timeseries.csv ...
# supersim timeseries_df shape => (102, 12)
# Reading data/superchainerc20-starter_timeseries.csv ...
# superchainerc20-starter timeseries_df shape => (19, 12)
# Reading data/superchain-registry_timeseries.csv ...
# superchain-registry timeseries_df shape => (216, 12)
# Reading data/superchain-ops_timeseries.csv ...
# superchain-ops timeseries_df shape => (157, 12)
# Reading data/docs_timeseries.csv ...
# docs timeseries_df shape => (249, 12)
# Reading data/specs_timeseries.csv ...
# specs timeseries_df shape => (190, 12)
# Reading data/design-docs_timeseries.csv ...
# design-docs timeseries_df shape => (83, 12)
# Reading data/infra_timeseries.csv ...
# infra timeseries_df shape => (59, 12)
# Reading data/optimism_timeseries.csv ...
#
# Sample data from data/optimism_timeseries.csv:
#        repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  optimism  2024-01-01              7                2.953278
# 1  optimism  2024-01-02              9                1.788615
# 2  optimism  2024-01-03             20                1.307060
# 3  optimism  2024-01-04             22                1.357202
# 4  optimism  2024-01-05             20                3.426893
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   1.085122                0.866840                8.776030
# 1                   1.449838                0.753218                3.693773
# 2                   0.638275                0.039213                5.099537
# 3                   0.082488                0.014537                6.476343
# 4                   2.866331                0.068322               12.599410
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                        NaN                        NaN
# 1                                        NaN                        NaN
# 2                                        NaN                        NaN
# 3                                        NaN                        NaN
# 4                                        NaN                        NaN
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                           NaN                  0.0             0.0
# 1                           NaN                  0.0             0.0
# 2                           NaN                  0.0             0.0
# 3                           NaN                  0.0             0.0
# 4                           NaN                  0.0             0.0
#
# Summary statistics for optimism:
#             repo        date  number_of_prs  avg_time_to_merge_days  \
# count        346         346     346.000000              331.000000
# unique         1         346            NaN                     NaN
# top     optimism  2024-01-01            NaN                     NaN
# freq         346           1            NaN                     NaN
# mean         NaN         NaN      10.910405                3.061687
# std          NaN         NaN       7.050999                3.435118
# min          NaN         NaN       1.000000                0.027002
# 25%          NaN         NaN       5.000000                1.044787
# 50%          NaN         NaN      11.000000                2.082442
# 75%          NaN         NaN      16.000000                3.589951
# max          NaN         NaN      35.000000               34.706638
#
#         median_time_to_merge_days  min_time_to_merge_days  \
# count                  331.000000              331.000000
# unique                        NaN                     NaN
# top                           NaN                     NaN
# freq                          NaN                     NaN
# mean                     1.512697                0.454990
# std                      2.762147                1.392929
# min                      0.027002                0.000069
# 25%                      0.275796                0.022384
# 50%                      0.763738                0.041377
# 75%                      1.593056                0.147998
# max                     34.706638               11.414282
#
#         max_time_to_merge_days  avg_time_to_first_non_bot_comment_days  \
# count               331.000000                              157.000000
# unique                     NaN                                     NaN
# top                        NaN                                     NaN
# freq                       NaN                                     NaN
# mean                 12.972424                                3.083705
# std                  17.604985                                7.728804
# min                   0.027002                                0.000619
# 25%                   2.873889                                0.287924
# 50%                   7.228287                                0.846759
# 75%                  15.006117                                2.677888
# max                 188.919664                               76.163310
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                  157.000000                 209.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     2.540157                   3.718364
# std                                      7.622802                   8.285991
# min                                      0.000619                   0.005694
# 25%                                      0.122083                   0.694797
# 50%                                      0.601759                   1.822422
# 75%                                      2.179792                   3.756903
# max                                     76.163310                 103.678194
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                     209.000000           346.000000      346.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        2.481259             0.491920        0.420280
# std                         8.336209             1.014156        0.406063
# min                         0.005694             0.000000        0.000000
# 25%                         0.101169             0.000000        0.000000
# 50%                         0.425683             0.000000        0.460606
# 75%                         1.433536             0.629934        0.809524
# max                       103.678194             9.333333        1.000000
#
# Columns and data types for optimism:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/supersim_timeseries.csv ...
#
# Sample data from data/supersim_timeseries.csv:
#        repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  supersim  2024-06-24              4                0.560486
# 1  supersim  2024-06-25              3                0.408619
# 2  supersim  2024-06-26              2                0.799225
# 3  supersim  2024-06-27              2                0.803108
# 4  supersim  2024-06-28              2               10.321146
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   0.769549                0.027905                0.884005
# 1                   0.054560                0.035613                1.135683
# 2                   0.799225                0.714016                0.884433
# 3                   0.803108                0.714051                0.892164
# 4                  10.321146                9.847164               10.795127
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                0.020116
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                9.842836
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                   0.020116                   0.130154
# 1                                        NaN                   0.587812
# 2                                        NaN                   0.425642
# 3                                        NaN                   0.771047
# 4                                   9.842836                   9.832078
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                      0.186331                 0.25        0.750000
# 1                      0.587812                 0.00        0.666667
# 2                      0.425642                 0.00        1.000000
# 3                      0.771047                 0.00        1.000000
# 4                      9.832078                 3.50        1.000000
#
# Summary statistics for supersim:
#             repo        date  number_of_prs  avg_time_to_merge_days  \
# count        102         102     102.000000               84.000000
# unique         1         102            NaN                     NaN
# top     supersim  2024-06-24            NaN                     NaN
# freq         102           1            NaN                     NaN
# mean         NaN         NaN       1.960784                3.404106
# std          NaN         NaN       1.142531                9.110840
# min          NaN         NaN       1.000000                0.009630
# 25%          NaN         NaN       1.000000                0.389030
# 50%          NaN         NaN       2.000000                0.890411
# 75%          NaN         NaN       2.750000                2.750023
# max          NaN         NaN       6.000000               73.877407
#
#         median_time_to_merge_days  min_time_to_merge_days  \
# count                   84.000000               84.000000
# unique                        NaN                     NaN
# top                           NaN                     NaN
# freq                          NaN                     NaN
# mean                     3.344286                2.801051
# std                      9.129531                9.200816
# min                      0.000093                0.000093
# 25%                      0.294497                0.024994
# 50%                      0.872972                0.379086
# 75%                      2.601243                1.022760
# max                     73.877407               73.877407
#
#         max_time_to_merge_days  avg_time_to_first_non_bot_comment_days  \
# count                84.000000                               46.000000
# unique                     NaN                                     NaN
# top                        NaN                                     NaN
# freq                       NaN                                     NaN
# mean                  4.067141                                4.530131
# std                   9.186948                               11.548238
# min                   0.009630                                0.000648
# 25%                   0.533958                                0.039442
# 50%                   1.139612                                0.759109
# 75%                   4.751311                                3.473999
# max                  73.877407                               69.139931
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                   46.000000                  85.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     4.528686                   3.214810
# std                                     11.548803                   8.795560
# min                                      0.000648                   0.001678
# 25%                                      0.039442                   0.158646
# 50%                                      0.759109                   0.742789
# 75%                                      3.473999                   2.638792
# max                                     69.139931                  71.238461
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                      85.000000           102.000000      102.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        3.154868             1.237745        0.775817
# std                         8.808720             2.513123        0.380077
# min                         0.001678             0.000000        0.000000
# 25%                         0.126447             0.000000        0.666667
# 50%                         0.698553             0.000000        1.000000
# 75%                         2.230376             1.458333        1.000000
# max                        71.238461            15.000000        1.000000
#
# Columns and data types for supersim:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/superchainerc20-starter_timeseries.csv ...
#
# Sample data from data/superchainerc20-starter_timeseries.csv:
#                       repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  superchainerc20-starter  2024-10-11              2                0.000359
# 1  superchainerc20-starter  2024-10-15              1                0.011863
# 2  superchainerc20-starter  2024-10-16              1                5.866620
# 3  superchainerc20-starter  2024-10-21              1                0.962708
# 4  superchainerc20-starter  2024-10-23              2                0.027182
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   0.000359                0.000347                0.000370
# 1                   0.011863                0.011863                0.011863
# 2                   5.866620                5.866620                5.866620
# 3                   0.962708                0.962708                0.962708
# 4                   0.027182                0.012060                0.042303
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                     NaN
# 1                                     NaN
# 2                                5.866562
# 3                                     NaN
# 4                                     NaN
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                        NaN                        NaN
# 1                                        NaN                   0.009988
# 2                                   5.866562                   5.865810
# 3                                        NaN                   0.908032
# 4                                        NaN                        NaN
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                           NaN                  0.0             0.0
# 1                      0.009988                  0.0             1.0
# 2                      5.865810                  1.0             1.0
# 3                      0.908032                  0.0             1.0
# 4                           NaN                  0.0             0.0
#
# Summary statistics for superchainerc20-starter:
#                            repo        date  number_of_prs  \
# count                        19          19      19.000000
# unique                        1          19            NaN
# top     superchainerc20-starter  2024-10-11            NaN
# freq                         19           1            NaN
# mean                        NaN         NaN       2.473684
# std                         NaN         NaN       2.064742
# min                         NaN         NaN       1.000000
# 25%                         NaN         NaN       1.000000
# 50%                         NaN         NaN       2.000000
# 75%                         NaN         NaN       3.000000
# max                         NaN         NaN       9.000000
#
#         avg_time_to_merge_days  median_time_to_merge_days  \
# count                17.000000                  17.000000
# unique                     NaN                        NaN
# top                        NaN                        NaN
# freq                       NaN                        NaN
# mean                  1.132199                   1.033908
# std                   2.160184                   2.172038
# min                   0.000359                   0.000359
# 25%                   0.006845                   0.005625
# 50%                   0.012350                   0.013067
# 75%                   0.962708                   0.957986
# max                   7.149502                   7.149502
#
#         min_time_to_merge_days  max_time_to_merge_days  \
# count                17.000000               17.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                  0.881885                1.482081
# std                   2.152854                2.499880
# min                   0.000069                0.000370
# 25%                   0.000475                0.012350
# 50%                   0.006227                0.031898
# 75%                   0.012350                0.962708
# max                   7.149502                7.149502
#
#         avg_time_to_first_non_bot_comment_days  \
# count                                 1.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                  5.866562
# std                                        NaN
# min                                   5.866562
# 25%                                   5.866562
# 50%                                   5.866562
# 75%                                   5.866562
# max                                   5.866562
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                    1.000000                   9.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     5.866562                   1.884282
# std                                           NaN                   2.579058
# min                                      5.866562                   0.003519
# 25%                                      5.866562                   0.009988
# 50%                                      5.866562                   0.154572
# 75%                                      5.866562                   4.986620
# max                                      5.866562                   5.865810
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                       9.000000            19.000000       19.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        1.884282             0.052632        0.294152
# std                         2.579058             0.229416        0.402604
# min                         0.003519             0.000000        0.000000
# 25%                         0.009988             0.000000        0.000000
# 50%                         0.154572             0.000000        0.000000
# 75%                         4.986620             0.000000        0.416667
# max                         5.865810             1.000000        1.000000
#
# Columns and data types for superchainerc20-starter:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/superchain-registry_timeseries.csv ...
#
# Sample data from data/superchain-registry_timeseries.csv:
#                   repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  superchain-registry  2024-01-05              3                4.903733
# 1  superchain-registry  2024-01-10              2                     NaN
# 2  superchain-registry  2024-01-16              1                     NaN
# 3  superchain-registry  2024-01-17              1                     NaN
# 4  superchain-registry  2024-01-18              2                0.082778
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   4.903733                4.902662                4.904803
# 1                        NaN                     NaN                     NaN
# 2                        NaN                     NaN                     NaN
# 3                        NaN                     NaN                     NaN
# 4                   0.082778                0.045799                0.119757
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                4.754514
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                   4.754514                   4.740712
# 1                                        NaN                   0.006047
# 2                                        NaN                        NaN
# 3                                        NaN                        NaN
# 4                                        NaN                   0.073762
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                      4.740712             0.333333        0.666667
# 1                      0.006047             0.000000        1.000000
# 2                           NaN             0.000000        0.000000
# 3                           NaN             0.000000        0.000000
# 4                      0.073762             0.000000        0.500000
#
# Summary statistics for superchain-registry:
#                        repo        date  number_of_prs  \
# count                   216         216     216.000000
# unique                    1         216            NaN
# top     superchain-registry  2024-01-05            NaN
# freq                    216           1            NaN
# mean                    NaN         NaN       2.828704
# std                     NaN         NaN       2.089466
# min                     NaN         NaN       1.000000
# 25%                     NaN         NaN       1.000000
# 50%                     NaN         NaN       2.000000
# 75%                     NaN         NaN       4.000000
# max                     NaN         NaN      13.000000
#
#         avg_time_to_merge_days  median_time_to_merge_days  \
# count               196.000000                 196.000000
# unique                     NaN                        NaN
# top                        NaN                        NaN
# freq                       NaN                        NaN
# mean                  3.380822                   2.993080
# std                   5.961443                   5.939564
# min                   0.004248                   0.001806
# 25%                   0.376832                   0.221304
# 50%                   1.439446                   0.872743
# 75%                   3.776192                   3.626929
# max                  45.676748                  45.676748
#
#         min_time_to_merge_days  max_time_to_merge_days  \
# count               196.000000              196.000000
# unique                     NaN                     NaN
# top                        NaN                     NaN
# freq                       NaN                     NaN
# mean                  1.947069                5.418618
# std                   5.053805                8.912195
# min                   0.000139                0.004248
# 25%                   0.019421                0.671907
# 50%                   0.175590                2.073866
# 75%                   1.252734                6.801565
# max                  45.676748               77.883310
#
#         avg_time_to_first_non_bot_comment_days  \
# count                                81.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                  2.641462
# std                                   5.818991
# min                                   0.001285
# 25%                                   0.083414
# 50%                                   0.644057
# 75%                                   1.980255
# max                                  30.994317
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                   81.000000                 199.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     2.632726                   2.678743
# std                                      5.822264                   5.430370
# min                                      0.001285                   0.000255
# 25%                                      0.083414                   0.178955
# 50%                                      0.514334                   0.719255
# 75%                                      1.980255                   2.626784
# max                                     30.994317                  42.885301
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                     199.000000           216.000000      216.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        2.335596             0.643905        0.794711
# std                         5.405494             1.551393        0.306057
# min                         0.000255             0.000000        0.000000
# 25%                         0.071759             0.000000        0.666667
# 50%                         0.430694             0.000000        1.000000
# 75%                         1.806030             0.500000        1.000000
# max                        42.885301            14.000000        1.000000
#
# Columns and data types for superchain-registry:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/superchain-ops_timeseries.csv ...
#
# Sample data from data/superchain-ops_timeseries.csv:
#              repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  superchain-ops  2024-01-12              3                0.103333
# 1  superchain-ops  2024-01-17              1                1.056678
# 2  superchain-ops  2024-01-18              2                0.195544
# 3  superchain-ops  2024-01-19              1                     NaN
# 4  superchain-ops  2024-01-22              1               10.922037
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   0.103333                0.066019                0.140648
# 1                   1.056678                1.056678                1.056678
# 2                   0.195544                0.195544                0.195544
# 3                        NaN                     NaN                     NaN
# 4                  10.922037               10.922037               10.922037
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                               15.619433
# 1                                0.290509
# 2                                     NaN
# 3                                     NaN
# 4                                0.723137
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                   0.029965                   0.075139
# 1                                   0.290509                   1.056424
# 2                                        NaN                   0.100700
# 3                                        NaN                        NaN
# 4                                   0.723137                  10.921840
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                      0.075139                  7.0        0.666667
# 1                      1.056424                  1.0        1.000000
# 2                      0.100700                  0.0        1.000000
# 3                           NaN                  0.0        0.000000
# 4                     10.921840                 17.0        1.000000
#
# Summary statistics for superchain-ops:
#                   repo        date  number_of_prs  avg_time_to_merge_days  \
# count              157         157     157.000000              143.000000
# unique               1         157            NaN                     NaN
# top     superchain-ops  2024-01-12            NaN                     NaN
# freq               157           1            NaN                     NaN
# mean               NaN         NaN       2.242038                3.367881
# std                NaN         NaN       1.558275                6.081238
# min                NaN         NaN       1.000000                0.000613
# 25%                NaN         NaN       1.000000                0.075116
# 50%                NaN         NaN       2.000000                1.067257
# 75%                NaN         NaN       3.000000                4.412361
# max                NaN         NaN      10.000000               34.472940
#
#         median_time_to_merge_days  min_time_to_merge_days  \
# count                  143.000000              143.000000
# unique                        NaN                     NaN
# top                           NaN                     NaN
# freq                          NaN                     NaN
# mean                     3.115720                2.206523
# std                      5.967233                5.147356
# min                      0.000613                0.000521
# 25%                      0.029022                0.010903
# 50%                      0.923472                0.120417
# 75%                      3.354473                1.913785
# max                     34.472940               34.472940
#
#         max_time_to_merge_days  avg_time_to_first_non_bot_comment_days  \
# count               143.000000                              102.000000
# unique                     NaN                                     NaN
# top                        NaN                                     NaN
# freq                       NaN                                     NaN
# mean                  4.827110                                2.335558
# std                   8.625575                                5.182587
# min                   0.000613                                0.000613
# 25%                   0.150961                                0.087244
# 50%                   1.199259                                0.727216
# 75%                   5.811227                                2.004578
# max                  48.873692                               33.527095
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                  102.000000                 142.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     2.093680                   2.994854
# std                                      4.965673                   5.549522
# min                                      0.000613                   0.000266
# 25%                                      0.052812                   0.046644
# 50%                                      0.670631                   0.958247
# 75%                                      1.960490                   3.120618
# max                                     33.527095                  33.859398
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                     142.000000           157.000000      157.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        2.733277             3.781299        0.811217
# std                         5.481485             6.621812        0.323723
# min                         0.000266             0.000000        0.000000
# 25%                         0.022329             0.000000        0.666667
# 50%                         0.796727             1.500000        1.000000
# 75%                         2.918827             4.500000        1.000000
# max                        33.859398            52.000000        1.000000
#
# Columns and data types for superchain-ops:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/docs_timeseries.csv ...
#
# Sample data from data/docs_timeseries.csv:
#    repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  docs  2024-01-02              2                1.499589
# 1  docs  2024-01-03              6                0.330758
# 2  docs  2024-01-04              6                0.260257
# 3  docs  2024-01-05              5                1.375391
# 4  docs  2024-01-08              4                1.001046
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   1.499589                0.004525                2.994653
# 1                   0.009850                0.002049                1.354641
# 2                   0.138704                0.030312                0.719271
# 3                   0.061667                0.009653                6.678738
# 4                   0.038102                0.010741                2.954294
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                        NaN                   1.499410
# 1                                        NaN                   0.329481
# 2                                        NaN                   0.112419
# 3                                        NaN                   1.192414
# 4                                        NaN                   1.000968
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                      1.499410                  0.0        1.000000
# 1                      0.008310                  0.0        1.000000
# 2                      0.109340                  0.0        0.833333
# 3                      0.061597                  0.0        1.000000
# 4                      0.038044                  0.0        0.750000
#
# Summary statistics for docs:
#         repo        date  number_of_prs  avg_time_to_merge_days  \
# count    249         249     249.000000              240.000000
# unique     1         249            NaN                     NaN
# top     docs  2024-01-02            NaN                     NaN
# freq     249           1            NaN                     NaN
# mean     NaN         NaN       2.441767                4.342068
# std      NaN         NaN       1.684136               10.117244
# min      NaN         NaN       1.000000                0.002049
# 25%      NaN         NaN       1.000000                0.192688
# 50%      NaN         NaN       2.000000                1.149346
# 75%      NaN         NaN       3.000000                4.424682
# max      NaN         NaN      12.000000              122.871400
#
#         median_time_to_merge_days  min_time_to_merge_days  \
# count                  240.000000              240.000000
# unique                        NaN                     NaN
# top                           NaN                     NaN
# freq                          NaN                     NaN
# mean                     3.619818                2.385591
# std                      9.873621                8.788720
# min                      0.002049                0.001736
# 25%                      0.086308                0.012384
# 50%                      0.797569                0.113999
# 75%                      2.909905                1.066594
# max                    122.871400              122.871400
#
#         max_time_to_merge_days  avg_time_to_first_non_bot_comment_days  \
# count               240.000000                               43.000000
# unique                     NaN                                     NaN
# top                        NaN                                     NaN
# freq                       NaN                                     NaN
# mean                  7.310766                                6.238720
# std                  15.048433                               10.413657
# min                   0.002049                                0.002812
# 25%                   0.275558                                0.380343
# 50%                   2.040793                                1.883160
# 75%                   7.931548                                6.238102
# max                 122.871400                               43.246968
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                   43.000000                 242.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     6.233037                   3.453965
# std                                     10.417016                   9.202754
# min                                      0.002812                   0.000567
# 25%                                      0.304491                   0.116736
# 50%                                      1.883160                   0.903646
# 75%                                      6.238102                   3.457836
# max                                     43.246968                 122.840961
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                     242.000000           249.000000      249.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        2.750795             0.438071        0.890479
# std                         8.912796             2.160923        0.225767
# min                         0.000567             0.000000        0.000000
# 25%                         0.047749             0.000000        1.000000
# 50%                         0.489983             0.000000        1.000000
# 75%                         2.076717             0.000000        1.000000
# max                       122.840961            29.000000        1.000000
#
# Columns and data types for docs:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/specs_timeseries.csv ...
#
# Sample data from data/specs_timeseries.csv:
#     repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  specs  2024-01-20              2               16.287789
# 1  specs  2024-01-23              2                8.512558
# 2  specs  2024-01-25              1               19.849062
# 3  specs  2024-01-26              2                4.179433
# 4  specs  2024-01-29              1                0.019178
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                  16.287789               16.287789               16.287789
# 1                   8.512558                7.136227                9.888889
# 2                  19.849062               19.849062               19.849062
# 3                   4.179433                4.179433                4.179433
# 4                   0.019178                0.019178                0.019178
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                     NaN
# 1                                0.732072
# 2                                0.018368
# 3                                     NaN
# 4                                     NaN
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                        NaN                  16.279861
# 1                                   0.732072                   5.454948
# 2                                   0.018368                        NaN
# 3                                        NaN                   4.178796
# 4                                        NaN                   0.018507
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                     16.279861                  0.0             0.5
# 1                      5.454948                  5.0             1.0
# 2                           NaN                 33.0             0.0
# 3                      4.178796                  0.0             0.5
# 4                      0.018507                  0.0             1.0
#
# Summary statistics for specs:
#          repo        date  number_of_prs  avg_time_to_merge_days  \
# count     190         190     190.000000              167.000000
# unique      1         190            NaN                     NaN
# top     specs  2024-01-20            NaN                     NaN
# freq      190           1            NaN                     NaN
# mean      NaN         NaN       2.000000                5.934730
# std       NaN         NaN       1.234427               12.637101
# ...
# freq                             NaN                  NaN             NaN
# mean                        3.677664             1.739223        0.762231
# std                         8.823777             5.928501        0.355398
# min                         0.001076             0.000000        0.000000
# 25%                         0.078663             0.000000        0.500000
# 50%                         0.393084             0.000000        1.000000
# 75%                         3.419919             1.000000        1.000000
# max                        65.826273            50.000000        1.000000
#
# Columns and data types for specs:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/design-docs_timeseries.csv ...
#
# Sample data from data/design-docs_timeseries.csv:
#           repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  design-docs  2024-05-01              1                7.368102
# 1  design-docs  2024-05-02              2                6.874601
# 2  design-docs  2024-05-08              1                0.010625
# 3  design-docs  2024-05-13              1                     NaN
# 4  design-docs  2024-05-14              2               19.479606
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   7.368102                7.368102                7.368102
# 1                   6.874601                5.963194                7.786007
# 2                   0.010625                0.010625                0.010625
# 3                        NaN                     NaN                     NaN
# 4                  19.479606               14.790833               24.168380
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                5.236620
# 1                                2.359751
# 2                                     NaN
# 3                                     NaN
# 4                                7.384462
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                   5.236620                        NaN
# 1                                   2.359751                        NaN
# 2                                        NaN                        NaN
# 3                                        NaN                        NaN
# 4                                   7.384462                   18.14456
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                           NaN                 12.0             0.0
# 1                           NaN                 11.0             0.0
# 2                           NaN                  0.0             0.0
# 3                           NaN                  0.0             0.0
# 4                      18.14456                  7.5             1.0
#
# Summary statistics for design-docs:
#                repo        date  number_of_prs  avg_time_to_merge_days  \
# count            83          83      83.000000               59.000000
# unique            1          83            NaN                     NaN
# top     design-docs  2024-05-01            NaN                     NaN
# freq             83           1            NaN                     NaN
# mean            NaN         NaN       1.771084               11.950934
# std             NaN         NaN       1.318955               13.054147
# min             NaN         NaN       1.000000                0.000498
# 25%             NaN         NaN       1.000000                1.683223
# 50%             NaN         NaN       1.000000                6.874601
# 75%             NaN         NaN       2.000000               18.639649
# max             NaN         NaN       9.000000               47.723021
#
#         median_time_to_merge_days  min_time_to_merge_days  \
# count                   59.000000               59.000000
# unique                        NaN                     NaN
# top                           NaN                     NaN
# freq                          NaN                     NaN
# mean                    11.433567                9.965860
# std                     13.303227               12.583498
# min                      0.000498                0.000208
# 25%                      1.002153                0.545955
# 50%                      6.738831                6.087222
# 75%                     18.767604               13.170376
# max                     47.723021               47.723021
#
#         max_time_to_merge_days  avg_time_to_first_non_bot_comment_days  \
# count                59.000000                               45.000000
# unique                     NaN                                     NaN
# top                        NaN                                     NaN
# freq                       NaN                                     NaN
# mean                 14.870743                                4.851405
# std                  15.534099                                6.460461
# min                   0.000498                                0.001088
# 25%                   1.683223                                0.410231
# 50%                   7.368102                                1.430710
# 75%                  26.185972                                7.384462
# max                  63.513009                               25.164994
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                   45.000000                  53.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     4.239187                   9.476196
# std                                      6.321374                  11.028408
# min                                      0.001088                   0.000475
# 25%                                      0.145301                   0.924965
# 50%                                      0.962060                   5.346788
# 75%                                      4.996157                  16.209242
# max                                     25.164994                  41.471296
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                      53.000000            83.000000       83.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        8.961644             4.202008        0.557631
# std                        11.212205             7.043622        0.451228
# min                         0.000475             0.000000        0.000000
# 25%                         0.678623             0.000000        0.000000
# 50%                         4.918808             1.000000        0.666667
# 75%                        16.209242             6.000000        1.000000
# max                        41.471296            41.000000        1.000000
#
# Columns and data types for design-docs:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------
#
# Reading data/infra_timeseries.csv ...
#
# Sample data from data/infra_timeseries.csv:
#     repo        date  number_of_prs  avg_time_to_merge_days  \
# 0  infra  2024-05-22              1                2.034745
# 1  infra  2024-05-30              5                3.031340
# 2  infra  2024-06-11              2                1.025434
# 3  infra  2024-06-13              2                0.074757
# 4  infra  2024-06-14              1                     NaN
#
#    median_time_to_merge_days  min_time_to_merge_days  max_time_to_merge_days  \
# 0                   2.034745                2.034745                2.034745
# 1                   0.083235                0.000382               11.958507
# 2                   1.025434                0.126528                1.924340
# 3                   0.074757                0.074757                0.074757
# 4                        NaN                     NaN                     NaN
#
#    avg_time_to_first_non_bot_comment_days  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# 0                                        NaN                   1.833681
# 1                                        NaN                   3.030506
# 2                                        NaN                   1.000642
# 3                                        NaN                   0.074699
# 4                                        NaN                        NaN
#
#    median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# 0                      1.833681                  0.0             1.0
# 1                      0.081904                  0.0             0.8
# 2                      1.000642                  0.0             1.0
# 3                      0.074699                  0.0             0.5
# 4                           NaN                  0.0             0.0
#
# Summary statistics for infra:
#          repo        date  number_of_prs  avg_time_to_merge_days  \
# count      59          59      59.000000               43.000000
# unique      1          59            NaN                     NaN
# top     infra  2024-05-22            NaN                     NaN
# freq       59           1            NaN                     NaN
# mean      NaN         NaN       1.813559                8.212920
# std       NaN         NaN       1.357922               14.510275
# min       NaN         NaN       1.000000                0.003032
# 25%       NaN         NaN       1.000000                0.071597
# 50%       NaN         NaN       1.000000                2.002060
# 75%       NaN         NaN       2.000000                6.892494
# max       NaN         NaN       8.000000               56.427049
#
#         median_time_to_merge_days  min_time_to_merge_days  \
# count                   43.000000               43.000000
# unique                        NaN                     NaN
# top                           NaN                     NaN
# freq                          NaN                     NaN
# mean                     8.117707                5.999249
# std                     14.553345               12.677960
# min                      0.003032                0.000382
# 25%                      0.070087                0.029873
# 50%                      1.953056                0.720995
# 75%                      6.892494                6.450017
# max                     56.427049               56.427049
#
#         max_time_to_merge_days  avg_time_to_first_non_bot_comment_days  \
# count                43.000000                               12.000000
# unique                     NaN                                     NaN
# top                        NaN                                     NaN
# freq                       NaN                                     NaN
# mean                 10.648651                                6.365442
# std                  18.557189                                8.937524
# min                   0.003032                                0.003889
# 25%                   0.071597                                0.460917
# 50%                   2.034745                                3.562616
# 75%                   8.900075                                6.133585
# max                  84.467616                               27.064236
#
#         median_time_to_first_non_bot_comment_days  avg_time_to_approval_days  \
# count                                   12.000000                  43.000000
# unique                                        NaN                        NaN
# top                                           NaN                        NaN
# freq                                          NaN                        NaN
# mean                                     6.365442                   5.870479
# std                                      8.937524                  10.946860
# min                                      0.003889                   0.001296
# 25%                                      0.460917                   0.049230
# 50%                                      3.562616                   0.987731
# 75%                                      6.133585                   5.060966
# max                                     27.064236                  48.590231
#
#         median_time_to_approval_days  avg_comments_per_pr  approval_ratio
# count                      43.000000            59.000000       59.000000
# unique                           NaN                  NaN             NaN
# top                              NaN                  NaN             NaN
# freq                             NaN                  NaN             NaN
# mean                        5.870598             0.676554        0.647034
# std                        10.979371             1.743219        0.437214
# min                         0.001296             0.000000        0.000000
# 25%                         0.049230             0.000000        0.000000
# 50%                         0.845544             0.000000        1.000000
# 75%                         6.036562             0.000000        1.000000
# max                        48.590231             8.000000        1.000000
#
# Columns and data types for infra:
# repo                                          object
# date                                          object
# number_of_prs                                  int64
# avg_time_to_merge_days                       float64
# median_time_to_merge_days                    float64
# min_time_to_merge_days                       float64
# max_time_to_merge_days                       float64
# avg_time_to_first_non_bot_comment_days       float64
# median_time_to_first_non_bot_comment_days    float64
# avg_time_to_approval_days                    float64
# median_time_to_approval_days                 float64
# avg_comments_per_pr                          float64
# approval_ratio                               float64
# dtype: object
#
# --------------------------------------------------

# %%
# ---------------------------
# Combine multiple repos into a single dataset for baseline analysis
# ---------------------------
all_datasets = []
for repo in repos:
    ts_path = f"data/{repo}_timeseries.csv"
    try:
        timeseries_df = pd.read_csv(ts_path)
    except FileNotFoundError:
        print(f"No timeseries data for {repo}, skipping.")
        continue

    if timeseries_df.empty:
        continue

    timeseries_df.set_index("date", inplace=True)
    timeseries_df.index = pd.to_datetime(timeseries_df.index)
    timeseries_df.sort_index(inplace=True)
    timeseries_df["repo"] = repo
    all_datasets.append(timeseries_df)

if not all_datasets:
    print("No data from any repo, cannot do combined analysis.")
    exit()

combined_df = pd.concat(all_datasets)
combined_df.fillna(0, inplace=True)
combined_df.reset_index(inplace=True)
combined_df.rename(columns={"index":"date"}, inplace=True)

# Example: group weekly, produce a baseline dataset
combined_df["date"] = pd.to_datetime(combined_df["date"])
weekly_dataset = combined_df.groupby(["repo", pd.Grouper(key="date", freq="W")]).agg(
    number_of_prs=("number_of_prs", "sum"),
    avg_time_to_approval_days=("avg_time_to_approval_days", "mean"),
    avg_time_to_first_non_bot_comment_days=("avg_time_to_first_non_bot_comment_days", "mean"),
    avg_time_to_merge_days=("avg_time_to_merge_days", "mean"),
    approval_ratio=("approval_ratio", "mean"),
    avg_comments_per_pr=("avg_comments_per_pr", "mean"),
).reset_index()

# Save combined weekly data to CSV
weekly_dataset.to_csv("data/github_timeseries_dataset.csv", index=False)
print("Wrote 'data/github_timeseries_dataset.csv' with shape:", weekly_dataset.shape)

# If you'd like some baseline stats for a specific date range:
cutoff_start = "2024-07-01"
df_filtered = weekly_dataset[weekly_dataset["date"] >= cutoff_start].copy()

# Summaries
print("\n== Baseline Stats since 2024-07-01 ==\n")
stats = df_filtered.groupby("repo")[
    ["number_of_prs", "avg_time_to_approval_days", "avg_time_to_first_non_bot_comment_days", 
     "avg_time_to_merge_days", "approval_ratio", "avg_comments_per_pr"]
].agg(["mean","median","std","min","max"])
print(stats)

# Plot an example bar chart of number_of_prs with error bars
import numpy as np

metric = "number_of_prs"

print(f"\nBar Chart for {metric} ...")
means = stats[metric]["mean"].sort_values()
stds = stats[metric]["std"].reindex(means.index)
repos_order = means.index.tolist()

plt.figure(figsize=(12, 6))
bars = plt.bar(repos_order, means.values, yerr=stds.values, color="skyblue", 
               capsize=5, edgecolor='black')

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.05*height,
             f'{height:.2f}', ha='center', va='bottom', fontsize=9)

plt.title(f"{metric.replace('_',' ').title()} Across Repositories")
plt.xlabel("Repository")
plt.ylabel(metric.replace('_',' ').title())
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# Example: Rolling average plot
window_size = 4
df_filtered["rolling_avg_prs"] = df_filtered.sort_values("date") \
    .groupby("repo")["number_of_prs"] \
    .apply(lambda x: x.rolling(window=window_size, min_periods=1).mean()) \
    .reset_index(level=0, drop=True)

plt.figure(figsize=(12, 6))
sns.lineplot(data=df_filtered, x="date", y="rolling_avg_prs", hue="repo", marker="o")
plt.title(f"{window_size}-Week Rolling Average of Number of PRs Over Time")
plt.xlabel("Week")
plt.ylabel("Number of PRs (Rolling Avg)")
plt.xticks(rotation=45, ha='right')
plt.legend(title="Repository")
plt.grid(True)
plt.tight_layout()
plt.show()
