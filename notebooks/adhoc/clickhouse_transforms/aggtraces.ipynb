# %%
import os

# Override to force BQ write.
os.environ["OPLABS_ENV"] = "prod"

from op_analytics.transforms.main import execute_dt_transforms

results = execute_dt_transforms(
    group_name="aggtraces",
    range_spec="@20250301:20250324",
    steps_to_run=[1, 2, 3],
    raise_if_empty=True,
    force_complete=True,
    reverse=True
)
# Out:
# 2025-03-26 21:06:38 [info     ] CREATE 01_agg_daily_trto_txto_txmethod_v2.sql ddl=01_agg_daily_trto_txto_txmethod_v2.sql env=PROD filename=create.py lineno=111 process=31409
# 2025-03-26 21:06:38 [info     ] CREATE 02_agg_daily_trfrom_trto_v2.sql ddl=02_agg_daily_trfrom_trto_v2.sql env=PROD filename=create.py lineno=111 process=31409
# 2025-03-26 21:06:38 [info     ] CREATE 03_agg_daily_trto_v2.sql ddl=03_agg_daily_trto_v2.sql env=PROD filename=create.py lineno=111 process=31409
# 2025-03-26 21:06:38 [info     ] 23/23 markers pending.         env=PROD filename=main.py lineno=101 process=31409
# 2025-03-26 21:06:38 [info     ] Prepared 23 transform tasks.   env=PROD filename=main.py lineno=116 process=31409
# 2025-03-26 21:06:38 [info     ] UPDATE 01_agg_daily_trto_txto_txmethod_v2.sql ddl=01_agg_daily_trto_txto_txmethod_v2.sql dt=2025-03-23 env=PROD filename=task.py lineno=100 process=31409 task=1/23
# 2025-03-26 21:07:38 [info     ] 01_agg_daily_trto_txto_txmethod_v2.sql -> 6793294 written rows ddl=01_agg_daily_trto_txto_txmethod_v2.sql dt=2025-03-23 elapsed_ns=59920914161 env=PROD filename=task.py lineno=123 process=31409 query_id=c6581e1f-8ef5-492b-8a57-fdf4ce5ae1c2 read_bytes=19741757738 read_rows=12201803 result_bytes=4742468966 result_rows=6793294 task=1/23 total_rows_to_read=12201803 written_bytes=4742468966 written_rows=6793294
# 2025-03-26 21:07:38 [info     ] UPDATE 02_agg_daily_trfrom_trto_v2.sql ddl=02_agg_daily_trfrom_trto_v2.sql dt=2025-03-23 env=PROD filename=task.py lineno=100 process=31409 task=1/23
# 2025-03-26 21:09:54 [info     ] 02_agg_daily_trfrom_trto_v2.sql -> 19081496 written rows ddl=02_agg_daily_trfrom_trto_v2.sql dt=2025-03-23 elapsed_ns=135498068512 env=PROD filename=task.py lineno=123 process=31409 query_id=5076fa75-d5e6-4013-9ec5-d55ae94a8789 read_bytes=39563910103 read_rows=26028192 result_bytes=12824117199 result_rows=19081496 task=1/23 total_rows_to_read=26028192 written_bytes=12824117199 written_rows=19081496
# 2025-03-26 21:09:54 [info     ] UPDATE 03_agg_daily_trto_v2.sql ddl=03_agg_daily_trto_v2.sql dt=2025-03-23 env=PROD filename=task.py lineno=100 process=31409 task=1/23
# 2025-03-26 21:10:47 [info     ] 03_agg_daily_trto_v2.sql -> 4687325 written rows ddl=03_agg_daily_trto_v2.sql dt=2025-03-23 elapsed_ns=52680595547 env=PROD filename=task.py lineno=123 process=31409 query_id=8b1ad705-749b-4b4c-9b6a-94a06815b6d2 read_bytes=39563910103 read_rows=26028192 result_bytes=2988023570 result_rows=4687325 task=1/23 total_rows_to_read=26028192 written_bytes=2988023570 written_rows=4687325
# 2025-03-26 21:10:47 [info     ] UPDATE 01_agg_daily_trto_txto_txmethod_v2.sql ddl=01_agg_daily_trto_txto_txmethod_v2.sql dt=2025-03-22 env=PROD filename=task.py lineno=100 process=31409 task=2/23
# 2025-03-26 21:12:00 [info     ] 01_agg_daily_trto_txto_txmethod_v2.sql -> 5907747 written rows ddl=01_agg_daily_trto_txto_txmethod_v2.sql dt=2025-03-22 elapsed_ns=72589752620 env=PROD filename=task.py lineno=123 process=31409 query_id=494391f0-03f1-4168-8189-96cc8447f0e8 read_bytes=19070381618 read_rows=11729370 result_bytes=4124052032 result_rows=5907747 task=2/23 total_rows_to_read=11729370 written_bytes=4124052032 written_rows=5907747
# 2025-03-26 21:12:00 [info     ] UPDATE 02_agg_daily_trfrom_trto_v2.sql ddl=02_agg_daily_trfrom_trto_v2.sql dt=2025-03-22 env=PROD filename=task.py lineno=100 process=31409 task=2/23
# 2025-03-26 21:12:00 [info     ] 02_agg_daily_trfrom_trto_v2.sql -> 0 written rows ddl=02_agg_daily_trfrom_trto_v2.sql dt=2025-03-22 elapsed_ns=30268925 env=PROD filename=task.py lineno=123 process=31409 query_id=1e4b7856-4ace-413a-9fc0-c035df29fb0f read_bytes=0 read_rows=0 result_bytes=0 result_rows=0 task=2/23 total_rows_to_read=0 written_bytes=0 written_rows=0
# 2025-03-26 21:12:00 [error    ] possible data quality issue 0 rows were written! ddl=02_agg_daily_trfrom_trto_v2.sql dt=2025-03-22 env=PROD filename=task.py lineno=136 process=31409 task=2/23
# ---------------------------------------------------------------------------
# NoWrittenRows                             Traceback (most recent call last)
# Cell In[6], line 8
#       4 os.environ["OPLABS_ENV"] = "prod"
#       6 from op_analytics.transforms.main import execute_dt_transforms
# ----> 8 results = execute_dt_transforms(
#       9     group_name="aggtraces",
#      10     range_spec="@20250301:20250324",
#      11     steps_to_run=[1, 2, 3],
#      12     raise_if_empty=True,
#      13     force_complete=True,
#      14     reverse=True
#      15 )
#
# File ~/github/ethereum-optimism/op-analytics/src/op_analytics/transforms/main.py:124, in execute_dt_transforms(group_name, range_spec, steps_to_run, steps_to_skip, raise_if_empty, force_complete, allow_missing_gcs_data, reverse)
#     122 with bound_contextvars(task=f"{ii + 1}/{num_tasks}", dt=date_tostr(task.dt)):
#     123     try:
# --> 124         result = task.execute()
#     125     except NoWrittenRows:
#     126         if task.dt == now_date():
#     127             # It is possible that NoWrittenRows is encountered when we are running
#     128             # close to real time. In that case don't error out the run, log a warning
#     129             # and exit gracefully.
#
# File ~/github/ethereum-optimism/op-analytics/src/op_analytics/transforms/task.py:51, in TransformTask.execute(self)
#      49 def execute(self):
#      50     # Run the updates.
# ---> 51     results = self.run_updates()
#      53     # Write completion markers.
#      54     self.write_marker(results)
#
# File ~/github/ethereum-optimism/op-analytics/src/op_analytics/transforms/task.py:81, in TransformTask.run_updates(self)
#      78     log.info(f"skipping index={step.index} ddl={step.name}")
#      79     continue
# ---> 81 result = self.run_update(client, step)
#      82 results.append(
#      83     UpdateResult(
#      84         name=step.name,
#      85         result=result.summary,
#      86     )
#      87 )
#      89 if step.step_type == StepType.EXPORT:
#
# File ~/github/ethereum-optimism/op-analytics/src/op_analytics/transforms/task.py:137, in TransformTask.run_update(self, client, step)
#     135         msg = "possible data quality issue 0 rows were written!"
#     136         log.error(msg)
# --> 137         raise NoWrittenRows(f"{msg} dt={self.dt}")
#     139 return result
#
# NoWrittenRows: possible data quality issue 0 rows were written! dt=2025-03-22
