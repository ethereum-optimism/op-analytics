# %%
import os

# Override to force BQ write.
os.environ["OPLABS_ENV"] = "prod"

from op_analytics.transforms.main import execute_dt_transforms

results = execute_dt_transforms(
    group_name="dune",
    range_spec="@20250306:20250311",

    # range_spec="@20241018:+1",
    update_only=[1],
    raise_if_empty=True,
    force_complete=False,
)
# Out:
# 2025-03-11 12:26:28 [info     ] loaded vault from .env file    env=PROD filename=vault.py lineno=32 process=79683
# 2025-03-11 12:26:28 [debug    ] loaded vault: 18 items         env=PROD filename=vault.py lineno=79 process=79683
# 2025-03-11 12:26:29 [info     ] CREATE fact_daily_dex_trades_v1.sql ddl=fact_daily_dex_trades_v1.sql env=PROD filename=create.py lineno=103 process=79683
# 2025-03-11 12:26:29 [debug    ] connecting to OPLABS Clickhouse client... env=PROD filename=client.py lineno=56 process=79683
# 2025-03-11 12:26:29 [debug    ] initialized OPLABS Clickhouse client. env=PROD filename=client.py lineno=61 process=79683
# 2025-03-11 12:26:29 [info     ] 5/5 markers pending.           env=PROD filename=main.py lineno=59 process=79683
# 2025-03-11 12:26:29 [info     ] Prepared 5 transform tasks.    env=PROD filename=main.py lineno=73 process=79683
# 2025-03-11 12:26:29 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-06 env=PROD filename=task.py lineno=86 process=79683 task=1/5
# 2025-03-11 12:26:30 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6964 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-06 elapsed_ns=592993659 env=PROD filename=task.py lineno=108 process=79683 query_id=d06ab30a-36dc-4072-834c-a11306479872 read_bytes=1136246 read_rows=7048 result_bytes=3497729 result_rows=6964 task=1/5 total_rows_to_read=0 written_bytes=3497729 written_rows=6964
# 2025-03-11 12:26:30 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-07 env=PROD filename=task.py lineno=86 process=79683 task=2/5
# 2025-03-11 12:26:31 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7284 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-07 elapsed_ns=575523227 env=PROD filename=task.py lineno=108 process=79683 query_id=44e1875d-77ec-4c3b-8523-2abb687290c6 read_bytes=1183666 read_rows=7368 result_bytes=3659444 result_rows=7284 task=2/5 total_rows_to_read=0 written_bytes=3659444 written_rows=7284
# 2025-03-11 12:26:31 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-08 env=PROD filename=task.py lineno=86 process=79683 task=3/5
# 2025-03-11 12:26:32 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6319 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-08 elapsed_ns=540358150 env=PROD filename=task.py lineno=108 process=79683 query_id=a1cf4e34-1e31-4050-89da-e05df4b9f040 read_bytes=1037763 read_rows=6403 result_bytes=3174922 result_rows=6319 task=3/5 total_rows_to_read=0 written_bytes=3174922 written_rows=6319
# 2025-03-11 12:26:32 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-09 env=PROD filename=task.py lineno=86 process=79683 task=4/5
# 2025-03-11 12:26:33 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6773 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-09 elapsed_ns=515425450 env=PROD filename=task.py lineno=108 process=79683 query_id=ea88d79a-e805-49b7-824b-c76223c0b14e read_bytes=1105602 read_rows=6857 result_bytes=3401015 result_rows=6773 task=4/5 total_rows_to_read=0 written_bytes=3401015 written_rows=6773
# 2025-03-11 12:26:33 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-10 env=PROD filename=task.py lineno=86 process=79683 task=5/5
# 2025-03-11 12:26:34 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7846 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-10 elapsed_ns=737370062 env=PROD filename=task.py lineno=108 process=79683 query_id=5d0115dc-1227-4aac-82c9-cb329f2c187f read_bytes=1267829 read_rows=7930 result_bytes=3940680 result_rows=7846 task=5/5 total_rows_to_read=0 written_bytes=3940680 written_rows=7846
