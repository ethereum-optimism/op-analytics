# %%
import os

# Override to force BQ write.
os.environ["OPLABS_ENV"] = "prod"

from op_analytics.transforms.main import execute_dt_transforms

results = execute_dt_transforms(
    group_name="dune",
    range_spec="@20241109:20250307",

    # range_spec="@20241018:+1",
    update_only=[1],
    skip_create=False,
    raise_if_empty=True,
    max_tasks=None,
    force_complete=True,
)
# Out:
# 2025-03-06 20:25:18 [info     ] 118/118 markers pending.       env=PROD filename=main.py lineno=54 process=21819
# 2025-03-06 20:25:18 [info     ] Prepared 118 transform tasks.  env=PROD filename=main.py lineno=68 process=21819
# 2025-03-06 20:25:19 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-09 elapsed_ns=89744167 env=PROD filename=create.py lineno=44 process=21819 query_id=e01ff593-ce21-4452-988a-6b68884d658b read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=1/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:19 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-09 env=PROD filename=transform.py lineno=94 process=21819 task=1/118
# 2025-03-06 20:25:19 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6919 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-09 elapsed_ns=455344002 env=PROD filename=transform.py lineno=107 process=21819 query_id=17374eee-d94f-4b9c-a8de-eeb1b6a4ab02 read_bytes=1151274 read_rows=7003 result_bytes=3442952 result_rows=6919 task=1/118 total_rows_to_read=0 written_bytes=3442952 written_rows=6919
# 2025-03-06 20:25:20 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-10 elapsed_ns=94198187 env=PROD filename=create.py lineno=44 process=21819 query_id=ea31dc83-eb52-472b-a8c2-c088bebe0fdc read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=2/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:20 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-10 env=PROD filename=transform.py lineno=94 process=21819 task=2/118
# 2025-03-06 20:25:20 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7632 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-10 elapsed_ns=599592956 env=PROD filename=transform.py lineno=107 process=21819 query_id=f5595173-03c0-43c8-a756-bd870a9659a7 read_bytes=1259876 read_rows=7716 result_bytes=3793807 result_rows=7632 task=2/118 total_rows_to_read=0 written_bytes=3793807 written_rows=7632
# 2025-03-06 20:25:21 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-11 elapsed_ns=93071577 env=PROD filename=create.py lineno=44 process=21819 query_id=fd44005e-7c29-4ef3-aa8c-4a334da30015 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=3/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:21 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-11 env=PROD filename=transform.py lineno=94 process=21819 task=3/118
# 2025-03-06 20:25:21 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7987 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-11 elapsed_ns=547079779 env=PROD filename=transform.py lineno=107 process=21819 query_id=caf649b4-f177-4241-b634-0025ea52d8e5 read_bytes=1317194 read_rows=8071 result_bytes=3970708 result_rows=7987 task=3/118 total_rows_to_read=0 written_bytes=3970708 written_rows=7987
# 2025-03-06 20:25:22 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-12 elapsed_ns=88828587 env=PROD filename=create.py lineno=44 process=21819 query_id=c856270d-f49d-4bac-8538-208fb8f23253 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=4/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:22 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-12 env=PROD filename=transform.py lineno=94 process=21819 task=4/118
# 2025-03-06 20:25:23 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8502 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-12 elapsed_ns=616097826 env=PROD filename=transform.py lineno=107 process=21819 query_id=2d90e73b-6335-404f-ac99-b8b8e7f80e26 read_bytes=1396608 read_rows=8586 result_bytes=4227073 result_rows=8502 task=4/118 total_rows_to_read=0 written_bytes=4227073 written_rows=8502
# 2025-03-06 20:25:23 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-13 elapsed_ns=93353887 env=PROD filename=create.py lineno=44 process=21819 query_id=fc37aae0-c5e1-43e9-8438-d203f0bc76a9 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=5/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:23 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-13 env=PROD filename=transform.py lineno=94 process=21819 task=5/118
# 2025-03-06 20:25:24 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8339 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-13 elapsed_ns=462751222 env=PROD filename=transform.py lineno=107 process=21819 query_id=7b5309fc-bebd-4d46-9e81-993f8a579bff read_bytes=1371712 read_rows=8423 result_bytes=4146716 result_rows=8339 task=5/118 total_rows_to_read=0 written_bytes=4146716 written_rows=8339
# 2025-03-06 20:25:24 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-14 elapsed_ns=93726246 env=PROD filename=create.py lineno=44 process=21819 query_id=79913300-b88c-4943-a1fc-418a77db8310 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=6/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:24 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-14 env=PROD filename=transform.py lineno=94 process=21819 task=6/118
# 2025-03-06 20:25:25 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8057 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-14 elapsed_ns=446566713 env=PROD filename=transform.py lineno=107 process=21819 query_id=f888066b-afb4-4b10-98f1-0c6d21ae808d read_bytes=1326723 read_rows=8141 result_bytes=4006866 result_rows=8057 task=6/118 total_rows_to_read=0 written_bytes=4006866 written_rows=8057
# 2025-03-06 20:25:25 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-15 elapsed_ns=91349366 env=PROD filename=create.py lineno=44 process=21819 query_id=43338f06-1125-4254-99b1-ff0e60f82718 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=7/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:25 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-15 env=PROD filename=transform.py lineno=94 process=21819 task=7/118
# 2025-03-06 20:25:26 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7696 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-15 elapsed_ns=569637918 env=PROD filename=transform.py lineno=107 process=21819 query_id=b8dcab67-d5e8-4b48-8545-6acd14aaf344 read_bytes=1268507 read_rows=7780 result_bytes=3828073 result_rows=7696 task=7/118 total_rows_to_read=0 written_bytes=3828073 written_rows=7696
# 2025-03-06 20:25:26 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-16 elapsed_ns=96211886 env=PROD filename=create.py lineno=44 process=21819 query_id=301e0b1d-4d99-4eb1-9a40-e2dbc5c715c4 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=8/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:26 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-16 env=PROD filename=transform.py lineno=94 process=21819 task=8/118
# 2025-03-06 20:25:27 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7907 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-16 elapsed_ns=538478280 env=PROD filename=transform.py lineno=107 process=21819 query_id=7848d93c-bed6-4bb0-b748-3493771c7153 read_bytes=1310091 read_rows=7991 result_bytes=3935390 result_rows=7907 task=8/118 total_rows_to_read=0 written_bytes=3935390 written_rows=7907
# 2025-03-06 20:25:27 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-17 elapsed_ns=92429557 env=PROD filename=create.py lineno=44 process=21819 query_id=8eeccab0-cfb2-437c-b0d3-961addb77690 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=9/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:27 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-17 env=PROD filename=transform.py lineno=94 process=21819 task=9/118
# 2025-03-06 20:25:28 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8017 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-17 elapsed_ns=638350955 env=PROD filename=transform.py lineno=107 process=21819 query_id=5d6961b0-52c9-49f5-80c9-5740a452f103 read_bytes=1334749 read_rows=8101 result_bytes=3991533 result_rows=8017 task=9/118 total_rows_to_read=0 written_bytes=3991533 written_rows=8017
# 2025-03-06 20:25:28 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-18 elapsed_ns=93334346 env=PROD filename=create.py lineno=44 process=21819 query_id=668c7c9f-928c-4c1c-b3a5-66d3949b8121 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=10/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:29 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-18 env=PROD filename=transform.py lineno=94 process=21819 task=10/118
# 2025-03-06 20:25:29 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8420 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-18 elapsed_ns=569096238 env=PROD filename=transform.py lineno=107 process=21819 query_id=09f89dee-f420-4d87-9eb2-de770da50c98 read_bytes=1391226 read_rows=8504 result_bytes=4190405 result_rows=8420 task=10/118 total_rows_to_read=0 written_bytes=4190405 written_rows=8420
# 2025-03-06 20:25:30 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-19 elapsed_ns=95918516 env=PROD filename=create.py lineno=44 process=21819 query_id=34fe05f8-ec3c-457f-83e1-1d5054aa762f read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=11/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:30 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-19 env=PROD filename=transform.py lineno=94 process=21819 task=11/118
# 2025-03-06 20:25:30 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8248 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-19 elapsed_ns=549815248 env=PROD filename=transform.py lineno=107 process=21819 query_id=f04b2a60-626f-4293-955b-35d1d2011888 read_bytes=1370400 read_rows=8332 result_bytes=4109452 result_rows=8248 task=11/118 total_rows_to_read=0 written_bytes=4109452 written_rows=8248
# 2025-03-06 20:25:31 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-20 elapsed_ns=92906066 env=PROD filename=create.py lineno=44 process=21819 query_id=55a9691e-4f06-4f79-ad1e-d0bff181e23e read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=12/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:31 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-20 env=PROD filename=transform.py lineno=94 process=21819 task=12/118
# 2025-03-06 20:25:31 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7665 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-20 elapsed_ns=443778512 env=PROD filename=transform.py lineno=107 process=21819 query_id=baf980b1-0146-4d18-8f71-8f45607ded1a read_bytes=1271830 read_rows=7749 result_bytes=3816660 result_rows=7665 task=12/118 total_rows_to_read=0 written_bytes=3816660 written_rows=7665
# 2025-03-06 20:25:32 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-21 elapsed_ns=98399277 env=PROD filename=create.py lineno=44 process=21819 query_id=79eb2de8-ac02-49d9-89de-64bac0c3b16d read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=13/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:32 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-21 env=PROD filename=transform.py lineno=94 process=21819 task=13/118
# 2025-03-06 20:25:32 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8072 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-21 elapsed_ns=506181841 env=PROD filename=transform.py lineno=107 process=21819 query_id=de6f0755-253a-49e5-a95d-b2877c303193 read_bytes=1329054 read_rows=8156 result_bytes=4014321 result_rows=8072 task=13/118 total_rows_to_read=0 written_bytes=4014321 written_rows=8072
# 2025-03-06 20:25:33 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-22 elapsed_ns=91558646 env=PROD filename=create.py lineno=44 process=21819 query_id=273d191a-51e7-4d7a-84f4-9c6e68c82883 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=14/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:33 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-22 env=PROD filename=transform.py lineno=94 process=21819 task=14/118
# 2025-03-06 20:25:34 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7779 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-22 elapsed_ns=647842645 env=PROD filename=transform.py lineno=107 process=21819 query_id=b9426b73-35de-40a1-881a-4a7d1fdf4e98 read_bytes=1284984 read_rows=7863 result_bytes=3868966 result_rows=7779 task=14/118 total_rows_to_read=0 written_bytes=3868966 written_rows=7779
# 2025-03-06 20:25:34 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-23 elapsed_ns=94468367 env=PROD filename=create.py lineno=44 process=21819 query_id=d0c8f8bb-6ef5-459c-9d06-0b72b3ed0d96 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=15/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:34 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-23 env=PROD filename=transform.py lineno=94 process=21819 task=15/118
# 2025-03-06 20:25:35 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8335 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-23 elapsed_ns=544625469 env=PROD filename=transform.py lineno=107 process=21819 query_id=1a5c4149-a284-47eb-8bdd-53066b832499 read_bytes=1376096 read_rows=8419 result_bytes=4150048 result_rows=8335 task=15/118 total_rows_to_read=0 written_bytes=4150048 written_rows=8335
# 2025-03-06 20:25:35 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-24 elapsed_ns=92960457 env=PROD filename=create.py lineno=44 process=21819 query_id=88328ff3-0ca2-4bbe-9a6a-bddb12503a0a read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=16/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:35 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-24 env=PROD filename=transform.py lineno=94 process=21819 task=16/118
# 2025-03-06 20:25:36 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8515 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-24 elapsed_ns=517868920 env=PROD filename=transform.py lineno=107 process=21819 query_id=70bbbf91-097e-4935-8d7f-bfffbb43fabb read_bytes=1411116 read_rows=8599 result_bytes=4240163 result_rows=8515 task=16/118 total_rows_to_read=0 written_bytes=4240163 written_rows=8515
# 2025-03-06 20:25:36 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-25 elapsed_ns=89764536 env=PROD filename=create.py lineno=44 process=21819 query_id=3951d336-25dc-4f00-93c2-66a5271af726 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=17/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:36 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-25 env=PROD filename=transform.py lineno=94 process=21819 task=17/118
# 2025-03-06 20:25:37 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8696 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-25 elapsed_ns=590356697 env=PROD filename=transform.py lineno=107 process=21819 query_id=b01fb503-86d6-4c04-94e0-40a558f1f026 read_bytes=1438391 read_rows=8780 result_bytes=4329358 result_rows=8696 task=17/118 total_rows_to_read=0 written_bytes=4329358 written_rows=8696
# 2025-03-06 20:25:37 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-26 elapsed_ns=93095647 env=PROD filename=create.py lineno=44 process=21819 query_id=5b565066-0bd0-482c-8c38-bc11290e103b read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=18/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:37 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-26 env=PROD filename=transform.py lineno=94 process=21819 task=18/118
# 2025-03-06 20:25:38 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8245 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-26 elapsed_ns=470307012 env=PROD filename=transform.py lineno=107 process=21819 query_id=19486da5-c05b-4585-b731-957a0c03f21b read_bytes=1369399 read_rows=8329 result_bytes=4105821 result_rows=8245 task=18/118 total_rows_to_read=0 written_bytes=4105821 written_rows=8245
# 2025-03-06 20:25:38 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-27 elapsed_ns=90723257 env=PROD filename=create.py lineno=44 process=21819 query_id=ebdf3e3e-e2ed-4de8-8976-943a616d564e read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=19/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:38 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-27 env=PROD filename=transform.py lineno=94 process=21819 task=19/118
# 2025-03-06 20:25:39 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8745 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-27 elapsed_ns=461146571 env=PROD filename=transform.py lineno=107 process=21819 query_id=2cf92d26-7166-47b7-a98e-a8791ef5955d read_bytes=1448094 read_rows=8829 result_bytes=4355290 result_rows=8745 task=19/118 total_rows_to_read=0 written_bytes=4355290 written_rows=8745
# 2025-03-06 20:25:39 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-28 elapsed_ns=91609597 env=PROD filename=create.py lineno=44 process=21819 query_id=a5a8bc6a-8cbd-48b6-9763-ae1ad452394f read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=20/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:39 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-28 env=PROD filename=transform.py lineno=94 process=21819 task=20/118
# 2025-03-06 20:25:40 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7812 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-28 elapsed_ns=555907498 env=PROD filename=transform.py lineno=107 process=21819 query_id=9587b1f2-5604-4807-9618-78ee4c825a59 read_bytes=1301069 read_rows=7896 result_bytes=3891040 result_rows=7812 task=20/118 total_rows_to_read=0 written_bytes=3891040 written_rows=7812
# 2025-03-06 20:25:40 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-29 elapsed_ns=89541797 env=PROD filename=create.py lineno=44 process=21819 query_id=7368f341-7831-45f7-a575-6ba17228514f read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=21/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:40 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-29 env=PROD filename=transform.py lineno=94 process=21819 task=21/118
# 2025-03-06 20:25:41 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7876 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-29 elapsed_ns=489556951 env=PROD filename=transform.py lineno=107 process=21819 query_id=195e53da-79cc-43eb-9c1c-f35f620f5a6e read_bytes=1312726 read_rows=7960 result_bytes=3925055 result_rows=7876 task=21/118 total_rows_to_read=0 written_bytes=3925055 written_rows=7876
# 2025-03-06 20:25:41 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-11-30 elapsed_ns=90548406 env=PROD filename=create.py lineno=44 process=21819 query_id=fc6b23e2-a80a-4f9a-9f81-d7983e97a2fd read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=22/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:41 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-30 env=PROD filename=transform.py lineno=94 process=21819 task=22/118
# 2025-03-06 20:25:42 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8087 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-11-30 elapsed_ns=576510587 env=PROD filename=transform.py lineno=107 process=21819 query_id=afbd4d08-0398-4cbb-8cfa-b774a455c226 read_bytes=1348394 read_rows=8171 result_bytes=4029446 result_rows=8087 task=22/118 total_rows_to_read=0 written_bytes=4029446 written_rows=8087
# 2025-03-06 20:25:43 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-01 elapsed_ns=93293127 env=PROD filename=create.py lineno=44 process=21819 query_id=9c5fab21-f7ac-4711-908f-8a6238609e6a read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=23/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:43 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-01 env=PROD filename=transform.py lineno=94 process=21819 task=23/118
# 2025-03-06 20:25:43 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7832 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-01 elapsed_ns=606126837 env=PROD filename=transform.py lineno=107 process=21819 query_id=9c8e902a-8466-4808-844e-3f89d83a1f24 read_bytes=1304010 read_rows=7916 result_bytes=3901182 result_rows=7832 task=23/118 total_rows_to_read=0 written_bytes=3901182 written_rows=7832
# 2025-03-06 20:25:44 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-02 elapsed_ns=92023726 env=PROD filename=create.py lineno=44 process=21819 query_id=30b76b8e-0bd3-4059-b02d-df04a67e847d read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=24/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:44 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-02 env=PROD filename=transform.py lineno=94 process=21819 task=24/118
# 2025-03-06 20:25:44 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8966 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-02 elapsed_ns=503250970 env=PROD filename=transform.py lineno=107 process=21819 query_id=d402163d-92d2-45d7-9c06-2c00319eab35 read_bytes=1479242 read_rows=9050 result_bytes=4464349 result_rows=8966 task=24/118 total_rows_to_read=0 written_bytes=4464349 written_rows=8966
# 2025-03-06 20:25:45 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-03 elapsed_ns=93421106 env=PROD filename=create.py lineno=44 process=21819 query_id=300c0690-30b5-4dec-89fc-64964b51bd92 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=25/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:45 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-03 env=PROD filename=transform.py lineno=94 process=21819 task=25/118
# 2025-03-06 20:25:45 [info     ] 01_fact_daily_dex_trades_v1.sql -> 9114 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-03 elapsed_ns=490918391 env=PROD filename=transform.py lineno=107 process=21819 query_id=083b48b4-9ec8-4719-a24c-9b0f52c5038e read_bytes=1502442 read_rows=9198 result_bytes=4538692 result_rows=9114 task=25/118 total_rows_to_read=0 written_bytes=4538692 written_rows=9114
# 2025-03-06 20:25:46 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-04 elapsed_ns=91201566 env=PROD filename=create.py lineno=44 process=21819 query_id=aa8c81cd-a267-4c08-ab12-9caf05375d95 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=26/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:46 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-04 env=PROD filename=transform.py lineno=94 process=21819 task=26/118
# 2025-03-06 20:25:46 [info     ] 01_fact_daily_dex_trades_v1.sql -> 9768 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-04 elapsed_ns=438616583 env=PROD filename=transform.py lineno=107 process=21819 query_id=afb5c194-758f-4563-af31-d382b61572fb read_bytes=1622901 read_rows=9852 result_bytes=4866700 result_rows=9768 task=26/118 total_rows_to_read=0 written_bytes=4866700 written_rows=9768
# 2025-03-06 20:25:47 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-05 elapsed_ns=94674327 env=PROD filename=create.py lineno=44 process=21819 query_id=07178882-2ea7-42b9-b3d1-8853ac23760f read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=27/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:47 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-05 env=PROD filename=transform.py lineno=94 process=21819 task=27/118
# 2025-03-06 20:25:47 [info     ] 01_fact_daily_dex_trades_v1.sql -> 9498 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-05 elapsed_ns=473992912 env=PROD filename=transform.py lineno=107 process=21819 query_id=26cc8e1c-c4fd-495e-816b-0bb3308f1360 read_bytes=1576903 read_rows=9582 result_bytes=4730744 result_rows=9498 task=27/118 total_rows_to_read=0 written_bytes=4730744 written_rows=9498
# 2025-03-06 20:25:48 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-06 elapsed_ns=94848886 env=PROD filename=create.py lineno=44 process=21819 query_id=f65f3319-25ad-45b9-ae63-98618c88ac20 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=28/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:48 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-06 env=PROD filename=transform.py lineno=94 process=21819 task=28/118
# 2025-03-06 20:25:49 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8952 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-06 elapsed_ns=463743552 env=PROD filename=transform.py lineno=107 process=21819 query_id=58ec3caa-8a73-4a88-b0ce-808a5086918d read_bytes=1489384 read_rows=9036 result_bytes=4459948 result_rows=8952 task=28/118 total_rows_to_read=0 written_bytes=4459948 written_rows=8952
# 2025-03-06 20:25:49 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-07 elapsed_ns=93289707 env=PROD filename=create.py lineno=44 process=21819 query_id=22d0fb28-d039-4896-b097-81c53e16c061 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=29/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:49 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-07 env=PROD filename=transform.py lineno=94 process=21819 task=29/118
# 2025-03-06 20:25:50 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8080 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-07 elapsed_ns=551939159 env=PROD filename=transform.py lineno=107 process=21819 query_id=252a26a0-983e-4e39-bbde-5ba9c0d0bead read_bytes=1353862 read_rows=8164 result_bytes=4030203 result_rows=8080 task=29/118 total_rows_to_read=0 written_bytes=4030203 written_rows=8080
# 2025-03-06 20:25:50 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-08 elapsed_ns=97168906 env=PROD filename=create.py lineno=44 process=21819 query_id=1a5d668e-9b70-462a-ad66-6939f18d15db read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=30/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:50 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-08 env=PROD filename=transform.py lineno=94 process=21819 task=30/118
# 2025-03-06 20:25:51 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7935 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-08 elapsed_ns=498717621 env=PROD filename=transform.py lineno=107 process=21819 query_id=059efce6-4bb9-4b3b-bb68-92e3275b8341 read_bytes=1330662 read_rows=8019 result_bytes=3957222 result_rows=7935 task=30/118 total_rows_to_read=0 written_bytes=3957222 written_rows=7935
# 2025-03-06 20:25:51 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-09 elapsed_ns=90777857 env=PROD filename=create.py lineno=44 process=21819 query_id=945f56b1-ee57-4e97-ba20-a3f0bf8d18f8 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=31/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:51 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-09 env=PROD filename=transform.py lineno=94 process=21819 task=31/118
# 2025-03-06 20:25:52 [info     ] 01_fact_daily_dex_trades_v1.sql -> 9243 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-09 elapsed_ns=535705439 env=PROD filename=transform.py lineno=107 process=21819 query_id=37e6f45d-d6de-4369-9054-f37e2b7db857 read_bytes=1533278 read_rows=9327 result_bytes=4603649 result_rows=9243 task=31/118 total_rows_to_read=0 written_bytes=4603649 written_rows=9243
# 2025-03-06 20:25:52 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-10 elapsed_ns=91312746 env=PROD filename=create.py lineno=44 process=21819 query_id=e3e12425-151c-4299-8c5e-d441794470f0 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=32/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:52 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-10 env=PROD filename=transform.py lineno=94 process=21819 task=32/118
# 2025-03-06 20:25:53 [info     ] 01_fact_daily_dex_trades_v1.sql -> 9209 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-10 elapsed_ns=621676296 env=PROD filename=transform.py lineno=107 process=21819 query_id=3b62a403-5e34-4679-aa96-1d8cda51dc6b read_bytes=1525129 read_rows=9293 result_bytes=4586793 result_rows=9209 task=32/118 total_rows_to_read=0 written_bytes=4586793 written_rows=9209
# 2025-03-06 20:25:54 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-11 elapsed_ns=90827207 env=PROD filename=create.py lineno=44 process=21819 query_id=1df01386-8a84-4b24-ac5f-5e150734cc30 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=33/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:54 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-11 env=PROD filename=transform.py lineno=94 process=21819 task=33/118
# 2025-03-06 20:25:54 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8287 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-11 elapsed_ns=565803618 env=PROD filename=transform.py lineno=107 process=21819 query_id=cf26d6f8-b713-44de-9c43-77feafa6e31b read_bytes=1383166 read_rows=8371 result_bytes=4129964 result_rows=8287 task=33/118 total_rows_to_read=0 written_bytes=4129964 written_rows=8287
# 2025-03-06 20:25:55 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-12 elapsed_ns=94150276 env=PROD filename=create.py lineno=44 process=21819 query_id=5e5f0c91-f4ba-4bd6-acf8-6caa54bcb2c2 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=34/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:55 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-12 env=PROD filename=transform.py lineno=94 process=21819 task=34/118
# 2025-03-06 20:25:55 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8620 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-12 elapsed_ns=514050640 env=PROD filename=transform.py lineno=107 process=21819 query_id=d8bc8a50-a7be-434f-9a60-da7527a55bc7 read_bytes=1429282 read_rows=8704 result_bytes=4294370 result_rows=8620 task=34/118 total_rows_to_read=0 written_bytes=4294370 written_rows=8620
# 2025-03-06 20:25:56 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-13 elapsed_ns=96952476 env=PROD filename=create.py lineno=44 process=21819 query_id=7e02b0c5-af96-498f-bfa9-33a538a2e691 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=35/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:56 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-13 env=PROD filename=transform.py lineno=94 process=21819 task=35/118
# 2025-03-06 20:25:56 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8233 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-13 elapsed_ns=453375762 env=PROD filename=transform.py lineno=107 process=21819 query_id=7fe95aeb-c2ae-40cb-8882-317436e546ae read_bytes=1372025 read_rows=8317 result_bytes=4101769 result_rows=8233 task=35/118 total_rows_to_read=0 written_bytes=4101769 written_rows=8233
# 2025-03-06 20:25:57 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-14 elapsed_ns=92763866 env=PROD filename=create.py lineno=44 process=21819 query_id=f4836504-e156-4214-87fb-9abb99782fbc read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=36/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:57 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-14 env=PROD filename=transform.py lineno=94 process=21819 task=36/118
# 2025-03-06 20:25:57 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7698 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-14 elapsed_ns=411995674 env=PROD filename=transform.py lineno=107 process=21819 query_id=94097d59-35cf-459b-9687-ebb116cccf83 read_bytes=1284941 read_rows=7782 result_bytes=3833534 result_rows=7698 task=36/118 total_rows_to_read=0 written_bytes=3833534 written_rows=7698
# 2025-03-06 20:25:58 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-15 elapsed_ns=88572356 env=PROD filename=create.py lineno=44 process=21819 query_id=025cd57c-8ee2-4e1c-b3f7-9d957fa55b19 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=37/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:58 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-15 env=PROD filename=transform.py lineno=94 process=21819 task=37/118
# 2025-03-06 20:25:58 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7655 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-15 elapsed_ns=511964580 env=PROD filename=transform.py lineno=107 process=21819 query_id=f7a65674-9415-4287-a370-568abb8dffe0 read_bytes=1273772 read_rows=7739 result_bytes=3812025 result_rows=7655 task=37/118 total_rows_to_read=0 written_bytes=3812025 written_rows=7655
# 2025-03-06 20:25:59 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-16 elapsed_ns=93794386 env=PROD filename=create.py lineno=44 process=21819 query_id=d819c27d-5d1e-4c04-91e2-1ef3227646a4 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=38/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:25:59 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-16 env=PROD filename=transform.py lineno=94 process=21819 task=38/118
# 2025-03-06 20:25:59 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8263 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-16 elapsed_ns=485089221 env=PROD filename=transform.py lineno=107 process=21819 query_id=7d40d462-c903-41b9-b4f4-d907098077c5 read_bytes=1370305 read_rows=8347 result_bytes=4114914 result_rows=8263 task=38/118 total_rows_to_read=0 written_bytes=4114914 written_rows=8263
# 2025-03-06 20:26:00 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-17 elapsed_ns=92194816 env=PROD filename=create.py lineno=44 process=21819 query_id=21569422-d73b-4220-8eaf-2ef66e5d2f51 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=39/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:00 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-17 env=PROD filename=transform.py lineno=94 process=21819 task=39/118
# 2025-03-06 20:26:00 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8217 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-17 elapsed_ns=432786713 env=PROD filename=transform.py lineno=107 process=21819 query_id=68dfc929-e1de-44a4-a5eb-2014b94c6ff2 read_bytes=1361664 read_rows=8301 result_bytes=4090857 result_rows=8217 task=39/118 total_rows_to_read=0 written_bytes=4090857 written_rows=8217
# 2025-03-06 20:26:01 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-18 elapsed_ns=93649006 env=PROD filename=create.py lineno=44 process=21819 query_id=1009d27d-704e-4251-9a80-77387b125c19 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=40/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:01 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-18 env=PROD filename=transform.py lineno=94 process=21819 task=40/118
# 2025-03-06 20:26:01 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8237 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-18 elapsed_ns=513066000 env=PROD filename=transform.py lineno=107 process=21819 query_id=ddb61764-54cf-4dec-b489-7495394ddf10 read_bytes=1357441 read_rows=8321 result_bytes=4098110 result_rows=8237 task=40/118 total_rows_to_read=0 written_bytes=4098110 written_rows=8237
# 2025-03-06 20:26:02 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-19 elapsed_ns=91312346 env=PROD filename=create.py lineno=44 process=21819 query_id=0840cb5c-5849-4af0-be5c-c50a2d2da0b7 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=41/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:02 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-19 env=PROD filename=transform.py lineno=94 process=21819 task=41/118
# 2025-03-06 20:26:02 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8408 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-19 elapsed_ns=439909753 env=PROD filename=transform.py lineno=107 process=21819 query_id=bbc52cde-7f32-4d95-b2c2-35bd367784d0 read_bytes=1374269 read_rows=8492 result_bytes=4179035 result_rows=8408 task=41/118 total_rows_to_read=0 written_bytes=4179035 written_rows=8408
# 2025-03-06 20:26:03 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-20 elapsed_ns=97582976 env=PROD filename=create.py lineno=44 process=21819 query_id=f044ea0c-abce-493c-9e45-02ad8a67cc42 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=42/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:03 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-20 env=PROD filename=transform.py lineno=94 process=21819 task=42/118
# 2025-03-06 20:26:03 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8672 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-20 elapsed_ns=453051913 env=PROD filename=transform.py lineno=107 process=21819 query_id=164c2267-e186-4973-9849-214e94968208 read_bytes=1414588 read_rows=8756 result_bytes=4311416 result_rows=8672 task=42/118 total_rows_to_read=0 written_bytes=4311416 written_rows=8672
# 2025-03-06 20:26:04 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-21 elapsed_ns=92472376 env=PROD filename=create.py lineno=44 process=21819 query_id=5b6ae063-601f-4d97-adde-bda6f381b708 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=43/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:04 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-21 env=PROD filename=transform.py lineno=94 process=21819 task=43/118
# 2025-03-06 20:26:04 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7790 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-21 elapsed_ns=423002873 env=PROD filename=transform.py lineno=107 process=21819 query_id=a14b4fb9-9204-45a1-9820-05dbdb0b0d1f read_bytes=1284292 read_rows=7874 result_bytes=3874562 result_rows=7790 task=43/118 total_rows_to_read=0 written_bytes=3874562 written_rows=7790
# 2025-03-06 20:26:05 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-22 elapsed_ns=90753157 env=PROD filename=create.py lineno=44 process=21819 query_id=1925eb11-66f6-4aa0-af78-bebad2efba89 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=44/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:05 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-22 env=PROD filename=transform.py lineno=94 process=21819 task=44/118
# 2025-03-06 20:26:05 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7319 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-22 elapsed_ns=463647012 env=PROD filename=transform.py lineno=107 process=21819 query_id=1207c208-8c39-4b89-8241-af0d8ec61d19 read_bytes=1210635 read_rows=7403 result_bytes=3641025 result_rows=7319 task=44/118 total_rows_to_read=0 written_bytes=3641025 written_rows=7319
# 2025-03-06 20:26:06 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-23 elapsed_ns=93565027 env=PROD filename=create.py lineno=44 process=21819 query_id=35002363-f148-43d5-878b-eabea2af5a73 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=45/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:06 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-23 env=PROD filename=transform.py lineno=94 process=21819 task=45/118
# 2025-03-06 20:26:06 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7834 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-23 elapsed_ns=543820910 env=PROD filename=transform.py lineno=107 process=21819 query_id=a5d92490-c1a8-4630-b79f-a81386456d94 read_bytes=1292179 read_rows=7918 result_bytes=3896493 result_rows=7834 task=45/118 total_rows_to_read=0 written_bytes=3896493 written_rows=7834
# 2025-03-06 20:26:07 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-24 elapsed_ns=92810756 env=PROD filename=create.py lineno=44 process=21819 query_id=3e61aac0-b695-4c2e-92a4-9c8181f49268 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=46/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:07 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-24 env=PROD filename=transform.py lineno=94 process=21819 task=46/118
# 2025-03-06 20:26:07 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7392 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-24 elapsed_ns=464666332 env=PROD filename=transform.py lineno=107 process=21819 query_id=9717683a-575f-481b-a23d-7e11d46eda46 read_bytes=1225090 read_rows=7476 result_bytes=3679468 result_rows=7392 task=46/118 total_rows_to_read=0 written_bytes=3679468 written_rows=7392
# 2025-03-06 20:26:08 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-25 elapsed_ns=93064456 env=PROD filename=create.py lineno=44 process=21819 query_id=cfce5311-13d0-4da4-850c-49667b72c109 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=47/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:08 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-25 env=PROD filename=transform.py lineno=94 process=21819 task=47/118
# 2025-03-06 20:26:08 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6437 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-25 elapsed_ns=446327853 env=PROD filename=transform.py lineno=107 process=21819 query_id=a06ffeb6-8252-4f98-b847-30f3f5d8a664 read_bytes=1071133 read_rows=6521 result_bytes=3202894 result_rows=6437 task=47/118 total_rows_to_read=0 written_bytes=3202894 written_rows=6437
# 2025-03-06 20:26:09 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-26 elapsed_ns=92402647 env=PROD filename=create.py lineno=44 process=21819 query_id=932f4213-0a48-4f8e-80ce-516cd0edaadd read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=48/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:09 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-26 env=PROD filename=transform.py lineno=94 process=21819 task=48/118
# 2025-03-06 20:26:09 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7101 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-26 elapsed_ns=522140170 env=PROD filename=transform.py lineno=107 process=21819 query_id=c3976365-f368-40eb-bfc8-9c8dc8443bb8 read_bytes=1182476 read_rows=7185 result_bytes=3535817 result_rows=7101 task=48/118 total_rows_to_read=0 written_bytes=3535817 written_rows=7101
# 2025-03-06 20:26:10 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-27 elapsed_ns=90636187 env=PROD filename=create.py lineno=44 process=21819 query_id=8c6f2166-0c32-417e-9fe5-0f16b5f3db69 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=49/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:10 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-27 env=PROD filename=transform.py lineno=94 process=21819 task=49/118
# 2025-03-06 20:26:10 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7129 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-27 elapsed_ns=434914283 env=PROD filename=transform.py lineno=107 process=21819 query_id=44a3c6ef-a8f9-45ba-91a7-e4c74e61267a read_bytes=1178984 read_rows=7213 result_bytes=3547801 result_rows=7129 task=49/118 total_rows_to_read=0 written_bytes=3547801 written_rows=7129
# 2025-03-06 20:26:11 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2024-12-28 elapsed_ns=94372627 env=PROD filename=create.py lineno=44 process=21819 query_id=607834e9-bb03-4eb0-af22-8000d52321f0 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=50/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:26:11 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2024-12-28 env=PROD filename=transform.py lineno=94 process=21819 task=50/118
# ...
# 2025-03-06 20:27:11 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-24 env=PROD filename=transform.py lineno=94 process=21819 task=108/118
# 2025-03-06 20:27:12 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7869 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-24 elapsed_ns=658932844 env=PROD filename=transform.py lineno=107 process=21819 query_id=76efb1c9-3f3d-4ff7-b694-8b908b49e917 read_bytes=1292416 read_rows=7953 result_bytes=3911728 result_rows=7869 task=108/118 total_rows_to_read=0 written_bytes=3911728 written_rows=7869
# 2025-03-06 20:27:13 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-02-25 elapsed_ns=103913486 env=PROD filename=create.py lineno=44 process=21819 query_id=9b019b6c-77f3-4762-ade6-08ff7ddfd514 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=109/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:13 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-25 env=PROD filename=transform.py lineno=94 process=21819 task=109/118
# 2025-03-06 20:27:13 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8302 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-25 elapsed_ns=558535548 env=PROD filename=transform.py lineno=107 process=21819 query_id=2b9a13f4-262a-4605-bd6e-57e1b5324e6e read_bytes=1346218 read_rows=8386 result_bytes=4123058 result_rows=8302 task=109/118 total_rows_to_read=0 written_bytes=4123058 written_rows=8302
# 2025-03-06 20:27:14 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-02-26 elapsed_ns=101189077 env=PROD filename=create.py lineno=44 process=21819 query_id=ce75f045-8236-4651-b8ad-e742f0972cab read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=110/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:14 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-26 env=PROD filename=transform.py lineno=94 process=21819 task=110/118
# 2025-03-06 20:27:14 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7299 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-26 elapsed_ns=499256931 env=PROD filename=transform.py lineno=107 process=21819 query_id=3d6f81ec-32c2-4bd2-9b60-d815523a7d3e read_bytes=1188986 read_rows=7383 result_bytes=3622514 result_rows=7299 task=110/118 total_rows_to_read=0 written_bytes=3622514 written_rows=7299
# 2025-03-06 20:27:15 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-02-27 elapsed_ns=95573036 env=PROD filename=create.py lineno=44 process=21819 query_id=67239a3e-e2d8-457a-b725-36932c9eacb1 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=111/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:15 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-27 env=PROD filename=transform.py lineno=94 process=21819 task=111/118
# 2025-03-06 20:27:16 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7009 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-27 elapsed_ns=561361768 env=PROD filename=transform.py lineno=107 process=21819 query_id=a94ef8da-0147-4e3a-a429-e8287e06d756 read_bytes=1146343 read_rows=7093 result_bytes=3479613 result_rows=7009 task=111/118 total_rows_to_read=0 written_bytes=3479613 written_rows=7009
# 2025-03-06 20:27:16 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-02-28 elapsed_ns=109957226 env=PROD filename=create.py lineno=44 process=21819 query_id=bbc35e23-f772-4cd2-9e37-1745cce45f58 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=112/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:16 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-28 env=PROD filename=transform.py lineno=94 process=21819 task=112/118
# 2025-03-06 20:27:17 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7786 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-02-28 elapsed_ns=471716472 env=PROD filename=transform.py lineno=107 process=21819 query_id=0ae2c78e-fb6c-4be7-bf79-a3bb4bc843bc read_bytes=1259903 read_rows=7870 result_bytes=3864877 result_rows=7786 task=112/118 total_rows_to_read=0 written_bytes=3864877 written_rows=7786
# 2025-03-06 20:27:17 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-03-01 elapsed_ns=89777657 env=PROD filename=create.py lineno=44 process=21819 query_id=826376cd-9955-4e31-99d9-e0f1b7dc9e1f read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=113/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:17 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-01 env=PROD filename=transform.py lineno=94 process=21819 task=113/118
# 2025-03-06 20:27:18 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6256 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-01 elapsed_ns=348744137 env=PROD filename=transform.py lineno=107 process=21819 query_id=4f1f6949-70b2-4b84-8eca-3d54b85b326b read_bytes=1027750 read_rows=6340 result_bytes=3104316 result_rows=6256 task=113/118 total_rows_to_read=0 written_bytes=3104316 written_rows=6256
# 2025-03-06 20:27:18 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-03-02 elapsed_ns=90347076 env=PROD filename=create.py lineno=44 process=21819 query_id=482e6874-c373-487b-8d05-7c293f670e70 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=114/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:18 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-02 env=PROD filename=transform.py lineno=94 process=21819 task=114/118
# 2025-03-06 20:27:19 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7283 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-02 elapsed_ns=549422258 env=PROD filename=transform.py lineno=107 process=21819 query_id=23cfb9a9-5dd9-4bb2-a1f5-d5a95081cb62 read_bytes=1185289 read_rows=7367 result_bytes=3613379 result_rows=7283 task=114/118 total_rows_to_read=0 written_bytes=3613379 written_rows=7283
# 2025-03-06 20:27:19 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-03-03 elapsed_ns=90159137 env=PROD filename=create.py lineno=44 process=21819 query_id=a64e04ed-86ef-4a80-a684-21dc32b28ddf read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=115/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:19 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-03 env=PROD filename=transform.py lineno=94 process=21819 task=115/118
# 2025-03-06 20:27:20 [info     ] 01_fact_daily_dex_trades_v1.sql -> 7632 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-03 elapsed_ns=483282581 env=PROD filename=transform.py lineno=107 process=21819 query_id=9bb5796f-ae4d-4446-abfd-b6a61fd7424c read_bytes=1241133 read_rows=7716 result_bytes=3786348 result_rows=7632 task=115/118 total_rows_to_read=0 written_bytes=3786348 written_rows=7632
# 2025-03-06 20:27:20 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-03-04 elapsed_ns=90110847 env=PROD filename=create.py lineno=44 process=21819 query_id=9e212d0f-a7a0-4144-abb2-f4dfb667f51b read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=116/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:20 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-04 env=PROD filename=transform.py lineno=94 process=21819 task=116/118
# 2025-03-06 20:27:21 [info     ] 01_fact_daily_dex_trades_v1.sql -> 8044 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-04 elapsed_ns=711339433 env=PROD filename=transform.py lineno=107 process=21819 query_id=4641149c-b0bd-48c6-95b8-f61bac3e5371 read_bytes=1298036 read_rows=8128 result_bytes=3991047 result_rows=8044 task=116/118 total_rows_to_read=0 written_bytes=3991047 written_rows=8044
# 2025-03-06 20:27:22 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-03-05 elapsed_ns=91656277 env=PROD filename=create.py lineno=44 process=21819 query_id=e31728a0-74a0-427b-ab7b-b647bac7385d read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=117/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:22 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-05 env=PROD filename=transform.py lineno=94 process=21819 task=117/118
# 2025-03-06 20:27:22 [info     ] 01_fact_daily_dex_trades_v1.sql -> 6869 written rows ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-05 elapsed_ns=525366590 env=PROD filename=transform.py lineno=107 process=21819 query_id=f9d3bb27-a56d-460a-96d0-661d6a5b7ad9 read_bytes=1120698 read_rows=6953 result_bytes=3407115 result_rows=6869 task=117/118 total_rows_to_read=0 written_bytes=3407115 written_rows=6869
# 2025-03-06 20:27:23 [info     ] fact_daily_dex_trades_v1.sql -> 0 written rows ddl=fact_daily_dex_trades_v1.sql dt=2025-03-06 elapsed_ns=90527177 env=PROD filename=create.py lineno=44 process=21819 query_id=22ed7016-c043-4d95-a874-71140b831ed0 read_bytes=142 read_rows=2 result_bytes=0 result_rows=0 task=118/118 total_rows_to_read=2 written_bytes=0 written_rows=0
# 2025-03-06 20:27:23 [info     ] running ddl 01_fact_daily_dex_trades_v1.sql ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-06 env=PROD filename=transform.py lineno=94 process=21819 task=118/118
# 2025-03-06 20:27:23 [error    ] database error                 ddl=01_fact_daily_dex_trades_v1.sql dt=2025-03-06 env=PROD filename=transform.py lineno=103 process=21819 task=118/118
# Traceback (most recent call last):
#   File "/Users/chuxinhuang/work/op-analytics/src/op_analytics/transforms/transform.py", line 97, in run_update
#     result: QuerySummary = client.command(
#                            ^^^^^^^^^^^^^^^
#   File "/Users/chuxinhuang/work/op-analytics/.venv/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py", line 350, in command
#     response = self._raw_request(payload, params, headers, method, fields=fields, server_wait=False)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chuxinhuang/work/op-analytics/.venv/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py", line 461, in _raw_request
#     self._error_handler(response)
#   File "/Users/chuxinhuang/work/op-analytics/.venv/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py", line 384, in _error_handler
#     raise OperationalError(err_str) if retried else DatabaseError(err_str) from None
# clickhouse_connect.driver.exceptions.DatabaseError: HTTPDriver for https://qeyct17r6o.us-central1.gcp.clickhouse.cloud:8443 received ClickHouse error code 636
#  Code: 636. DB::Exception: The table structure cannot be extracted from a parquet format file, because there are no files with provided path in S3ObjectStorage or all files are empty. You can specify table structure manually: The table structure cannot be extracted from a parquet format file. You can specify the structure manually. (CANNOT_EXTRACT_TABLE_STRUCTURE) (version 24.10.1.11366 (official build))
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[11], line 8
#       4 os.environ["OPLABS_ENV"] = "prod"
#       6 from op_analytics.transforms.main import execute_dt_transforms
# ----> 8 results = execute_dt_transforms(
#       9     group_name="dune",
#      10     range_spec="@20241109:20250307",
#      11
#      12     # range_spec="@20241018:+1",
#      13     update_only=[1],
#      14     skip_create=False,
#      15     raise_if_empty=True,
#      16     max_tasks=None,
#      17     force_complete=True,
#      18 )
#
# File ~/work/op-analytics/src/op_analytics/transforms/main.py:80, in execute_dt_transforms(group_name, range_spec, update_only, skip_create, raise_if_empty, force_complete, max_tasks)
#      78 with bound_contextvars(task=f"{ii+1}/{num_tasks}"):
#      79     try:
# ---> 80         result = task.execute()
#      81     except NoWrittenRows:
#      82         if task.dt == now_date():
#      83             # It is possible that NoWrittenRows is encountered when we are running
#      84             # close to real time. In that case don't error out the run, log a warning
#      85             # and exit gracefully.
#
# File ~/work/op-analytics/src/op_analytics/transforms/transform.py:56, in TransformTask.execute(self)
#      54 if not self.skip_create:
#      55     self.create_tables()
# ---> 56 results = self.run_updates(client)
#      57 result_dicts = [_.to_dict() for _ in results]
#      58 self.write_marker(result_dicts)
#
# File ~/work/op-analytics/src/op_analytics/transforms/transform.py:75, in TransformTask.run_updates(self, client)
#      72     log.info(f"skipping index={step.index} ddl={step.name}")
#      73     continue
# ---> 75 result = self.run_update(client, step)
#      76 results.append(
#      77     UpdateResult(
#      78         name=step.name,
#      79         result=result.summary,
#      80     )
#      81 )
#      83 if step.step_type == StepType.EXPORT:
#
# File ~/work/op-analytics/src/op_analytics/transforms/transform.py:97, in TransformTask.run_update(self, client, step)
#      94 log.info(f"running ddl {step.name}")
#      96 try:
# ---> 97     result: QuerySummary = client.command(
#      98         cmd=step.sql_statement,
#      99         parameters={"dtparam": self.dt},
#     100         settings={"use_hive_partitioning": 1},
#     101     )
#     102 except DatabaseError as ex:
#     103     log.error("database error", exc_info=ex)
#
# File ~/work/op-analytics/.venv/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:350, in HttpClient.command(self, cmd, parameters, data, settings, use_database, external_data)
#     347 params.update(self._validate_settings(settings or {}))
#     349 method = 'POST' if payload or fields else 'GET'
# --> 350 response = self._raw_request(payload, params, headers, method, fields=fields, server_wait=False)
#     351 if response.data:
#     352     try:
#
# File ~/work/op-analytics/.venv/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:461, in HttpClient._raw_request(self, data, params, headers, method, retries, stream, server_wait, fields, error_handler)
#     459     error_handler(response)
#     460 else:
# --> 461     self._error_handler(response)
#
# File ~/work/op-analytics/.venv/lib/python3.12/site-packages/clickhouse_connect/driver/httpclient.py:384, in HttpClient._error_handler(self, response, retried)
#     381 else:
#     382     err_str = 'The ClickHouse server returned an error.'
# --> 384 raise OperationalError(err_str) if retried else DatabaseError(err_str) from None
#
# DatabaseError: HTTPDriver for https://qeyct17r6o.us-central1.gcp.clickhouse.cloud:8443 received ClickHouse error code 636
#  Code: 636. DB::Exception: The table structure cannot be extracted from a parquet format file, because there are no files with provided path in S3ObjectStorage or all files are empty. You can specify table structure manually: The table structure cannot be extracted from a parquet format file. You can specify the structure manually. (CANNOT_EXTRACT_TABLE_STRUCTURE) (version 24.10.1.11366 (official build))
