# %%
# %load_ext autoreload
# %autoreload 2

import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
import pandas as pd
import plotly.express as px
import numpy as np
import pandas as pd
import re
from datetime import timedelta
import plotly.express as px

from op_analytics.datasources.defillama.dataaccess import DefiLlama
from op_analytics.coreutils.request import get_data, new_session

import urllib3
import warnings
pd.set_option('display.float_format', lambda x: '%.3f' % x)
urllib3.disable_warnings()
warnings.filterwarnings("ignore")

# %%
from op_analytics.coreutils.duckdb_inmem.localcopy import dump_local_copy, load_local_copy
from op_analytics.datasources.defillama.dataaccess import DefiLlama
from op_analytics.coreutils.duckdb_inmem.client import init_client

# %%
from dataclasses import dataclass

import polars as pl


from op_analytics.coreutils.duckdb_inmem.localcopy import dump_local_copy, load_local_copy
from op_analytics.datasources.defillama.dataaccess import DefiLlama
from op_analytics.coreutils.duckdb_inmem.client import init_client


from op_analytics.coreutils.bigquery.write import most_recent_dates
from op_analytics.coreutils.logger import structlog
from op_analytics.coreutils.partitioned.dailydatautils import dt_summary
from op_analytics.coreutils.request import get_data, new_session
from op_analytics.coreutils.threads import run_concurrently
from op_analytics.coreutils.time import now_dt, dt_fromisostr

from op_analytics.datasources.defillama.dataaccess import DefiLlama

log = structlog.get_logger()

YIELD_POOLS_ENDPOINT = "https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/poolsBorrow"
YIELD_POOL_CHART_ENDPOINT = "https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/{pool}"

YIELD_TABLE_LAST_N_DAYS = 7


@dataclass
class DefillamaYield:
    """Metadata and yield data for all pools.

    This is the result we obtain after fetching from the API and extracting the data
    that we need to ingest.
    """

    pool_yield_df: pl.DataFrame


def pull_yield_data(pull_pools: list[str] | None = None) -> pl.DataFrame:
    """
    Pulls and processes yield pool data from DeFiLlama.

    Args:
        pull_pools: list of pool IDs to process. Defaults to None (process all).

    Returns:
        A polars DataFrame containing joined pool and historical yield data.
    """
    session = new_session()

    # Get all pools data
    pools_data = get_data(session, YIELD_POOLS_ENDPOINT)
    pools_df = extract_pools_data(pools_data["data"])
    print(pools_df.schema)
    # Write pools metadata
    DefiLlama.YIELD_POOLS_METADATA.write(
        dataframe=pools_df.with_columns(dt=pl.lit(now_dt())),
        sort_by=["pool"],
    )

    # Get pool IDs to process
    pool_ids = pools_df["pool"].to_list() if pull_pools is None else pull_pools

    # Call the API endpoint for each pool in parallel
    urls = {pool: YIELD_POOL_CHART_ENDPOINT.format(pool=pool) for pool in pool_ids}
    historical_yield_data = run_concurrently(lambda x: get_data(session, x), urls, max_workers=4)

    # Extract historical yield data
    historical_yield_df = extract_historical_yield_data(historical_yield_data)

    # Merge historical data with pool metadata
    pool_yield_df = historical_yield_df.join(pools_df, on="pool", how="left")

    # # Write yield data
    DefiLlama.YIELD_POOLS_HISTORICAL.write(
        dataframe=most_recent_dates(
            pool_yield_df, n_dates=YIELD_TABLE_LAST_N_DAYS, date_column="dt"
        ),
        sort_by=["dt", "chain", "protocol_slug", "pool"],
    )

    return DefillamaYield(pool_yield_df=pool_yield_df)


def execute_pull():
    result = pull_yield_data()
    return {"pool_yield_df": dt_summary(result.pool_yield_df)}


def extract_pools_data(pools_data: list) -> pl.DataFrame:
    """Extract pools data and transform into dataframe"""
    records = [
        {
            "pool": pool["pool"],
            "protocol_slug": pool["project"],
            "chain": pool["chain"],
            "symbol": pool["symbol"],
            "underlying_tokens": pool.get("underlyingTokens", []),
            "reward_tokens": pool.get("rewardTokens", []),
            "il_risk": pool["ilRisk"],
            "is_stablecoin": pool["stablecoin"],
            "exposure": pool["exposure"],
            "borrowable": pool["borrowable"],
            "minted_coin": pool["mintedCoin"],
            "borrow_factor": float(pool["borrowFactor"] or np.nan),
            "pool_meta": pool["poolMeta"] or "main_pool"
        }
        for pool in pools_data
    ]

    return pl.DataFrame(records)


def extract_historical_yield_data(data: dict) -> pl.DataFrame:
    """Extract historical yield data and transform into dataframe"""   
    records = [
        {
            "pool": pool_id,
            "dt": dt_fromisostr(entry["timestamp"]),
            "total_supply_usd": int(entry["totalSupplyUsd"] or 0),
            "total_borrow_usd": int(entry["totalBorrowUsd"] or 0),
            "debt_ceiling_usd": int(entry["debtCeilingUsd"] or 0),
            "apy_base": float(entry.get("apyBase") or 0.0),
            "apy_reward": float(entry.get("apyReward")  or 0.0),
            "apy_base_borrow": float(entry.get("apyBaseBorrow") or 0.0),
            "apy_reward_borrow": float(entry.get("apyRewardBorrow") or 0.0),
        }
        for pool_id, pool_data in data.items()
        for entry in pool_data["data"]
    ]

    return pl.DataFrame(records)

# %%
result = pull_yield_data()
# Out:
# 2025-01-29 11:19:20 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/poolsBorrow: 0.20 seconds filename=request.py lineno=81 process=11019
# Schema({'pool': String, 'protocol_slug': String, 'chain': String, 'symbol': String, 'underlying_tokens': List(String), 'reward_tokens': List(String), 'il_risk': String, 'is_stablecoin': Boolean, 'exposure': String, 'borrowable': Boolean, 'minted_coin': String, 'borrow_factor': Float64, 'pool_meta': String})
# 2025-01-29 11:19:20 [info     ] done writing 1.6Krows 76.7KB   filename=gcs_parquet.py lineno=57 maxrss=597999616 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_metadata_v1/dt=2025-01-29/out.parquet process=11019 root=defillama/yield_pools_metadata_v1 rows=1649 size=76739
# 2025-01-29 11:19:20 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=598.0 process=11019 root=defillama/yield_pools_metadata_v1
# 2025-01-29 11:19:20 [debug    ] done writing defillama/yield_pools_metadata_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_metadata_v1
# 2025-01-29 11:19:20 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/db678df9-3281-4bc2-a8bb-01160ffd6d48: 0.05 seconds counter=002/1649 eta=None filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f981a304-bb6c-45b8-b0c5-fd2f515ad23a: 0.04 seconds counter=005/1649 eta=None filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7e382157-b1bc-406d-b17b-facba43b716e: 0.12 seconds counter=004/1649 eta=None filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e880e828-ca59-4ec6-8d4f-27182a4dc23d: 0.12 seconds counter=001/1649 eta=None filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e6435aae-cbe9-4d26-ab2c-a4d533db9972: 0.15 seconds counter=003/1649 eta=None filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/90d3f42a-8700-4b9f-baa8-090a3c4322c9: 0.05 seconds counter=006/1649 eta=None filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/aa70268e-4b52-42bf-a116-608b370f9501: 0.06 seconds counter=007/1649 eta=67 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3b45941c-16cb-48c5-a490-16c6c4f1d86a: 0.06 seconds counter=008/1649 eta=52 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/31e2bebc-85e6-4974-b2e3-7f24675095cf: 0.06 seconds counter=010/1649 eta=42 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d3be212c-f337-40e2-87fc-fb636a3de38f: 0.05 seconds counter=011/1649 eta=43 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/51d2f8d4-1fb5-4f6b-938b-e9cd17ca1ceb: 0.08 seconds counter=009/1649 eta=50 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e26ce7d9-db75-4aa4-b1db-cc21ae17bdfb: 0.05 seconds counter=012/1649 eta=38 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/24195b31-d749-445f-bf9e-b65aa025ebdd: 0.05 seconds counter=014/1649 eta=38 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/29932dea-cd71-44c3-95bd-3e1525f4e3dd: 0.05 seconds counter=015/1649 eta=35 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/54600482-cfb9-4dd9-a73b-342cffd4644a: 0.07 seconds counter=013/1649 eta=40 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/87c8ee0d-b812-47c1-803f-f91a3907079e: 0.06 seconds counter=016/1649 eta=33 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/71418c17-d2aa-4eff-b68a-806fff9ec951: 0.06 seconds counter=017/1649 eta=36 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/747b58ab-aefd-42e1-a312-01ad5a0ab7f5: 0.05 seconds counter=019/1649 eta=32 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d541708e-1283-4feb-bc7a-457fc5f8db2c: 0.06 seconds counter=018/1649 eta=34 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c1ca08e4-d618-415e-ad63-fcec58705469: 0.05 seconds counter=020/1649 eta=31 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ef8c5c38-6a41-4383-9dc8-6fb31e69a0c9: 0.06 seconds counter=021/1649 eta=33 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ccc467d1-bdf5-4062-81cd-7aed7dd9050b: 0.06 seconds counter=023/1649 eta=30 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7da72d09-56ca-4ec5-a45f-59114353e487: 0.07 seconds counter=024/1649 eta=29 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/525b2dab-ea6a-4cbc-a07f-84ce561d1f83: 0.08 seconds counter=022/1649 eta=32 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b1986007-81f3-4150-9565-94d5a4066ce4: 0.06 seconds counter=025/1649 eta=32 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/abced696-4921-4bcc-9e1a-ac5164833e47: 0.05 seconds counter=028/1649 eta=29 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e705187b-da56-463d-a429-4e17bfb7e0d4: 0.06 seconds counter=026/1649 eta=31 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e302de4d-952e-4e18-9749-0a9dc86e98bc: 0.07 seconds counter=027/1649 eta=30 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1da10c92-fd2e-4506-a4d1-8c8fa22ff744: 0.05 seconds counter=029/1649 eta=31 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/974c8391-3686-4fc9-8477-9df4b618b594: 0.05 seconds counter=030/1649 eta=30 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ddd25534-e3d5-4e4e-9b99-d3102323ac61: 0.05 seconds counter=031/1649 eta=29 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/9f3a6015-5045-4471-ba65-ad3dc7c38269: 0.06 seconds counter=032/1649 eta=29 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1d876729-4445-4623-8b6b-c5290db5d100: 0.04 seconds counter=033/1649 eta=30 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d9fa8e14-0447-4207-9ae8-7810199dfa1f: 0.07 seconds counter=034/1649 eta=29 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b847133f-f5d5-4692-b74e-d815d51988fc: 0.06 seconds counter=035/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7ee6c38b-ac42-4388-88dc-389140276cf8: 0.06 seconds counter=036/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7c5e69a4-2430-4fa2-b7cb-857f79d7d1bf: 0.05 seconds counter=037/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3df9ffeb-8c72-438c-a9ae-026488d8f2b2: 0.05 seconds counter=038/1649 eta=29 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d5c4945f-5df7-42a3-8199-a8d290d8eda5: 0.05 seconds counter=040/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/072f6554-daa7-4708-80ba-371b896a89db: 0.05 seconds counter=039/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/bd335b46-3daf-4507-adb2-6fd4337ea33b: 0.07 seconds counter=041/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e65588a1-27ad-4e20-9232-68a6cfaccf63: 0.04 seconds counter=042/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/51eb4b5c-6d62-42fe-99d6-92ba6eecd2d5: 0.05 seconds counter=043/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/23405eee-97e7-4b8e-8625-19c3a36047e8: 0.05 seconds counter=044/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d2141a59-c199-4be7-8d4b-c8223954836b: 0.05 seconds counter=046/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/40e0d8b7-5eba-4d6c-a3c2-9ac375bcd4bf: 0.06 seconds counter=045/1649 eta=28 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1e5da7c6-59bb-49bd-9f97-4f4fceeffad4: 0.05 seconds counter=047/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/9da8a761-eb0f-4d41-ad05-0ebb2ed82913: 0.06 seconds counter=048/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/00d1e1f8-b3c8-4350-a247-5da693d2d4dd: 0.05 seconds counter=051/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f0131970-afac-4835-b22c-520f192e01d5: 0.07 seconds counter=049/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7e0661bf-8cf3-45e6-9424-31916d4c7b84: 0.05 seconds counter=052/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/da5e182c-b440-4b80-ab54-c1bc94a4ffd4: 0.07 seconds counter=050/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/85c57261-b75b-4447-a115-d79b1a7de8ed: 0.05 seconds counter=053/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/4dab1166-614a-429a-831f-4af70fd29c7d: 0.05 seconds counter=055/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/de8928ad-d03a-423d-92d7-3c4648e3ffd2: 0.06 seconds counter=054/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/03406d3a-fcc4-4fe3-8809-7a95222951b6: 0.06 seconds counter=056/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e62bcb01-ed4c-4ec9-8cfa-e86e7ccf7688: 0.05 seconds counter=058/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c918d01c-bc22-42ba-a6e6-374b9eb94378: 0.04 seconds counter=060/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3665ee7e-6c5d-49d9-abb7-c47ab5d9d4ac: 0.06 seconds counter=057/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0a842b8b-c003-4f6c-8f4e-b231c4cdaec8: 0.06 seconds counter=059/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/89bc7c4c-d71c-435c-ab28-56c803d51320: 0.05 seconds counter=062/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/55205d7a-7939-42aa-ad8a-0c0123db9474: 0.05 seconds counter=064/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f1a22245-a1f1-4389-8ff2-dde4914b272d: 0.05 seconds counter=063/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/44c94cb2-8af3-4b7a-8cb5-0784ddcf3471: 0.07 seconds counter=061/1649 eta=27 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/007d03bd-4987-4b3b-b7d2-2f3af42fa4b4: 0.04 seconds counter=067/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3a6cc030-738d-4e19-8a40-e63e9c4d5a6f: 0.05 seconds counter=065/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/57647093-2868-4e65-97ab-9cae8ec74e7d: 0.05 seconds counter=066/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:21 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/2d1aa052-64c0-4c2c-82a0-db39062f04ab: 0.05 seconds counter=068/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/58d18059-f1d1-45ed-acd3-f386e98cc506: 0.05 seconds counter=070/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/462c6f50-ceab-4235-aa0e-21ee1e345908: 0.05 seconds counter=071/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0827aa12-5831-47f0-b5ba-549294a2032b: 0.05 seconds counter=072/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f4d5b566-e815-4ca2-bb07-7bcd8bc797f1: 0.09 seconds counter=069/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d3694b72-5bc4-44c9-8ab6-1fc7941d216a: 0.04 seconds counter=074/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f2726d05-1f8d-4b9c-80e3-43d03d85d117: 0.05 seconds counter=073/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/89eba1e5-1b1b-47b6-958b-38138a04c244: 0.05 seconds counter=075/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c47eea82-1e3d-4b66-8777-278b8db1dd77: 0.04 seconds counter=076/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/8eabad30-1d9e-4f5f-a80e-7e634c8a4ceb: 0.05 seconds counter=077/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/69b12bf9-edb6-46d9-b5bc-761cf9efe137: 0.05 seconds counter=078/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c4f1e434-3386-4f48-b0ac-dc89782dfa55: 0.05 seconds counter=080/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/dac406f6-5600-437e-849d-f03daa383864: 0.06 seconds counter=079/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/914284ae-dbef-421f-bbb7-7c42f527fd5f: 0.05 seconds counter=081/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ec8af777-6c9e-440a-9a3d-355f556baa04: 0.04 seconds counter=082/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/4cb6e33e-d95b-4690-83d5-a0b26ebab5a5: 0.05 seconds counter=083/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/53b3663f-9096-49df-8787-f6ea3b6d0612: 0.07 seconds counter=084/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/8751078b-6be1-403b-ac44-9f11fe87d400: 0.06 seconds counter=086/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0e458a5b-fd99-4667-8706-dd938934cb0c: 0.08 seconds counter=085/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/9859863a-2752-4253-a6ec-a719e6f2143f: 0.05 seconds counter=089/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7d33d57d-36dc-414b-9538-22a223250468: 0.06 seconds counter=088/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/867aff4c-33fc-4591-940a-019549d5a8af: 0.11 seconds counter=087/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/23676f13-f8c7-4865-ae69-e757395828ee: 0.08 seconds counter=090/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e043585f-923f-4009-934f-005232f34a27: 0.08 seconds counter=092/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7d114ce1-2af1-42c3-a719-406fbbc3ed92: 0.08 seconds counter=091/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d396662e-9ab3-42da-b79c-8c47116c3f21: 0.08 seconds counter=094/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0c3c1b07-7c36-4fbb-8e71-226e02bf15c1: 0.10 seconds counter=093/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/afce8a53-cee4-4e62-b2b4-f80dcaaf87b5: 0.07 seconds counter=095/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/fa36ea14-cfb0-4f04-853f-366b22f0d887: 0.09 seconds counter=096/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1170b465-309b-4026-b10d-abdf7b1ac369: 0.06 seconds counter=097/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b37c26c3-848f-45f0-bd75-af97f1674a4d: 0.06 seconds counter=098/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/a3b13ece-8c9f-4cda-8a5f-069ef67680f2: 0.07 seconds counter=099/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/2b9bf1c6-a018-4e93-a32f-7cf6ccd311fc: 0.05 seconds counter=100/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/03a0cf78-c2f0-4ce5-85a8-2d5b77349276: 0.06 seconds counter=101/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/4a1e51bc-ff04-4da6-94df-219fd018f792: 0.07 seconds counter=102/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/45bfb85f-deb5-4990-b9c4-cfb99629e6e8: 0.05 seconds counter=103/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3390bc30-c664-4b42-af8e-0f1c5d26ecd0: 0.07 seconds counter=104/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f38a1e55-ee6a-427c-83b5-74232e1b2c24: 0.06 seconds counter=105/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/5c886b97-2625-4859-8ec7-36928be59047: 0.05 seconds counter=106/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/cbb9fc26-2b9e-436a-95d0-c75e2c0f5869: 0.06 seconds counter=108/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3e332a41-3a15-41bc-8d5c-438c09609349: 0.09 seconds counter=107/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f4b334a3-1724-450f-b06f-4163e566a950: 0.06 seconds counter=110/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/5a8d7827-00d9-416a-b1bb-ddc7f758a66e: 0.10 seconds counter=109/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/9f035eb1-ec9d-4324-8a9a-333ef47eeeee: 0.06 seconds counter=111/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/38583317-5354-4767-8f1e-6a0ae3aa7b5d: 0.07 seconds counter=112/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7e7821a2-3d20-4ae7-9c3d-04cd57904555: 0.10 seconds counter=113/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/69cf831d-624a-4f23-b5e3-c0f63ad1fa01: 0.06 seconds counter=115/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c037a916-a462-4c65-b217-100db0fdc0e0: 0.08 seconds counter=114/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/4583ba83-7e1d-4d10-b41f-c71b81665d55: 0.05 seconds counter=116/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c45984a2-4e5f-4c8d-83db-5fdff56afecb: 0.05 seconds counter=117/1649 eta=26 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b7444791-ecab-4bc4-85dc-9eb351064d98: 0.05 seconds counter=118/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/dd998393-9abe-4c08-b5db-b181babb235e: 0.04 seconds counter=119/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d5a5e303-325e-4b01-a2dc-96494eef2f8b: 0.08 seconds counter=120/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e52b9cd8-3f81-4a0e-a906-9af336579033: 0.07 seconds counter=121/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/dde4c16c-504d-470b-9404-006287ce0906: 0.09 seconds counter=122/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f77d3465-d067-43ff-a325-3450716aed9c: 0.05 seconds counter=124/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/a349fea4-d780-4e16-973e-70ca9b606db2: 0.10 seconds counter=123/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7c4da504-8972-466c-8b74-57132d939dc9: 0.05 seconds counter=125/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ff59b165-64e0-4868-a6db-6049b5135358: 0.05 seconds counter=126/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e466a720-dca3-47ed-92a1-1acefd3036d8: 0.05 seconds counter=127/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:22 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/504d25f6-9720-4bc3-bac3-3d4cb2e528c3: 0.05 seconds counter=128/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/60d657c9-5f63-4771-a85b-2cf8d507ec00: 0.07 seconds counter=129/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1262521f-3ba5-47d7-b035-ace072a0d0df: 0.05 seconds counter=130/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ebe53ee0-db95-478e-8476-b8aa420be700: 0.06 seconds counter=131/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1b8b4cdb-0728-42a8-bf13-2c8fea7427ee: 0.08 seconds counter=132/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b6b9796f-d033-4582-8fbe-23902dcba331: 0.05 seconds counter=133/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c0921c0f-51aa-45b8-87e3-5eec59a6972b: 0.05 seconds counter=134/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b37c61f5-cd40-43ca-87ee-fa2ebf206ccb: 0.05 seconds counter=135/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/2fd993e9-2dcb-46a4-ae11-bdb2933bb77e: 0.06 seconds counter=136/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/4ea995cd-f67b-4283-97e5-96640f8de0c7: 0.05 seconds counter=138/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/fd9e9a70-84fe-43fc-a76b-d3efcd0ead10: 0.06 seconds counter=137/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1f2252e3-64c0-47ad-8249-84a8711862fb: 0.06 seconds counter=139/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/eaa642e5-a8d2-4628-afee-4041c7d60a56: 0.06 seconds counter=141/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ca969cae-bbcb-4cd7-985e-be4df9815e15: 0.05 seconds counter=143/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d25b5f1e-3368-4c79-a876-479834b15195: 0.07 seconds counter=142/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0b65cb9f-2c63-40d5-9344-2a867fbfc41a: 0.08 seconds counter=140/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3ebae7dd-d7b6-4406-a6a8-032aa23502ad: 0.04 seconds counter=145/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/43644487-e26c-450c-8bcb-fb10c1e512e0: 0.05 seconds counter=146/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/73afa0b0-a513-4fdd-a9af-09c6ceac109b: 0.05 seconds counter=147/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0bd46e52-cddc-4c50-bcd1-1e4b9a39815d: 0.07 seconds counter=144/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/07ba9ce6-f3f0-456d-a310-263eceb1ffe9: 0.06 seconds counter=148/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/bd5f0157-491d-4d2b-a966-7f7bb5ca0331: 0.05 seconds counter=149/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e053590b-54f1-40aa-ae0d-14e701ca734c: 0.05 seconds counter=150/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3334cafe-4a30-4a33-90a7-1b292a289e72: 0.06 seconds counter=151/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/30eb7dd0-a154-4e28-add4-5879add62c58: 0.05 seconds counter=152/1649 eta=25 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/ea8d9aa8-46ae-4447-a192-74515706a575: 0.05 seconds counter=153/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c11cb1b9-3cd5-4252-93da-51b130fc4f45: 0.05 seconds counter=154/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/717e962a-6251-446f-8581-005f8e85ce03: 0.05 seconds counter=155/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0758c3b8-4ffb-4176-b0a9-f446e367db46: 0.05 seconds counter=156/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/eaece65e-ffb2-4631-a95e-7f267cb2f1ba: 0.05 seconds counter=157/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d5e3d09c-f681-46cb-932c-8d6fe1ff1487: 0.07 seconds counter=158/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/9ddf4d9b-aab8-4ad5-b6c2-af9e1b7fd043: 0.07 seconds counter=159/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/5554eb0a-d66e-4878-af40-9c53c3dbb4e0: 0.05 seconds counter=161/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/a5453ca0-7ec4-44b8-81c8-9154ce8465f7: 0.06 seconds counter=160/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0cc952a9-714e-4724-9fed-56ac675e34c5: 0.05 seconds counter=163/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1e83d9c5-019c-4ad9-87d7-eab5c29e7178: 0.04 seconds counter=164/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/cefa9bb8-c230-459a-a855-3b94e96acd8c: 0.08 seconds counter=162/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/9837ed71-8e5e-45c4-a56d-54d738a1cb1e: 0.05 seconds counter=165/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/94657e4e-5345-48f0-9132-f7a709e2021e: 0.04 seconds counter=166/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/30d7bddf-9c7b-4495-a34a-e8d4ab1ff5c3: 0.05 seconds counter=167/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d9c395b9-00d0-4426-a6b3-572a6dd68e54: 0.04 seconds counter=168/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/dbddf880-255a-4754-83ca-4580fea4ad7b: 0.06 seconds counter=169/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/29be6a85-414f-4a66-b075-98863278912a: 0.06 seconds counter=170/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1c495ee8-f454-4c6d-af22-9affcfc8c222: 0.04 seconds counter=171/1649 eta=24 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:23 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/52fdf254-e837-4f8f-955f-993c3fb31f91: 0.08 seconds counter=172/1649 eta=24 secs filename=request.py lineno=81 process=11019
# ...
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/bd7319a8-acff-42f2-b64f-253b40a45ccc: 0.07 seconds counter=1609/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/83a841bb-dfc9-4d57-85a9-0252e45cef99: 0.05 seconds counter=1610/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/629b3ebc-115b-45e6-9f63-2135e3615df2: 0.06 seconds counter=1611/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/791a72df-e5cc-4181-8555-ac8f3eb6b58e: 0.06 seconds counter=1613/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/eed1b0b5-5b31-432a-9f70-0d1b602a45d5: 0.07 seconds counter=1612/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/084d7da1-7261-48ed-8afe-b9244a7b4676: 0.06 seconds counter=1614/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/b1faeff2-9b70-4a6f-9bbf-0a90a145e302: 0.05 seconds counter=1615/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/c93392fb-9c1b-4ab7-a2e0-73ad2d1e782d: 0.05 seconds counter=1616/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/54392a64-2165-47a2-b08e-88dd61b8768c: 0.05 seconds counter=1617/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/09bbef48-cd64-4596-a00b-f5fb246510ee: 0.05 seconds counter=1618/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/08fc7a73-1258-490f-b27a-ff8fd04b2cd4: 0.04 seconds counter=1620/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1386631d-1f7a-4ea3-8e51-ca10c732015d: 0.06 seconds counter=1619/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/016cfe4a-df91-4cc1-a951-60f4e40c45dc: 0.06 seconds counter=1621/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0b31e6a6-5ff8-4239-9b01-78ca1aa7c301: 0.06 seconds counter=1622/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/02305c4f-3e5f-4c38-b5e3-9688a2d0518e: 0.05 seconds counter=1624/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/4043083e-2856-4966-b533-d9afabb81281: 0.06 seconds counter=1623/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/415e8e87-ffb0-4aa1-8cc3-ee2a73443a9a: 0.05 seconds counter=1625/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:45 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/873c5cfd-9669-4513-a6c6-c6fc7a033df9: 0.05 seconds counter=1626/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f20d5ead-6c76-475d-ae85-0e03fb3884bd: 0.06 seconds counter=1627/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0def0cb3-188d-4a6e-b42a-8d1bb13fccee: 0.06 seconds counter=1628/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/d7131eb0-3cd6-45af-a8e6-20dd64fdc578: 0.06 seconds counter=1629/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/5f7bacea-278b-473b-979f-834d8e4d522a: 0.07 seconds counter=1630/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/e2e39d18-ae19-46e4-b6e8-dbdeb0e1733e: 0.05 seconds counter=1632/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/25c68707-2be9-4228-b47d-00ba510ce54a: 0.05 seconds counter=1631/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/2693d1a5-c610-4925-a32e-b5928899a53f: 0.05 seconds counter=1633/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/17df64e8-44ac-451d-ab86-7512533ad20d: 0.05 seconds counter=1634/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/a69daab6-97a4-4d12-bc5c-db6a9dfb37b5: 0.05 seconds counter=1635/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/430f521e-8d75-42ab-9996-747558a10433: 0.05 seconds counter=1636/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/83933c1f-7e6c-4312-a724-d6361b983e15: 0.06 seconds counter=1637/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/7d774813-b675-4297-b16d-691261faa93e: 0.04 seconds counter=1639/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/add7ad5b-4005-4cad-91cf-5b62b4d40c3a: 0.06 seconds counter=1638/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0aaeff7a-7455-4c0e-aa7f-3f8705d46259: 0.08 seconds counter=1640/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/72e5565f-9c43-4012-9958-99bc9b184bd2: 0.04 seconds counter=1642/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/f6a11019-68e7-4bb5-92d0-1bc3e21a8ac8: 0.08 seconds counter=1641/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/03f2f1e1-d015-4821-86d3-d7af8f36d674: 0.06 seconds counter=1643/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/0e1b2a2b-dc19-4701-88ed-deabdff13fac: 0.05 seconds counter=1644/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1806b085-e7d0-4ec9-b293-29c150c7fcf8: 0.05 seconds counter=1645/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/2439cc3f-5984-4e63-a949-8366c35c57a2: 0.04 seconds counter=1647/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/1e00ac2b-0c3c-4b1f-95be-9378f98d2b40: 0.06 seconds counter=1646/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/3c34c22f-79eb-418a-b231-f31b0caf8d61: 0.08 seconds counter=1648/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:46 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/chartLendBorrow/8cdccd5c-7696-4900-8f29-dfd29a6ce37f: 0.07 seconds counter=1649/1649 eta=1 secs filename=request.py lineno=81 process=11019
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.4KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-23/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1634 size=104390
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.6KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-24/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1633 size=104616
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.7KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-25/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1637 size=104728
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.6KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-26/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1636 size=104615
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.5KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-27/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1635 size=104523
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.4KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-28/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1633 size=104371
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [info     ] done writing 1.6Krows 104.4KB  filename=gcs_parquet.py lineno=57 maxrss=1537687552 path=/Users/chuck/codebase/op-analytics/ozone/warehouse/defillama/yield_pools_historical_v1/dt=2025-01-29/out.parquet process=11019 root=defillama/yield_pools_historical_v1 rows=1632 size=104367
# 2025-01-29 11:19:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1537.69 process=11019 root=defillama/yield_pools_historical_v1
# 2025-01-29 11:19:47 [debug    ] done writing defillama/yield_pools_historical_v1 to LOCAL filename=writehelper.py lineno=131 process=11019 root=defillama/yield_pools_historical_v1

# %%
from op_analytics.coreutils.duckdb_inmem.client import init_client

ctx = init_client()
client = ctx.client

tvl_view = DefiLlama.YIELD_POOLS_HISTORICAL.read(
    min_date="2021-01-01",
)

# Process protocol TVL
df_yield_pool = client.sql(f"""
    SELECT
        *
    FROM {tvl_view}
""").pl().to_pandas()
# Out:
# 2025-01-29 15:07:00 [info     ] Reading data from 'defillama/yield_pools_historical_v1' with filters min_date=2021-01-01, max_date=None, date_range_spec=None filename=dailydata.py lineno=187 process=11019
# 2025-01-29 15:07:00 [info     ] querying markers for 'defillama/yield_pools_historical_v1' DateFilter(min_date=datetime.date(2021, 1, 1), max_date=None, datevals=None) filename=dailydata.py lineno=105 process=11019
# 2025-01-29 15:07:00 [info     ] 2429 markers found             filename=dailydata.py lineno=119 max_dt=2025-01-28 min_dt=2022-02-11 process=11019
# 2025-01-29 15:07:00 [info     ] 1083 distinct paths            filename=dailydata.py lineno=129 process=11019
# 2025-01-29 15:07:02 [info     ] registered view: 'defillama_yield_pools_historical_v1' using 1083 parquet paths filename=client.py lineno=291 process=11019
# ┌─────────────────────────────────────┐
# │                name                 │
# │               varchar               │
# ├─────────────────────────────────────┤
# │ defillama_yield_pools_historical_v1 │
# └─────────────────────────────────────┘

# %%
borrow_df = result.pool_yield_df.to_pandas()

# %%
borrow_df["dt"] = pd.to_datetime(borrow_df["dt"])

# %%
borrow_df[
    (borrow_df.chain == "Ethereum")
    & (borrow_df.protocol_slug == "aave-v2")
    & (borrow_df.pool_meta == "main_pool")
    & (borrow_df.symbol == "STETH")
    # & (borrow_df.borrowable == True)
    # & (borrow_df.symbol.isin(["USDT", "USDC"])
    # & (borrow_df.dt == "2025-01-28")

]
# Out:
#                                        pool         dt  total_supply_usd  \
# 47045  0e458a5b-fd99-4667-8706-dd938934cb0c 2022-02-28                 0
# 47046  0e458a5b-fd99-4667-8706-dd938934cb0c 2022-03-01                 0
# 47047  0e458a5b-fd99-4667-8706-dd938934cb0c 2022-03-02                 0
# 47048  0e458a5b-fd99-4667-8706-dd938934cb0c 2022-03-03                 0
# 47049  0e458a5b-fd99-4667-8706-dd938934cb0c 2022-03-04                 0
# ...                                     ...        ...               ...
# 48105  0e458a5b-fd99-4667-8706-dd938934cb0c 2025-01-25         118837051
# 48106  0e458a5b-fd99-4667-8706-dd938934cb0c 2025-01-26         117298106
# 48107  0e458a5b-fd99-4667-8706-dd938934cb0c 2025-01-27         113142412
# 48108  0e458a5b-fd99-4667-8706-dd938934cb0c 2025-01-28         109879721
# 48109  0e458a5b-fd99-4667-8706-dd938934cb0c 2025-01-29         110284557
#
#        total_borrow_usd  debt_ceiling_usd  apy_base  apy_reward  \
# 47045                 0                 0     0.000       0.000
# 47046                 0                 0     0.000       0.000
# 47047                 0                 0     0.000       0.000
# 47048                 0                 0     0.000       0.000
# 47049                 0                 0     0.000       0.000
# ...                 ...               ...       ...         ...
# 48105                 0                 0     0.000       0.000
# 48106                 0                 0     0.000       0.000
# 48107                 0                 0     0.000       0.000
# 48108                 0                 0     0.000       0.000
# 48109                 0                 0     0.000       0.000
#
#        apy_base_borrow  apy_reward_borrow protocol_slug  ... symbol  \
# 47045            0.000              0.000       aave-v2  ...  STETH
# 47046            0.000              0.000       aave-v2  ...  STETH
# 47047            0.000              0.000       aave-v2  ...  STETH
# 47048            0.000              0.000       aave-v2  ...  STETH
# 47049            0.000              0.000       aave-v2  ...  STETH
# ...                ...                ...           ...  ...    ...
# 48105            0.000              0.000       aave-v2  ...  STETH
# 48106            0.000              0.000       aave-v2  ...  STETH
# 48107            0.000              0.000       aave-v2  ...  STETH
# 48108            0.000              0.000       aave-v2  ...  STETH
# 48109            0.000              0.000       aave-v2  ...  STETH
#
#                                   underlying_tokens reward_tokens il_risk  \
# 47045  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 47046  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 47047  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 47048  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 47049  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# ...                                             ...           ...     ...
# 48105  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 48106  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 48107  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 48108  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
# 48109  [0xae7ab96520DE3A18E5e111B5EaAb095312D7fE84]          None      no
#
#       is_stablecoin  exposure borrowable minted_coin borrow_factor  pool_meta
# 47045         False    single      False        None           NaN  main_pool
# 47046         False    single      False        None           NaN  main_pool
# 47047         False    single      False        None           NaN  main_pool
# 47048         False    single      False        None           NaN  main_pool
# 47049         False    single      False        None           NaN  main_pool
# ...             ...       ...        ...         ...           ...        ...
# 48105         False    single      False        None           NaN  main_pool
# 48106         False    single      False        None           NaN  main_pool
# 48107         False    single      False        None           NaN  main_pool
# 48108         False    single      False        None           NaN  main_pool
# 48109         False    single      False        None           NaN  main_pool
#
# [1065 rows x 21 columns]

# %%
import plotly.graph_objects as go

# Filter the dataframe for WSTETH and the two protocols
filtered_wsteth_df = borrow_df[
    (borrow_df["chain"] == "Ethereum") &
    (borrow_df["symbol"].isin(["WSTETH", "STETH"])) &
    (borrow_df["protocol_slug"].isin(["aave-v3", "spark", "aave-v2"])) &
    (borrow_df["pool_meta"] == "main_pool") & 
    (borrow_df["dt"] >= "2022-09-21")
]

# Define custom colors
color_mapping = {
    "aave-v2": "black",
    "aave-v3": "purple",
    "spark": "magenta"
}

# Create the figure
fig = go.Figure()

for protocol in filtered_wsteth_df["protocol_slug"].unique():
    df_subset = filtered_wsteth_df[filtered_wsteth_df["protocol_slug"] == protocol]
    fig.add_trace(go.Scatter(
        x=df_subset["dt"],
        y=df_subset["total_supply_usd"],
        mode="lines",
        name=f"{protocol} - WSTETH",
        line=dict(color=color_mapping[protocol], width=3)  # Slightly thicker lines for visibility
    ))

# Update layout
fig.update_layout(
    title="WSTETH Total Supply on Aave v2, Aave v3, & Spark",
    xaxis_title="Date",
    yaxis_title="Total Supply (USD)",
    template="plotly_white",
    margin=dict(t=50, l=25, r=25, b=50),
    legend=dict(
        title="Protocol",
        yanchor="top",
        y=1,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_79.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.express as px
import plotly.graph_objects as go

# Filter the dataframe
filtered_df = borrow_df[
    (borrow_df["chain"] == "Ethereum") &
    (borrow_df["is_stablecoin"] == True) &
    (borrow_df["protocol_slug"].isin(["aave-v3", "spark"])) &
    (borrow_df["pool_meta"] == "main_pool") &
    (borrow_df["borrowable"] == True) &
    (
        ((borrow_df["symbol"].isin(["USDC", "USDT", "GHO"])) & (borrow_df["protocol_slug"] == "aave-v3")) |
        ((borrow_df["symbol"] == "DAI") & (borrow_df["protocol_slug"] == "spark"))
    )
]

# Create a new column combining protocol and symbol
filtered_df["protocol_symbol"] = filtered_df["protocol_slug"] + " - " + filtered_df["symbol"]

# Define custom colors
color_mapping = {
    "aave-v3 - USDT": "green",
    "aave-v3 - USDC": "blue",
    "aave-v3 - GHO": "purple",
    "spark - DAI": "orange"
}

# Define line width (make DAI thicker)
line_width_mapping = {
    "aave-v3 - USDT": 2,
    "aave-v3 - USDC": 2,
    "aave-v3 - GHO": 2,
    "spark - DAI": 4  # Thicker line for DAI
}

# Create the figure
fig = go.Figure()

for protocol_symbol in ["aave-v3 - USDT", "aave-v3 - USDC", "aave-v3 - GHO", ""]:
    df_subset = filtered_df[filtered_df["protocol_symbol"] == protocol_symbol]
    fig.add_trace(go.Scatter(
        x=df_subset["dt"],
        y=df_subset["apy_base_borrow"],
        mode="lines",
        name=protocol_symbol,
        line=dict(color=color_mapping[protocol_symbol], width=line_width_mapping[protocol_symbol])
    ))

# Update layout
fig.update_layout(
    title="Borrow Rates Over Time",
    xaxis_title="Date",
    yaxis_title="Base Borrow APY",
    template="plotly_white",
    margin=dict(t=50, l=25, r=25, b=50),
    legend=dict(
        title="Protocol & Token",
        yanchor="top",
        y=1,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_164.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.graph_objects as go

# Filter borrow APY data for Aave v3 and Spark (only selected tokens)
filtered_borrow_df = borrow_df[
    (borrow_df["chain"] == "Ethereum") &
    (borrow_df["is_stablecoin"] == True) &
    (borrow_df["protocol_slug"].isin(["aave-v3", "spark"])) &
    (borrow_df["pool_meta"] == "main_pool") &
    (borrow_df["borrowable"] == True) &
    (
        ((borrow_df["protocol_slug"] == "aave-v3") & (borrow_df["symbol"].isin(["USDT", "USDC", "GHO"]))) |
        ((borrow_df["protocol_slug"] == "spark") & (borrow_df["symbol"] == "DAI"))
    )
]

# Filter total supply data for WSTETH on Aave v3 and Spark
filtered_supply_df = borrow_df[
    (borrow_df["chain"] == "Ethereum") &
    (borrow_df["symbol"] == "WSTETH") &
    (borrow_df["protocol_slug"].isin(["aave-v3", "spark"])) &
    (borrow_df["pool_meta"] == "main_pool")
]

# Define colors
borrow_colors = {"USDT": "green", "USDC": "blue", "GHO": "purple", "DAI": "orange"}
supply_colors = {"aave-v3": "purple", "spark": "magenta"}

# Create figure
fig = go.Figure()

# Add total supply (Left Y-axis)
for protocol in filtered_supply_df["protocol_slug"].unique():
    df_subset = filtered_supply_df[filtered_supply_df["protocol_slug"] == protocol]
    fig.add_trace(go.Scatter(
        x=df_subset["dt"],
        y=df_subset["total_supply_usd"],
        mode="lines",
        name=f"{protocol} - WSTETH Supply",
        line=dict(color=supply_colors[protocol], width=3),  # Thicker lines for clarity
        yaxis="y1"
    ))

# Add borrow APY (Right Y-axis)
for symbol in filtered_borrow_df["symbol"].unique():
    df_subset = filtered_borrow_df[filtered_borrow_df["symbol"] == symbol]
    for protocol in df_subset["protocol_slug"].unique():
        df_proto = df_subset[df_subset["protocol_slug"] == protocol]
        line_width = 4 if (symbol == "DAI" and protocol == "spark") else 2  # DAI on Spark should be thicker
        fig.add_trace(go.Scatter(
            x=df_proto["dt"],
            y=df_proto["apy_base_borrow"],
            mode="lines",
            name=f"{protocol} - {symbol} Borrow APY",
            line=dict(color=borrow_colors[symbol], width=line_width),
            yaxis="y2"
        ))

# Update layout
fig.update_layout(
    title="Total Supply & Borrow APY for Aave v3 & Spark",
    xaxis_title="Date",
    yaxis=dict(
        title="Total Supply (USD)",
        side="left",
        showgrid=False
    ),
    yaxis2=dict(
        title="Borrow APY (%)",
        side="right",
        overlaying="y",
        showgrid=False
    ),
    template="plotly_white",
    margin=dict(t=50, l=25, r=50, b=50),
    legend=dict(
        title="Legend",
        yanchor="top",
        y=1.05,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_152.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.graph_objects as go

# Filter for only Aave v3 and USDC
filtered_borrow_df = borrow_df[
    (borrow_df["chain"] == "Ethereum") &
    (borrow_df["is_stablecoin"] == True) &
    (borrow_df["protocol_slug"] == "aave-v3") &  # Only Aave v3
    (borrow_df["pool_meta"] == "main_pool") &
    (borrow_df["borrowable"] == True) &
    (borrow_df["symbol"] == "USDC")  # Only USDC
]

# Define colors
borrow_color = "blue"

# Create figure
fig = go.Figure()

# Add total borrow (Left Y-axis) - Solid Blue Line
fig.add_trace(go.Scatter(
    x=filtered_borrow_df["dt"],
    y=filtered_borrow_df["total_supply_usd"] - filtered_borrow_df["total_borrow_usd"],
    mode="lines",
    name="Aave v3 - USDC Total Borrow",
    line=dict(color=borrow_color, width=2),  # Solid blue
    yaxis="y1"
))

# Add borrow APY (Right Y-axis) - Dashed & Thicker Blue Line
fig.add_trace(go.Scatter(
    x=filtered_borrow_df["dt"],
    y=filtered_borrow_df["apy_base_borrow"],
    mode="lines",
    name="Aave v3 - USDC Borrow APY",
    line=dict(color="black", width=3, dash="dash"),  # Thicker dashed blue
    yaxis="y2"
))

# Update layout
fig.update_layout(
    title="Aave v3 USDC - APY increases as borrowable suppply decreases",
    xaxis_title="Date",
    yaxis=dict(
        title="Total USD Amount Borrowable (Supply - Borrowed)",
        side="left",
        showgrid=False
    ),
    yaxis2=dict(
        title="Borrow APY (%)",
        side="right",
        overlaying="y",
        showgrid=False
    ),
    template="plotly_white",
    margin=dict(t=50, l=25, r=50, b=50),
    legend=dict(
        title="Legend",
        yanchor="top",
        y=1.05,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_212.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
borrow_df[
    (borrow_df["chain"] == "Ethereum")
    & (borrow_df.protocol_slug == "spark")    
    & (borrow_df.dt == "2025-01-28")

]
# Out:
#                                         pool         dt  total_supply_usd  \
# 5471    3b45941c-16cb-48c5-a490-16c6c4f1d86a 2025-01-28        2358738746
# 7573    e26ce7d9-db75-4aa4-b1db-cc21ae17bdfb 2025-01-28        1150098662
# 8205    24195b31-d749-445f-bf9e-b65aa025ebdd 2025-01-28         946752595
# 28946   9da8a761-eb0f-4d41-ad05-0ebb2ed82913 2025-01-28         181951773
# 29067   00d1e1f8-b3c8-4350-a247-5da693d2d4dd 2025-01-28         181583139
# 33471   03406d3a-fcc4-4fe3-8809-7a95222951b6 2025-01-28         165860995
# 41572   d3694b72-5bc4-44c9-8ab6-1fc7941d216a 2025-01-28         122960482
# 47043   8751078b-6be1-403b-ac44-9f11fe87d400 2025-01-28         103539214
# 270006  65ce8276-b4d9-41ba-9f6f-21fc374cf9bc 2025-01-28           1410430
# 286047  8fbe28b8-140d-4e37-8804-5d2aba4daded 2025-01-28           1018609
# 290028  0b8fec3b-a715-4803-94ce-9fe3b7520b23 2025-01-28            980425
#
#         total_borrow_usd  debt_ceiling_usd  apy_base  apy_reward  \
# 5471              228446                 0     0.000       0.000
# 7573          1020902619                 0    10.868       0.000
# 8205           810529095                 0     1.926       0.000
# 28946                  0                 0     0.000       0.000
# 29067            1928336                 0     0.001       0.000
# 33471            1686600                 0     0.000       0.000
# 41572                  0                 0     0.000       0.000
# 47043              26737                 0     0.000       0.000
# 270006           1179583                 0     8.257       0.000
# 286047            780824                 0     6.928       0.000
# 290028                 0                 0     0.000       0.000
#
#         apy_base_borrow  apy_reward_borrow protocol_slug  ...  symbol  \
# 5471              0.000              0.000         spark  ...  WSTETH
# 7573             12.028              0.000         spark  ...     DAI
# 8205              2.368              0.000         spark  ...    WETH
# 28946             5.000              0.000         spark  ...   WEETH
# 29067             0.071              0.000         spark  ...   CBBTC
# 33471             0.034              0.000         spark  ...    WBTC
# 41572             0.000              0.000         spark  ...   SUSDS
# 47043             0.254              0.000         spark  ...    RETH
# 270006           10.381              0.000         spark  ...    USDC
# 286047            9.509              0.000         spark  ...    USDT
# 290028            1.000              0.000         spark  ...    SDAI
#
#                                    underlying_tokens reward_tokens il_risk  \
# 5471    [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 7573    [0x6B175474E89094C44Da98b954EedeAC495271d0F]          None      no
# 8205    [0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2]          None      no
# 28946   [0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee]          None      no
# 29067   [0xcbB7C0000aB88B473b1f5aFd9ef808440eed33Bf]          None      no
# 33471   [0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599]          None      no
# 41572   [0xa3931d71877C0E7a3148CB7Eb4463524FEc27fbD]          None      no
# 47043   [0xae78736Cd615f374D3085123A210448E74Fc6393]          None      no
# 270006  [0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48]          None      no
# 286047  [0xdAC17F958D2ee523a2206206994597C13D831ec7]          None      no
# 290028  [0x83F20F44975D03b1b09e64809B757c47f942BEeA]          None      no
#
#        is_stablecoin  exposure borrowable minted_coin borrow_factor  pool_meta
# 5471           False    single       True        None           NaN  main_pool
# 7573            True    single       True        None           NaN  main_pool
# 8205           False    single       True        None           NaN  main_pool
# 28946          False    single      False        None           NaN  main_pool
# 29067          False    single       True        None           NaN  main_pool
# 33471          False    single      False        None           NaN  main_pool
# 41572           True    single      False        None           NaN  main_pool
# 47043          False    single       True        None           NaN  main_pool
# 270006          True    single       True        None           NaN  main_pool
# 286047          True    single       True        None           NaN  main_pool
# 290028          True    single      False        None           NaN  main_pool
#
# [11 rows x 21 columns]

# %%
borrow_df.columns
# Out:
# Index(['pool', 'dt', 'total_supply_usd', 'total_borrow_usd',
#        'debt_ceiling_usd', 'apy_base', 'apy_reward', 'apy_base_borrow',
#        'apy_reward_borrow', 'protocol_slug', 'chain', 'symbol',
#        'underlying_tokens', 'reward_tokens', 'il_risk', 'is_stablecoin',
#        'exposure', 'borrowable', 'minted_coin', 'borrow_factor', 'pool_meta'],
#       dtype='object')

# %%
steth_df = df_yield_pool[
    (df_yield_pool.chain == "Ethereum")
    & (df_yield_pool.symbol == "STETH") 
    & (df_yield_pool.protocol_slug == "lido")
][["dt", "apy"]].rename(columns={"apy": "steth_native_apy"})

# %%
supply_df = borrow_df[
    (borrow_df["chain"] == "Ethereum")
    & (borrow_df["symbol"] == "WSTETH")
    & (borrow_df["protocol_slug"].isin(["aave-v3", "spark"]))
    & (borrow_df["pool_meta"] == "main_pool")
][["dt", "total_supply_usd", "total_borrow_usd", "apy_base", "protocol_slug", "symbol"]].rename(
    columns={
        "apy_base": "supply_apy",
        "symbol": "supply_token",
    }
)

# %%
stable_borrow_df = (
    borrow_df[
        (borrow_df["chain"] == "Ethereum")
        & (borrow_df["is_stablecoin"] == True)
        & (borrow_df["protocol_slug"].isin(["aave-v3", "spark"]))
        & (borrow_df["pool_meta"] == "main_pool")
        & (borrow_df["borrowable"] == True)
        & (
            (
                (borrow_df["protocol_slug"] == "aave-v3")
                & (borrow_df["symbol"].isin(["USDT", "USDC", "GHO"]))
            )
            | ((borrow_df["protocol_slug"] == "spark") & (borrow_df["symbol"] == "DAI"))
        )
    ][["dt", "apy_base_borrow", "protocol_slug", "symbol"]].rename(
        columns={"symbol": "borrow_token", "apy_base_borrow": "borrow_apy"}
    )
)

# %%
susde_df = df_yield_pool[
    (df_yield_pool.chain == "Ethereum")
    & (df_yield_pool.symbol == "SUSDE") 
    & (df_yield_pool.protocol_slug == "ethena-usde")
][["dt", "apy"]].rename(columns={"apy": "susde_native_apy"})

# %%
strategy_df = (
    pd.merge(steth_df, supply_df, on="dt", how="left")
    .merge(stable_borrow_df, on=["dt", "protocol_slug"], how="left")
    .merge(susde_df, on="dt", how="left")
    
)

# %%
strategy_df["borrow_net_apy"] = (
    strategy_df.steth_native_apy
    + strategy_df.supply_apy
    - strategy_df.borrow_apy    
)

# %%
strategy_df["trade_yield"] = (
    strategy_df.steth_native_apy
    + strategy_df.supply_apy
    + strategy_df.susde_native_apy
    - strategy_df.borrow_apy

    
)

# %%
strategy_df
# Out:
#              dt  steth_native_apy  total_supply_usd  total_borrow_usd  \
# 0    2022-05-03             3.600               NaN               NaN
# 1    2022-05-04             3.600               NaN               NaN
# 2    2022-05-05             3.600               NaN               NaN
# 3    2022-05-06             3.500               NaN               NaN
# 4    2022-05-07             3.500               NaN               NaN
# ...         ...               ...               ...               ...
# 2473 2025-01-27             3.075    2448236242.000        236104.000
# 2474 2025-01-28             2.906    3870713354.000    1144511678.000
# 2475 2025-01-28             2.906    3870713354.000    1144511678.000
# 2476 2025-01-28             2.906    3870713354.000    1144511678.000
# 2477 2025-01-28             2.906    2358738746.000        228446.000
#
#       supply_apy protocol_slug supply_token  borrow_apy borrow_token  \
# 0            NaN           NaN          NaN         NaN          NaN
# 1            NaN           NaN          NaN         NaN          NaN
# 2            NaN           NaN          NaN         NaN          NaN
# 3            NaN           NaN          NaN         NaN          NaN
# 4            NaN           NaN          NaN         NaN          NaN
# ...          ...           ...          ...         ...          ...
# 2473       0.000         spark       WSTETH      12.028          DAI
# 2474       0.182       aave-v3       WSTETH       9.699         USDT
# 2475       0.182       aave-v3       WSTETH       9.681         USDC
# 2476       0.182       aave-v3       WSTETH       9.000          GHO
# 2477       0.000         spark       WSTETH      12.028          DAI
#
#       susde_native_apy  borrow_net_apy  trade_yield
# 0                  NaN             NaN          NaN
# 1                  NaN             NaN          NaN
# 2                  NaN             NaN          NaN
# 3                  NaN             NaN          NaN
# 4                  NaN             NaN          NaN
# ...                ...             ...          ...
# 2473            14.780          -8.953        5.827
# 2474            14.729          -6.611        8.119
# 2475            14.729          -6.593        8.136
# 2476            14.729          -5.912        8.817
# 2477            14.729          -9.122        5.607
#
# [2478 rows x 12 columns]

# %%
import plotly.graph_objects as go

# Define color mapping for the borrow tokens
color_mapping = {
    "DAI": "orange",
    "USDT": "green",
    "USDC": "blue",
    "GHO": "purple"
}

# Filter data for dates starting from Feb 16, 2024
strategy_df_filtered = strategy_df[strategy_df["dt"] >= "2024-02-16"]

# Create the figure
fig = go.Figure()

# Iterate through unique protocol_slug + borrow_token combinations
for (protocol, token) in strategy_df_filtered[["protocol_slug", "borrow_token"]].drop_duplicates().sort_values(by="protocol_slug", ascending=True).itertuples(index=False):
    df_subset = strategy_df_filtered[
        (strategy_df_filtered["protocol_slug"] == protocol) &
        (strategy_df_filtered["borrow_token"] == token)
    ]
    
    fig.add_trace(go.Scatter(
        x=df_subset["dt"],
        y=df_subset["borrow_net_apy"],
        mode="lines",
        name=f"{protocol} - {token}",
        line=dict(
            color=color_mapping.get(token, "gray"),
            width=3 if token == "DAI" else 2 
        )
    ))

# Update layout
fig.update_layout(
    title="Net Cost to Borrow Stables against wstETH",
    xaxis_title="Date",
    yaxis_title="Net Cost to Borrow",
    template="plotly_white",
    margin=dict(t=50, l=25, r=25, b=50),
    legend=dict(
        title="Protocol - Borrow Token",
        yanchor="top",
        y=1.02,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_215.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import plotly.graph_objects as go

# Define color mapping for the borrow tokens
color_mapping = {
    "USDT": "green",
    "USDC": "blue",
    "DAI": "orange"
}

# Define line width mapping (make DAI thicker)
line_width_mapping = {
    "USDT": 2,
    "USDC": 2,
    "DAI": 4  # Thicker line for DAI
}

# Filter data for dates starting from Feb 16, 2024
strategy_df_filtered = strategy_df[
    (strategy_df["dt"] >= "2024-02-16")
    & (strategy_df.borrow_token != "GHO")
]

# Create the figure
fig = go.Figure()

# Iterate through unique protocol_slug + borrow_token combinations
for (protocol, token) in strategy_df_filtered[["protocol_slug", "borrow_token"]].drop_duplicates().itertuples(index=False):
    df_subset = strategy_df_filtered[
        (strategy_df_filtered["protocol_slug"] == protocol) &
        (strategy_df_filtered["borrow_token"] == token)
    ]
    
    fig.add_trace(go.Scatter(
        x=df_subset["dt"],
        y=df_subset["trade_yield"],
        mode="lines",
        name=f"{protocol} - {token}",
        line=dict(
            color=color_mapping.get(token, "gray"),  # Default to gray for unknown tokens
            width=line_width_mapping.get(token, 2)   # Default width is 2 unless specified
        )
    ))

# Update layout
fig.update_layout(
    title="Cost to Supply wstETH, Borrow Stables, and Swap to sUSDe",
    xaxis_title="Date",
    yaxis_title="Trade Yield",
    template="plotly_white",
    margin=dict(t=50, l=25, r=25, b=50),
    legend=dict(
        title="Protocol - Borrow Token",
        yanchor="top",
        y=1.02,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_214.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Pendle

# %%
from op_analytics.coreutils.duckdb_inmem.client import init_client

ctx = init_client()
client = ctx.client

tvl_view = DefiLlama.PROTOCOL_TOKEN_TVL_BREAKDOWN.read(
    min_date="2024-01-01",
)

# Process protocol TVL
df_tvl_breakdown = client.sql(f"""
    SELECT
        *
    FROM {tvl_view}
""").pl().to_pandas()
# Out:
# 2025-01-31 09:36:29 [info     ] Reading data from 'defillama/protocol_token_tvl_breakdown_v1' with filters min_date=2024-01-01, max_date=None, date_range_spec=None filename=dailydata.py lineno=187 process=11019
# 2025-01-31 09:36:29 [info     ] querying markers for 'defillama/protocol_token_tvl_breakdown_v1' DateFilter(min_date=datetime.date(2024, 1, 1), max_date=None, datevals=None) filename=dailydata.py lineno=105 process=11019
# 2025-01-31 09:36:30 [info     ] 1025 markers found             filename=dailydata.py lineno=119 max_dt=2025-01-30 min_dt=2024-01-01 process=11019
# 2025-01-31 09:36:30 [info     ] 396 distinct paths             filename=dailydata.py lineno=129 process=11019
# 2025-01-31 09:36:32 [info     ] registered view: 'defillama_protocol_token_tvl_breakdown_v1' using 396 parquet paths filename=client.py lineno=291 process=11019
# ┌───────────────────────────────────────────┐
# │                   name                    │
# │                  varchar                  │
# ├───────────────────────────────────────────┤
# │ defillama_protocol_token_tvl_breakdown_v1 │
# │ defillama_yield_pools_historical_v1       │
# └───────────────────────────────────────────┘

# %%
df_tvl_breakdown
# Out:
#             protocol_slug               chain   token  app_token_tvl  \
# 0            acala-dollar               Acala     ACA  146394293.350
# 1            acala-dollar               Acala     DOT      18165.438
# 2            acala-dollar               Acala    USDT    6330450.659
# 3         acala-euphrates               Acala     DOT    1110062.013
# 4         acala-euphrates               Acala    LDOT   13013285.527
# ...                   ...                 ...     ...            ...
# 31102326       zkswap-era  zkSync Era-staking    WETH          0.054
# 31102327        zkswap-v2  zkSync Era-staking      ZF  184182035.802
# 31102328   sablier-lockup  zkSync Era-vesting  CHEEMS     250020.000
# 31102329   sablier-lockup  zkSync Era-vesting     ZFI  265598512.505
# 31102330   sablier-lockup  zkSync Era-vesting      ZK     453488.076
#
#           app_token_tvl_usd    protocol_name protocol_category  \
# 0              14709405.807     Acala Dollar               CDP
# 1                148956.595     Acala Dollar               CDP
# 2               6330450.659     Acala Dollar               CDP
# 3               9102508.503  Acala Euphrates             Yield
# 4              14705012.646  Acala Euphrates             Yield
# ...                     ...              ...               ...
# 31102326            167.821       zkSwap Era              Dexs
# 31102327        1099686.472        zkSwap V2              Dexs
# 31102328              0.208   Sablier Lockup          Payments
# 31102329        7151813.642   Sablier Lockup          Payments
# 31102330          63269.749   Sablier Lockup          Payments
#
#           parent_protocol  misrepresented_tokens  is_protocol_misrepresented  \
# 0            acala-dollar                      1                           0
# 1            acala-dollar                      1                           0
# 2            acala-dollar                      1                           0
# 3         acala-euphrates                      1                           0
# 4         acala-euphrates                      1                           0
# ...                   ...                    ...                         ...
# 31102326       zkswap-era                      1                           0
# 31102327   zkswap-finance                      0                           0
# 31102328  sablier-finance                      0                           0
# 31102329  sablier-finance                      0                           0
# 31102330  sablier-finance                      0                           0
#
#           is_double_counted  to_filter_out         dt
# 0                         0              0 2024-01-01
# 1                         0              0 2024-01-01
# 2                         0              0 2024-01-01
# 3                         1              0 2024-01-01
# 4                         1              0 2024-01-01
# ...                     ...            ...        ...
# 31102326                  0              1 2025-01-30
# 31102327                  0              1 2025-01-30
# 31102328                  0              1 2025-01-30
# 31102329                  0              1 2025-01-30
# 31102330                  0              1 2025-01-30
#
# [31102331 rows x 13 columns]

# %%
import plotly.graph_objects as go

# Filter DataFrame for Base chain and Pendle protocol
df_filtered = df_tvl_breakdown[
    (df_tvl_breakdown["chain"] == "Base") &
    (df_tvl_breakdown["parent_protocol"] == "pendle")
]

# Create figure
fig = go.Figure()

# Loop through unique tokens to create separate lines
for token in df_filtered["token"].unique():
    df_subset = df_filtered[df_filtered["token"] == token]
    fig.add_trace(go.Scatter(
        x=df_subset["dt"],
        y=df_subset["app_token_tvl_usd"],
        mode="lines",
        name=token,
        line=dict(width=3)
    ))

# Update layout
fig.update_layout(
    title="Pendle Token TVL Breakdown on Base",
    xaxis_title="Date",
    yaxis_title="TVL (USD)",
    template="plotly_white",
    margin=dict(t=50, l=25, r=25, b=50),
    legend=dict(
        title="Token",
        yanchor="top",
        y=1,
        xanchor="left",
        x=1.02
    )
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_222.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
borrow_df[
    (borrow_df.symbol == "WSTETH")
    & (borrow_df.chain == "Ethereum")
    & (borrow_df.dt >= "2023-01-01")
].protocol_slug.unique()
# Out:
# array(['aave-v3', 'spark', 'makerdao', 'compound-v3', 'morpho-blue',
#        'fluid-lending', 'crvusd', 'strike', 'fraxlend', 'silo-v1',
#        'inverse-finance-firm', 'dforce', 'prismalst', 'gravita-protocol'],
#       dtype=object)

# %%
borrow_df[
    (borrow_df.symbol == "WSTETH")
    & (borrow_df.chain == "Ethereum")
    & (borrow_df.protocol_slug == "spark")
    & (borrow_df.dt >= "2023-01-01")
    & (borrow_df.pool == "d541708e-1283-4feb-bc7a-457fc5f8db2c")
]
# Out:
#                                        pool         dt  total_supply_usd  \
# 12064  d541708e-1283-4feb-bc7a-457fc5f8db2c 2024-11-08         624674139
# 12065  d541708e-1283-4feb-bc7a-457fc5f8db2c 2024-11-09         657591500
# 12066  d541708e-1283-4feb-bc7a-457fc5f8db2c 2024-11-10         659516954
# 12067  d541708e-1283-4feb-bc7a-457fc5f8db2c 2024-11-11         714208367
# 12068  d541708e-1283-4feb-bc7a-457fc5f8db2c 2024-11-12         668385136
# ...                                     ...        ...               ...
# 12142  d541708e-1283-4feb-bc7a-457fc5f8db2c 2025-01-25         778052218
# 12143  d541708e-1283-4feb-bc7a-457fc5f8db2c 2025-01-26         772177209
# 12144  d541708e-1283-4feb-bc7a-457fc5f8db2c 2025-01-27         774567379
# 12145  d541708e-1283-4feb-bc7a-457fc5f8db2c 2025-01-28         750569027
# 12146  d541708e-1283-4feb-bc7a-457fc5f8db2c 2025-01-29         758030650
#
#        total_borrow_usd  debt_ceiling_usd  apy_base  apy_reward  \
# 12064         301385532                 0     0.622       0.000
# 12065         315944660                 0     0.617       0.000
# 12066         323299374                 0     0.642       0.000
# 12067         342235671                 0     0.614       0.000
# 12068         334217528                 0     0.668       0.000
# ...                 ...               ...       ...         ...
# 12142         313612097                 0     0.300       0.000
# 12143         311031751                 0     0.300       0.000
# 12144         298747764                 0     0.275       0.000
# 12145         289064012                 0     0.274       0.000
# 12146         291880806                 0     0.274       0.000
#
#        apy_base_borrow  apy_reward_borrow protocol_slug  ...  symbol  \
# 12064            1.357              0.000       aave-v3  ...  WSTETH
# 12065            1.351              0.000       aave-v3  ...  WSTETH
# 12066            1.379              0.000       aave-v3  ...  WSTETH
# 12067            1.348              0.000       aave-v3  ...  WSTETH
# 12068            1.406              0.000       aave-v3  ...  WSTETH
# ...                ...                ...           ...  ...     ...
# 12142            0.784              0.000       aave-v3  ...  WSTETH
# 12143            0.783              0.000       aave-v3  ...  WSTETH
# 12144            0.750              0.000       aave-v3  ...  WSTETH
# 12145            0.749              0.000       aave-v3  ...  WSTETH
# 12146            0.749              0.000       aave-v3  ...  WSTETH
#
#                                   underlying_tokens reward_tokens il_risk  \
# 12064  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12065  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12066  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12067  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12068  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# ...                                             ...           ...     ...
# 12142  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12143  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12144  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12145  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 12146  [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
#
#       is_stablecoin  exposure borrowable minted_coin borrow_factor  \
# 12064         False    single       True        None           NaN
# 12065         False    single       True        None           NaN
# 12066         False    single       True        None           NaN
# 12067         False    single       True        None           NaN
# 12068         False    single       True        None           NaN
# ...             ...       ...        ...         ...           ...
# 12142         False    single       True        None           NaN
# 12143         False    single       True        None           NaN
# 12144         False    single       True        None           NaN
# 12145         False    single       True        None           NaN
# 12146         False    single       True        None           NaN
#
#          pool_meta
# 12064  lido-market
# 12065  lido-market
# 12066  lido-market
# 12067  lido-market
# 12068  lido-market
# ...            ...
# 12142  lido-market
# 12143  lido-market
# 12144  lido-market
# 12145  lido-market
# 12146  lido-market
#
# [83 rows x 21 columns]

# %%
session = new_session()

# Get all pools data
pools_data = get_data(session, YIELD_POOLS_ENDPOINT)
pools_df = extract_pools_data(pools_data["data"]).to_pandas()
# Out:
# 2025-01-29 10:07:56 [info     ] Fetched from https://pro-api.llama.fi/slPjmq113xSROlwRStlysKOhP0coMlgQkcPd0lgLMV3sL316g8l8CQ/yields/poolsBorrow: 0.20 seconds filename=request.py lineno=81 process=68721

# %%
pools_df
# Out:
#                                       pool protocol_slug     chain  \
# 0     e880e828-ca59-4ec6-8d4f-27182a4dc23d       aave-v3  Ethereum
# 1     db678df9-3281-4bc2-a8bb-01160ffd6d48       aave-v3  Ethereum
# 2     e6435aae-cbe9-4d26-ab2c-a4d533db9972       aave-v3  Ethereum
# 3     7e382157-b1bc-406d-b17b-facba43b716e       aave-v3  Ethereum
# 4     f981a304-bb6c-45b8-b0c5-fd2f515ad23a       aave-v3  Ethereum
# ...                                    ...           ...       ...
# 1644  1806b085-e7d0-4ec9-b293-29c150c7fcf8       silo-v1  Ethereum
# 1645  1e00ac2b-0c3c-4b1f-95be-9378f98d2b40       aave-v3  Ethereum
# 1646  2439cc3f-5984-4e63-a949-8366c35c57a2       silo-v1  Ethereum
# 1647  3c34c22f-79eb-418a-b231-f31b0caf8d61       silo-v1  Ethereum
# 1648  8cdccd5c-7696-4900-8f29-dfd29a6ce37f       silo-v1  Ethereum
#
#                      symbol  \
# 0                      WETH
# 1                     WEETH
# 2                    WSTETH
# 3                      WBTC
# 4                      USDT
# ...                     ...
# 1644                   USDT
# 1645                    GHO
# 1646     PT-WEETH-27JUN2024
# 1647  STKCVXSTETH-NG-F-SILO
# 1648     PT-EZETH-26DEC2024
#
#                                       underlying_tokens reward_tokens il_risk  \
# 0          [0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2]          None      no
# 1          [0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee]          None      no
# 2          [0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0]          None      no
# 3          [0x2260FAC5E5542a773Aa44fBCfeDf7C193bc2C599]          None      no
# 4          [0xdAC17F958D2ee523a2206206994597C13D831ec7]          None      no
# ...                                                 ...           ...     ...
# 1644  [0xdAC17F958D2ee523a2206206994597C13D831ec7, 0...          None      no
# 1645       [0x40D16FC0246aD3160Ccc09B8D0D3A2cD28aE6C2f]          None      no
# 1646  [0xc69Ad9baB1dEE23F4605a82b3354F8E40d1E5966, 0...          None     yes
# 1647  [0x470f9f350642eDF3CB3f2a6eB4569c0219386F0b, 0...          None     yes
# 1648  [0xf7906F274c174A52d444175729E3fa98f9bde285, 0...          None     yes
#
#       is_stablecoin exposure   ltv borrowable minted_coin  borrow_factor
# 0             False   single 0.805       True        None            NaN
# 1             False   single 0.775       True        None            NaN
# 2             False   single 0.785       True        None            NaN
# 3             False   single 0.730       True        None            NaN
# 4              True   single 0.750       True        None            NaN
# ...             ...      ...   ...        ...         ...            ...
# 1644           True   single 0.900       None        None            NaN
# 1645           True   single   NaN       True         GHO            NaN
# 1646          False    multi 0.850       None        None            NaN
# 1647          False    multi 0.850       None        None            NaN
# 1648          False    multi 0.850       None        None            NaN
#
# [1649 rows x 13 columns]

# %%
borrow = pools_data["data"][0]

# %%
/yields/pools

# %%
e880e828-ca59-4ec6-8d4f-27182a4dc23d

# %%
borrow
# Out:
# {'chain': 'Ethereum',
#  'project': 'aave-v3',
#  'symbol': 'WETH',
#  'tvlUsd': 712932922,
#  'apyBase': 1.96095,
#  'apyReward': None,
#  'apy': 1.96095,
#  'rewardTokens': None,
#  'pool': 'e880e828-ca59-4ec6-8d4f-27182a4dc23d',
#  'apyPct1D': 0.05369,
#  'apyPct7D': 0.06972,
#  'apyPct30D': 0.09553,
#  'stablecoin': False,
#  'ilRisk': 'no',
#  'exposure': 'single',
#  'predictions': {'predictedClass': 'Stable/Up',
#   'predictedProbability': 94,
#   'binnedConfidence': 3},
#  'poolMeta': None,
#  'mu': 1.87273,
#  'sigma': 0.01931,
#  'count': 721,
#  'outlier': False,
#  'underlyingTokens': ['0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'],
#  'il7d': None,
#  'apyBase7d': None,
#  'apyMean30d': 1.84372,
#  'volumeUsd1d': None,
#  'volumeUsd7d': None,
#  'apyBaseInception': None,
#  'apyBaseBorrow': 2.63078,
#  'apyRewardBorrow': None,
#  'totalSupplyUsd': 5792539003,
#  'totalBorrowUsd': 5079606082,
#  'debtCeilingUsd': None,
#  'ltv': 0.805,
#  'borrowable': True,
#  'mintedCoin': None,
#  'borrowFactor': None}

# %%
5079606082/(5792539003+712932922)
# Out:
# 0.7808205370127702

# %%
chain_yield_df = pools_df.groupby("chain").agg({"tvl_usd": "sum", "pool": "nunique"}).reset_index()

# %%
chain_yield_df[chain_yield_df.chain.str.contains("zk")]
# Out:
#             chain   tvl_usd  pool
# 28   Cronos_zkevm   2938777     6
# 74  Polygon zkEVM   5193751    47
# 97     zkSync Era  99682496    77

# %%
chain_yield_df[chain_yield_df.tvl_usd > 50_000_000].chain.to_list()
# Out:
# ['Algorand',
#  'Aptos',
#  'Arbitrum',
#  'Avalanche',
#  'BSC',
#  'Base',
#  'Bitcoin',
#  'Cardano',
#  'Core',
#  'Cronos',
#  'Ethereum',
#  'Filecoin',
#  'Flare',
#  'Fraxtal',
#  'Gnosis',
#  'Hedera',
#  'Kava',
#  'Linea',
#  'Mode',
#  'MultiversX',
#  'Optimism',
#  'Osmosis',
#  'Polygon',
#  'Scroll',
#  'Solana',
#  'Sonic',
#  'Starknet',
#  'Sui',
#  'Ton',
#  'Tron',
#  'zkSync Era']

# %%
chain_list = chain_yield_df[chain_yield_df.tvl_usd > 50_000_000].chain.to_list()

pools_df[
    (pools_df.chain.isin(chain_list))
    & (pools_df.tvl_usd < 50_000)
].sample(20)
# Out:
#                                        pool protocol_slug      chain  \
# 18245  e4de64db-c623-440a-8b4a-7959164c0705        kiloex        BSC
# 14740  e148ba96-42b4-4a64-9091-bc3d269c314a    uniswap-v2       Base
# 12417  c7f10b6c-d289-40aa-8db2-79d5c2505327       raydium     Solana
# 15108  8a0be992-6026-4b74-808a-ac98dc44fdde    uniswap-v3   Arbitrum
# 17517  695f07e6-0a68-45f7-a876-ac214647fbf2     cetus-amm        Sui
# 19680  e55861ed-4580-4950-a9f0-1618b93c77c1       raydium     Solana
# 13846  24ecd148-4a08-4196-afde-fe22f07c5a26     cetus-amm        Sui
# 13386  0bea8700-111c-43fc-a564-2c9bd9ebcd78      joe-v2.1   Arbitrum
# 17114  e1a7c8ca-0445-4511-ab84-86139fb4054c       raydium     Solana
# 19172  e7ff2754-dc17-4dba-801a-ad4f2ab7443e       joe-dex  Avalanche
# 15657  5d858a29-a8a1-4277-84ea-2ab7e774ebb8  aerodrome-v1       Base
# 13406  49660b3e-f2df-4956-8bd4-e14549287964  aerodrome-v1       Base
# 14093  3e597581-0d98-46cb-a41c-b814f20fa5c5    uniswap-v2       Base
# 14630  9a23f2c0-37ed-4d45-b8db-8894473e749e    uniswap-v2       Base
# 18560  d6725459-3b64-4bb8-8130-05c6059c3396       raydium     Solana
# 15400  d0b38993-9871-4e71-8ab4-e4564d04d316       raydium     Solana
# 14994  4661180a-3368-49cc-b3c1-3b6efb0d58f9         gamma   Optimism
# 16549  5715e779-d7ac-478f-b12a-3153794b8b16          orca     Solana
# 12492  bbe1f800-c099-4d45-bb50-45d811c410e3     sushiswap   Ethereum
# 16971  5084e22e-4e50-478c-a6ad-d672eb1f717e    uniswap-v2       Base
#
#                 symbol                                  underlying_tokens  \
# 18245          SOLVBTC       [0x4aae823a6a0b376de6a78e74ecc5b079d38cbcf7]
# 14740       TRUMP-WETH  [0x06342c8681498b49cb548c1b6e9213454290e707, 0...
# 12417          WSOL-RF                                               None
# 15108      UXLINK-WETH  [0x1a6b3a62391eccaaa992ade44cd4afe6bec8cff1, 0...
# 17517         PEWS-SUI  [0xace82dd859217d7f3b0cd82ac180449b8de25c4df55...
# 19680      WSOL-FRANCE                                               None
# 13846        USDC-FOMO  [0xdba34672e30cb065b1f93e3ab55318768fd6fef66c1...
# 13386        VEIN-WETH  [0xc4a70668dec1da9862d9d20bf67d1ef4ee182450, 0...
# 17114      WSOL-PSYCHO                                               None
# 19172         MIM-WINE  [0x130966628846bfd36ff31a822705796e8cb8c18d, 0...
# 15657  USDC-SUPEROETHB  [0x833589fCD6eDb6E08f4c7C32D4f71b54bdA02913, 0...
# 13406        RITE-USDC  [0x0808Bf94d57C905F1236212654268EF82E1e594E, 0...
# 14093         WETH-USM  [0x4200000000000000000000000000000000000006, 0...
# 14630       WETH-BRIAN  [0x4200000000000000000000000000000000000006, 0...
# 18560       WSOL-VAULT                                               None
# 15400       WSOL-SILK2                                               None
# 14994         USDC-WLD  [0x7f5c764cbc14f9669b88837ca1490cca17c31607, 0...
# 16549          SNS-SOL  [SNSNkV9zfG5ZKWQs6x4hxvBRV6s8SqMfSGCtECDvdMd, ...
# 12492        BANK-WETH  [0x24a6a37576377f63f194caa5f518a60f45b42921, 0...
# 16971      WETH-JOGECO  [0x4200000000000000000000000000000000000006, 0...
#
#        tvl_usd
# 18245    13213
# 14740    27141
# 12417    49180
# 15108    24506
# 17517    14966
# 19680    10497
# 13846    33917
# 13386    37711
# 17114    16111
# 19172    11263
# 15657    21724
# 13406    37536
# 14093    31910
# 14630    27800
# 18560    12480
# 15400    23005
# 14994    25261
# 16549    18024
# 12492    48012
# 16971    16585

# %%
chain_yield_df[chain_yield_df.chain.str.contains("Ink")]
# Out:
# Empty DataFrame
# Columns: [chain, tvl_usd, pool]
# Index: []

# %%
ctx = init_client()
client = ctx.client

tvl_view = DefiLlama.PROTOCOL_TOKEN_TVL_BREAKDOWN.read(min_date="2024-08-01")

df_protocol_tvl = client.sql(f"""
    SELECT
        *
    FROM {tvl_view}
""").pl().to_pandas()
# Out:
# 2025-01-24 12:32:29 [info     ] Reading data from 'defillama/protocol_token_tvl_breakdown_v1' with filters min_date=2024-08-01, max_date=None, date_range_spec=None filename=dailydata.py lineno=187 process=66595
# 2025-01-24 12:32:29 [info     ] querying markers for 'defillama/protocol_token_tvl_breakdown_v1' DateFilter(min_date=datetime.date(2024, 8, 1), max_date=None, datevals=None) filename=dailydata.py lineno=105 process=66595
# 2025-01-24 12:32:29 [info     ] 391 markers found              filename=dailydata.py lineno=119 max_dt=2025-01-23 min_dt=2024-08-01 process=66595
# 2025-01-24 12:32:29 [info     ] 176 distinct paths             filename=dailydata.py lineno=129 process=66595
# 2025-01-24 12:32:31 [info     ] registered view: 'defillama_protocol_token_tvl_breakdown_v1' using 176 parquet paths filename=client.py lineno=291 process=66595
# ┌───────────────────────────────────────────┐
# │                   name                    │
# │                  varchar                  │
# ├───────────────────────────────────────────┤
# │ defillama_protocol_token_tvl_breakdown_v1 │
# │ defillama_protocols_token_tvl_v1          │
# └───────────────────────────────────────────┘

# %%
YIELD_ENDPOINT = "https://yields.llama.fi/pools"
session = new_session()
yield_data = get_data(session, YIELD_ENDPOINT)

yield_lists = []

for yield_pool in yield_data["data"]:
    chain = yield_pool["chain"]
    project = yield_pool["project"]
    pool = yield_pool["pool"]
    symbol = yield_pool["symbol"]
    underlying_tokens = yield_pool["underlyingTokens"] 
    yield_lists.append(
        {
            "chain_name": chain,
            "protocol_slug": project,
            "pool": pool,
            "symbol": symbol,
            "underlying_tokens": underlying_tokens
        }
    )

df_yield = pd.DataFrame(yield_lists)
# Out:
# 2025-01-24 12:32:51 [info     ] Fetched from https://yields.llama.fi/pools: 0.82 seconds filename=request.py lineno=81 process=66595

# %%
ethena_pool = df_yield[df_yield.protocol_slug == "ethena-usde"].pool.to_list()
aave_pools = df_yield[
    (df_yield.protocol_slug == "aave-v3")
    & (df_yield.chain_name == "Ethereum")
].pool.to_list()

yield_pools = ethena_pool + aave_pools

# %%
YIELD_POOL_ENDPOINT = "https://yields.llama.fi/chart/{pool}"
session = new_session()
yield_data = get_data(session, YIELD_ENDPOINT)

pool_dfs = []
for pool in yield_pools:
    url = YIELD_POOL_ENDPOINT.format(pool=pool)
    pool_chart = get_data(session, url)
    df_pool = pd.DataFrame(pool_chart["data"])
    df_pool["pool"] = pool
    
    pool_dfs.append(df_pool)
# Out:
# 2025-01-24 12:33:07 [info     ] Fetched from https://yields.llama.fi/pools: 0.62 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:08 [info     ] Fetched from https://yields.llama.fi/chart/66985a81-9c51-46ca-9977-42b4fe7bc6df: 0.64 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:08 [info     ] Fetched from https://yields.llama.fi/chart/db678df9-3281-4bc2-a8bb-01160ffd6d48: 0.63 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:09 [info     ] Fetched from https://yields.llama.fi/chart/7e382157-b1bc-406d-b17b-facba43b716e: 0.74 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:10 [info     ] Fetched from https://yields.llama.fi/chart/e6435aae-cbe9-4d26-ab2c-a4d533db9972: 0.76 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:10 [info     ] Fetched from https://yields.llama.fi/chart/d3be212c-f337-40e2-87fc-fb636a3de38f: 0.44 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:11 [info     ] Fetched from https://yields.llama.fi/chart/29932dea-cd71-44c3-95bd-3e1525f4e3dd: 0.54 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:12 [info     ] Fetched from https://yields.llama.fi/chart/f981a304-bb6c-45b8-b0c5-fd2f515ad23a: 0.74 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:12 [info     ] Fetched from https://yields.llama.fi/chart/e880e828-ca59-4ec6-8d4f-27182a4dc23d: 0.74 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:13 [info     ] Fetched from https://yields.llama.fi/chart/aa70268e-4b52-42bf-a116-608b370f9501: 0.75 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:14 [info     ] Fetched from https://yields.llama.fi/chart/b1986007-81f3-4150-9565-94d5a4066ce4: 0.53 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:14 [info     ] Fetched from https://yields.llama.fi/chart/d541708e-1283-4feb-bc7a-457fc5f8db2c: 0.59 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:15 [info     ] Fetched from https://yields.llama.fi/chart/974c8391-3686-4fc9-8477-9df4b618b594: 0.21 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:15 [info     ] Fetched from https://yields.llama.fi/chart/7ee6c38b-ac42-4388-88dc-389140276cf8: 0.71 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:16 [info     ] Fetched from https://yields.llama.fi/chart/b847133f-f5d5-4692-b74e-d815d51988fc: 0.76 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:17 [info     ] Fetched from https://yields.llama.fi/chart/e65588a1-27ad-4e20-9232-68a6cfaccf63: 0.56 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:17 [info     ] Fetched from https://yields.llama.fi/chart/f1a22245-a1f1-4389-8ff2-dde4914b272d: 0.73 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:18 [info     ] Fetched from https://yields.llama.fi/chart/ff2a68af-030c-4697-b0a1-b62a738eaef0: 0.64 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:19 [info     ] Fetched from https://yields.llama.fi/chart/ef8c5c38-6a41-4383-9dc8-6fb31e69a0c9: 0.53 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:19 [info     ] Fetched from https://yields.llama.fi/chart/c4f1e434-3386-4f48-b0ac-dc89782dfa55: 0.53 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:20 [info     ] Fetched from https://yields.llama.fi/chart/f4b334a3-1724-450f-b06f-4163e566a950: 0.61 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:20 [info     ] Fetched from https://yields.llama.fi/chart/e043585f-923f-4009-934f-005232f34a27: 0.67 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:21 [info     ] Fetched from https://yields.llama.fi/chart/d25b5f1e-3368-4c79-a876-479834b15195: 0.58 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:21 [info     ] Fetched from https://yields.llama.fi/chart/55205d7a-7939-42aa-ad8a-0c0123db9474: 0.52 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:22 [info     ] Fetched from https://yields.llama.fi/chart/30d7bddf-9c7b-4495-a34a-e8d4ab1ff5c3: 0.56 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:33:23 [info     ] Fetched from https://yields.llama.fi/chart/3665ee7e-6c5d-49d9-abb7-c47ab5d9d4ac: 0.73 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:24 [info     ] Fetched from https://yields.llama.fi/chart/c5af4fbd-932d-40c5-8ee4-6b45ee691b76: 61.24 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:24 [info     ] Fetched from https://yields.llama.fi/chart/fdf02dc0-c38d-4850-8d61-74668d281325: 0.43 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:25 [info     ] Fetched from https://yields.llama.fi/chart/334605f4-c559-4545-8819-5e123a3686fa: 0.64 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:26 [info     ] Fetched from https://yields.llama.fi/chart/21e1ac8a-b3aa-4576-9506-0b40137721a0: 0.67 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:27 [info     ] Fetched from https://yields.llama.fi/chart/9a73da78-b8e5-4325-bc35-6732dd9f9d64: 0.71 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:27 [info     ] Fetched from https://yields.llama.fi/chart/9932d2d8-1e4e-4248-9307-4f99c7e466a8: 0.74 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:28 [info     ] Fetched from https://yields.llama.fi/chart/475e0e56-2648-4b75-82cb-e82f5983787a: 0.64 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:29 [info     ] Fetched from https://yields.llama.fi/chart/d118f505-e75f-4152-bad3-49a2dc7482bf: 0.61 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:29 [info     ] Fetched from https://yields.llama.fi/chart/a214e900-2bcd-431f-9744-632fa5436fee: 0.68 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:30 [info     ] Fetched from https://yields.llama.fi/chart/4a2ded3a-3667-40a8-a9b2-503b6d357b49: 0.69 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:30 [info     ] Fetched from https://yields.llama.fi/chart/1a1780eb-febf-4083-8788-b9aca19da68e: 0.54 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:31 [info     ] Fetched from https://yields.llama.fi/chart/ef897898-4a03-4e06-8e81-5c26139c7b5b: 0.67 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:32 [info     ] Fetched from https://yields.llama.fi/chart/ef8fbf02-ac96-4453-a78c-37bda4cd65e3: 0.69 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:32 [info     ] Fetched from https://yields.llama.fi/chart/effcb4a4-4dcb-45e5-935d-f15542c13e6b: 0.51 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:37 [info     ] Fetched from https://yields.llama.fi/chart/f4a63672-f7ae-400c-b4b3-7cfe704d2daf: 4.90 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:38 [info     ] Fetched from https://yields.llama.fi/chart/814326a1-e8f9-4dcd-9b35-952350ab74f7: 0.26 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:42 [info     ] Fetched from https://yields.llama.fi/chart/d2e98d69-238c-41a8-8899-15aee7358e33: 4.90 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:43 [info     ] Fetched from https://yields.llama.fi/chart/4ef4eb9a-e22e-4190-b8f3-8c75373ad0d6: 0.65 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:44 [info     ] Fetched from https://yields.llama.fi/chart/b6fdb4b4-569c-4e1d-a5a6-ed9885e04c60: 0.53 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:48 [info     ] Fetched from https://yields.llama.fi/chart/45d6af39-ed10-4002-8b4b-e5da908bdb75: 4.66 seconds filename=request.py lineno=81 process=66595
# 2025-01-24 12:34:49 [info     ] Fetched from https://yields.llama.fi/chart/1e00ac2b-0c3c-4b1f-95be-9378f98d2b40: 0.54 seconds filename=request.py lineno=81 process=66595

# %%
df_pools = pd.concat(pool_dfs)

# %%
df_pools = pd.merge(
    df_pools,
    df_yield,
    on="pool",
    how="left"
)

# %%
pool_counts = df_pools.groupby(["pool", "symbol"]).agg({"timestamp": "nunique"}).reset_index().sort_values(by="symbol")

# %%
symbols = [
    'CBBTC',
    'CBETH',
    'CRVUSD',
    'ETHX',
    'FRAX',
    'LUSD',
    'OSETH',
    'PYUSD',
    'RETH',
    'SUSDE',
    'TBTC',
    'USDC',
    'USDE',
    'USDS',
    'USDT',
    'WBTC',
    'WEETH',
    'WETH',
    'WSTETH'
]

# %%
pools_to_use = (
    pool_counts[
    (pool_counts.timestamp > 40) # manual filter, need to understand what's happening 
    & pool_counts.symbol.isin(symbols)
    & (pool_counts.pool != "29932dea-cd71-44c3-95bd-3e1525f4e3dd")
    ].pool.to_list()
)

# %%
df_pools["slug_symbol"] = df_pools["symbol"] + "-" + df_pools["protocol_slug"]

# %%
df_pools = df_pools.sort_values(by=["pool", "timestamp"])
df_pools["timestamp"] = pd.to_datetime(df_pools["timestamp"], utc=True)

df_pools["apy_7d_rolling_avg"] = df_pools.groupby("pool").apply(
    lambda group: group.sort_values("timestamp").rolling("7d", on="timestamp")["apy"].mean()
).reset_index(level=0, drop=True)

# %%
df_pools["timestamp"] = pd.to_datetime(df_pools["timestamp"])

# Create the line plot
fig = px.line(
    df_pools[
       df_pools.pool.isin(pools_to_use)
        & (df_pools.timestamp >= "2024-09-01")
        & (df_pools.symbol.isin(["USDE", "SUSDE", "USDT", "USDC"]))
    ]
    ,
    x="timestamp",
    y="apy_7d_rolling_avg",
    color="symbol",
    title="Yield pool APY over time",
    labels={"dt": "Date", "app_token_tvl_usd": "TVL (USD)", "symbol": "Token"},
)

# Customize layout for better visualization
fig.update_layout(
    template="plotly_white",
    xaxis_title="Date",
    yaxis_title="TVL (USD)",
    legend_title="Token",
    margin=dict(t=50, l=25, r=25, b=50),
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_18.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# drop duplicates due to an ongoing data upload issue
df_all = pd.merge(
    df_metadata.drop_duplicates(), 
    df_protocol_tvl.drop_duplicates(), 
    on="protocol_slug",
    how="left"
)

# %%
# Merge data and join alignment and token categories
df_all = pd.merge(df_all, alignment_df, on="chain", how="left")
df_all["alignment"] = df_all["alignment"].fillna("Other")
df_all = pd.merge(df_all, token_categories, on="token", how="left")
df_all["token_category"] = df_all["token_category"].fillna("Other")

# %%
# Chain level misrepresented tokens
df_misrep = (
    df_all[df_all.dt == df_all["dt"].max()-pd.Timedelta(days=1)]
    [["protocol_slug", "chain", "misrepresented_tokens", "token"]]
    .groupby(["protocol_slug", "chain", "misrepresented_tokens"])
    .agg(
        token_count=("token", "nunique"),
        has_usdt=("token", lambda x: 1 if "USDT" in x.values else 0)
    )
    .reset_index()
)

df_misrep["chain_misrepresented_tokens"] = (
    (df_misrep["misrepresented_tokens"] == 1) 
    & (df_misrep["token_count"] == 1) 
    & (df_misrep["has_usdt"] == 1)
).astype(int)

df_all = pd.merge(
    df_all, 
    df_misrep[["protocol_slug", "chain", "chain_misrepresented_tokens"]], 
    on=["protocol_slug", "chain"],
    how="left"
)

# %%
protocol_slug = "aave-v3"

# %%
df_borrow = df_all[
    (df_all.dt >= "2023-12-15")
    # & (df_all.chain.str.contains("borrow"))
    & (df_all.chain == "Ethereum-borrowed")
    & (df_all.protocol_slug == protocol_slug)
    # & (df_all.token_category == "Stablecoins")
    # & (df_all.token.isin(["SUSDE", "USDT", "USDC", "DAI"]))
].groupby(["dt", "protocol_name", "token"]).agg({"app_token_tvl_usd": "sum"}).reset_index()

# %%
df_borrow["token"] = df_borrow["token"] + "_borrowed"

# %%
df_lending = df_all[
    (df_all.dt >= "2023-12-15")
    # & (df_all.chain.str.contains("borrow"))
    & (df_all.chain == "Ethereum")
    & (df_all.protocol_slug == protocol_slug)
    # & (df_all.token_category == "Stablecoins")
    & (df_all.token.isin(["SUSDE", "USDT", "USDC"]))

].groupby(["dt", "protocol_name", "token"]).agg({"app_token_tvl_usd": "sum"}).reset_index()

# %%
df_lending_borrow = pd.concat([df_lending, df_borrow])

# %%
df_lending_borrow["dt"] = pd.to_datetime(df_lending_borrow["dt"])

# Create the line plot
fig = px.line(
    df_lending_borrow[
        (df_lending_borrow.token.isin(["SUSDE", "USDT", "USDC", "USDE"]))
        & (df_lending_borrow.dt >= "2024-06-15")
    ]
    ,
    x="dt",
    y="app_token_tvl_usd",
    color="token",
    title="App Token TVL (USD) Over Time",
    labels={"dt": "Date", "app_token_tvl_usd": "TVL (USD)", "token": "Token"},
)

# Customize layout for better visualization
fig.update_layout(
    template="plotly_white",
    xaxis_title="Date",
    yaxis_title="TVL (USD)",
    legend_title="Token",
    margin=dict(t=50, l=25, r=25, b=50),
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# Filter data for the pools and lending data
df_pools_filtered = df_pools[
    df_pools["pool"].isin(pools_to_use) &
    (df_pools["timestamp"] >= "2024-06-01") &
    (df_pools["symbol"].isin(["USDE", "SUSDE", "USDT", "USDC"]))
]

df_lending_borrow_filtered = df_lending_borrow[
    (df_lending_borrow["token"] == "SUSDE") &
    (df_lending_borrow["dt"] >= "2024-06-15")
]

# Create the figure for the SUSDE Lending TVL first (dashed black line)
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=df_lending_borrow_filtered["dt"],
        y=df_lending_borrow_filtered["app_token_tvl_usd"],
        mode="lines",
        name="sUSDe AAVE Lending TVL",
        line=dict(color="black", width=2, dash="dash"),
        yaxis="y2"
    )
)

# Add the lines for the lending APY
color_mapping = {
    "SUSDE": "black",         # SUSDE Ethena APY (solid black)
    "USDE": "gray",           # USDE Lending APY (gray)
    "USDT": "green",          # USDT Lending APY (green)
    "USDC": "blue"            # USDC Lending APY (blue)
}

label_mapping = {
    "SUSDE": "sUSDe Ethena Native APY",
    "USDE": "USDe AAVE Lending APY",
    "USDT": "USDT AAVE Lending APY",
    "USDC": "USDC AAVE Lending APY"
}

for symbol in ["SUSDE", "USDE", "USDT", "USDC"]:
    filtered_df = df_pools_filtered[df_pools_filtered["symbol"] == symbol]
    fig.add_trace(
        go.Scatter(
            x=filtered_df["timestamp"],
            y=filtered_df["apy_7d_rolling_avg"],
            mode="lines",
            name=label_mapping[symbol],
            line=dict(color=color_mapping[symbol], width=2)
        )
    )

# Update layout to include a secondary y-axis and adjust the legend position
fig.update_layout(
    template="plotly_white",
    xaxis_title="Date",
    yaxis_title="APY (%)",
    yaxis2=dict(
        title="Lending TVL (USD)",
        overlaying="y",
        side="right",
        showgrid=False
    ),
    legend=dict(
        x=1.05,  # Move the legend slightly to the right
        y=1,     # Align the legend to the top
        xanchor="left", 
        yanchor="top"
    ),
    margin=dict(t=50, l=25, r=50, b=50),
)

# Show plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_42.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
