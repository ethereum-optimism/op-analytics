# %%
from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.platform_metrics import execute
import os
with write_to_prod():
    result = execute.execute_pull()
# Out:
# 2025-06-03 14:58:20 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=5367
# 2025-06-03 14:58:20 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=5367
# /Users/bellaokiddy/Documents/Github/op-analytics/src/op_analytics/coreutils/postgres/client.py:112: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return pl.DataFrame(data, schema=columns)
# 2025-06-03 15:02:25 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=5367
# 2025-06-03 15:02:25 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=5367
# 2025-06-03 15:02:36 [info     ] Fetched from https://prometheus-blocks-prod-us-central1.grafana.net/api/prom/api/v1/query_range: 1.22 seconds filename=request.py lineno=100 process=5367
# 2025-06-03 15:02:36 [info     ] Prometheus range query executed duration=1.23s filename=client.py lineno=112 process=5367 query='sum(increase(nat_tests_total[1d  ]))'
# 2025-06-03 15:02:36 [info     ] done writing 4.0Krows 107.1KB  filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-28/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=4025 size=107138
# 2025-06-03 15:02:36 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:40 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:40 [info     ] done writing 4.3Krows 114.8KB  filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-29/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=4328 size=114767
# 2025-06-03 15:02:40 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:41 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:41 [info     ] done writing 5.6Krows 146.9KB  filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-30/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=5624 size=146917
# 2025-06-03 15:02:41 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:43 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:43 [info     ] done writing 137rows 8.3KB     filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-31/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=137 size=8252
# 2025-06-03 15:02:43 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:44 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:44 [info     ] done writing 229rows 10.4KB    filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-01/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=229 size=10372
# 2025-06-03 15:02:44 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:46 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:46 [info     ] done writing 5.1Krows 130.5KB  filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-02/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=5051 size=130533
# 2025-06-03 15:02:46 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:48 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:48 [info     ] done writing 635rows 20.9KB    filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-03/out.parquet' process=5367 root=platformmetrics/platform_metrics_jobs_v1 rows=635 size=20945
# 2025-06-03 15:02:48 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:49 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-03 15:02:49 [info     ] done writing 87rows 7.3KB      filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-05-28/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=87 size=7309
# 2025-06-03 15:02:49 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:50 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:50 [info     ] done writing 92rows 7.5KB      filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-05-29/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=92 size=7494
# 2025-06-03 15:02:50 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:51 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:51 [info     ] done writing 120rows 9.0KB     filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-05-30/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=120 size=8988
# 2025-06-03 15:02:51 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:53 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:53 [info     ] done writing 3rows 2.5KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-05-31/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=3 size=2545
# 2025-06-03 15:02:53 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:54 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:54 [info     ] done writing 5rows 2.7KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-01/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=5 size=2715
# 2025-06-03 15:02:54 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:55 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:55 [info     ] done writing 105rows 8.2KB     filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-02/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=105 size=8183
# 2025-06-03 15:02:55 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:58 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:58 [info     ] done writing 18rows 3.4KB      filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-03/out.parquet' process=5367 root=platformmetrics/platform_metrics_pipelines_v1 rows=18 size=3430
# 2025-06-03 15:02:58 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:59 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-03 15:02:59 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-05-28/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:02:59 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:00 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:00 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-05-29/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:03:00 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:01 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:01 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-05-30/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:03:01 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:02 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:03 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-05-31/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:03:03 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:04 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:04 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-01/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:03:04 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:05 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:05 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-02/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:03:05 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:06 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:07 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=917667840 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-03/out.parquet' process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-03 15:03:07 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=917.67 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-03 15:03:08 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=5367 root=platformmetrics/platform_metrics_prometheus_metrics_v1
