# %%
from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.platform_metrics import execute
import os
with write_to_prod():
    result = execute.execute_pull()
# Out:
# 2025-05-26 12:43:49 [info     ] loaded vault from .env file    filename=vault.py lineno=32 process=26048
# 2025-05-26 12:43:49 [debug    ] loaded vault: 28 items         filename=vault.py lineno=79 process=26048
# 2025-05-26 12:43:49 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=26048
# 2025-05-26 12:43:50 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=26048
# /Users/bellaokiddy/Documents/Github/op-analytics/src/op_analytics/coreutils/postgres/client.py:112: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return pl.DataFrame(data, schema=columns)
# 2025-05-26 12:45:37 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=26048
# 2025-05-26 12:45:37 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=26048
# 2025-05-26 12:45:46 [info     ] Fetched from https://prometheus-blocks-prod-us-central1.grafana.net/api/prom/api/v1/query_range: 1.08 seconds filename=request.py lineno=100 process=26048
# 2025-05-26 12:45:46 [info     ] Prometheus range query executed duration=1.08s filename=client.py lineno=112 process=26048 query='sum(increase(nat_tests_total[1d  ]))'
# 2025-05-26 12:45:46 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:46 [info     ] Initialized gcsfs client for bucket=gs://oplabs-tools-data-sink filename=gcs_parquet.py lineno=32 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:46 [info     ] done writing 3.1Krows 87.7KB   filename=gcs_parquet.py lineno=57 maxrss=870957056 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-20/out.parquet' process=26048 root=platformmetrics/platform_metrics_jobs_v1 rows=3059 size=87694
# 2025-05-26 12:45:46 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=870.96 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:48 [debug    ] connecting to OPLABS Clickhouse client... filename=client.py lineno=56 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:50 [debug    ] initialized OPLABS Clickhouse client. filename=client.py lineno=61 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:50 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:50 [info     ] done writing 3.6Krows 96.3KB   filename=gcs_parquet.py lineno=57 maxrss=870957056 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-21/out.parquet' process=26048 root=platformmetrics/platform_metrics_jobs_v1 rows=3613 size=96288
# 2025-05-26 12:45:50 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=870.96 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:52 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:52 [info     ] done writing 4.8Krows 128.0KB  filename=gcs_parquet.py lineno=57 maxrss=870957056 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-22/out.parquet' process=26048 root=platformmetrics/platform_metrics_jobs_v1 rows=4835 size=127982
# 2025-05-26 12:45:52 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=870.96 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:54 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:54 [info     ] done writing 3.5Krows 91.8KB   filename=gcs_parquet.py lineno=57 maxrss=870957056 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-23/out.parquet' process=26048 root=platformmetrics/platform_metrics_jobs_v1 rows=3458 size=91758
# 2025-05-26 12:45:54 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=870.96 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:57 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:57 [info     ] done writing 174rows 9.3KB     filename=gcs_parquet.py lineno=57 maxrss=870957056 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-05-24/out.parquet' process=26048 root=platformmetrics/platform_metrics_jobs_v1 rows=174 size=9260
# 2025-05-26 12:45:57 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=870.96 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45:58 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=26048 root=platformmetrics/platform_metrics_jobs_v1
# 2025-05-26 12:45