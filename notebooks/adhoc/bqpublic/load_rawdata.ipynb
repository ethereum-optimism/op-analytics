# %%
import os

# Override to force BQ write.
os.environ["OPLABS_ENV"] = "prod"

from op_analytics.datapipeline.etl.loadbq.main import (
    load_superchain_raw_to_bq,
)

result = load_superchain_raw_to_bq(
    range_spec="@20250422:20250429",
    dryrun=False,
    force_complete=True,
    force_not_ready=True,
)
# Out:
# 2025-04-29 14:55:20 [debug    ] connecting to GOLDSKY Clickhouse client... counter=001/027 env=PROD eta=None filename=client.py lineno=56 process=32927
# 2025-04-29 14:55:20 [info     ] loaded vault from .env file    counter=001/027 env=PROD eta=None filename=vault.py lineno=32 process=32927
# 2025-04-29 14:55:20 [debug    ] loaded vault: 21 items         counter=001/027 env=PROD eta=None filename=vault.py lineno=79 process=32927
# 2025-04-29 14:55:21 [debug    ] initialized GOLDSKY Clickhouse client. counter=001/027 env=PROD eta=None filename=client.py lineno=61 process=32927
# 2025-04-29 14:55:23 [info     ] querying markers at time range min: 2025-04-22 00:00:00, max: 2025-04-29 00:00:00 root_paths=['ingestion/blocks_v1', 'ingestion/logs_v1', 'ingestion/traces_v1', 'ingestion/transactions_v1'] env=PROD filename=request.py lineno=146 process=32927
# 2025-04-29 14:55:23 [debug    ] connecting to OPLABS Clickhouse client... env=PROD filename=client.py lineno=56 process=32927
# 2025-04-29 14:55:23 [debug    ] initialized OPLABS Clickhouse client. env=PROD filename=client.py lineno=61 process=32927
# 2025-04-29 14:55:24 [info     ] prepared 189 input dt,chain readers env=PROD filename=bydate.py lineno=92 process=32927
# 2025-04-29 14:55:24 [info     ] pre-fetched 84 markers         env=PROD filename=construct.py lineno=66 process=32927
# 2025-04-29 14:55:24 [info     ] Consolidated to 7 dateval tasks. env=PROD filename=construct.py lineno=139 process=32927
# 2025-04-29 14:55:24 [info     ] forced execution despite complete markers date=2025-04-22 env=PROD filename=load.py lineno=70 process=32927 task=1/7
# 2025-04-29 14:55:24 [info     ] BEGIN Loading 811 files to superchain_raw.blocks date=2025-04-22 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/blocks task=1/7
# 2025-04-29 14:55:24 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) date=2025-04-22 env=PROD filename=gcpauth.py lineno=18 process=32927 root=superchain_raw/blocks task=1/7
# 2025-04-29 14:56:06 [info     ] WRITE_TRUNCATE to BQ superchain_raw.blocks$20250422 date=2025-04-22 env=PROD filename=load.py lineno=63 process=32927 root=superchain_raw/blocks task=1/7
# 2025-04-29 14:56:06 [info     ] DONE Loading 811 files to superchain_raw.blocks date=2025-04-22 env=PROD filename=loader.py lineno=123 process=32927 root=superchain_raw/blocks task=1/7
# 2025-04-29 14:56:06 [debug    ] done writing superchain_raw/blocks to BIGQUERY date=2025-04-22 env=PROD filename=writemanager.py lineno=131 process=32927 root=superchain_raw/blocks task=1/7
# 2025-04-29 14:56:06 [info     ] task                           date=2025-04-22 env=PROD filename=load.py lineno=75 process=32927 status=success task=1/7
# 2025-04-29 14:56:06 [info     ] BEGIN Loading 811 files to superchain_raw.logs date=2025-04-22 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/logs task=1/7
# 2025-04-29 14:56:43 [info     ] WRITE_TRUNCATE to BQ superchain_raw.logs$20250422 date=2025-04-22 env=PROD filename=load.py lineno=63 process=32927 root=superchain_raw/logs task=1/7
# 2025-04-29 14:56:43 [info     ] DONE Loading 811 files to superchain_raw.logs date=2025-04-22 env=PROD filename=loader.py lineno=123 process=32927 root=superchain_raw/logs task=1/7
# 2025-04-29 14:56:43 [debug    ] done writing superchain_raw/logs to BIGQUERY date=2025-04-22 env=PROD filename=writemanager.py lineno=131 process=32927 root=superchain_raw/logs task=1/7
# 2025-04-29 14:56:43 [info     ] task                           date=2025-04-22 env=PROD filename=load.py lineno=75 process=32927 status=success task=1/7
# 2025-04-29 14:56:43 [info     ] BEGIN Loading 811 files to superchain_raw.traces date=2025-04-22 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/traces task=1/7
# 2025-04-29 14:57:47 [info     ] WRITE_TRUNCATE to BQ superchain_raw.traces$20250422 date=2025-04-22 env=PROD filename=load.py lineno=63 process=32927 root=superchain_raw/traces task=1/7
# 2025-04-29 14:57:47 [info     ] DONE Loading 811 files to superchain_raw.traces date=2025-04-22 env=PROD filename=loader.py lineno=123 process=32927 root=superchain_raw/traces task=1/7
# 2025-04-29 14:57:47 [debug    ] done writing superchain_raw/traces to BIGQUERY date=2025-04-22 env=PROD filename=writemanager.py lineno=131 process=32927 root=superchain_raw/traces task=1/7
# 2025-04-29 14:57:47 [info     ] task                           date=2025-04-22 env=PROD filename=load.py lineno=75 process=32927 status=success task=1/7
# 2025-04-29 14:57:47 [info     ] BEGIN Loading 811 files to superchain_raw.transactions date=2025-04-22 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/transactions task=1/7
# 2025-04-29 14:58:23 [info     ] WRITE_TRUNCATE to BQ superchain_raw.transactions$20250422 date=2025-04-22 env=PROD filename=load.py lineno=63 process=32927 root=superchain_raw/transactions task=1/7
# 2025-04-29 14:58:23 [info     ] DONE Loading 811 files to superchain_raw.transactions date=2025-04-22 env=PROD filename=loader.py lineno=123 process=32927 root=superchain_raw/transactions task=1/7
# 2025-04-29 14:58:24 [debug    ] done writing superchain_raw/transactions to BIGQUERY date=2025-04-22 env=PROD filename=writemanager.py lineno=131 process=32927 root=superchain_raw/transactions task=1/7
# 2025-04-29 14:58:24 [info     ] task                           date=2025-04-22 env=PROD filename=load.py lineno=75 process=32927 status=success task=1/7
# 2025-04-29 14:58:24 [info     ] forced execution despite complete markers date=2025-04-23 env=PROD filename=load.py lineno=70 process=32927 task=2/7
# 2025-04-29 14:58:24 [info     ] BEGIN Loading 812 files to superchain_raw.blocks date=2025-04-23 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/blocks task=2/7
# 2025-04-29 14:58:51 [info     ] WRITE_TRUNCATE to BQ superchain_raw.blocks$20250423 date=2025-04-23 env=PROD filename=load.py lineno=63 process=32927 root=superchain_raw/blocks task=2/7
# 2025-04-29 14:58:51 [info     ] DONE Loading 812 files to superchain_raw.blocks date=2025-04-23 env=PROD filename=loader.py lineno=123 process=32927 root=superchain_raw/blocks task=2/7
# 2025-04-29 14:58:51 [debug    ] done writing superchain_raw/blocks to BIGQUERY date=2025-04-23 env=PROD filename=writemanager.py lineno=131 process=32927 root=superchain_raw/blocks task=2/7
# 2025-04-29 14:58:51 [info     ] task                           date=2025-04-23 env=PROD filename=load.py lineno=75 process=32927 status=success task=2/7
# 2025-04-29 14:58:51 [info     ] BEGIN Loading 812 files to superchain_raw.logs date=2025-04-23 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/logs task=2/7
# 2025-04-29 14:59:28 [info     ] WRITE_TRUNCATE to BQ superchain_raw.logs$20250423 date=2025-04-23 env=PROD filename=load.py lineno=63 process=32927 root=superchain_raw/logs task=2/7
# 2025-04-29 14:59:28 [info     ] DONE Loading 812 files to superchain_raw.logs date=2025-04-23 env=PROD filename=loader.py lineno=123 process=32927 root=superchain_raw/logs task=2/7
# 2025-04-29 14:59:28 [debug    ] done writing superchain_raw/logs to BIGQUERY date=2025-04-23 env=PROD filename=writemanager.py lineno=131 process=32927 root=superchain_raw/logs task=2/7
# 2025-04-29 14:59:28 [info     ] task                           date=2025-04-23 env=PROD filename=load.py lineno=75 process=32927 status=success task=2/7
# 2025-04-29 14:59:28 [info     ] BEGIN Loading 812 files to superchain_raw.traces date=2025-04-23 env=PROD filename=loader.py lineno=112 process=32927 root=superchain_raw/traces task=2/7
