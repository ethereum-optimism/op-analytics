# %%
# %load_ext autoreload
# %autoreload 2


from dataclasses import dataclass
from decimal import Decimal
from typing import Optional

import polars as pl
from op_analytics.coreutils.bigquery.write import (
    most_recent_dates,
)
from op_analytics.coreutils.logger import structlog
from op_analytics.coreutils.request import get_data, new_session
from op_analytics.coreutils.threads import run_concurrently
from op_analytics.coreutils.time import dt_fromepoch, now_dt

from op_analytics.datasources.defillama.dataaccess import DefiLlama

log = structlog.get_logger()

SUMMARY_ENDPOINT = "https://stablecoins.llama.fi/stablecoins?includePrices=true"
BREAKDOWN_ENDPOINT = "https://stablecoins.llama.fi/stablecoin/{id}"


BALANCES_TABLE_LAST_N_DAYS = 7  # upsert only the last 7 days of balances fetched from the api


MUST_HAVE_METADATA_FIELDS = [
    "id",
    "name",
    "address",
    "symbol",
    "url",
    "pegType",
    "pegMechanism",
]

OPTIONAL_METADATA_FIELDS = [
    "description",
    "mintRedeemDescription",
    "onCoinGecko",
    "gecko_id",
    "cmcId",
    "priceSource",
    "twitter",
    "price",
]

METADATA_DF_SCHEMA = {
    "id": pl.String,
    "name": pl.String,
    "address": pl.String,
    "symbol": pl.String,
    "url": pl.String,
    "pegType": pl.String,
    "pegMechanism": pl.String,
    "description": pl.String,
    "mintRedeemDescription": pl.String,
    "onCoinGecko": pl.String,
    "gecko_id": pl.String,
    "cmcId": pl.String,
    "priceSource": pl.String,
    "twitter": pl.String,
    "price": pl.Float64,
}

BALANCES_DF_SCHEMA = {
    "id": pl.String(),
    "chain": pl.String(),
    "dt": pl.String(),
    "circulating": pl.Decimal(scale=18),
    "bridged_to": pl.Decimal(scale=18),
    "minted": pl.Decimal(scale=18),
    "unreleased": pl.Decimal(scale=18),
    "name": pl.String(),
    "symbol": pl.String(),
}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
@dataclass
class DefillamaStablecoins:
    """Metadata and balances for all stablecoins.

    This is the result we obtain after fetching from the API and extracting the data
    that we need to ingest.
    """

    metadata_df: pl.DataFrame
    balances_df: pl.DataFrame


def construct_urls(stablecoins_summary, symbols: list[str] | None) -> dict[str, str]:
    """Build the collection of urls that we will fetch from DefiLlama.

    Args:
        symbols: list of symbols to process. Defaults to None (process all).
    """
    urls = {}
    for stablecoin in stablecoins_summary:
        stablecoin_symbol = stablecoin["symbol"]
        stablecoin_id = stablecoin["id"]
        if symbols is None or stablecoin_symbol in symbols:
            urls[stablecoin_id] = BREAKDOWN_ENDPOINT.format(id=stablecoin_id)

    if not urls:
        raise ValueError("No valid stablecoin IDs provided.")
    return urls


def pull_stablecoins(symbols: list[str] | None = None) -> DefillamaStablecoins:
    """
    Pulls and processes stablecoin data from DeFiLlama.

    Args:
        stablecoin_ids: list of stablecoin IDs to process. Defaults to None (process all).
    """
    session = new_session()

    # Call the summary endpoint to find the list of stablecoins tracked by DefiLLama.
    summary = get_data(session, SUMMARY_ENDPOINT)
    stablecoins_summary = summary["peggedAssets"]

    # Call the API endpoint for each stablecoin in parallel.
    urls = construct_urls(stablecoins_summary, symbols=symbols)
    stablecoins_data = run_concurrently(lambda x: get_data(session, x), urls, max_workers=4)

    # Extract all the balances (includes metadata).
    result = extract(stablecoins_data)

    # Write metadata.
    DefiLlama.STABLECOINS_METADATA.write(
        dataframe=result.metadata_df.with_columns(dt=pl.lit(now_dt())),
        sort_by=["symbol"],
    )

    # Write balances.
    DefiLlama.STABLECOINS_BALANCE.write(
        dataframe=most_recent_dates(result.balances_df, n_dates=BALANCES_TABLE_LAST_N_DAYS),
        sort_by=["symbol", "chain"],
    )

    return result


def execute_pull():
    result = pull_stablecoins()
    return {
        "metadata_df": len(result.metadata_df),
        "balances_df": len(result.balances_df),
    }


def extract(stablecoins_data) -> DefillamaStablecoins:
    """Extract metadata and balances for all stablecoins."""
    metadata: list[dict] = []
    balances: list[dict] = []
    for stablecoin_id, data in stablecoins_data.items():
        assert stablecoin_id == data["id"]
        metadata_row, balance_rows = single_stablecoin_balances(data)

        if not metadata_row:
            raise ValueError(f"No metadata for stablecoin={data['name']}")

        if not balance_rows:
            raise ValueError(f"No balances for stablecoin={data['name']}")

        metadata.append(metadata_row)
        balances.extend(balance_rows)

    metadata_df = pl.DataFrame(metadata, infer_schema_length=len(metadata))
    balances_df = pl.DataFrame(balances, schema=BALANCES_DF_SCHEMA)

    # Schema assertions to help our future selves reading this code.
    assert metadata_df.schema == METADATA_DF_SCHEMA
    assert balances_df.schema == BALANCES_DF_SCHEMA

    return DefillamaStablecoins(metadata_df=metadata_df, balances_df=balances_df)


def single_stablecoin_metadata(data: dict) -> dict:
    """Extract metadata for a single stablecoin.

    Will fail if the response data from the API is missing any of the "must-have"
    metadata fields.

    Args:
        data: Data for this stablecoin as returned by the API

    Returns:
        The metadata dictionary.
    """
    metadata: dict[str, Optional[str]] = {}

    # Collect required metadata fields
    for key in MUST_HAVE_METADATA_FIELDS:
        metadata[key] = data[key]

    # Collect additional optional metadata fields
    for key in OPTIONAL_METADATA_FIELDS:
        metadata[key] = data.get(key)

    return metadata


def safe_decimal(float_val):
    """Safely convert DefiLLama balance values to Decimal.

    Balance values can be int or float. This function converts values to Decimal,
    so we don't have to rely on polars schema inference.
    """
    if float_val is None:
        return None

    return Decimal(str(float_val))


def single_stablecoin_balances(data: dict) -> tuple[dict, list[dict]]:
    """Extract balances for a single stablecoin.

    Args:
        data: Data for this stablecoin as returned by the API

    Returns:
        Tuple of metadata dict and balances for this stablecoin.
        Each item in balances is one data point obtained from DefiLlama.
    """
    metadata = single_stablecoin_metadata(data)
    peg_type: str = data["pegType"]

    def get_value(_datapoint, _metric_name):
        """Helper to get a nested dict key with fallback."""
        return _datapoint.get(_metric_name, {}).get(peg_type)

    balances = []

    for chain, balance in data["chainBalances"].items():
        tokens = balance.get("tokens", [])

        for datapoint in tokens:
            row = {
                "id": data["id"],
                "chain": chain,
                "dt": dt_fromepoch(datapoint["date"]),
                "circulating": safe_decimal(get_value(datapoint, "circulating")),
                "bridged_to": safe_decimal(get_value(datapoint, "bridgedTo")),
                "minted": safe_decimal(get_value(datapoint, "minted")),
                "unreleased": safe_decimal(get_value(datapoint, "unreleased")),
                "name": metadata["name"],
                "symbol": metadata["symbol"],
            }
            balances.append(row)

    return metadata, balances

# %%
result = pull_stablecoins()
# Out:
# 2025-01-17 12:54:02 [info     ] Fetched from https://stablecoins.llama.fi/stablecoins?includePrices=true: 0.18 seconds filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:02 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/3: 0.18 seconds counter=003/212 eta=None filename=request.py lineno=81 process=55515
# 2025-01-17 12:54
212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/173: 0.08 seconds counter=162/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/175: 0.08 seconds counter=164/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/176: 0.05 seconds counter=165/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/174: 0.12 seconds counter=163/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/177: 0.06 seconds counter=166/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/178: 0.05 seconds counter=167/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/179: 0.05 seconds counter=168/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/181: 0.06 seconds counter=170/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/180: 0.08 seconds counter=169/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/183: 0.05 seconds counter=172/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/182: 0.07 seconds counter=171/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/184: 0.07 seconds counter=173/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/186: 0.06 seconds counter=175/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/187: 0.08 seconds counter=176/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/185: 0.10 seconds counter=174/212 eta=2 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/189: 0.05 seconds counter=178/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/188: 0.07 seconds counter=177/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:06 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/190: 0.05 seconds counter=179/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/191: 0.08 seconds counter=180/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/192: 0.07 seconds counter=181/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/195: 0.06 seconds counter=183/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/193: 0.08 seconds counter=182/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/196: 0.07 seconds counter=184/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/198: 0.05 seconds counter=186/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/199: 0.05 seconds counter=187/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/197: 0.07 seconds counter=185/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/200: 0.05 seconds counter=188/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/201: 0.06 seconds counter=189/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/202: 0.06 seconds counter=190/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/203: 0.07 seconds counter=191/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/204: 0.05 seconds counter=192/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/206: 0.05 seconds counter=194/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/205: 0.06 seconds counter=193/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/207: 0.05 seconds counter=195/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/208: 0.05 seconds counter=196/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/209: 0.04 seconds counter=197/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/211: 0.04 seconds counter=199/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/210: 0.05 seconds counter=198/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/212: 0.05 seconds counter=200/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/213: 0.04 seconds counter=201/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/214: 0.05 seconds counter=202/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/215: 0.05 seconds counter=203/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/216: 0.05 seconds counter=204/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/217: 0.05 seconds counter=205/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/219: 0.05 seconds counter=207/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/218: 0.08 seconds counter=206/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/221: 0.05 seconds counter=209/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/220: 0.06 seconds counter=208/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/222: 0.05 seconds counter=210/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/223: 0.05 seconds counter=211/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:07 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/224: 0.04 seconds counter=212/212 eta=1 secs filename=request.py lineno=81 process=55515
# 2025-01-17 12:54:09 [info     ] done writing 212rows 49.2KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_metadata_v1/dt=2025-01-17/out.parquet process=55515 root=defillama/stablecoins_metadata_v1 rows=212 size=49154
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_metadata_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_metadata_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_metadata_v1
# 2025-01-17 12:54:09 [info     ] done writing 757rows 23.4KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-11/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=757 size=23439
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [info     ] done writing 757rows 23.5KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-12/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=757 size=23461
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [info     ] done writing 756rows 23.4KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-13/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=756 size=23382
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [info     ] done writing 757rows 23.4KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-14/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=757 size=23415
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [info     ] done writing 759rows 23.4KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-15/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=759 size=23423
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [info     ] done writing 759rows 23.5KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-16/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=759 size=23501
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [info     ] done writing 806rows 25.9KB    filename=gcs_parquet.py lineno=57 maxrss=1890484224 path=ozone/warehouse/defillama/stablecoins_balances_v1/dt=2025-01-17/out.parquet process=55515 root=defillama/stablecoins_balances_v1 rows=806 size=25862
# 2025-01-17 12:54:09 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1890.48 process=55515 root=defillama/stablecoins_balances_v1
# 2025-01-17 12:54:09 [debug    ] done writing defillama/stablecoins_balances_v1 to LOCAL filename=writehelper.py lineno=131 process=55515 root=defillama/stablecoins_balances_v1

# %%
metadata_df
# Out:
# 'metadata_df'

# %%
result.balances_df.to_pandas()
# Out:
#          id     chain          dt                 circulating  \
# 0         3  Optimism  2022-06-03   100326.000000000000000000
# 1         3  Optimism  2022-06-04   100326.000000000000000000
# 2         3  Optimism  2022-06-05   100326.000000000000000000
# 3         3  Optimism  2022-06-06   100326.000000000000000000
# 4         3  Optimism  2022-06-07   100326.000000000000000000
# ...     ...       ...         ...                         ...
# 480066  224   Fraxtal  2025-01-13  1652496.000000000000000000
# 480067  224   Fraxtal  2025-01-14  1652496.000000000000000000
# 480068  224   Fraxtal  2025-01-15  1652496.000000000000000000
# 480069  224   Fraxtal  2025-01-16  1656943.000000000000000000
# 480070  224   Fraxtal  2025-01-17  1675275.396589000000000000
#
#                        bridged_to                      minted unreleased  \
# 0       100326.000000000000000000                        None       None
# 1       100326.000000000000000000                        None       None
# 2       100326.000000000000000000                        None       None
# 3       100326.000000000000000000                        None       None
# 4       100326.000000000000000000                        None       None
# ...                           ...                         ...        ...
# 480066                       None  1652496.000000000000000000       None
# 480067                       None  1652496.000000000000000000       None
# 480068                       None  1652496.000000000000000000       None
# 480069                       None  1656943.000000000000000000       None
# 480070                      0E-18  1675275.396589000000000000      0E-18
#
#                    name symbol
# 0       TerraClassicUSD   USTC
# 1       TerraClassicUSD   USTC
# 2       TerraClassicUSD   USTC
# 3       TerraClassicUSD   USTC
# 4       TerraClassicUSD   USTC
# ...                 ...    ...
# 480066     dTRINITY USD   dUSD
# 480067     dTRINITY USD   dUSD
# 480068     dTRINITY USD   dUSD
# 480069     dTRINITY USD   dUSD
# 480070     dTRINITY USD   dUSD
#
# [480071 rows x 9 columns]

# %%
from op_analytics.datasources.defillama.tvl_breakdown_enrichment import DefillamaTVLBreakdown

# %%
test = DefillamaTVLBreakdown.of_date("2025-01-01")
# Out:
# 2025-01-17 13:09:00 [info     ] Reading data from 'defillama/protocols_metadata_v1' with filters min_date=2024-12-31, max_date=2025-01-01, date_range_spec=None filename=dailydata.py lineno=188 process=55515
# 2025-01-17 13:09:00 [info     ] querying markers for 'defillama/protocols_metadata_v1' DateFilter(min_date=datetime.date(2024, 12, 31), max_date=datetime.date(2025, 1, 1), datevals=None) filename=dailydata.py lineno=105 process=55515
# 2025-01-17 13:09:01 [info     ] 1 markers found                filename=dailydata.py lineno=119 max_dt=2024-12-31 min_dt=2024-12-31 process=55515
# 2025-01-17 13:09:01 [info     ] 1 distinct paths               filename=dailydata.py lineno=129 process=55515
# 2025-01-17 13:09:02 [info     ] registered view: 'defillama_protocols_metadata_v1' using 1 parquet paths filename=client.py lineno=273 process=55515
# ┌──────────────────────────────────┐
# │               name               │
# │             varchar              │
# ├──────────────────────────────────┤
# │ defillama_protocols_metadata_v1  │
# │ defillama_protocols_token_tvl_v1 │
# └──────────────────────────────────┘
#
# 2025-01-17 13:09:02 [info     ] Reading data from 'defillama/protocols_token_tvl_v1' with filters min_date=2024-12-25, max_date=2025-01-01, date_range_spec=None filename=dailydata.py lineno=188 process=55515
# 2025-01-17 13:09:02 [info     ] querying markers for 'defillama/protocols_token_tvl_v1' DateFilter(min_date=datetime.date(2024, 12, 25), max_date=datetime.date(2025, 1, 1), datevals=None) filename=dailydata.py lineno=105 process=55515
# 2025-01-17 13:09:03 [info     ] 57 markers found               filename=dailydata.py lineno=119 max_dt=2024-12-31 min_dt=2024-12-25 process=55515
# 2025-01-17 13:09:03 [info     ] 7 distinct paths               filename=dailydata.py lineno=129 process=55515
# 2025-01-17 13:09:04 [info     ] registered view: 'defillama_protocols_token_tvl_v1' using 7 parquet paths filename=client.py lineno=273 process=55515
# ┌──────────────────────────────────┐
# │               name               │
# │             varchar              │
# ├──────────────────────────────────┤
# │ defillama_protocols_metadata_v1  │
# │ defillama_protocols_token_tvl_v1 │
# └──────────────────────────────────┘
#
# shape: (5, 12)
# ┌────────────┬────────────┬──────────┬─────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ dt         ┆ protocol_s ┆ chain    ┆ token   ┆ … ┆ parent_pr ┆ misrepres ┆ is_protoc ┆ is_double │
# │ ---        ┆ lug        ┆ ---      ┆ ---     ┆   ┆ otocol    ┆ ented_tok ┆ ol_misrep ┆ _counted  │
# │ datetime[μ ┆ ---        ┆ str      ┆ str     ┆   ┆ ---       ┆ ens       ┆ resented  ┆ ---       │
# │ s]         ┆ str        ┆          ┆         ┆   ┆ str       ┆ ---       ┆ ---       ┆ i8        │
# │            ┆            ┆          ┆         ┆   ┆           ┆ i32       ┆ i32       ┆           │
# ╞════════════╪════════════╪══════════╪═════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2024-12-29 ┆ nolus-prot ┆ Osmosis  ┆ OSMO    ┆ … ┆ nolus-pro ┆ 0         ┆ 0         ┆ 0         │
# │ 00:00:00   ┆ ocol       ┆          ┆         ┆   ┆ tocol     ┆           ┆           ┆           │
# │ 2024-12-26 ┆ uniswap-v3 ┆ Ethereum ┆ CBETH   ┆ … ┆ uniswap   ┆ 0         ┆ 0         ┆ 0         │
# │ 00:00:00   ┆            ┆          ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2024-12-29 ┆ axelar     ┆ Osmosis  ┆ LVN     ┆ … ┆ axelar    ┆ 0         ┆ 0         ┆ 1         │
# │ 00:00:00   ┆            ┆          ┆         ┆   ┆           ┆           ┆           ┆           │
# │ 2024-12-30 ┆ archly-v1  ┆ Optimism ┆ WETH    ┆ … ┆ archly-fi ┆ 0         ┆ 0         ┆ 0         │
# │ 00:00:00   ┆            ┆          ┆         ┆   ┆ nance     ┆           ┆           ┆           │
# │ 2024-12-27 ┆ alex       ┆ Stacks   ┆ WGIGGLE ┆ … ┆ alex      ┆ 0         ┆ 0         ┆ 0         │
# │ 00:00:00   ┆            ┆          ┆         ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴──────────┴─────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
test.df_tvl_breakdown.to_pandas()
# Out:
#                dt   protocol_slug     chain    token  app_token_tvl  \
# 0      2024-12-29  nolus-protocol   Osmosis     OSMO   5.972255e+05
# 1      2024-12-26      uniswap-v3  Ethereum    CBETH   2.498653e+03
# 2      2024-12-29          axelar   Osmosis      LVN   6.808130e+02
# 3      2024-12-30       archly-v1  Optimism     WETH   1.067000e-02
# 4      2024-12-27            alex    Stacks  WGIGGLE   5.142357e+09
# ...           ...             ...       ...      ...            ...
# 679905 2024-12-26     pangea-swap    Klaytn      SSX   1.000000e+01
# 679906 2024-12-27        betfolio   Polygon     USDC   5.753800e+03
# 679907 2024-12-29       curve-dex  Ethereum    SUSDX   4.757654e+05
# 679908 2024-12-28     balancer-v2   Polygon      BCT   7.357508e+01
# 679909 2024-12-25      uniswap-v3  Ethereum      DIP   2.097409e+07
#
#         app_token_tvl_usd   protocol_name  protocol_category parent_protocol  \
# 0            2.786774e+05  Nolus Protocol            Lending  nolus-protocol
# 1            9.436688e+06      Uniswap V3              Dexes         uniswap
# 2            9.397300e+00          Axelar             Bridge          axelar
# 3            3.622993e+01       Archly V1              Dexes  archly-finance
# 4            3.298479e+03            ALEX              Dexes            alex
# ...                   ...             ...                ...             ...
# 679905       3.720000e-03     Pangea Swap              Dexes     pangea-swap
# 679906       5.759554e+03        BetFolio  Prediction Market        betfolio
# 679907       4.988083e+05       Curve DEX              Dexes   curve-finance
# 679908       2.902625e+01     Balancer V2              Dexes        balancer
# 679909       2.936909e+05      Uniswap V3              Dexes         uniswap
#
#         misrepresented_tokens  is_protocol_misrepresented  is_double_counted  \
# 0                           0                           0                  0
# 1                           0                           0                  0
# 2                           0                           0                  1
# 3                           0                           0                  0
# 4                           0                           0                  0
# ...                       ...                         ...                ...
# 679905                      0                           0                  0
# 679906                      0                           0                  0
# 679907                      0                           0                  0
# 679908                      0                           0                  0
# 679909                      0                           0                  0
#
#         to_filter_out
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 679905              0
# 679906              0
# 679907              0
# 679908              0
# 679909              0
#
# [679910 rows x 13 columns]
