# %%
from op_analytics.datasources.defillama import stablecoins

result = stablecoins.execute_pull()
# Out:
# 2025-01-24 22:03:12 [info     ] Fetched from https://stablecoins.llama.fi/stablecoins?includePrices=true: 0.07 seconds filename=request.py lineno=81 process=54379
# 2025-01-24 22:03:12 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/3: 0.06 seconds counter=003/215 eta=None filename=request.py lineno=81 process=54379
# 2025-01-24 22:03:12 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/1: 0.08 seconds counter=001/215 eta=None filename=request.py lineno=81 process=54379
# 2025-01-24 22:03:12 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/4: 0.18 seconds counter=004/215 eta=None filename=request.py lineno=81 process=54379
# 2025-01-24 22:03:12 [info     ] Fetched from https://stablecoins.llama.fi/stablecoin/5: 0.14 seconds counter=005/215 eta=None filename=request.py lineno=81 process=54379
# ...
