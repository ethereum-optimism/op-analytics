# %%
from op_analytics.datapipeline.etl.blockbatchload.clickhouse.main import load_to_clickhouse


df = load_to_clickhouse(range_spec="@20250120:+1")
# Out:
# 2025-01-28 07:34:29 [debug    ] connecting to OPLABS Clickhouse client... filename=client.py lineno=37 process=95085
# 2025-01-28 07:34:29 [info     ] loaded vault from .env file    filename=vault.py lineno=32 process=95085
# 2025-01-28 07:34:29 [debug    ] loaded vault: 18 items         filename=vault.py lineno=79 process=95085
# 2025-01-28 07:34:30 [debug    ] initialized OPLABS Clickhouse client. filename=client.py lineno=42 process=95085
# 2025-01-28 07:34:30 [info     ] 300/300 markers pending load to Clickhouse. filename=main.py lineno=24 process=95085
# 2025-01-28 07:34:30 [info     ] Prepared 300 insert tasks.     filename=main.py lineno=54 process=95085
# 2025-01-28 07:34:30 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025270800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:30 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=211333 read_rows=117 written_bytes=1950084 written_rows=117
# 2025-01-28 07:34:30 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025271200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:31 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=272679 read_rows=229 written_bytes=4480213 written_rows=229
# 2025-01-28 07:34:31 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025271600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:31 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=274360 read_rows=183 written_bytes=3534528 written_rows=183
# 2025-01-28 07:34:31 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025272000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:32 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=198213 read_rows=187 written_bytes=3160989 written_rows=187
# 2025-01-28 07:34:32 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025272400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:32 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=250987 read_rows=170 written_bytes=3242543 written_rows=170
# 2025-01-28 07:34:32 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025272800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:33 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=281203 read_rows=168 written_bytes=3646873 written_rows=168
# 2025-01-28 07:34:33 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025273200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:33 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=124250 read_rows=99 written_bytes=1977219 written_rows=99
# 2025-01-28 07:34:34 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025274000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:35 [info     ] insert results                 elapsed_s=1.4 filename=insert.py lineno=101 process=95085 read_bytes=228330 read_rows=171 written_bytes=2999095 written_rows=171
# 2025-01-28 07:34:35 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025274400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:35 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=153721 read_rows=116 written_bytes=2311751 written_rows=116
# 2025-01-28 07:34:36 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025275600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:36 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=171171 read_rows=179 written_bytes=3341520 written_rows=179
# 2025-01-28 07:34:36 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025276000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:37 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=205033 read_rows=220 written_bytes=4163865 written_rows=220
# 2025-01-28 07:34:37 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025276400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:37 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=290546 read_rows=237 written_bytes=4839610 written_rows=237
# 2025-01-28 07:34:37 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025276800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:38 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=90931 read_rows=21 written_bytes=305849 written_rows=21
# 2025-01-28 07:34:38 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025277200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:38 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=254370 read_rows=232 written_bytes=4473174 written_rows=232
# 2025-01-28 07:34:38 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025277600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:39 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=218571 read_rows=204 written_bytes=3766218 written_rows=204
# 2025-01-28 07:34:39 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025278000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:39 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=373254 read_rows=258 written_bytes=5533716 written_rows=258
# 2025-01-28 07:34:39 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025278400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:40 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=216357 read_rows=216 written_bytes=4069813 written_rows=216
# 2025-01-28 07:34:40 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025278800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:40 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=195425 read_rows=251 written_bytes=3855984 written_rows=251
# 2025-01-28 07:34:40 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025279200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:41 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=207270 read_rows=212 written_bytes=3983466 written_rows=212
# 2025-01-28 07:34:41 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025279600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:41 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=205519 read_rows=271 written_bytes=4446758 written_rows=271
# 2025-01-28 07:34:41 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025280000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:42 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=234164 read_rows=243 written_bytes=5027282 written_rows=243
# 2025-01-28 07:34:42 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025280400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:34:42 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=282308 read_rows=280 written_bytes=5790198 written_rows=280
# 2025-01-28 07:34:42 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000
[info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025304000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:17 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=281229 read_rows=311 written_bytes=6754712 written_rows=311
# 2025-01-28 07:35:17 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025304400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:17 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=399472 read_rows=4779 written_bytes=9636853 written_rows=4779
# 2025-01-28 07:35:18 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025304800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:18 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=651915 read_rows=8018 written_bytes=11312082 written_rows=8018
# 2025-01-28 07:35:18 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025305200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:19 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=351293 read_rows=3197 written_bytes=8198497 written_rows=3197
# 2025-01-28 07:35:19 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025305600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:19 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=375685 read_rows=2222 written_bytes=9246064 written_rows=2222
# 2025-01-28 07:35:19 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025306000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:20 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=375373 read_rows=649 written_bytes=8048623 written_rows=649
# 2025-01-28 07:35:20 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025306400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:20 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=293083 read_rows=402 written_bytes=8418567 written_rows=402
# 2025-01-28 07:35:20 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025306800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:21 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=348113 read_rows=375 written_bytes=7337932 written_rows=375
# 2025-01-28 07:35:21 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025307200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:21 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=361307 read_rows=1196 written_bytes=7272875 written_rows=1196
# 2025-01-28 07:35:22 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025307600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:24 [info     ] insert results                 elapsed_s=2.0 filename=insert.py lineno=101 process=95085 read_bytes=270416 read_rows=331 written_bytes=6317416 written_rows=331
# 2025-01-28 07:35:24 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025308000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:24 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=245581 read_rows=318 written_bytes=6157118 written_rows=318
# 2025-01-28 07:35:24 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025308400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:25 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=248364 read_rows=361 written_bytes=7622189 written_rows=361
# 2025-01-28 07:35:25 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025308800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:25 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=462379 read_rows=350 written_bytes=8230865 written_rows=350
# 2025-01-28 07:35:25 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025309200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:26 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=295293 read_rows=279 written_bytes=5517967 written_rows=279
# 2025-01-28 07:35:26 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025309600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:26 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=277596 read_rows=326 written_bytes=5950532 written_rows=326
# 2025-01-28 07:35:27 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025310000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:27 [info     ] insert results                 elapsed_s=0.5 filename=insert.py lineno=101 process=95085 read_bytes=400478 read_rows=319 written_bytes=6189812 written_rows=319
# 2025-01-28 07:35:27 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025310400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:28 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=283419 read_rows=281 written_bytes=5116763 written_rows=281
# 2025-01-28 07:35:28 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025310800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:28 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=292978 read_rows=281 written_bytes=6517893 written_rows=281
# 2025-01-28 07:35:28 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025311200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:29 [info     ] insert results                 elapsed_s=0.8 filename=insert.py lineno=101 process=95085 read_bytes=257378 read_rows=288 written_bytes=5673868 written_rows=288
# 2025-01-28 07:35:29 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025311600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:30 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=347557 read_rows=318 written_bytes=6184452 written_rows=318
# 2025-01-28 07:35:30 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025312000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:30 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=214216 read_rows=240 written_bytes=4847332 written_rows=240
# 2025-01-28 07:35:30 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025312400.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:31 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=476710 read_rows=299 written_bytes=7181292 written_rows=299
# 2025-01-28 07:35:31 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025312800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:31 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=278106 read_rows=239 written_bytes=5605163 written_rows=239
# 2025-01-28 07:35:31 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025313200.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:32 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=275496 read_rows=290 written_bytes=6743133 written_rows=290
# 2025-01-28 07:35:32 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025313600.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:32 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=260212 read_rows=240 written_bytes=5450777 written_rows=240
# 2025-01-28 07:35:32 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=base/dt=2025-01-20/000025314000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:33 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=102211 read_rows=86 written_bytes=1821433 written_rows=86
# 2025-01-28 07:35:33 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=bob/dt=2025-01-20/000012232000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:35:33 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=3440 read_rows=1 written_bytes=792 written_rows=1
# 2025-01-28 07:35:33 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain
[info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=77765 read_rows=1740 written_bytes=3344461 written_rows=1740
# 2025-01-28 07:37:06 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=worldchain/dt=2025-01-20/000009040000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:07 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=79325 read_rows=1820 written_bytes=3498624 written_rows=1820
# 2025-01-28 07:37:08 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=worldchain/dt=2025-01-20/000009040800.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:08 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=22716 read_rows=404 written_bytes=776700 written_rows=404
# 2025-01-28 07:37:09 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025312000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:09 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=38944 read_rows=96 written_bytes=2870172 written_rows=96
# 2025-01-28 07:37:09 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025320000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:10 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=147202 read_rows=472 written_bytes=11866629 written_rows=472
# 2025-01-28 07:37:10 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025328000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:10 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=155865 read_rows=1071 written_bytes=22069982 written_rows=1071
# 2025-01-28 07:37:10 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025336000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:11 [info     ] insert results                 elapsed_s=0.5 filename=insert.py lineno=101 process=95085 read_bytes=212366 read_rows=1389 written_bytes=34208169 written_rows=1389
# 2025-01-28 07:37:11 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025344000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:11 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=157852 read_rows=912 written_bytes=26605155 written_rows=912
# 2025-01-28 07:37:12 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025352000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:12 [info     ] insert results                 elapsed_s=0.4 filename=insert.py lineno=101 process=95085 read_bytes=133976 read_rows=761 written_bytes=22165102 written_rows=761
# 2025-01-28 07:37:12 [info     ] using gcs path: https://storage.googleapis.com/oplabs-tools-data-sink/blockbatch/contract_creation/create_traces_v1/chain=zora/dt=2025-01-20/000025360000.parquet filename=inferschema.py lineno=18 process=95085
# 2025-01-28 07:37:13 [info     ] insert results                 elapsed_s=0.3 filename=insert.py lineno=101 process=95085 read_bytes=57354 read_rows=231 written_bytes=8284575 written_rows=231

# %%
len(df)
# Out:
# 300

# %%
df
# Out:
# [{'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25270800,
#   'written_rows': 117},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25271200,
#   'written_rows': 229},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25271600,
#   'written_rows': 183},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25272000,
#   'written_rows': 187},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25272400,
#   'written_rows': 170},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25272800,
#   'written_rows': 168},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25273200,
#   'written_rows': 99},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25274000,
#   'written_rows': 171},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25274400,
#   'written_rows': 116},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25275600,
#   'written_rows': 179},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25276000,
#   'written_rows': 220},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25276400,
#   'written_rows': 237},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25276800,
#   'written_rows': 21},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25277200,
#   'written_rows': 232},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25277600,
#   'written_rows': 204},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25278000,
#   'written_rows': 258},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25278400,
#   'written_rows': 216},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25278800,
#   'written_rows': 251},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25279200,
#   'written_rows': 212},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25279600,
#   'written_rows': 271},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25280000,
#   'written_rows': 243},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25280400,
#   'written_rows': 280},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25280800,
#   'written_rows': 277},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25281200,
#   'written_rows': 291},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25281600,
#   'written_rows': 227},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25282000,
#   'written_rows': 294},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25282400,
#   'written_rows': 290},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25282800,
#   'written_rows': 362},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25283200,
#   'written_rows': 281},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25283600,
#   'written_rows': 250},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25284000,
#   'written_rows': 265},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25284400,
#   'written_rows': 347},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25284800,
#   'written_rows': 293},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25285200,
#   'written_rows': 365},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25285600,
#   'written_rows': 350},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25286000,
#   'written_rows': 366},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25286400,
#   'written_rows': 320},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25286800,
#   'written_rows': 268},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25287200,
#   'written_rows': 372},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25287600,
#   'written_rows': 870},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25288000,
#   'written_rows': 385},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25288400,
#   'written_rows': 361},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25288800,
#   'written_rows': 335},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25289200,
#   'written_rows': 378},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25289600,
#   'written_rows': 371},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25290000,
#   'written_rows': 331},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25290400,
#   'written_rows': 360},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25290800,
#   'written_rows': 410},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25291200,
#   'written_rows': 335},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25291600,
#   'written_rows': 453},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25292000,
#   'written_rows': 418},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25292400,
#   'written_rows': 410},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25292800,
#   'written_rows': 408},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25293200,
#   'written_rows': 400},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25293600,
#   'written_rows': 397},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25294000,
#   'written_rows': 652},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25294400,
#   'written_rows': 344},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25294800,
#   'written_rows': 338},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25295200,
#   'written_rows': 372},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25295600,
#   'written_rows': 327},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25296000,
#   'written_rows': 335},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25296400,
#   'written_rows': 360},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25296800,
#   'written_rows': 371},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25297200,
#   'written_rows': 384},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25297600,
#   'written_rows': 339},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25298000,
#   'written_rows': 355},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25298400,
#   'written_rows': 425},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25298800,
#   'written_rows': 315},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25299200,
#   'written_rows': 338},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25299600,
#   'written_rows': 357},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25300000,
#   'written_rows': 309},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25300400,
#   'written_rows': 269},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25300800,
#   'written_rows': 289},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25301200,
#   'written_rows': 295},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25301600,
#   'written_rows': 408},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25302000,
#   'written_rows': 346},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25302400,
#   'written_rows': 306},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25302800,
#   'written_rows': 292},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25303200,
#   'written_rows': 285},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25303600,
#   'written_rows': 314},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25304000,
#   'written_rows': 311},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25304400,
#   'written_rows': 4779},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25304800,
#   'written_rows': 8018},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25305200,
#   'written_rows': 3197},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25305600,
#   'written_rows': 2222},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25306000,
#   'written_rows': 649},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25306400,
#   'written_rows': 402},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25306800,
#   'written_rows': 375},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25307200,
#   'written_rows': 1196},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25307600,
#   'written_rows': 331},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25308000,
#   'written_rows': 318},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25308400,
#   'written_rows': 361},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25308800,
#   'written_rows': 350},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25309200,
#   'written_rows': 279},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25309600,
#   'written_rows': 326},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25310000,
#   'written_rows': 319},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25310400,
#   'written_rows': 281},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25310800,
#   'written_rows': 281},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25311200,
#   'written_rows': 288},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25311600,
#   'written_rows': 318},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25312000,
#   'written_rows': 240},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25312400,
#   'written_rows': 299},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25312800,
#   'written_rows': 239},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25313200,
#   'written_rows': 290},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25313600,
#   'written_rows': 240},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'base',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25314000,
#   'written_rows': 86},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'bob',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12232000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'bob',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12240000,
#   'written_rows': 9},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'bob',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12248000,
#   'written_rows': 8},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'bob',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12256000,
#   'written_rows': 17},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'bob',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12264000,
#   'written_rows': 23},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'bob',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12272000,
#   'written_rows': 5},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'cyber',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11968000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'cyber',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11976000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'cyber',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11992000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'fraxtal',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 15264000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'fraxtal',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 15272000,
#   'written_rows': 16},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'fraxtal',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 15280000,
#   'written_rows': 8},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'fraxtal',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 15288000,
#   'written_rows': 9},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'fraxtal',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 15296000,
#   'written_rows': 4},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ham',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20736000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ham',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20752000,
#   'written_rows': 3},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ham',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20768000,
#   'written_rows': 5},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ham',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20776000,
#   'written_rows': 3},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ham',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20792000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3832000,
#   'written_rows': 35},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3840000,
#   'written_rows': 44},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3848000,
#   'written_rows': 59},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3856000,
#   'written_rows': 75},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3864000,
#   'written_rows': 78},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3872000,
#   'written_rows': 77},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3880000,
#   'written_rows': 110},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3888000,
#   'written_rows': 89},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3896000,
#   'written_rows': 121},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3904000,
#   'written_rows': 80},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'ink',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3912000,
#   'written_rows': 43},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lisk',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11296000,
#   'written_rows': 7},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lisk',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11304000,
#   'written_rows': 96},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lisk',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11312000,
#   'written_rows': 26},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lisk',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11320000,
#   'written_rows': 24},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lisk',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11328000,
#   'written_rows': 44},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lisk',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 11336000,
#   'written_rows': 51},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18652000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18656000,
#   'written_rows': 9},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18660000,
#   'written_rows': 13},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18664000,
#   'written_rows': 14},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18668000,
#   'written_rows': 60},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18672000,
#   'written_rows': 58},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18676000,
#   'written_rows': 22},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18680000,
#   'written_rows': 38},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18684000,
#   'written_rows': 24},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18688000,
#   'written_rows': 16},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18692000,
#   'written_rows': 16},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'lyra',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18696000,
#   'written_rows': 4},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'metal',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12904000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mint',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 10856000,
#   'written_rows': 13},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mint',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 10864000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mint',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 10872000,
#   'written_rows': 7},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mint',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 10880000,
#   'written_rows': 17},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mint',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 10888000,
#   'written_rows': 4},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mint',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 10896000,
#   'written_rows': 7},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18580000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18582000,
#   'written_rows': 12},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18584000,
#   'written_rows': 9},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18586000,
#   'written_rows': 11},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18588000,
#   'written_rows': 12},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18590000,
#   'written_rows': 4},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18592000,
#   'written_rows': 7},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18594000,
#   'written_rows': 6},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18596000,
#   'written_rows': 13},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18598000,
#   'written_rows': 30},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18600000,
#   'written_rows': 35},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18602000,
#   'written_rows': 33},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18604000,
#   'written_rows': 30},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18606000,
#   'written_rows': 33},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18608000,
#   'written_rows': 30},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18610000,
#   'written_rows': 38},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18612000,
#   'written_rows': 27},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18614000,
#   'written_rows': 19},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18616000,
#   'written_rows': 23},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18618000,
#   'written_rows': 15},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18620000,
#   'written_rows': 27},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18622000,
#   'written_rows': 31},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'mode',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 18624000,
#   'written_rows': 3},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130866000,
#   'written_rows': 904},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130868000,
#   'written_rows': 1389},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130870000,
#   'written_rows': 1317},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130872000,
#   'written_rows': 7581},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130874000,
#   'written_rows': 1260},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130876000,
#   'written_rows': 18036},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130878000,
#   'written_rows': 6663},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130880000,
#   'written_rows': 20038},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130882000,
#   'written_rows': 22339},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130884000,
#   'written_rows': 23770},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130886000,
#   'written_rows': 18388},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130888000,
#   'written_rows': 5491},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130890000,
#   'written_rows': 2715},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130892000,
#   'written_rows': 3409},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130894000,
#   'written_rows': 4100},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130896000,
#   'written_rows': 4091},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130898000,
#   'written_rows': 4058},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130900000,
#   'written_rows': 4324},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130902000,
#   'written_rows': 4735},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130904000,
#   'written_rows': 4419},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130906000,
#   'written_rows': 3339},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'op',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 130908000,
#   'written_rows': 1528},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'orderly',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20380000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'orderly',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 20385000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'polynomial',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9640000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'polynomial',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9648000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'polynomial',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9656000,
#   'written_rows': 4},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'polynomial',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9664000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'polynomial',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9672000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12580000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12584000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12592000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12596000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12600000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12604000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12608000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'redstone',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 12612000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'shape',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 7808000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'shape',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 7816000,
#   'written_rows': 3},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'soneium',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2096000,
#   'written_rows': 59},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'soneium',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2104000,
#   'written_rows': 189},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'soneium',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2112000,
#   'written_rows': 403},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'soneium',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2120000,
#   'written_rows': 452},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'soneium',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2128000,
#   'written_rows': 379},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'soneium',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2136000,
#   'written_rows': 200},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swan',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3736000,
#   'written_rows': 2},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swan',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3744000,
#   'written_rows': 5},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swan',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 3752000,
#   'written_rows': 3},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swell',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2320000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swell',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2328000,
#   'written_rows': 1},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swell',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2336000,
#   'written_rows': 6},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swell',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2344000,
#   'written_rows': 53},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'swell',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 2352000,
#   'written_rows': 3},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'unichain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 6640000,
#   'written_rows': 4},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 8997600,
#   'written_rows': 992},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 8998400,
#   'written_rows': 1420},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 8999200,
#   'written_rows': 1352},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9000000,
#   'written_rows': 1326},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9000800,
#   'written_rows': 1290},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9001600,
#   'written_rows': 1272},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9002400,
#   'written_rows': 1213},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9003200,
#   'written_rows': 1202},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9004000,
#   'written_rows': 1173},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9004800,
#   'written_rows': 1142},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9005600,
#   'written_rows': 1072},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9006400,
#   'written_rows': 971},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9007200,
#   'written_rows': 917},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9008000,
#   'written_rows': 844},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9008800,
#   'written_rows': 744},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9009600,
#   'written_rows': 705},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9010400,
#   'written_rows': 670},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9011200,
#   'written_rows': 638},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9012000,
#   'written_rows': 673},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9012800,
#   'written_rows': 682},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9013600,
#   'written_rows': 618},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9014400,
#   'written_rows': 621},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9015200,
#   'written_rows': 677},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9016000,
#   'written_rows': 741},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9016800,
#   'written_rows': 806},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9017600,
#   'written_rows': 909},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9018400,
#   'written_rows': 950},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9019200,
#   'written_rows': 1065},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9020000,
#   'written_rows': 1156},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9020800,
#   'written_rows': 1332},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9021600,
#   'written_rows': 1438},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9022400,
#   'written_rows': 1512},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9023200,
#   'written_rows': 1601},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9024000,
#   'written_rows': 1823},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9024800,
#   'written_rows': 1910},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9025600,
#   'written_rows': 2039},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9026400,
#   'written_rows': 2084},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9027200,
#   'written_rows': 2085},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9028000,
#   'written_rows': 2090},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9028800,
#   'written_rows': 2068},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9029600,
#   'written_rows': 1422},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9030400,
#   'written_rows': 2436},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9031200,
#   'written_rows': 2019},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9032000,
#   'written_rows': 1955},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9032800,
#   'written_rows': 1937},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9033600,
#   'written_rows': 2001},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9034400,
#   'written_rows': 2031},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9035200,
#   'written_rows': 1947},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9036000,
#   'written_rows': 2018},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9036800,
#   'written_rows': 1939},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9037600,
#   'written_rows': 1852},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9038400,
#   'written_rows': 1749},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9039200,
#   'written_rows': 1740},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9040000,
#   'written_rows': 1820},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'worldchain',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 9040800,
#   'written_rows': 404},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25312000,
#   'written_rows': 96},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25320000,
#   'written_rows': 472},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25328000,
#   'written_rows': 1071},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25336000,
#   'written_rows': 1389},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25344000,
#   'written_rows': 912},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25352000,
#   'written_rows': 761},
#  {'dt': datetime.date(2025, 1, 20),
#   'chain': 'zora',
#   'table': 'contract_creation__create_traces_v1',
#   'min_block': 25360000,
#   'written_rows': 231}]
