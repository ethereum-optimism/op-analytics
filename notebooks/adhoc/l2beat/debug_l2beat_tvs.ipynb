# %%
# USE THIS FOR BACKFILLING:

from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.l2beat.executetvs import execute_pull

with write_to_prod():
    execute_pull()

# %%
# This cell is for debugging. We manually set up some L2Beat projects and fetch data for each of them.

from op_analytics.datasources.l2beat.projects import L2BeatProject
from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown


projects = [
    L2BeatProject(id="arbitrum", slug="arbitrum"),
    L2BeatProject(id="base", slug="base"),
    L2BeatProject(id="optimism", slug="op-mainnet"),
    L2BeatProject(id="polygon-pos", slug="polygon-pos"),
    L2BeatProject(id="mantle", slug="mantle"),
    L2BeatProject(id="zksync2", slug="zksync-era"),
    L2BeatProject(id="starknet", slug="starknet"),
    L2BeatProject(id="celo", slug="celo"),
    L2BeatProject(id="linea", slug="linea"),
    L2BeatProject(id="blast", slug="blast"),
    L2BeatProject(id="mantapacific", slug="mantapacific"),
    L2BeatProject(id="bob", slug="bob"),
    L2BeatProject(id="worldchain", slug="world"),
    L2BeatProject(id="fraxtal", slug="fraxtal"),
    L2BeatProject(id="scroll", slug="scroll"),
    L2BeatProject(id="mode", slug="mode"),
    L2BeatProject(id="soneium", slug="soneium"),
    L2BeatProject(id="taiko", slug="taiko"),
    L2BeatProject(id="zircuit", slug="zircuit"),
    L2BeatProject(id="metis", slug="metis"),
    L2BeatProject(id="sophon", slug="sophon"),
    L2BeatProject(id="lisk", slug="lisk"),
    L2BeatProject(id="swell", slug="swell"),
    L2BeatProject(id="ink", slug="ink"),
    L2BeatProject(id="galxegravity", slug="galxegravity"),
    L2BeatProject(id="lyra", slug="derive"),
    L2BeatProject(id="fuel", slug="fuel"),
    L2BeatProject(id="cronoszkevm", slug="cronoszkevm"),
    L2BeatProject(id="eclipse", slug="eclipse"),
    L2BeatProject(id="paradex", slug="paradex"),
    L2BeatProject(id="degate3", slug="degate3"),
    L2BeatProject(id="aevo", slug="aevo"),
    L2BeatProject(id="abstract", slug="abstract"),
    L2BeatProject(id="zksync", slug="zksync-lite"),
    L2BeatProject(id="immutablex", slug="immutablex"),
    L2BeatProject(id="polygonzkevm", slug="polygonzkevm"),
    L2BeatProject(id="corn", slug="corn"),
    L2BeatProject(id="apex", slug="apex"),
    L2BeatProject(id="xlayer", slug="xlayer"),
    L2BeatProject(id="educhain", slug="edu-chain"),
    L2BeatProject(id="kinto", slug="kinto"),
    L2BeatProject(id="loopring", slug="loopring"),
    L2BeatProject(id="lumia", slug="lumia"),
    L2BeatProject(id="rss3", slug="rss3"),
    L2BeatProject(id="nova", slug="nova"),
    L2BeatProject(id="zklinknova", slug="zklinknova"),
    L2BeatProject(id="unichain", slug="unichain"),
    L2BeatProject(id="sxnetwork", slug="sxnetwork"),
    L2BeatProject(id="morph", slug="morph"),
    L2BeatProject(id="reya", slug="reya"),
    L2BeatProject(id="immutablezkevm", slug="immutablezkevm"),
    L2BeatProject(id="game7", slug="g7"),
    L2BeatProject(id="orderly", slug="orderly"),
    L2BeatProject(id="silicon", slug="silicon"),
    L2BeatProject(id="karak", slug="k2"),
    L2BeatProject(id="sorare", slug="sorare"),
    L2BeatProject(id="zora", slug="zora"),
    L2BeatProject(id="lightlink", slug="lightlink"),
    L2BeatProject(id="cyber", slug="cyber"),
    L2BeatProject(id="hashkey", slug="hashkey"),
    L2BeatProject(id="pepeunchained", slug="pepeunchained"),
    L2BeatProject(id="bobanetwork", slug="bobanetwork"),
    L2BeatProject(id="soon", slug="soon"),
    L2BeatProject(id="polynomial", slug="polynomial"),
    L2BeatProject(id="treasure", slug="treasure"),
    L2BeatProject(id="real", slug="real"),
    L2BeatProject(id="kroma", slug="kroma"),
    L2BeatProject(id="zeronetwork", slug="zeronetwork"),
    L2BeatProject(id="sanko", slug="sanko"),
    L2BeatProject(id="mint", slug="mint"),
    L2BeatProject(id="shibarium", slug="shibarium"),
    L2BeatProject(id="aztec", slug="aztecv1"),
    L2BeatProject(id="ancient", slug="ancient8"),
    L2BeatProject(id="winr", slug="winr"),
    L2BeatProject(id="prom", slug="prom"),
    L2BeatProject(id="fluence", slug="fluence"),
    L2BeatProject(id="hychain", slug="hychain"),
    L2BeatProject(id="brine", slug="tanx"),
    L2BeatProject(id="shape", slug="shape"),
    L2BeatProject(id="degen", slug="degen"),
    L2BeatProject(id="superposition", slug="superposition"),
    L2BeatProject(id="redstone", slug="redstone"),
    L2BeatProject(id="xai", slug="xai"),
    L2BeatProject(id="zkfair", slug="zkfair"),
    L2BeatProject(id="facet", slug="facet"),
    L2BeatProject(id="metal", slug="metal"),
    L2BeatProject(id="funki", slug="funki"),
    L2BeatProject(id="gasp", slug="gasp"),
    L2BeatProject(id="alephzero", slug="aleph-zero"),
    L2BeatProject(id="everclear", slug="everclear"),
    L2BeatProject(id="rari", slug="rari"),
    L2BeatProject(id="superseed", slug="superseed"),
    L2BeatProject(id="popapex", slug="popapex"),
    L2BeatProject(id="dbk", slug="dbk"),
    L2BeatProject(id="alienx", slug="alienx"),
    L2BeatProject(id="ternoa", slug="ternoa"),
    L2BeatProject(id="zkspace", slug="zkspace"),
    L2BeatProject(id="ham", slug="ham"),
    L2BeatProject(id="b3", slug="b3"),
    L2BeatProject(id="river", slug="towns"),
    L2BeatProject(id="popboss", slug="popboss"),
    L2BeatProject(id="termstructure", slug="termstructure"),
    L2BeatProject(id="superlumio", slug="superlumio"),
    L2BeatProject(id="swan", slug="swan"),
    L2BeatProject(id="optopia", slug="optopia"),
    L2BeatProject(id="myria", slug="myria"),
    L2BeatProject(id="honeypot", slug="cartesi-honeypot"),
    L2BeatProject(id="form", slug="form"),
    L2BeatProject(id="oevnetwork", slug="oev"),
    L2BeatProject(id="ebichain", slug="ebichain"),
    L2BeatProject(id="arenaz", slug="arenaz"),
    L2BeatProject(id="geist", slug="geist"),
    L2BeatProject(id="xchain", slug="xchain"),
    L2BeatProject(id="molten", slug="molten"),
    L2BeatProject(id="edgeless", slug="edgeless"),
    L2BeatProject(id="cheese", slug="cheese"),
    L2BeatProject(id="race", slug="race"),
    L2BeatProject(id="muster", slug="muster"),
    L2BeatProject(id="xterio", slug="xterio"),
    L2BeatProject(id="syndicateframe", slug="syndicateframe"),
    L2BeatProject(id="snaxchain", slug="snaxchain"),
    L2BeatProject(id="deri", slug="deri"),
    L2BeatProject(id="ethernity", slug="ethernity"),
    L2BeatProject(id="automata", slug="automata"),
    L2BeatProject(id="huddle01", slug="huddle01"),
    L2BeatProject(id="stack", slug="stack"),
    L2BeatProject(id="phala", slug="phala"),
    L2BeatProject(id="donatuz", slug="donatuz"),
    L2BeatProject(id="settlus", slug="settlus"),
    L2BeatProject(id="henez", slug="henez"),
    L2BeatProject(id="rarimo", slug="rarimo"),
    L2BeatProject(id="clique", slug="clique"),
    L2BeatProject(id="forta", slug="forta"),
    L2BeatProject(id="fuelv1", slug="fuelv1"),
    L2BeatProject(id="pmon", slug="pmon"),
    L2BeatProject(id="r0ar", slug="r0ar"),
    L2BeatProject(id="bugbuster", slug="bugbuster"),
    L2BeatProject(id="kontos", slug="kontos"),
    L2BeatProject(id="rufus", slug="rufus"),
    L2BeatProject(id="airas", slug="airas"),
    L2BeatProject(id="grvt", slug="grvt"),
    L2BeatProject(id="openzk", slug="openzk"),
    L2BeatProject(id="apechain", slug="apechain"),
    L2BeatProject(id="bitlazer", slug="bitlazer"),
    L2BeatProject(id="blockfit", slug="blockfit"),
    L2BeatProject(id="conwai", slug="conwai"),
    L2BeatProject(id="dodochain", slug="dodochain"),
    L2BeatProject(id="inevm", slug="inevm"),
    L2BeatProject(id="onchain", slug="onchain"),
    L2BeatProject(id="skynet", slug="skynet"),
    L2BeatProject(id="playblock", slug="playblock"),
    L2BeatProject(id="xrone", slug="xrone"),
]


result = L2BeatTVSBreakdown.fetch(projects=projects)

# %%
result.df

# %%
# This cell is for debugging the whole thing in one go.


from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown

df = L2BeatTVSBreakdown.fetch()
# Out:
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/summary: 0.89 seconds filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-era/breakdown: 0.21 seconds counter=006/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [error    ] Failed to run thread for L2BeatProject(id='zksync2', slug='zksync-era') filename=threads.py lineno=88 process=13733
# Traceback (most recent call last):
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 99, in fetch
#     parsed_data = parse_tvs(data, project)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 123, in parse_tvs
#     "asset_id": asset["assetId"],
#                 ~~~~~^^^^^^^^^^^
# KeyError: 'assetId'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py", line 86, in run_concurrently
#     results[key] = future.result()
#                    ^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py", line 41, in wrapper
#     return func(target_item)
#            ^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 57, in <lambda>
#     function=lambda project: L2BeatProjectTVS.fetch(project, session),
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 101, in fetch
#     raise Exception(f"Failed to parse TVS data for project {project}") from e
# Exception: Failed to parse TVS data for project L2BeatProject(id='zksync2', slug='zksync-era')
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polygon-pos/breakdown: 0.23 seconds counter=004/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/unichain/breakdown: 0.24 seconds counter=007/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/base/breakdown: 0.25 seconds counter=002/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/arbitrum/breakdown: 0.26 seconds counter=001/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/op-mainnet/breakdown: 0.27 seconds counter=003/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/celo/breakdown: 0.09 seconds counter=009/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mantle/breakdown: 0.30 seconds counter=005/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/linea/breakdown: 0.09 seconds counter=010/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/starknet/breakdown: 0.33 seconds counter=008/151 eta=None filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/world/breakdown: 0.08 seconds counter=013/151 eta='8 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/blast/breakdown: 0.10 seconds counter=012/151 eta='10 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bob/breakdown: 0.09 seconds counter=014/151 eta='7 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fraxtal/breakdown: 0.08 seconds counter=015/151 eta='7 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mantapacific/breakdown: 0.14 seconds counter=011/151 eta='12 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/scroll/breakdown: 0.09 seconds counter=016/151 eta='6 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:00 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/soneium/breakdown: 0.08 seconds counter=017/151 eta='6 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/metis/breakdown: 0.08 seconds counter=021/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/taiko/breakdown: 0.10 seconds counter=019/151 eta='5 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mode/breakdown: 0.11 seconds counter=018/151 eta='5 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zircuit/breakdown: 0.10 seconds counter=020/151 eta='5 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sophon/breakdown: 0.08 seconds counter=023/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lisk/breakdown: 0.09 seconds counter=022/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/galxegravity/breakdown: 0.09 seconds counter=025/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ink/breakdown: 0.13 seconds counter=024/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/swell/breakdown: 0.09 seconds counter=026/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/derive/breakdown: 0.09 seconds counter=027/151 eta='4 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fuel/breakdown: 0.09 seconds counter=029/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/paradex/breakdown: 0.09 seconds counter=030/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/apechain/breakdown: 0.11 seconds counter=028/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sxnetwork/breakdown: 0.09 seconds counter=032/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cronoszkevm/breakdown: 0.10 seconds counter=033/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/eclipse/breakdown: 0.11 seconds counter=034/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/degate3/breakdown: 0.10 seconds counter=036/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aevo/breakdown: 0.11 seconds counter=035/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/immutablex/breakdown: 0.09 seconds counter=038/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/edu-chain/breakdown: 0.10 seconds counter=037/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polygonzkevm/breakdown: 0.09 seconds counter=039/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/corn/breakdown: 0.08 seconds counter=041/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kinto/breakdown: 0.08 seconds counter=040/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rss3/breakdown: 0.08 seconds counter=044/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-lite/breakdown: 0.10 seconds counter=042/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/apex/breakdown: 0.09 seconds counter=045/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/loopring/breakdown: 0.09 seconds counter=046/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lumia/breakdown: 0.09 seconds counter=048/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/abstract/breakdown: 0.33 seconds counter=031/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/g7/breakdown: 0.09 seconds counter=047/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/nova/breakdown: 0.09 seconds counter=050/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zklinknova/breakdown: 0.10 seconds counter=049/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/immutablezkevm/breakdown: 0.10 seconds counter=051/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/treasure/breakdown: 0.08 seconds counter=052/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xlayer/breakdown: 0.22 seconds counter=043/151 eta='3 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/orderly/breakdown: 0.08 seconds counter=055/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/morph/breakdown: 0.09 seconds counter=053/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cyber/breakdown: 0.09 seconds counter=057/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/reya/breakdown: 0.12 seconds counter=054/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/silicon/breakdown: 0.10 seconds counter=056/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lightlink/breakdown: 0.10 seconds counter=058/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/hashkey/breakdown: 0.09 seconds counter=060/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/k2/breakdown: 0.09 seconds counter=061/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zora/breakdown: 0.15 seconds counter=059/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sorare/breakdown: 0.12 seconds counter=062/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/soon/breakdown: 0.08 seconds counter=064/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bobanetwork/breakdown: 0.09 seconds counter=063/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/pepeunchained/breakdown: 0.09 seconds counter=066/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kroma/breakdown: 0.09 seconds counter=067/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polynomial/breakdown: 0.11 seconds counter=065/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/shibarium/breakdown: 0.10 seconds counter=068/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zeronetwork/breakdown: 0.09 seconds counter=070/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sanko/breakdown: 0.09 seconds counter=071/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/real/breakdown: 0.10 seconds counter=069/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mint/breakdown: 0.11 seconds counter=072/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/winr/breakdown: 0.09 seconds counter=075/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aztecv1/breakdown: 0.10 seconds counter=074/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/prom/breakdown: 0.07 seconds counter=076/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ancient8/breakdown: 0.12 seconds counter=073/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fluence/breakdown: 0.08 seconds counter=077/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xai/breakdown: 0.08 seconds counter=079/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/tanx/breakdown: 0.09 seconds counter=078/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superposition/breakdown: 0.07 seconds counter=081/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/degen/breakdown: 0.10 seconds counter=080/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/shape/breakdown: 0.09 seconds counter=082/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/hychain/breakdown: 0.09 seconds counter=084/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/everclear/breakdown: 0.08 seconds counter=086/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/redstone/breakdown: 0.12 seconds counter=083/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aleph-zero/breakdown: 0.09 seconds counter=085/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lens/breakdown: 0.08 seconds counter=087/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/facet/breakdown: 0.09 seconds counter=088/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superseed/breakdown: 0.10 seconds counter=090/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkfair/breakdown: 0.09 seconds counter=091/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/gasp/breakdown: 0.09 seconds counter=093/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ternoa/breakdown: 0.08 seconds counter=095/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/popapex/breakdown: 0.10 seconds counter=094/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rari/breakdown: 0.15 seconds counter=089/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/funki/breakdown: 0.12 seconds counter=092/151 eta='2 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/alienx/breakdown: 0.09 seconds counter=096/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/dbk/breakdown: 0.09 seconds counter=097/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/metal/breakdown: 0.08 seconds counter=098/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:01 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ham/breakdown: 0.08 seconds counter=100/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkspace/breakdown: 0.09 seconds counter=099/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/b3/breakdown: 0.09 seconds counter=101/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/towns/breakdown: 0.08 seconds counter=102/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/popboss/breakdown: 0.09 seconds counter=103/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superlumio/breakdown: 0.09 seconds counter=104/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cartesi-honeypot/breakdown: 0.08 seconds counter=106/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/swan/breakdown: 0.10 seconds counter=105/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/optopia/breakdown: 0.09 seconds counter=107/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/myria/breakdown: 0.08 seconds counter=108/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/form/breakdown: 0.09 seconds counter=109/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/oev/breakdown: 0.08 seconds counter=112/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/arenaz/breakdown: 0.10 seconds counter=110/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/appchain/breakdown: 0.08 seconds counter=114/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/termstructure/breakdown: 0.13 seconds counter=111/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/geist/breakdown: 0.10 seconds counter=113/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xchain/breakdown: 0.09 seconds counter=115/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/edgeless/breakdown: 0.10 seconds counter=116/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/molten/breakdown: 0.08 seconds counter=117/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/race/breakdown: 0.08 seconds counter=119/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cheese/breakdown: 0.10 seconds counter=118/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/syndicateframe/breakdown: 0.08 seconds counter=121/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/snaxchain/breakdown: 0.08 seconds counter=122/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/muster/breakdown: 0.10 seconds counter=120/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/deri/breakdown: 0.10 seconds counter=123/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/automata/breakdown: 0.09 seconds counter=125/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ethernity/breakdown: 0.10 seconds counter=124/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/onyx/breakdown: 0.09 seconds counter=126/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/huddle01/breakdown: 0.08 seconds counter=127/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/donatuz/breakdown: 0.08 seconds counter=128/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/phala/breakdown: 0.10 seconds counter=129/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rarimo/breakdown: 0.10 seconds counter=130/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/settlus/breakdown: 0.08 seconds counter=132/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/henez/breakdown: 0.09 seconds counter=131/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/clique/breakdown: 0.08 seconds counter=133/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fuelv1/breakdown: 0.09 seconds counter=135/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/forta/breakdown: 0.10 seconds counter=134/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/pmon/breakdown: 0.09 seconds counter=136/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rufus/breakdown: 0.06 seconds counter=139/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/grvt/breakdown: 0.07 seconds counter=140/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/r0ar/breakdown: 0.09 seconds counter=137/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/openzk/breakdown: 0.08 seconds counter=141/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kontos/breakdown: 0.11 seconds counter=138/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkcandy/breakdown: 0.08 seconds counter=142/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/conwai/breakdown: 0.07 seconds counter=145/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bitlazer/breakdown: 0.11 seconds counter=143/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/inevm/breakdown: 0.09 seconds counter=147/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/onchain/breakdown: 0.08 seconds counter=148/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/skynet/breakdown: 0.08 seconds counter=149/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/playblock/breakdown: 0.09 seconds counter=150/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/dodochain/breakdown: 0.18 seconds counter=146/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/blockfit/breakdown: 0.20 seconds counter=144/151 eta='1 secs' filename=request.py lineno=96 process=13733
# 2025-04-22 10:20:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xrone/breakdown: 0.13 seconds counter=151/151 eta='1 secs' filename=request.py lineno=96 process=13733
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:99, in L2BeatProjectTVS.fetch(cls, project, session)
#      98 try:
# ---> 99     parsed_data = parse_tvs(data, project)
#     100 except Exception as e:
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:123, in parse_tvs(data, project)
#     117 for escrow in escrows:
#     118     row = {
#     119         "dt": dt_fromepoch(timestamp),
#     120         "project_id": project.id,
#     121         "project_slug": project.slug,
#     122         "timestamp": timestamp,
# --> 123         "asset_id": asset["assetId"],
#     124         "chain_name": asset["chain"]["name"],
#     125         "chain_id": asset["chain"]["id"],
#     126         "amount": asset["amount"],
#     127         "usd_value": asset["usdValue"],
#     128         "usd_price": float(asset["usdPrice"]),
#     129         "is_gas_token": asset.get("isGasToken"),
#     130         "token_address": asset.get("tokenAddress"),
#     131         "escrow_address": escrow.get("escrowAddress") if escrow else None,
#     132         "escrow_name": escrow.get("name") if escrow else None,
#     133         "is_shared_escrow": escrow.get("isSharedEscrow") if escrow else None,
#     134         "escrow_url": escrow.get("url") if escrow else None,
#     135         "asset_url": asset.get("url"),
#     136         "icon_url": asset.get("iconUrl"),
#     137         "symbol": asset["symbol"],
#     138         "name": asset.get("name"),
#     139         "supply": asset.get("supply"),
#     140         "category": category,
#     141     }
#     142     rows.append(row)
#
# KeyError: 'assetId'
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 # This cell is for debugging the whole thing in one go.
#       4 from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown
# ----> 6 df = L2BeatTVSBreakdown.fetch()
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:56, in L2BeatTVSBreakdown.fetch(cls, projects, session)
#      53 l2beat_projects = projects or L2BeatProjectsSummary.fetch(session).projects
#      55 # Fetch the TVS breakdown for each project
# ---> 56 projects_tvs = run_concurrently(
#      57     function=lambda project: L2BeatProjectTVS.fetch(project, session),
#      58     targets=l2beat_projects,
#      59     max_workers=8,
#      60 )
#      62 rows = []
#      63 for parsed_data in projects_tvs.values():
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py:86, in run_concurrently(function, targets, max_workers)
#      84 key = futures[future]
#      85 try:
# ---> 86     results[key] = future.result()
#      87 except Exception as ex:
#      88     log.error(f"Failed to run thread for {key}", exc_info=ex)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py:41, in ProgressTracker.wrap.<locals>.wrapper(target_item)
#      39 with bound_contextvars(counter=self.counter(current_index), eta=self.eta()):
#      40     try:
# ---> 41         return func(target_item)
#      42     finally:
#      43         self.completed_tasks += 1
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:57, in L2BeatTVSBreakdown.fetch.<locals>.<lambda>(project)
#      53 l2beat_projects = projects or L2BeatProjectsSummary.fetch(session).projects
#      55 # Fetch the TVS breakdown for each project
#      56 projects_tvs = run_concurrently(
# ---> 57     function=lambda project: L2BeatProjectTVS.fetch(project, session),
#      58     targets=l2beat_projects,
#      59     max_workers=8,
#      60 )
#      62 rows = []
#      63 for parsed_data in projects_tvs.values():
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:101, in L2BeatProjectTVS.fetch(cls, project, session)
#      99     parsed_data = parse_tvs(data, project)
#     100 except Exception as e:
# --> 101     raise Exception(f"Failed to parse TVS data for project {project}") from e
#     103 return cls(slug=project.slug, data=parsed_data)
#
# Exception: Failed to parse TVS data for project L2BeatProject(id='zksync2', slug='zksync-era')

# %%
# This cell is to debu a single project 

from op_analytics.datasources.l2beat.projects import L2BeatProject
from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown

result = L2BeatTVSBreakdown.fetch(projects=[
    L2BeatProject(id='zksync2', slug='zksync-era')
])
# Out:
# 2025-04-22 10:24:42 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-era/breakdown: 0.46 seconds counter=001/001 eta=None filename=request.py lineno=96 process=14246
# {'address': {'address': '0x000000000000000000000000000000000000800A',
#              'url': 'https://era.zksync.network/address/0x000000000000000000000000000000000000800A'},
#  'amount': 94788.34,
#  'category': 'ether',
#  'formula': {'address': '0x000000000000000000000000000000000000800A',
#              'chain': 'zksync2',
#              'decimals': 18,
#              'sinceTimestamp': 1739109131,
#              'type': 'totalSupply'},
#  'iconUrl': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1595348880',
#  'id': 'zksync2-ETH-1',
#  'isAssociated': False,
#  'isGasToken': True,
#  'mode': 'auto',
#  'name': 'Ethereum',
#  'priceId': 'ethereum',
#  'source': 'canonical',
#  'symbol': 'ETH',
#  'usdValue': 154567490}
# this is wrong
# 2025-04-22 10:32:07 [error    ] Failed to run thread for L2BeatProject(id='zksync2', slug='zksync-era') filename=threads.py lineno=88 process=14246
# Traceback (most recent call last):
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 99, in fetch
#     parsed_data = parse_tvs(data, project)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 126, in parse_tvs
#     "asset_id": asset["assetId"],
#                 ~~~~~^^^^^^^^^^^
# KeyError: 'assetId'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py", line 86, in run_concurrently
#     results[key] = future.result()
#                    ^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py", line 41, in wrapper
#     return func(target_item)
#            ^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 57, in <lambda>
#     function=lambda project: L2BeatProjectTVS.fetch(project, session),
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/pedro/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py", line 101, in fetch
#     raise Exception(f"Failed to parse TVS data for project {project}") from e
# Exception: Failed to parse TVS data for project L2BeatProject(id='zksync2', slug='zksync-era')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:99, in L2BeatProjectTVS.fetch(cls, project, session)
#      98 try:
# ---> 99     parsed_data = parse_tvs(data, project)
#     100 except Exception as e:
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:126, in parse_tvs(data, project)
#     120 for escrow in escrows:
#     121     row = {
#     122         "dt": dt_fromepoch(timestamp),
#     123         "project_id": project.id,
#     124         "project_slug": project.slug,
#     125         "timestamp": timestamp,
# --> 126         "asset_id": asset["assetId"],
#     127         "chain_name": asset["chain"]["name"],
#     128         "chain_id": asset["chain"]["id"],
#     129         "amount": asset["amount"],
#     130         "usd_value": asset["usdValue"],
#     131         "usd_price": float(asset["usdPrice"]),
#     132         "is_gas_token": asset.get("isGasToken"),
#     133         "token_address": asset.get("tokenAddress"),
#     134         "escrow_address": escrow.get("escrowAddress") if escrow else None,
#     135         "escrow_name": escrow.get("name") if escrow else None,
#     136         "is_shared_escrow": escrow.get("isSharedEscrow") if escrow else None,
#     137         "escrow_url": escrow.get("url") if escrow else None,
#     138         "asset_url": asset.get("url"),
#     139         "icon_url": asset.get("iconUrl"),
#     140         "symbol": asset["symbol"],
#     141         "name": asset.get("name"),
#     142         "supply": asset.get("supply"),
#     143         "category": category,
#     144     }
#     145     rows.append(row)
#
# KeyError: 'assetId'
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 from op_analytics.datasources.l2beat.projects import L2BeatProject
#       4 from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown
# ----> 6 result = L2BeatTVSBreakdown.fetch(projects=[
#       7     L2BeatProject(id='zksync2', slug='zksync-era')
#       8 ])
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:56, in L2BeatTVSBreakdown.fetch(cls, projects, session)
#      53 l2beat_projects = projects or L2BeatProjectsSummary.fetch(session).projects
#      55 # Fetch the TVS breakdown for each project
# ---> 56 projects_tvs = run_concurrently(
#      57     function=lambda project: L2BeatProjectTVS.fetch(project, session),
#      58     targets=l2beat_projects,
#      59     max_workers=8,
#      60 )
#      62 rows = []
#      63 for parsed_data in projects_tvs.values():
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py:86, in run_concurrently(function, targets, max_workers)
#      84 key = futures[future]
#      85 try:
# ---> 86     results[key] = future.result()
#      87 except Exception as ex:
#      88     log.error(f"Failed to run thread for {key}", exc_info=ex)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/coreutils/threads.py:41, in ProgressTracker.wrap.<locals>.wrapper(target_item)
#      39 with bound_contextvars(counter=self.counter(current_index), eta=self.eta()):
#      40     try:
# ---> 41         return func(target_item)
#      42     finally:
#      43         self.completed_tasks += 1
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:57, in L2BeatTVSBreakdown.fetch.<locals>.<lambda>(project)
#      53 l2beat_projects = projects or L2BeatProjectsSummary.fetch(session).projects
#      55 # Fetch the TVS breakdown for each project
#      56 projects_tvs = run_concurrently(
# ---> 57     function=lambda project: L2BeatProjectTVS.fetch(project, session),
#      58     targets=l2beat_projects,
#      59     max_workers=8,
#      60 )
#      62 rows = []
#      63 for parsed_data in projects_tvs.values():
#
# File ~/github/ethereum-optimism/op-analytics-alt/src/op_analytics/datasources/l2beat/tvsbreakdown.py:101, in L2BeatProjectTVS.fetch(cls, project, session)
#      99     parsed_data = parse_tvs(data, project)
#     100 except Exception as e:
# --> 101     raise Exception(f"Failed to parse TVS data for project {project}") from e
#     103 return cls(slug=project.slug, data=parsed_data)
#
# Exception: Failed to parse TVS data for project L2BeatProject(id='zksync2', slug='zksync-era')

# %%
from op_analytics.coreutils.request import get_data, new_session

data = get_data(
    session=new_session(),
    url=f"https://l2beat.com/api/scaling/tvs/unichain/breakdown",
)

# %%
# debug
import json

breakdown = data["data"]["breakdown"]

print(json.dumps(list(breakdown.keys()), indent=2))

for category, assets in breakdown.items():
    print(f"{category}: {len(assets)} assets")

timestamp = data["data"]["dataTimestamp"]
timestamp
