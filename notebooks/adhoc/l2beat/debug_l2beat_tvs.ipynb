# %%
# USE THIS FOR BACKFILLING:

from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.l2beat.executetvs import execute_pull

with write_to_prod():
    execute_pull()

# %%
# This cell is for debugging. We manually set up some L2Beat projects and fetch data for each of them.

from op_analytics.datasources.l2beat.projects import L2BeatProject
from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown


projects = [
    L2BeatProject(id="arbitrum", slug="arbitrum"),
    L2BeatProject(id="base", slug="base"),
    L2BeatProject(id="optimism", slug="op-mainnet"),
    L2BeatProject(id="polygon-pos", slug="polygon-pos"),
    L2BeatProject(id="mantle", slug="mantle"),
    L2BeatProject(id="zksync2", slug="zksync-era"),
    L2BeatProject(id="starknet", slug="starknet"),
    L2BeatProject(id="celo", slug="celo"),
    L2BeatProject(id="linea", slug="linea"),
    L2BeatProject(id="blast", slug="blast"),
    L2BeatProject(id="mantapacific", slug="mantapacific"),
    L2BeatProject(id="bob", slug="bob"),
    L2BeatProject(id="worldchain", slug="world"),
    L2BeatProject(id="fraxtal", slug="fraxtal"),
    L2BeatProject(id="scroll", slug="scroll"),
    L2BeatProject(id="mode", slug="mode"),
    L2BeatProject(id="soneium", slug="soneium"),
    L2BeatProject(id="taiko", slug="taiko"),
    L2BeatProject(id="zircuit", slug="zircuit"),
    L2BeatProject(id="metis", slug="metis"),
    L2BeatProject(id="sophon", slug="sophon"),
    L2BeatProject(id="lisk", slug="lisk"),
    L2BeatProject(id="swell", slug="swell"),
    L2BeatProject(id="ink", slug="ink"),
    L2BeatProject(id="galxegravity", slug="galxegravity"),
    L2BeatProject(id="lyra", slug="derive"),
    L2BeatProject(id="fuel", slug="fuel"),
    L2BeatProject(id="cronoszkevm", slug="cronoszkevm"),
    L2BeatProject(id="eclipse", slug="eclipse"),
    L2BeatProject(id="paradex", slug="paradex"),
    L2BeatProject(id="degate3", slug="degate3"),
    L2BeatProject(id="aevo", slug="aevo"),
    L2BeatProject(id="abstract", slug="abstract"),
    L2BeatProject(id="zksync", slug="zksync-lite"),
    L2BeatProject(id="immutablex", slug="immutablex"),
    L2BeatProject(id="polygonzkevm", slug="polygonzkevm"),
    L2BeatProject(id="corn", slug="corn"),
    L2BeatProject(id="apex", slug="apex"),
    L2BeatProject(id="xlayer", slug="xlayer"),
    L2BeatProject(id="educhain", slug="edu-chain"),
    L2BeatProject(id="kinto", slug="kinto"),
    L2BeatProject(id="loopring", slug="loopring"),
    L2BeatProject(id="lumia", slug="lumia"),
    L2BeatProject(id="rss3", slug="rss3"),
    L2BeatProject(id="nova", slug="nova"),
    L2BeatProject(id="zklinknova", slug="zklinknova"),
    L2BeatProject(id="unichain", slug="unichain"),
    L2BeatProject(id="sxnetwork", slug="sxnetwork"),
    L2BeatProject(id="morph", slug="morph"),
    L2BeatProject(id="reya", slug="reya"),
    L2BeatProject(id="immutablezkevm", slug="immutablezkevm"),
    L2BeatProject(id="game7", slug="g7"),
    L2BeatProject(id="orderly", slug="orderly"),
    L2BeatProject(id="silicon", slug="silicon"),
    L2BeatProject(id="karak", slug="k2"),
    L2BeatProject(id="sorare", slug="sorare"),
    L2BeatProject(id="zora", slug="zora"),
    L2BeatProject(id="lightlink", slug="lightlink"),
    L2BeatProject(id="cyber", slug="cyber"),
    L2BeatProject(id="hashkey", slug="hashkey"),
    L2BeatProject(id="pepeunchained", slug="pepeunchained"),
    L2BeatProject(id="bobanetwork", slug="bobanetwork"),
    L2BeatProject(id="soon", slug="soon"),
    L2BeatProject(id="polynomial", slug="polynomial"),
    L2BeatProject(id="treasure", slug="treasure"),
    L2BeatProject(id="real", slug="real"),
    L2BeatProject(id="kroma", slug="kroma"),
    L2BeatProject(id="zeronetwork", slug="zeronetwork"),
    L2BeatProject(id="sanko", slug="sanko"),
    L2BeatProject(id="mint", slug="mint"),
    L2BeatProject(id="shibarium", slug="shibarium"),
    L2BeatProject(id="aztec", slug="aztecv1"),
    L2BeatProject(id="ancient", slug="ancient8"),
    L2BeatProject(id="winr", slug="winr"),
    L2BeatProject(id="prom", slug="prom"),
    L2BeatProject(id="fluence", slug="fluence"),
    L2BeatProject(id="hychain", slug="hychain"),
    L2BeatProject(id="brine", slug="tanx"),
    L2BeatProject(id="shape", slug="shape"),
    L2BeatProject(id="degen", slug="degen"),
    L2BeatProject(id="superposition", slug="superposition"),
    L2BeatProject(id="redstone", slug="redstone"),
    L2BeatProject(id="xai", slug="xai"),
    L2BeatProject(id="zkfair", slug="zkfair"),
    L2BeatProject(id="facet", slug="facet"),
    L2BeatProject(id="metal", slug="metal"),
    L2BeatProject(id="funki", slug="funki"),
    L2BeatProject(id="gasp", slug="gasp"),
    L2BeatProject(id="alephzero", slug="aleph-zero"),
    L2BeatProject(id="everclear", slug="everclear"),
    L2BeatProject(id="rari", slug="rari"),
    L2BeatProject(id="superseed", slug="superseed"),
    L2BeatProject(id="popapex", slug="popapex"),
    L2BeatProject(id="dbk", slug="dbk"),
    L2BeatProject(id="alienx", slug="alienx"),
    L2BeatProject(id="ternoa", slug="ternoa"),
    L2BeatProject(id="zkspace", slug="zkspace"),
    L2BeatProject(id="ham", slug="ham"),
    L2BeatProject(id="b3", slug="b3"),
    L2BeatProject(id="river", slug="towns"),
    L2BeatProject(id="popboss", slug="popboss"),
    L2BeatProject(id="termstructure", slug="termstructure"),
    L2BeatProject(id="superlumio", slug="superlumio"),
    L2BeatProject(id="swan", slug="swan"),
    L2BeatProject(id="optopia", slug="optopia"),
    L2BeatProject(id="myria", slug="myria"),
    L2BeatProject(id="honeypot", slug="cartesi-honeypot"),
    L2BeatProject(id="form", slug="form"),
    L2BeatProject(id="oevnetwork", slug="oev"),
    L2BeatProject(id="ebichain", slug="ebichain"),
    L2BeatProject(id="arenaz", slug="arenaz"),
    L2BeatProject(id="geist", slug="geist"),
    L2BeatProject(id="xchain", slug="xchain"),
    L2BeatProject(id="molten", slug="molten"),
    L2BeatProject(id="edgeless", slug="edgeless"),
    L2BeatProject(id="cheese", slug="cheese"),
    L2BeatProject(id="race", slug="race"),
    L2BeatProject(id="muster", slug="muster"),
    L2BeatProject(id="xterio", slug="xterio"),
    L2BeatProject(id="syndicateframe", slug="syndicateframe"),
    L2BeatProject(id="snaxchain", slug="snaxchain"),
    L2BeatProject(id="deri", slug="deri"),
    L2BeatProject(id="ethernity", slug="ethernity"),
    L2BeatProject(id="automata", slug="automata"),
    L2BeatProject(id="huddle01", slug="huddle01"),
    L2BeatProject(id="stack", slug="stack"),
    L2BeatProject(id="phala", slug="phala"),
    L2BeatProject(id="donatuz", slug="donatuz"),
    L2BeatProject(id="settlus", slug="settlus"),
    L2BeatProject(id="henez", slug="henez"),
    L2BeatProject(id="rarimo", slug="rarimo"),
    L2BeatProject(id="clique", slug="clique"),
    L2BeatProject(id="forta", slug="forta"),
    L2BeatProject(id="fuelv1", slug="fuelv1"),
    L2BeatProject(id="pmon", slug="pmon"),
    L2BeatProject(id="r0ar", slug="r0ar"),
    L2BeatProject(id="bugbuster", slug="bugbuster"),
    L2BeatProject(id="kontos", slug="kontos"),
    L2BeatProject(id="rufus", slug="rufus"),
    L2BeatProject(id="airas", slug="airas"),
    L2BeatProject(id="grvt", slug="grvt"),
    L2BeatProject(id="openzk", slug="openzk"),
    L2BeatProject(id="apechain", slug="apechain"),
    L2BeatProject(id="bitlazer", slug="bitlazer"),
    L2BeatProject(id="blockfit", slug="blockfit"),
    L2BeatProject(id="conwai", slug="conwai"),
    L2BeatProject(id="dodochain", slug="dodochain"),
    L2BeatProject(id="inevm", slug="inevm"),
    L2BeatProject(id="onchain", slug="onchain"),
    L2BeatProject(id="skynet", slug="skynet"),
    L2BeatProject(id="playblock", slug="playblock"),
    L2BeatProject(id="xrone", slug="xrone"),
]


result = L2BeatTVSBreakdown.fetch(projects=projects)

# %%
result.df

# %%
# This cell is for debugging the whole thing in one go.


from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown

df = L2BeatTVSBreakdown.fetch()
# Out:
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/summary: 0.16 seconds filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/base/breakdown: 0.11 seconds counter=001/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/unichain/breakdown: 0.14 seconds counter=007/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/arbitrum/breakdown: 0.15 seconds counter=002/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'arbitrum-GALA-1', 'priceId': 'gala', 'symbol': 'GALA', 'name': 'Gala', 'iconUrl': 'https://assets.coingecko.com/coins/images/12493/large/GALA-COINGECKO.png?1696512310', 'amount': 309484.25, 'category': 'other', 'source': 'canonical', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1623784100, 'address': '0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA', 'decimals': 8, 'escrowAddress': '0xa3A7B6F88361F48403514059F1F16C8E78d60EeC'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1681915991, 'address': '0xd1d2Eb1B1e90B638588728b4130137D262C87cae', 'decimals': 8, 'escrowAddress': '0xa3A7B6F88361F48403514059F1F16C8E78d60EeC'}]}, 'usdValue': 5426.8, 'isGasToken': False, 'escrow': {'address': '0xa3A7B6F88361F48403514059F1F16C8E78d60EeC', 'url': 'https://etherscan.io/address/0xa3A7B6F88361F48403514059F1F16C8E78d60EeC', 'name': 'L1ERC20Gateway'}} counter=002/154 eta=None filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-era/breakdown: 0.18 seconds counter=006/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polygon-pos/breakdown: 0.19 seconds counter=004/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Unknown escrow structure: {'type': 'calculation', 'operator': 'min', 'arguments': [{'type': 'circulatingSupply', 'sinceTimestamp': 1629331200, 'apiId': 'polytrade', 'decimals': 18, 'address': '0x6e5970DBd6fc7eb1f29C6D2eDF2bC4c36124C0C1', 'chain': 'ethereum'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1629331200, 'address': '0x6e5970DBd6fc7eb1f29C6D2eDF2bC4c36124C0C1', 'decimals': 18, 'escrowAddress': '0x40ec5B33f54e0E8A33A975908C5BA1c14e5BbbDf'}]} counter=004/154 eta=None filename=tvsbreakdown.py lineno=198 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'polygon-pos-GALA', 'priceId': 'gala', 'symbol': 'GALA', 'name': 'Gala', 'iconUrl': 'https://assets.coingecko.com/coins/images/12493/large/GALA-COINGECKO.png?1696512310', 'amount': 350368.47, 'category': 'other', 'source': 'canonical', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1600214400, 'address': '0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA', 'decimals': 8, 'escrowAddress': '0x401F6c983eA34274ec46f84D70b31C151321188b'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1681915991, 'address': '0xd1d2Eb1B1e90B638588728b4130137D262C87cae', 'decimals': 8, 'escrowAddress': '0x401F6c983eA34274ec46f84D70b31C151321188b'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1600214400, 'address': '0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA', 'decimals': 8, 'escrowAddress': '0x40ec5B33f54e0E8A33A975908C5BA1c14e5BbbDf'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1681915991, 'address': '0xd1d2Eb1B1e90B638588728b4130137D262C87cae', 'decimals': 8, 'escrowAddress': '0x40ec5B33f54e0E8A33A975908C5BA1c14e5BbbDf'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1613100777, 'address': '0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA', 'decimals': 8, 'escrowAddress': '0x9923263fA127b3d1484cFD649df8f1831c2A74e4'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1681915991, 'address': '0xd1d2Eb1B1e90B638588728b4130137D262C87cae', 'decimals': 8, 'escrowAddress': '0x9923263fA127b3d1484cFD649df8f1831c2A74e4'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1627373890, 'address': '0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA', 'decimals': 8, 'escrowAddress': '0x21ada4D8A799c4b0ADF100eB597a6f1321bCD3E4'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1681915991, 'address': '0xd1d2Eb1B1e90B638588728b4130137D262C87cae', 'decimals': 8, 'escrowAddress': '0x21ada4D8A799c4b0ADF100eB597a6f1321bCD3E4'}]}, 'usdValue': 6143.7, 'escrow': 'multiple'} counter=004/154 eta=None filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/celo/breakdown: 0.09 seconds counter=009/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mantle/breakdown: 0.20 seconds counter=005/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/world/breakdown: 0.07 seconds counter=010/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/op-mainnet/breakdown: 0.22 seconds counter=003/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/linea/breakdown: 0.08 seconds counter=011/154 eta='8 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/starknet/breakdown: 0.24 seconds counter=008/154 eta=None filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bob/breakdown: 0.09 seconds counter=014/154 eta='5 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/blast/breakdown: 0.10 seconds counter=013/154 eta='6 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mantapacific/breakdown: 0.11 seconds counter=012/154 eta='7 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/soneium/breakdown: 0.08 seconds counter=017/154 eta='4 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fraxtal/breakdown: 0.10 seconds counter=015/154 eta='5 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/taiko/breakdown: 0.07 seconds counter=019/154 eta='4 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mode/breakdown: 0.09 seconds counter=018/154 eta='4 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sophon/breakdown: 0.08 seconds counter=023/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zircuit/breakdown: 0.09 seconds counter=021/154 eta='4 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/scroll/breakdown: 0.18 seconds counter=016/154 eta='4 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/metis/breakdown: 0.10 seconds counter=020/154 eta='4 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ink/breakdown: 0.09 seconds counter=024/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/swell/breakdown: 0.08 seconds counter=026/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/galxegravity/breakdown: 0.11 seconds counter=025/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/apechain/breakdown: 0.08 seconds counter=028/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/paradex/breakdown: 0.08 seconds counter=030/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/derive/breakdown: 0.09 seconds counter=027/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-sUSDe-2', 'priceId': 'ethena-staked-usde', 'symbol': 'sUSDe', 'name': 'Staked USDe', 'iconUrl': 'https://assets.coingecko.com/coins/images/33669/large/photo_2023-12-14_17-00-20.jpg?1702696035', 'amount': 10279275, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1719833675, 'address': '0x9D39A5DE30e57443BfF2A8307A4256c8797A3497', 'decimals': 18, 'escrowAddress': '0xE3E96892D30E0ee1a8131BAf87c891201F7137bf'}, 'priceId': 'ethena-staked-usde'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1719833737, 'value': '0', 'decimals': 0}, 'priceId': 'ethena-staked-usde'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1719833783, 'value': '0', 'decimals': 0}, 'priceId': 'ethena-staked-usde'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1719833706, 'value': '0', 'decimals': 0}, 'priceId': 'ethena-staked-usde'}]}, 'category': 'other', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1719833675, 'address': '0x9D39A5DE30e57443BfF2A8307A4256c8797A3497', 'decimals': 18, 'escrowAddress': '0xE3E96892D30E0ee1a8131BAf87c891201F7137bf'}, {'type': 'balanceOfEscrow', 'chain': 'optimism', 'sinceTimestamp': 1719833737, 'address': '0x211Cc4DD073734dA055fbF44a2b4667d5E5fE5d2', 'decimals': 18, 'escrowAddress': '0x5324c6d731a3d9D740e880929E2c952bA27408De'}, {'type': 'balanceOfEscrow', 'chain': 'mode', 'sinceTimestamp': 1719833783, 'address': '0x211Cc4DD073734dA055fbF44a2b4667d5E5fE5d2', 'decimals': 18, 'escrowAddress': '0xdE45E2bCCb99E0ed1a2876cFC51a71ca5e822641'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1719833706, 'address': '0x211Cc4DD073734dA055fbF44a2b4667d5E5fE5d2', 'decimals': 18, 'escrowAddress': '0x3c143EA5eBaB50ad6D2B2d14FA719234d1d38F1b'}]}, 'usdValue': 12003581, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-weETH-2', 'priceId': 'wrapped-eeth', 'symbol': 'weETH', 'name': 'Wrapped eETH', 'iconUrl': 'https://coin-images.coingecko.com/coins/images/33033/large/weETH.png?1701438396', 'amount': 5076.28, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1717674807, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-eeth'}, {'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1715846411, 'address': '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee', 'decimals': 18, 'escrowAddress': '0x8180EcCC825b692ef65FF099a0A387743788bf78'}, 'priceId': 'wrapped-eeth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1715846405, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-eeth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1717674807, 'address': '0x04C0599Ae5A44757c0af6F9eC3b93da8976c150A', 'decimals': 18, 'escrowAddress': '0xF982c812099d03AFFa0c8062aa1abcb584c23329'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1715846411, 'address': '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee', 'decimals': 18, 'escrowAddress': '0x8180EcCC825b692ef65FF099a0A387743788bf78'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1715846405, 'address': '0x35751007a407ca6FEFfE80b3cB397736D2cf4dbe', 'decimals': 18, 'escrowAddress': '0x3FBFD80EF7591658d1D7DdEC067F413eFd6f985c'}]}, 'usdValue': 9652263, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-wBTC', 'priceId': 'wrapped-bitcoin', 'symbol': 'wBTC', 'name': 'Wrapped BTC', 'iconUrl': 'https://coin-images.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1696507857', 'amount': 75.15, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1704715873, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-bitcoin'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1704715871, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-bitcoin'}]}, 'category': 'other', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'optimism', 'sinceTimestamp': 1704715873, 'address': '0x68f180fcCe6836688e9084f035309E29Bf0A2095', 'decimals': 8, 'escrowAddress': '0xE5967877065f111a556850d8f05b8DaD88edCEc9'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1704715871, 'address': '0x2f2a2543B76A4166549F7aaB2e75Bef0aefC5B0f', 'decimals': 8, 'escrowAddress': '0x3D20c6A2b719129af175E0ff7B1875DEb360896f'}]}, 'usdValue': 7091576, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-WETH-2', 'priceId': 'weth', 'symbol': 'WETH', 'name': 'Wrapped Ether', 'iconUrl': 'https://assets.coingecko.com/coins/images/2518/large/weth.png?1696503332', 'amount': 2495.47, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1705069895, 'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2', 'decimals': 18, 'escrowAddress': '0xD4efe33C66B8CdE33B8896a2126E41e5dB571b7e'}, 'priceId': 'weth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1711532017, 'value': '0', 'decimals': 0}, 'priceId': 'weth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1704715809, 'value': '0', 'decimals': 0}, 'priceId': 'weth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1704715806, 'value': '0', 'decimals': 0}, 'priceId': 'weth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1705069895, 'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2', 'decimals': 18, 'escrowAddress': '0xD4efe33C66B8CdE33B8896a2126E41e5dB571b7e'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1711532017, 'address': '0x4200000000000000000000000000000000000006', 'decimals': 18, 'escrowAddress': '0xBd282333710B9C7e33E8a37d027885A7C079Ae23'}, {'type': 'balanceOfEscrow', 'chain': 'optimism', 'sinceTimestamp': 1704715809, 'address': '0x4200000000000000000000000000000000000006', 'decimals': 18, 'escrowAddress': '0xdD4c717a69763176d8B7A687728e228597eAB86d'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1704715806, 'address': '0x82aF49447D8a07e3bd95BD0d56f35241523fBab1', 'decimals': 18, 'escrowAddress': '0x8e9f58E6c206CB9C98aBb9F235E0f02D65dFc922'}]}, 'usdValue': 4452391, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-wstETH-2', 'priceId': 'wrapped-steth', 'symbol': 'wstETH', 'name': 'Wrapped liquid staked Ether 2.0', 'iconUrl': 'https://coin-images.coingecko.com/coins/images/18834/large/wstETH.png?1696518295', 'amount': 1903.34, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1709502861, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-steth'}, {'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1709517155, 'address': '0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0', 'decimals': 18, 'escrowAddress': '0xeBB5D642aA8ccDeE98373D6aC3ee0602b63824b3'}, 'priceId': 'wrapped-steth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1709502863, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-steth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1709502860, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-steth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1709502861, 'address': '0xc1CBa3fCea344f92D9239c08C0568f6F2F0ee452', 'decimals': 18, 'escrowAddress': '0x2805B908a0F9CA58a2b3b7900341b4EBd0B994e9'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1709517155, 'address': '0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0', 'decimals': 18, 'escrowAddress': '0xeBB5D642aA8ccDeE98373D6aC3ee0602b63824b3'}, {'type': 'balanceOfEscrow', 'chain': 'optimism', 'sinceTimestamp': 1709502863, 'address': '0x1F32b1c2345538c0c6f582fCB022739c4A194Ebb', 'decimals': 18, 'escrowAddress': '0xAA8f9D05599F1a5d5929c40342c06a5Da063a4dE'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1709502860, 'address': '0x5979D7b546E38E414F7E9822514be443A4800529', 'decimals': 18, 'escrowAddress': '0x8574CBC539c26Df9ec11bA283218268101ff10e1'}]}, 'usdValue': 4076768.8, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-USDC-2', 'priceId': 'usd-coin', 'symbol': 'USDC', 'name': 'USD Coin', 'iconUrl': 'https://assets.coingecko.com/coins/images/6319/large/usdc.png?1696506694', 'amount': 1277971.9, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1700227943, 'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48', 'decimals': 6, 'escrowAddress': '0x6D303CEE7959f814042D31E0624fB88Ec6fbcC1d'}, 'priceId': 'usd-coin'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1709518033, 'value': '0', 'decimals': 0}, 'priceId': 'usd-coin'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1704715451, 'value': '0', 'decimals': 0}, 'priceId': 'usd-coin'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1704715450, 'value': '0', 'decimals': 0}, 'priceId': 'usd-coin'}]}, 'category': 'stablecoin', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1700227943, 'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48', 'decimals': 6, 'escrowAddress': '0x6D303CEE7959f814042D31E0624fB88Ec6fbcC1d'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1709518033, 'address': '0x833589fCD6eDb6E08f4c7C32D4f71b54bdA02913', 'decimals': 6, 'escrowAddress': '0x4e798659b9846F1da7B6D6B5d09d581270aB6FEC'}, {'type': 'balanceOfEscrow', 'chain': 'optimism', 'sinceTimestamp': 1704715451, 'address': '0x0b2C639c533813f4Aa9D7837CAf62653d097Ff85', 'decimals': 6, 'escrowAddress': '0xDEf0bfBdf7530C75AB3C73f8d2F64d9eaA7aA98e'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1704715450, 'address': '0xaf88d065e77c8cC2239327C5EDb3A432268e5831', 'decimals': 6, 'escrowAddress': '0x5e027ad442e031424b5a2C0ad6f656662Be32882'}]}, 'usdValue': 1277970.1, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-rsETH-2', 'priceId': 'kelp-dao-restaked-eth', 'symbol': 'rsETH', 'name': 'rsETH', 'iconUrl': 'https://coin-images.coingecko.com/coins/images/33800/large/Icon___Dark.png?1702991855', 'amount': 437.48, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1717724723, 'address': '0xA1290d69c65A6Fe4DF752f95823fae25cB99e5A7', 'decimals': 18, 'escrowAddress': '0x35d4D9bc79B0a543934b1769304B90d752691caD'}, 'priceId': 'kelp-dao-restaked-eth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1717724847, 'value': '0', 'decimals': 0}, 'priceId': 'kelp-dao-restaked-eth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1717724755, 'value': '0', 'decimals': 0}, 'priceId': 'kelp-dao-restaked-eth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1717724723, 'address': '0xA1290d69c65A6Fe4DF752f95823fae25cB99e5A7', 'decimals': 18, 'escrowAddress': '0x35d4D9bc79B0a543934b1769304B90d752691caD'}, {'type': 'balanceOfEscrow', 'chain': 'mode', 'sinceTimestamp': 1717724847, 'address': '0x4186BFC76E2E237523CBC30FD220FE055156b41F', 'decimals': 18, 'escrowAddress': '0xAA8f9D05599F1a5d5929c40342c06a5Da063a4dE'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1717724755, 'address': '0x4186BFC76E2E237523CBC30FD220FE055156b41F', 'decimals': 18, 'escrowAddress': '0x486936FB1CE805e8C46E71C69256e72f3f550d38'}]}, 'usdValue': 813111.4, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-USDT-2', 'priceId': 'tether', 'symbol': 'USDT', 'name': 'Tether USD', 'iconUrl': 'https://assets.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'amount': 664582.8, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1705566299, 'address': '0xdAC17F958D2ee523a2206206994597C13D831ec7', 'decimals': 6, 'escrowAddress': '0x5e98A25d8d6FF69A8992d6Aa57948dFB77D4ECBa'}, 'priceId': 'tether'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1706918400, 'value': '0', 'decimals': 0}, 'priceId': 'tether'}]}, 'category': 'stablecoin', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1705566299, 'address': '0xdAC17F958D2ee523a2206206994597C13D831ec7', 'decimals': 6, 'escrowAddress': '0x5e98A25d8d6FF69A8992d6Aa57948dFB77D4ECBa'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1706918400, 'address': '0xFd086bC7CD5C481DCC9C85ebE478A1C0b69FCbb9', 'decimals': 6, 'escrowAddress': '0xb2Cb9aDA6e00118dA8E83a6A53dF1EC6331A60a6'}]}, 'usdValue': 664798.25, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-USDe-2', 'priceId': 'ethena-usde', 'symbol': 'USDe', 'name': 'USDe', 'iconUrl': 'https://coin-images.coingecko.com/coins/images/33613/large/USDE.png?1716355685', 'amount': 662771.2, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1724140527, 'value': '0', 'decimals': 0}, 'priceId': 'ethena-usde'}, {'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1724140487, 'address': '0x4c9EDD5852cd905f086C759E8383e09bff1E68B3', 'decimals': 18, 'escrowAddress': '0x26Cf1Dc84694E04277F2Fe4C13E43597c6010C2A'}, 'priceId': 'ethena-usde'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1724140518, 'value': '0', 'decimals': 0}, 'priceId': 'ethena-usde'}]}, 'category': 'stablecoin', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1724140527, 'address': '0x5d3a1Ff2b6BAb83b63cd9AD0787074081a52ef34', 'decimals': 18, 'escrowAddress': '0x3BcB0FF2D4B674784ac1c33bc85a047b5a726E71'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1724140487, 'address': '0x4c9EDD5852cd905f086C759E8383e09bff1E68B3', 'decimals': 18, 'escrowAddress': '0x26Cf1Dc84694E04277F2Fe4C13E43597c6010C2A'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1724140518, 'address': '0x5d3a1Ff2b6BAb83b63cd9AD0787074081a52ef34', 'decimals': 18, 'escrowAddress': '0x5fAA613365331A5062F3A00126954b742aBEb2FF'}]}, 'usdValue': 662701.1, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fuel/breakdown: 0.09 seconds counter=029/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'lyra-SNX-2', 'priceId': 'havven', 'symbol': 'SNX', 'name': 'Synthetix Network Token', 'iconUrl': 'https://assets.coingecko.com/coins/images/3406/large/SNX.png?1696504103', 'amount': 210.16, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1708294763, 'address': '0xC011a73ee8576Fb46F5E1c5751cA3B9Fe0af2a6F', 'decimals': 18, 'escrowAddress': '0x7D7aC8d55A9bD4152b703011f3E61AB3bB0A5592'}, 'priceId': 'havven'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1708294759, 'value': '0', 'decimals': 0}, 'priceId': 'havven'}]}, 'category': 'other', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1708294763, 'address': '0xC011a73ee8576Fb46F5E1c5751cA3B9Fe0af2a6F', 'decimals': 18, 'escrowAddress': '0x7D7aC8d55A9bD4152b703011f3E61AB3bB0A5592'}, {'type': 'balanceOfEscrow', 'chain': 'optimism', 'sinceTimestamp': 1708294759, 'address': '0x8700dAec35aF8Ff88c16BdF0418774CB3D7599B4', 'decimals': 18, 'escrowAddress': '0x8574CBC539c26Df9ec11bA283218268101ff10e1'}]}, 'usdValue': 162.84, 'isGasToken': False} counter=027/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/abstract/breakdown: 0.09 seconds counter=031/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cronoszkevm/breakdown: 0.08 seconds counter=032/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/eclipse/breakdown: 0.07 seconds counter=033/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lisk/breakdown: 0.21 seconds counter=022/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/immutablex/breakdown: 0.09 seconds counter=036/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sxnetwork/breakdown: 0.10 seconds counter=034/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/edu-chain/breakdown: 0.11 seconds counter=035/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aevo/breakdown: 0.10 seconds counter=037/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-lite/breakdown: 0.09 seconds counter=040/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/degate3/breakdown: 0.10 seconds counter=038/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'degate3-GALA', 'priceId': 'gala', 'symbol': 'GALA', 'name': 'Gala', 'iconUrl': 'https://assets.coingecko.com/coins/images/12493/large/GALA-COINGECKO.png?1696512310', 'amount': 16168.53, 'category': 'other', 'source': 'canonical', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1699746983, 'address': '0x15D4c048F83bd7e37d49eA4C83a07267Ec4203dA', 'decimals': 8, 'escrowAddress': '0x54D7aE423Edb07282645e740C046B9373970a168'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1699746983, 'address': '0xd1d2Eb1B1e90B638588728b4130137D262C87cae', 'decimals': 8, 'escrowAddress': '0x54D7aE423Edb07282645e740C046B9373970a168'}]}, 'usdValue': 283.51, 'escrow': {'address': '0x54D7aE423Edb07282645e740C046B9373970a168', 'url': 'https://etherscan.io/address/0x54D7aE423Edb07282645e740C046B9373970a168', 'name': 'DefaultDepositContract'}} counter=038/154 eta='3 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polygonzkevm/breakdown: 0.09 seconds counter=039/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xlayer/breakdown: 0.09 seconds counter=042/154 eta='3 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kinto/breakdown: 0.09 seconds counter=043/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-wstETH', 'priceId': 'wrapped-steth', 'symbol': 'wstETH', 'name': 'Wrapped liquid staked Ether 2.0', 'iconUrl': 'https://assets.coingecko.com/coins/images/18834/large/wstETH.png?1696518295', 'amount': 4359.1, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716128303, 'address': '0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0', 'decimals': 18, 'escrowAddress': '0xc5d01939Af7Ce9Ffc505F0bb36eFeDde7920f2dc'}, 'priceId': 'wrapped-steth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716128411, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-steth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716128387, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-steth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716128303, 'address': '0x7f39C581F595B53c5cb19bD0b3f8dA6c935E2Ca0', 'decimals': 18, 'escrowAddress': '0xc5d01939Af7Ce9Ffc505F0bb36eFeDde7920f2dc'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1716128411, 'address': '0xc1CBa3fCea344f92D9239c08C0568f6F2F0ee452', 'decimals': 18, 'escrowAddress': '0xE194f2B41A5dc6Be311aD7811eF391a0ac84687d'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1716128387, 'address': '0x5979D7b546E38E414F7E9822514be443A4800529', 'decimals': 18, 'escrowAddress': '0x6F855dE562CC9d019757f5F68a15Cd392FF52962'}]}, 'usdValue': 9336790, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-USDC', 'priceId': 'usd-coin', 'symbol': 'USDC', 'name': 'USD Coin', 'iconUrl': 'https://assets.coingecko.com/coins/images/6319/large/usdc.png?1696506694', 'amount': 525914.3, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716142595, 'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48', 'decimals': 6, 'escrowAddress': '0x755cD5d147036E11c76F1EeffDd94794fC265f0d'}, 'priceId': 'usd-coin'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716142647, 'value': '0', 'decimals': 0}, 'priceId': 'usd-coin'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716142624, 'value': '0', 'decimals': 0}, 'priceId': 'usd-coin'}]}, 'category': 'stablecoin', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716142595, 'address': '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48', 'decimals': 6, 'escrowAddress': '0x755cD5d147036E11c76F1EeffDd94794fC265f0d'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1716142647, 'address': '0x833589fCD6eDb6E08f4c7C32D4f71b54bdA02913', 'decimals': 6, 'escrowAddress': '0xc7744d1A93c56a6eE12CCF1F2264641F219528fE'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1716142624, 'address': '0xaf88d065e77c8cC2239327C5EDb3A432268e5831', 'decimals': 6, 'escrowAddress': '0xC88A469B96A62d4DA14Dc5e23BDBC495D2b15C6B'}]}, 'usdValue': 525913.6, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-weETH', 'priceId': 'wrapped-eeth', 'symbol': 'weETH', 'name': 'Wrapped eETH', 'iconUrl': 'https://assets.coingecko.com/coins/images/33033/large/weETH.png?1701438396', 'amount': 193.71, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716143951, 'address': '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee', 'decimals': 18, 'escrowAddress': '0xeB66259d2eBC3ed1d3a98148f6298927d8A36397'}, 'priceId': 'wrapped-eeth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716143999, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-eeth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716143980, 'value': '0', 'decimals': 0}, 'priceId': 'wrapped-eeth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716143951, 'address': '0xCd5fE23C85820F7B72D0926FC9b05b43E359b7ee', 'decimals': 18, 'escrowAddress': '0xeB66259d2eBC3ed1d3a98148f6298927d8A36397'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1716143999, 'address': '0x04C0599Ae5A44757c0af6F9eC3b93da8976c150A', 'decimals': 18, 'escrowAddress': '0x8de880ecA6B95214C1ECd1556BF1DB4d23f212B5'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1716143980, 'address': '0x35751007a407ca6FEFfE80b3cB397736D2cf4dbe', 'decimals': 18, 'escrowAddress': '0x8bD30d8c5d5cBb5e41Af7B9A4bD654b34772e890'}]}, 'usdValue': 368334.2, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-WETH', 'priceId': 'weth', 'symbol': 'WETH', 'name': 'Wrapped Ether', 'iconUrl': 'https://assets.coingecko.com/coins/images/2518/large/weth.png?1696503332', 'amount': 156.26, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716142367, 'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2', 'decimals': 18, 'escrowAddress': '0x00A0c9d82B95a17Cdf2D46703F2DcA13EB0E8A94'}, 'priceId': 'weth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716142417, 'value': '0', 'decimals': 0}, 'priceId': 'weth'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716142397, 'value': '0', 'decimals': 0}, 'priceId': 'weth'}]}, 'category': 'ether', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716142367, 'address': '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2', 'decimals': 18, 'escrowAddress': '0x00A0c9d82B95a17Cdf2D46703F2DcA13EB0E8A94'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1716142417, 'address': '0x4200000000000000000000000000000000000006', 'decimals': 18, 'escrowAddress': '0xfDF267c43c0C868046c66695c1a85c973418CBFb'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1716142397, 'address': '0x82aF49447D8a07e3bd95BD0d56f35241523fBab1', 'decimals': 18, 'escrowAddress': '0x4D585D346DFB27b297C37F480a82d4cAB39491Bb'}]}, 'usdValue': 278792.06, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-LINK', 'priceId': 'chainlink', 'symbol': 'LINK', 'name': 'ChainLink Token', 'iconUrl': 'https://assets.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1696502009', 'amount': 6426.52, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1730655983, 'address': '0x514910771AF9Ca656af840dff83E8264EcF986CA', 'decimals': 18, 'escrowAddress': '0xA6Ae29Ce5c38DFE0Dd95B716748ac747f31E4013'}, 'priceId': 'chainlink'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1730656015, 'value': '0', 'decimals': 0}, 'priceId': 'chainlink'}]}, 'category': 'other', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1730655983, 'address': '0x514910771AF9Ca656af840dff83E8264EcF986CA', 'decimals': 18, 'escrowAddress': '0xA6Ae29Ce5c38DFE0Dd95B716748ac747f31E4013'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1730656015, 'address': '0xf97f4df75117a78c1A5a0DBb814Af92458539FB4', 'decimals': 18, 'escrowAddress': '0xC9a9f47Ae41Fa4287837751AF7325e87a1dE9326'}]}, 'usdValue': 97188.61, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-SPX', 'priceId': 'spx6900', 'symbol': 'SPX', 'name': 'SPX6900', 'iconUrl': 'https://coin-images.coingecko.com/coins/images/31401/large/sticker_%281%29.jpg?1702371083', 'amount': 44768.69, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1730147723, 'address': '0xE0f63A424a4439cBE457D80E4f4b51aD25b2c56C', 'decimals': 8, 'escrowAddress': '0xd1228C6CB94a670F30D5ACb1340a9d96aC30e6A8'}, 'priceId': 'spx6900'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1730154133, 'value': '0', 'decimals': 0}, 'priceId': 'spx6900'}]}, 'category': 'other', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1730147723, 'address': '0xE0f63A424a4439cBE457D80E4f4b51aD25b2c56C', 'decimals': 8, 'escrowAddress': '0xd1228C6CB94a670F30D5ACb1340a9d96aC30e6A8'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1730154133, 'address': '0x50dA645f148798F68EF2d7dB7C1CB22A6819bb2C', 'decimals': 8, 'escrowAddress': '0x67c1869c1A105d8117938cFC6597409f59eA9af7'}]}, 'usdValue': 28499.33, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-USDe', 'priceId': 'ethena-usde', 'symbol': 'USDe', 'name': 'USDe', 'iconUrl': 'https://assets.coingecko.com/coins/images/33613/large/3466ef_3c088c66c7d941e8856339d0bddf33cc_mv2.png?1702514458', 'amount': 16082.7, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716143207, 'address': '0x4c9EDD5852cd905f086C759E8383e09bff1E68B3', 'decimals': 18, 'escrowAddress': '0xdf34E61B6e7B9e348713d528fEB019d504d38c1e'}, 'priceId': 'ethena-usde'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1716143237, 'value': '0', 'decimals': 0}, 'priceId': 'ethena-usde'}]}, 'category': 'stablecoin', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1716143207, 'address': '0x4c9EDD5852cd905f086C759E8383e09bff1E68B3', 'decimals': 18, 'escrowAddress': '0xdf34E61B6e7B9e348713d528fEB019d504d38c1e'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1716143237, 'address': '0x5d3a1Ff2b6BAb83b63cd9AD0787074081a52ef34', 'decimals': 18, 'escrowAddress': '0x7C852c2a3e367453Ce3a68A4D12c313BaD0565e3'}]}, 'usdValue': 16081, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'kinto-DAI', 'priceId': 'dai', 'symbol': 'DAI', 'name': 'Dai Stablecoin', 'iconUrl': 'https://assets.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996', 'amount': 5163.29, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1715972567, 'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F', 'decimals': 18, 'escrowAddress': '0x12Cf431BdF7F143338cC09A0629EDcCEDCBCEcB5'}, 'priceId': 'dai'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1715972109, 'value': '0', 'decimals': 0}, 'priceId': 'dai'}, {'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1715972440, 'value': '0', 'decimals': 0}, 'priceId': 'dai'}]}, 'category': 'stablecoin', 'source': 'external', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1715972567, 'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F', 'decimals': 18, 'escrowAddress': '0x12Cf431BdF7F143338cC09A0629EDcCEDCBCEcB5'}, {'type': 'balanceOfEscrow', 'chain': 'base', 'sinceTimestamp': 1715972109, 'address': '0x50c5725949A6F0c72E6C4a641F24049A917DB0Cb', 'decimals': 18, 'escrowAddress': '0x9354E3822CE6BF77B2761f8922972BB767D771d8'}, {'type': 'balanceOfEscrow', 'chain': 'arbitrum', 'sinceTimestamp': 1715972440, 'address': '0xDA10009cBd5D07dd0CeCc66161FC93D7c9000da1', 'decimals': 18, 'escrowAddress': '0x36E2DBe085eE4d028fD60f70670f662365d0E978'}]}, 'usdValue': 5161.2, 'isGasToken': False} counter=043/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lumia/breakdown: 0.09 seconds counter=045/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zklinknova/breakdown: 0.10 seconds counter=048/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:02 [error    ] Failed to parse URL for asset {'mode': 'auto', 'id': 'zklinknova-ezETH-2', 'priceId': 'renzo-restaked-eth', 'symbol': 'ezETH', 'name': 'Renzo Restaked ETH', 'iconUrl': 'https://assets.coingecko.com/coins/images/34753/large/eth_renzo_logo_%281%29.png?1705956747', 'amount': 242.24, 'valueForSummary': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'value', 'amount': {'type': 'const', 'sinceTimestamp': 1710337050, 'value': '0', 'decimals': 0}, 'priceId': 'renzo-restaked-eth'}, {'type': 'value', 'amount': {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1709295323, 'address': '0xbf5495Efe5DB9ce00f80364C8B423567e58d2110', 'decimals': 18, 'escrowAddress': '0xAd16eDCF7DEB7e90096A259c81269d811544B6B6'}, 'priceId': 'renzo-restaked-eth'}]}, 'category': 'ether', 'source': 'canonical', 'isAssociated': False, 'address': 'multiple', 'formula': {'type': 'calculation', 'operator': 'sum', 'arguments': [{'type': 'balanceOfEscrow', 'chain': 'linea', 'sinceTimestamp': 1710337050, 'address': '0x2416092f143378750bb29b79eD961ab195CcEea5', 'decimals': 18, 'escrowAddress': '0x62cE247f34dc316f93D3830e4Bf10959FCe630f8'}, {'type': 'balanceOfEscrow', 'chain': 'ethereum', 'sinceTimestamp': 1709295323, 'address': '0xbf5495Efe5DB9ce00f80364C8B423567e58d2110', 'decimals': 18, 'escrowAddress': '0xAd16eDCF7DEB7e90096A259c81269d811544B6B6'}]}, 'usdValue': 452205, 'escrow': 'multiple'} counter=048/154 eta='2 secs' filename=tvsbreakdown.py lineno=175 process=74228
# ...
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sanko/breakdown: 0.08 seconds counter=070/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mint/breakdown: 0.08 seconds counter=071/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ancient8/breakdown: 0.08 seconds counter=073/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/apex/breakdown: 0.09 seconds counter=072/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aztecv1/breakdown: 0.08 seconds counter=074/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/winr/breakdown: 0.09 seconds counter=075/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fluence/breakdown: 0.09 seconds counter=076/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/treasure/breakdown: 0.43 seconds counter=052/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/degen/breakdown: 0.09 seconds counter=078/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/prom/breakdown: 0.10 seconds counter=077/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/hychain/breakdown: 0.08 seconds counter=079/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/tanx/breakdown: 0.08 seconds counter=080/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xai/breakdown: 0.08 seconds counter=081/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superposition/breakdown: 0.08 seconds counter=082/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/redstone/breakdown: 0.08 seconds counter=084/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lens/breakdown: 0.09 seconds counter=085/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/shape/breakdown: 0.10 seconds counter=083/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aleph-zero/breakdown: 0.08 seconds counter=086/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/facet/breakdown: 0.09 seconds counter=087/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superseed/breakdown: 0.08 seconds counter=089/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/everclear/breakdown: 0.09 seconds counter=088/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rari/breakdown: 0.12 seconds counter=090/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkfair/breakdown: 0.08 seconds counter=091/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/popapex/breakdown: 0.08 seconds counter=094/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/funki/breakdown: 0.09 seconds counter=092/154 eta='2 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/gasp/breakdown: 0.09 seconds counter=093/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/dbk/breakdown: 0.09 seconds counter=095/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/alienx/breakdown: 0.09 seconds counter=096/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ternoa/breakdown: 0.11 seconds counter=097/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/metal/breakdown: 0.09 seconds counter=098/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/powerloom/breakdown: 0.08 seconds counter=099/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkspace/breakdown: 0.08 seconds counter=100/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/popboss/breakdown: 0.09 seconds counter=104/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ham/breakdown: 0.11 seconds counter=102/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/b3/breakdown: 0.13 seconds counter=101/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superlumio/breakdown: 0.09 seconds counter=105/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/swan/breakdown: 0.08 seconds counter=106/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cartesi-honeypot/breakdown: 0.09 seconds counter=107/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/towns/breakdown: 0.14 seconds counter=103/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/optopia/breakdown: 0.09 seconds counter=108/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/myria/breakdown: 0.10 seconds counter=109/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/termstructure/breakdown: 0.08 seconds counter=112/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/arenaz/breakdown: 0.09 seconds counter=111/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/geist/breakdown: 0.07 seconds counter=114/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/oev/breakdown: 0.10 seconds counter=113/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/form/breakdown: 0.12 seconds counter=110/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xchain/breakdown: 0.09 seconds counter=115/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/appchain/breakdown: 0.10 seconds counter=116/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/molten/breakdown: 0.08 seconds counter=118/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cheese/breakdown: 0.08 seconds counter=119/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/race/breakdown: 0.09 seconds counter=120/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/syndicateframe/breakdown: 0.09 seconds counter=122/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/edgeless/breakdown: 0.12 seconds counter=117/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/muster/breakdown: 0.10 seconds counter=121/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/snaxchain/breakdown: 0.09 seconds counter=123/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/deri/breakdown: 0.09 seconds counter=124/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/automata/breakdown: 0.09 seconds counter=125/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/onyx/breakdown: 0.09 seconds counter=126/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/huddle01/breakdown: 0.08 seconds counter=128/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/donatuz/breakdown: 0.08 seconds counter=129/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/phala/breakdown: 0.09 seconds counter=130/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rarimo/breakdown: 0.09 seconds counter=131/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/settlus/breakdown: 0.09 seconds counter=132/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ethernity/breakdown: 0.13 seconds counter=127/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:03 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/henez/breakdown: 0.08 seconds counter=133/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/clique/breakdown: 0.10 seconds counter=134/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/forta/breakdown: 0.09 seconds counter=135/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fuelv1/breakdown: 0.09 seconds counter=136/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/r0ar/breakdown: 0.08 seconds counter=138/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/pmon/breakdown: 0.10 seconds counter=137/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rufus/breakdown: 0.08 seconds counter=140/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kontos/breakdown: 0.09 seconds counter=139/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/grvt/breakdown: 0.08 seconds counter=141/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/openzk/breakdown: 0.08 seconds counter=143/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lasernet/breakdown: 0.09 seconds counter=142/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkcandy/breakdown: 0.08 seconds counter=144/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/blockfit/breakdown: 0.08 seconds counter=146/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/dodochain/breakdown: 0.09 seconds counter=148/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/conwai/breakdown: 0.09 seconds counter=147/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/gridy/breakdown: 0.10 seconds counter=149/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bitlazer/breakdown: 0.14 seconds counter=145/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/inevm/breakdown: 0.08 seconds counter=150/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/onchain/breakdown: 0.07 seconds counter=151/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/skynet/breakdown: 0.10 seconds counter=152/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/playblock/breakdown: 0.10 seconds counter=153/154 eta='1 secs' filename=request.py lineno=96 process=74228
# 2025-04-25 11:27:04 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xrone/breakdown: 0.09 seconds counter=154/154 eta='1 secs' filename=request.py lineno=96 process=74228

# %%
# This cell is to debug a single project 

from op_analytics.datasources.l2beat.projects import L2BeatProject
from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown

result = L2BeatTVSBreakdown.fetch(projects=[
    L2BeatProject(id='zksync2', slug='zksync-era')
])

# %%
from op_analytics.coreutils.request import get_data, new_session

data = get_data(
    session=new_session(),
    url=f"https://l2beat.com/api/scaling/tvs/unichain/breakdown",
)

# %%
# debug
import json

breakdown = data["data"]["breakdown"]

print(json.dumps(list(breakdown.keys()), indent=2))

for category, assets in breakdown.items():
    print(f"{category}: {len(assets)} assets")

timestamp = data["data"]["dataTimestamp"]
timestamp
