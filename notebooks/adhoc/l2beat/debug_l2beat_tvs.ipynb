# %%
from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.l2beat.executetvs import execute_pull

with write_to_prod():
    execute_pull()

# %%
from op_analytics.datasources.l2beat.projects import L2BeatProject
from op_analytics.datasources.l2beat.tvsbreakdown import L2BeatTVSBreakdown


projects = [
    L2BeatProject(id="arbitrum", slug="arbitrum"),
    L2BeatProject(id="base", slug="base"),
    L2BeatProject(id="optimism", slug="op-mainnet"),
    L2BeatProject(id="polygon-pos", slug="polygon-pos"),
    L2BeatProject(id="mantle", slug="mantle"),
    L2BeatProject(id="zksync2", slug="zksync-era"),
    L2BeatProject(id="starknet", slug="starknet"),
    L2BeatProject(id="celo", slug="celo"),
    L2BeatProject(id="linea", slug="linea"),
    L2BeatProject(id="blast", slug="blast"),
    L2BeatProject(id="mantapacific", slug="mantapacific"),
    L2BeatProject(id="bob", slug="bob"),
    L2BeatProject(id="worldchain", slug="world"),
    L2BeatProject(id="fraxtal", slug="fraxtal"),
    L2BeatProject(id="scroll", slug="scroll"),
    L2BeatProject(id="mode", slug="mode"),
    L2BeatProject(id="soneium", slug="soneium"),
    L2BeatProject(id="taiko", slug="taiko"),
    L2BeatProject(id="zircuit", slug="zircuit"),
    L2BeatProject(id="metis", slug="metis"),
    L2BeatProject(id="sophon", slug="sophon"),
    L2BeatProject(id="lisk", slug="lisk"),
    L2BeatProject(id="swell", slug="swell"),
    L2BeatProject(id="ink", slug="ink"),
    L2BeatProject(id="galxegravity", slug="galxegravity"),
    L2BeatProject(id="lyra", slug="derive"),
    L2BeatProject(id="fuel", slug="fuel"),
    L2BeatProject(id="cronoszkevm", slug="cronoszkevm"),
    L2BeatProject(id="eclipse", slug="eclipse"),
    L2BeatProject(id="paradex", slug="paradex"),
    L2BeatProject(id="degate3", slug="degate3"),
    L2BeatProject(id="aevo", slug="aevo"),
    L2BeatProject(id="abstract", slug="abstract"),
    L2BeatProject(id="zksync", slug="zksync-lite"),
    L2BeatProject(id="immutablex", slug="immutablex"),
    L2BeatProject(id="polygonzkevm", slug="polygonzkevm"),
    L2BeatProject(id="corn", slug="corn"),
    L2BeatProject(id="apex", slug="apex"),
    L2BeatProject(id="xlayer", slug="xlayer"),
    L2BeatProject(id="educhain", slug="edu-chain"),
    L2BeatProject(id="kinto", slug="kinto"),
    L2BeatProject(id="loopring", slug="loopring"),
    L2BeatProject(id="lumia", slug="lumia"),
    L2BeatProject(id="rss3", slug="rss3"),
    L2BeatProject(id="nova", slug="nova"),
    L2BeatProject(id="zklinknova", slug="zklinknova"),
    L2BeatProject(id="unichain", slug="unichain"),
    L2BeatProject(id="sxnetwork", slug="sxnetwork"),
    L2BeatProject(id="morph", slug="morph"),
    L2BeatProject(id="reya", slug="reya"),
    L2BeatProject(id="immutablezkevm", slug="immutablezkevm"),
    L2BeatProject(id="game7", slug="g7"),
    L2BeatProject(id="orderly", slug="orderly"),
    L2BeatProject(id="silicon", slug="silicon"),
    L2BeatProject(id="karak", slug="k2"),
    L2BeatProject(id="sorare", slug="sorare"),
    L2BeatProject(id="zora", slug="zora"),
    L2BeatProject(id="lightlink", slug="lightlink"),
    L2BeatProject(id="cyber", slug="cyber"),
    L2BeatProject(id="hashkey", slug="hashkey"),
    L2BeatProject(id="pepeunchained", slug="pepeunchained"),
    L2BeatProject(id="bobanetwork", slug="bobanetwork"),
    L2BeatProject(id="soon", slug="soon"),
    L2BeatProject(id="polynomial", slug="polynomial"),
    L2BeatProject(id="treasure", slug="treasure"),
    L2BeatProject(id="real", slug="real"),
    L2BeatProject(id="kroma", slug="kroma"),
    L2BeatProject(id="zeronetwork", slug="zeronetwork"),
    L2BeatProject(id="sanko", slug="sanko"),
    L2BeatProject(id="mint", slug="mint"),
    L2BeatProject(id="shibarium", slug="shibarium"),
    L2BeatProject(id="aztec", slug="aztecv1"),
    L2BeatProject(id="ancient", slug="ancient8"),
    L2BeatProject(id="winr", slug="winr"),
    L2BeatProject(id="prom", slug="prom"),
    L2BeatProject(id="fluence", slug="fluence"),
    L2BeatProject(id="hychain", slug="hychain"),
    L2BeatProject(id="brine", slug="tanx"),
    L2BeatProject(id="shape", slug="shape"),
    L2BeatProject(id="degen", slug="degen"),
    L2BeatProject(id="superposition", slug="superposition"),
    L2BeatProject(id="redstone", slug="redstone"),
    L2BeatProject(id="xai", slug="xai"),
    L2BeatProject(id="zkfair", slug="zkfair"),
    L2BeatProject(id="facet", slug="facet"),
    L2BeatProject(id="metal", slug="metal"),
    L2BeatProject(id="funki", slug="funki"),
    L2BeatProject(id="gasp", slug="gasp"),
    L2BeatProject(id="alephzero", slug="aleph-zero"),
    L2BeatProject(id="everclear", slug="everclear"),
    L2BeatProject(id="rari", slug="rari"),
    L2BeatProject(id="superseed", slug="superseed"),
    L2BeatProject(id="popapex", slug="popapex"),
    L2BeatProject(id="dbk", slug="dbk"),
    L2BeatProject(id="alienx", slug="alienx"),
    L2BeatProject(id="ternoa", slug="ternoa"),
    L2BeatProject(id="zkspace", slug="zkspace"),
    L2BeatProject(id="ham", slug="ham"),
    L2BeatProject(id="b3", slug="b3"),
    L2BeatProject(id="river", slug="towns"),
    L2BeatProject(id="popboss", slug="popboss"),
    L2BeatProject(id="termstructure", slug="termstructure"),
    L2BeatProject(id="superlumio", slug="superlumio"),
    L2BeatProject(id="swan", slug="swan"),
    L2BeatProject(id="optopia", slug="optopia"),
    L2BeatProject(id="myria", slug="myria"),
    L2BeatProject(id="honeypot", slug="cartesi-honeypot"),
    L2BeatProject(id="form", slug="form"),
    L2BeatProject(id="oevnetwork", slug="oev"),
    L2BeatProject(id="ebichain", slug="ebichain"),
    L2BeatProject(id="arenaz", slug="arenaz"),
    L2BeatProject(id="geist", slug="geist"),
    L2BeatProject(id="xchain", slug="xchain"),
    L2BeatProject(id="molten", slug="molten"),
    L2BeatProject(id="edgeless", slug="edgeless"),
    L2BeatProject(id="cheese", slug="cheese"),
    L2BeatProject(id="race", slug="race"),
    L2BeatProject(id="muster", slug="muster"),
    L2BeatProject(id="xterio", slug="xterio"),
    L2BeatProject(id="syndicateframe", slug="syndicateframe"),
    L2BeatProject(id="snaxchain", slug="snaxchain"),
    L2BeatProject(id="deri", slug="deri"),
    L2BeatProject(id="ethernity", slug="ethernity"),
    L2BeatProject(id="automata", slug="automata"),
    L2BeatProject(id="huddle01", slug="huddle01"),
    L2BeatProject(id="stack", slug="stack"),
    L2BeatProject(id="phala", slug="phala"),
    L2BeatProject(id="donatuz", slug="donatuz"),
    L2BeatProject(id="settlus", slug="settlus"),
    L2BeatProject(id="henez", slug="henez"),
    L2BeatProject(id="rarimo", slug="rarimo"),
    L2BeatProject(id="clique", slug="clique"),
    L2BeatProject(id="forta", slug="forta"),
    L2BeatProject(id="fuelv1", slug="fuelv1"),
    L2BeatProject(id="pmon", slug="pmon"),
    L2BeatProject(id="r0ar", slug="r0ar"),
    L2BeatProject(id="bugbuster", slug="bugbuster"),
    L2BeatProject(id="kontos", slug="kontos"),
    L2BeatProject(id="rufus", slug="rufus"),
    L2BeatProject(id="airas", slug="airas"),
    L2BeatProject(id="grvt", slug="grvt"),
    L2BeatProject(id="openzk", slug="openzk"),
    L2BeatProject(id="apechain", slug="apechain"),
    L2BeatProject(id="bitlazer", slug="bitlazer"),
    L2BeatProject(id="blockfit", slug="blockfit"),
    L2BeatProject(id="conwai", slug="conwai"),
    L2BeatProject(id="dodochain", slug="dodochain"),
    L2BeatProject(id="inevm", slug="inevm"),
    L2BeatProject(id="onchain", slug="onchain"),
    L2BeatProject(id="skynet", slug="skynet"),
    L2BeatProject(id="playblock", slug="playblock"),
    L2BeatProject(id="xrone", slug="xrone"),
]


result = L2BeatTVSBreakdown.fetch(projects=projects)

# %%
result.df

# %%
from op_analytics.coreutils.request import get_data, new_session

data = get_data(
    session=new_session(),
    url=f"https://l2beat.com/api/scaling/tvs/unichain/breakdown",
)

# %%
# debug
import json

breakdown = data["data"]["breakdown"]

print(json.dumps(list(breakdown.keys()), indent=2))

for category, assets in breakdown.items():
    print(f"{category}: {len(assets)} assets")

timestamp = data["data"]["dataTimestamp"]
timestamp

# %%
from op_analytics.datasources.l2beat.tvsbreakdown import parse_tvs, L2BeatTVSBreakdown

df = L2BeatTVSBreakdown.fetch()
# Out:
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/summary: 0.65 seconds filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mantle/breakdown: 0.11 seconds counter=005/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/starknet/breakdown: 0.12 seconds counter=007/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/op-mainnet/breakdown: 0.12 seconds counter=003/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-era/breakdown: 0.12 seconds counter=006/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/base/breakdown: 0.13 seconds counter=002/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polygon-pos/breakdown: 0.13 seconds counter=004/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/celo/breakdown: 0.16 seconds counter=008/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/arbitrum/breakdown: 0.16 seconds counter=001/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/linea/breakdown: 0.08 seconds counter=009/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/world/breakdown: 0.07 seconds counter=013/152 eta='4 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bob/breakdown: 0.07 seconds counter=012/152 eta='5 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fraxtal/breakdown: 0.07 seconds counter=014/152 eta='4 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/blast/breakdown: 0.10 seconds counter=010/152 eta=None filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/scroll/breakdown: 0.06 seconds counter=015/152 eta='4 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mantapacific/breakdown: 0.10 seconds counter=011/152 eta='7 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mode/breakdown: 0.05 seconds counter=017/152 eta='4 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/soneium/breakdown: 0.09 seconds counter=016/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/metis/breakdown: 0.06 seconds counter=019/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/taiko/breakdown: 0.08 seconds counter=018/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ink/breakdown: 0.05 seconds counter=023/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zircuit/breakdown: 0.07 seconds counter=020/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sophon/breakdown: 0.06 seconds counter=021/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lisk/breakdown: 0.07 seconds counter=022/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/derive/breakdown: 0.08 seconds counter=025/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/swell/breakdown: 0.09 seconds counter=024/152 eta='3 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fuel/breakdown: 0.07 seconds counter=027/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/galxegravity/breakdown: 0.08 seconds counter=026/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cronoszkevm/breakdown: 0.07 seconds counter=028/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aevo/breakdown: 0.07 seconds counter=031/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/eclipse/breakdown: 0.08 seconds counter=030/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/paradex/breakdown: 0.08 seconds counter=029/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/degate3/breakdown: 0.08 seconds counter=033/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/edu-chain/breakdown: 0.08 seconds counter=032/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zksync-lite/breakdown: 0.07 seconds counter=035/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/abstract/breakdown: 0.07 seconds counter=034/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/corn/breakdown: 0.06 seconds counter=038/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/apex/breakdown: 0.06 seconds counter=037/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polygonzkevm/breakdown: 0.07 seconds counter=039/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xlayer/breakdown: 0.09 seconds counter=036/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/immutablex/breakdown: 0.07 seconds counter=040/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kinto/breakdown: 0.07 seconds counter=041/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rss3/breakdown: 0.07 seconds counter=043/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/g7/breakdown: 0.05 seconds counter=047/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/nova/breakdown: 0.07 seconds counter=045/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lumia/breakdown: 0.07 seconds counter=044/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/unichain/breakdown: 0.06 seconds counter=046/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/loopring/breakdown: 0.10 seconds counter=042/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sxnetwork/breakdown: 0.06 seconds counter=049/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/morph/breakdown: 0.05 seconds counter=052/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/immutablezkevm/breakdown: 0.06 seconds counter=051/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/reya/breakdown: 0.07 seconds counter=050/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lightlink/breakdown: 0.06 seconds counter=055/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zklinknova/breakdown: 0.09 seconds counter=048/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/orderly/breakdown: 0.08 seconds counter=053/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sorare/breakdown: 0.06 seconds counter=056/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/k2/breakdown: 0.05 seconds counter=058/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/silicon/breakdown: 0.12 seconds counter=054/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cyber/breakdown: 0.07 seconds counter=059/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zora/breakdown: 0.08 seconds counter=057/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/pepeunchained/breakdown: 0.06 seconds counter=061/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/hashkey/breakdown: 0.06 seconds counter=060/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/soon/breakdown: 0.07 seconds counter=062/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/polynomial/breakdown: 0.06 seconds counter=064/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bobanetwork/breakdown: 0.06 seconds counter=063/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zeronetwork/breakdown: 0.05 seconds counter=068/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/treasure/breakdown: 0.06 seconds counter=065/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/real/breakdown: 0.06 seconds counter=066/152 eta='2 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kroma/breakdown: 0.07 seconds counter=067/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/mint/breakdown: 0.06 seconds counter=069/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ancient8/breakdown: 0.05 seconds counter=072/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/sanko/breakdown: 0.07 seconds counter=070/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/shibarium/breakdown: 0.06 seconds counter=071/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aztecv1/breakdown: 0.05 seconds counter=073/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/winr/breakdown: 0.05 seconds counter=074/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/prom/breakdown: 0.07 seconds counter=075/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/hychain/breakdown: 0.07 seconds counter=077/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/shape/breakdown: 0.06 seconds counter=079/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fluence/breakdown: 0.07 seconds counter=078/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkfair/breakdown: 0.06 seconds counter=082/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/redstone/breakdown: 0.08 seconds counter=081/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/degen/breakdown: 0.06 seconds counter=084/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/lens/breakdown: 0.05 seconds counter=087/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/facet/breakdown: 0.07 seconds counter=085/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/aleph-zero/breakdown: 0.07 seconds counter=086/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xai/breakdown: 0.11 seconds counter=083/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/gasp/breakdown: 0.08 seconds counter=088/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/metal/breakdown: 0.07 seconds counter=089/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/everclear/breakdown: 0.06 seconds counter=091/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superseed/breakdown: 0.06 seconds counter=092/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superposition/breakdown: 0.21 seconds counter=080/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/funki/breakdown: 0.08 seconds counter=090/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rari/breakdown: 0.06 seconds counter=093/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/popapex/breakdown: 0.05 seconds counter=094/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:47 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/alienx/breakdown: 0.05 seconds counter=096/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/dbk/breakdown: 0.09 seconds counter=095/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ham/breakdown: 0.07 seconds counter=099/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/towns/breakdown: 0.05 seconds counter=102/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/b3/breakdown: 0.07 seconds counter=100/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/popboss/breakdown: 0.06 seconds counter=101/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkspace/breakdown: 0.10 seconds counter=098/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ternoa/breakdown: 0.12 seconds counter=097/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/tanx/breakdown: 0.35 seconds counter=076/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/termstructure/breakdown: 0.06 seconds counter=103/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cartesi-honeypot/breakdown: 0.06 seconds counter=107/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/swan/breakdown: 0.06 seconds counter=105/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/myria/breakdown: 0.04 seconds counter=108/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/superlumio/breakdown: 0.08 seconds counter=104/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/optopia/breakdown: 0.11 seconds counter=106/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/arenaz/breakdown: 0.06 seconds counter=111/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/oev/breakdown: 0.07 seconds counter=110/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/form/breakdown: 0.08 seconds counter=109/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/geist/breakdown: 0.06 seconds counter=112/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/edgeless/breakdown: 0.05 seconds counter=115/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xchain/breakdown: 0.06 seconds counter=113/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/molten/breakdown: 0.07 seconds counter=114/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/race/breakdown: 0.06 seconds counter=116/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/cheese/breakdown: 0.06 seconds counter=119/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/muster/breakdown: 0.07 seconds counter=117/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xterio/breakdown: 0.07 seconds counter=118/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/deri/breakdown: 0.06 seconds counter=122/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/snaxchain/breakdown: 0.06 seconds counter=121/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/syndicateframe/breakdown: 0.06 seconds counter=120/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/ethernity/breakdown: 0.06 seconds counter=123/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/phala/breakdown: 0.05 seconds counter=127/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rarimo/breakdown: 0.05 seconds counter=130/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/settlus/breakdown: 0.05 seconds counter=129/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/automata/breakdown: 0.07 seconds counter=124/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/huddle01/breakdown: 0.07 seconds counter=125/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/donatuz/breakdown: 0.07 seconds counter=128/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/stack/breakdown: 0.07 seconds counter=126/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/henez/breakdown: 0.06 seconds counter=131/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/pmon/breakdown: 0.06 seconds counter=134/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/r0ar/breakdown: 0.05 seconds counter=136/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/fuelv1/breakdown: 0.06 seconds counter=135/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/clique/breakdown: 0.07 seconds counter=132/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/forta/breakdown: 0.06 seconds counter=133/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/kontos/breakdown: 0.06 seconds counter=137/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/grvt/breakdown: 0.06 seconds counter=140/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/zkcandy/breakdown: 0.06 seconds counter=142/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/bitlazer/breakdown: 0.06 seconds counter=144/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/blockfit/breakdown: 0.06 seconds counter=145/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/apechain/breakdown: 0.07 seconds counter=143/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/conwai/breakdown: 0.05 seconds counter=146/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/onchain/breakdown: 0.05 seconds counter=149/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/inevm/breakdown: 0.06 seconds counter=148/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/dodochain/breakdown: 0.07 seconds counter=147/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/airas/breakdown: 0.16 seconds counter=139/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/skynet/breakdown: 0.06 seconds counter=150/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/openzk/breakdown: 0.16 seconds counter=141/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/rufus/breakdown: 0.21 seconds counter=138/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/playblock/breakdown: 0.06 seconds counter=151/152 eta='1 secs' filename=request.py lineno=96 process=30952
# 2025-04-08 10:45:48 [info     ] Fetched from https://l2beat.com/api/scaling/tvs/xrone/breakdown: 0.09 seconds counter=152/152 eta='1 secs' filename=request.py lineno=96 process=30952

# %%
df
# Out:
# L2BeatTVSBreakdown(df=shape: (2_348, 22)
# ┌────────────┬────────────┬────────────┬────────────┬───┬────────┬────────────┬────────┬───────────┐
# │ dt         ┆ project_id ┆ project_sl ┆ timestamp  ┆ … ┆ symbol ┆ name       ┆ supply ┆ category  │
# │ ---        ┆ ---        ┆ ug         ┆ ---        ┆   ┆ ---    ┆ ---        ┆ ---    ┆ ---       │
# │ str        ┆ str        ┆ ---        ┆ i64        ┆   ┆ str    ┆ str        ┆ str    ┆ str       │
# │            ┆            ┆ str        ┆            ┆   ┆        ┆            ┆        ┆           │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪════════╪════════════╪════════╪═══════════╡
# │ 2025-04-08 ┆ mantle     ┆ mantle     ┆ 1744113600 ┆ … ┆ USDT   ┆ Tether USD ┆ zero   ┆ canonical │
# │ 2025-04-08 ┆ mantle     ┆ mantle     ┆ 1744113600 ┆ … ┆ MNT    ┆ Mantle     ┆ zero   ┆ canonical │
# │ 2025-04-08 ┆ mantle     ┆ mantle     ┆ 1744113600 ┆ … ┆ MNT    ┆ Mantle     ┆ zero   ┆ canonical │
# │ 2025-04-08 ┆ mantle     ┆ mantle     ┆ 1744113600 ┆ … ┆ ETH    ┆ Ether      ┆ zero   ┆ canonical │
# │ 2025-04-08 ┆ mantle     ┆ mantle     ┆ 1744113600 ┆ … ┆ mETH   ┆ mETH       ┆ zero   ┆ canonical │
# │ …          ┆ …          ┆ …          ┆ …          ┆ … ┆ …      ┆ …          ┆ …      ┆ …         │
# │ 2025-04-08 ┆ kontos     ┆ kontos     ┆ 1744113600 ┆ … ┆ PENDLE ┆ Pendle     ┆ zero   ┆ canonical │
# │ 2025-04-08 ┆ kontos     ┆ kontos     ┆ 1744113600 ┆ … ┆ RAI    ┆ Rai Reflex ┆ zero   ┆ canonical │
# │            ┆            ┆            ┆            ┆   ┆        ┆ Index      ┆        ┆           │
# │ 2025-04-08 ┆ kontos     ┆ kontos     ┆ 1744113600 ┆ … ┆ PEOPLE ┆ Constituti ┆ zero   ┆ canonical │
# │            ┆            ┆            ┆            ┆   ┆        ┆ onDAO      ┆        ┆           │
# │ 2025-04-08 ┆ kontos     ┆ kontos     ┆ 1744113600 ┆ … ┆ FET    ┆ Fetch      ┆ zero   ┆ canonical │
# │ 2025-04-08 ┆ rufus      ┆ rufus      ┆ 1744113600 ┆ … ┆ ELON   ┆ Dogelon    ┆ zero   ┆ canonical │
# └────────────┴────────────┴────────────┴────────────┴───┴────────┴────────────┴────────┴───────────┘)

# %%
# Access the DataFrame
df_result = df.df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Access the DataFrame
#       2 df_result = df.df
# ----> 3 all_data = df.collect()
#
# AttributeError: 'L2BeatTVSBreakdown' object has no attribute 'collect'

# %%
# count the number of rows per category
df_result.group_by("category").count()
# Out:
# /var/folders/80/jqw6kmgj7j34j0x4mcs6hcl00000gn/T/ipykernel_30952/1176701051.py:2: DeprecationWarning: `GroupBy.count` is deprecated. It has been renamed to `len`.
#   df_result.group_by("category").count()
# shape: (3, 2)
# ┌───────────┬───────┐
# │ category  ┆ count │
# │ ---       ┆ ---   │
# │ str       ┆ u32   │
# ╞═══════════╪═══════╡
# │ native    ┆ 146   │
# │ canonical ┆ 1821  │
# │ external  ┆ 381   │
# └───────────┴───────┘
