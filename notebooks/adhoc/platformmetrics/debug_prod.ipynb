# %%
from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.platformmetrics import execute
import os
with write_to_prod():
    result = execute.execute_pull()
# Out:
# 2025-07-14 21:42:44 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=40312
# 2025-07-14 21:42:44 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=40312
# /Users/bellaokiddy/Documents/Github/op-analytics/src/op_analytics/coreutils/postgres/client.py:112: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return pl.DataFrame(data, schema=columns)
# 2025-07-14 21:44:26 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=40312
# 2025-07-14 21:44:26 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=40312
# 2025-07-14 21:44:33 [info     ] Fetched from https://prometheus-blocks-prod-us-central1.grafana.net/api/prom/api/v1/query_range: 0.97 seconds filename=request.py lineno=100 process=40312
# 2025-07-14 21:44:33 [info     ] Prometheus range query executed duration=0.97s filename=client.py lineno=112 process=40312 query='sum(increase(nat_tests_total[1d  ]))'
# 2025-07-14 21:44:34 [info     ] done writing 1.2Krows 35.6KB   filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-08/out.parquet' process=40312 root=platformmetrics/platform_metrics_jobs_v1 rows=1194 size=35621
# 2025-07-14 21:44:34 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:36 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:36 [info     ] done writing 2.2Krows 63.7KB   filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-09/out.parquet' process=40312 root=platformmetrics/platform_metrics_jobs_v1 rows=2220 size=63668
# 2025-07-14 21:44:36 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:37 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:37 [info     ] done writing 2.8Krows 80.4KB   filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-10/out.parquet' process=40312 root=platformmetrics/platform_metrics_jobs_v1 rows=2819 size=80365
# 2025-07-14 21:44:37 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:39 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:39 [info     ] done writing 1.6Krows 44.6KB   filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-11/out.parquet' process=40312 root=platformmetrics/platform_metrics_jobs_v1 rows=1573 size=44623
# 2025-07-14 21:44:39 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:41 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:41 [info     ] done writing 618rows 18.5KB    filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-13/out.parquet' process=40312 root=platformmetrics/platform_metrics_jobs_v1 rows=618 size=18546
# 2025-07-14 21:44:41 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:42 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:42 [info     ] done writing 1.1Krows 34.3KB   filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-14/out.parquet' process=40312 root=platformmetrics/platform_metrics_jobs_v1 rows=1147 size=34336
# 2025-07-14 21:44:42 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:43 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-14 21:44:43 [info     ] done writing 25rows 3.8KB      filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-08/out.parquet' process=40312 root=platformmetrics/platform_metrics_pipelines_v1 rows=25 size=3838
# 2025-07-14 21:44:44 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:45 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:45 [info     ] done writing 46rows 5.1KB      filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-09/out.parquet' process=40312 root=platformmetrics/platform_metrics_pipelines_v1 rows=46 size=5127
# 2025-07-14 21:44:45 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:46 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:46 [info     ] done writing 57rows 5.7KB      filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-10/out.parquet' process=40312 root=platformmetrics/platform_metrics_pipelines_v1 rows=57 size=5669
# 2025-07-14 21:44:46 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:47 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:47 [info     ] done writing 32rows 4.5KB      filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-11/out.parquet' process=40312 root=platformmetrics/platform_metrics_pipelines_v1 rows=32 size=4451
# 2025-07-14 21:44:47 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:48 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:48 [info     ] done writing 11rows 3.2KB      filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-13/out.parquet' process=40312 root=platformmetrics/platform_metrics_pipelines_v1 rows=11 size=3152
# 2025-07-14 21:44:48 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:49 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:49 [info     ] done writing 23rows 3.9KB      filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-14/out.parquet' process=40312 root=platformmetrics/platform_metrics_pipelines_v1 rows=23 size=3867
# 2025-07-14 21:44:49 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:50 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-14 21:44:50 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-08/out.parquet' process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-14 21:44:50 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:51 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:51 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-09/out.parquet' process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-14 21:44:51 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:53 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:53 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-10/out.parquet' process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-14 21:44:53 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:54 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:54 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-11/out.parquet' process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-14 21:44:54 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:55 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:55 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-12/out.parquet' process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-14 21:44:55 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:56 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:56 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=1000112128 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-13/out.parquet' process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-14 21:44:56 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=1000.11 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-14 21:44:57 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=40312 root=platformmetrics/platform_metrics_prometheus_metrics_v1
