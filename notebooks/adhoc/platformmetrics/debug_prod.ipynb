# %%
from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.platform_metrics import execute
import os
with write_to_prod():
    result = execute.execute_pull()
# Out:
# 2025-06-26 16:30:53 [info     ] loaded vault from .env file    filename=vault.py lineno=32 process=84317
# 2025-06-26 16:30:53 [debug    ] loaded vault: 28 items         filename=vault.py lineno=79 process=84317
# 2025-06-26 16:30:53 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=84317
# 2025-06-26 16:30:53 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=84317
# /Users/bellaokiddy/Documents/Github/op-analytics/src/op_analytics/coreutils/postgres/client.py:112: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return pl.DataFrame(data, schema=columns)
# 2025-06-26 16:32:04 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=84317
# 2025-06-26 16:32:04 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=84317
# 2025-06-26 16:32:13 [info     ] Fetched from https://prometheus-blocks-prod-us-central1.grafana.net/api/prom/api/v1/query_range: 1.34 seconds filename=request.py lineno=100 process=84317
# 2025-06-26 16:32:13 [info     ] Prometheus range query executed duration=1.35s filename=client.py lineno=112 process=84317 query='sum(increase(nat_tests_total[1d  ]))'
# 2025-06-26 16:32:13 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:13 [info     ] Initialized gcsfs client for bucket=gs://oplabs-tools-data-sink filename=gcs_parquet.py lineno=32 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:13 [info     ] done writing 1.8Krows 53.0KB   filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-20/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=1759 size=53009
# 2025-06-26 16:32:13 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:15 [debug    ] connecting to OPLABS Clickhouse client... filename=client.py lineno=56 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:17 [debug    ] initialized OPLABS Clickhouse client. filename=client.py lineno=61 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:17 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:17 [info     ] done writing 281rows 11.8KB    filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-21/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=281 size=11767
# 2025-06-26 16:32:17 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:18 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:18 [info     ] done writing 95rows 7.3KB      filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-22/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=95 size=7259
# 2025-06-26 16:32:18 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:19 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:19 [info     ] done writing 2.4Krows 69.9KB   filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-23/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=2414 size=69877
# 2025-06-26 16:32:19 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:21 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:21 [info     ] done writing 2.5Krows 72.0KB   filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-24/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=2494 size=72031
# 2025-06-26 16:32:21 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:22 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:22 [info     ] done writing 3.1Krows 90.3KB   filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-25/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=3135 size=90349
# 2025-06-26 16:32:22 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:24 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:24 [info     ] done writing 382rows 14.4KB    filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-06-26/out.parquet' process=84317 root=platformmetrics/platform_metrics_jobs_v1 rows=382 size=14353
# 2025-06-26 16:32:24 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:25 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_jobs_v1
# 2025-06-26 16:32:25 [info     ] done writing 36rows 4.4KB      filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-20/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=36 size=4449
# 2025-06-26 16:32:25 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:27 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:27 [info     ] done writing 6rows 2.6KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-21/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=6 size=2580
# 2025-06-26 16:32:27 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:28 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:28 [info     ] done writing 2rows 2.3KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-22/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=2 size=2312
# 2025-06-26 16:32:28 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:29 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:29 [info     ] done writing 51rows 5.3KB      filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-23/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=51 size=5348
# 2025-06-26 16:32:29 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:30 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:30 [info     ] done writing 53rows 5.5KB      filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-24/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=53 size=5543
# 2025-06-26 16:32:30 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:31 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:31 [info     ] done writing 66rows 6.1KB      filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-25/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=66 size=6146
# 2025-06-26 16:32:31 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:32 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:32 [info     ] done writing 8rows 2.9KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-06-26/out.parquet' process=84317 root=platformmetrics/platform_metrics_pipelines_v1 rows=8 size=2905
# 2025-06-26 16:32:32 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:33 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-06-26 16:32:33 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-20/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:33 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:34 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:34 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-21/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:34 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:35 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:35 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-22/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:35 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:36 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:36 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-23/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:36 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:38 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:38 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-24/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:38 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:39 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:39 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-25/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:39 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:40 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:40 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=777895936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-06-26/out.parquet' process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-06-26 16:32:40 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=777.9 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-06-26 16:32:41 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=84317 root=platformmetrics/platform_metrics_prometheus_metrics_v1
