# %%
from op_analytics.coreutils.partitioned.dailydatawrite import write_to_prod
from op_analytics.datasources.platformmetrics import execute
import os
with write_to_prod():
    result = execute.execute_pull()
# Out:
# 2025-07-09 11:36:18 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=28478
# 2025-07-09 11:36:18 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=28478
# /Users/bellaokiddy/Documents/Github/op-analytics/src/op_analytics/coreutils/postgres/client.py:112: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return pl.DataFrame(data, schema=columns)
# 2025-07-09 11:36:52 [debug    ] Found vault variable GOOGLE_SERVICE_ACCOUNT (has JSON key) filename=gcpauth.py lineno=18 process=28478
# 2025-07-09 11:36:53 [info     ] Initialized Google Cloud SQL connector filename=client.py lineno=32 process=28478
# 2025-07-09 11:36:59 [info     ] Fetched from https://prometheus-blocks-prod-us-central1.grafana.net/api/prom/api/v1/query_range: 1.08 seconds filename=request.py lineno=100 process=28478
# 2025-07-09 11:36:59 [info     ] Prometheus range query executed duration=1.09s filename=client.py lineno=112 process=28478 query='sum(increase(nat_tests_total[1d  ]))'
# 2025-07-09 11:36:59 [info     ] done writing 47rows 6.0KB      filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-03/out.parquet' process=28478 root=platformmetrics/platform_metrics_jobs_v1 rows=47 size=5956
# 2025-07-09 11:36:59 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:03 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:03 [info     ] done writing 47rows 6.0KB      filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-04/out.parquet' process=28478 root=platformmetrics/platform_metrics_jobs_v1 rows=47 size=5965
# 2025-07-09 11:37:03 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:04 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:04 [info     ] done writing 240rows 10.6KB    filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-06/out.parquet' process=28478 root=platformmetrics/platform_metrics_jobs_v1 rows=240 size=10633
# 2025-07-09 11:37:04 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:06 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:06 [info     ] done writing 999rows 30.3KB    filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-07/out.parquet' process=28478 root=platformmetrics/platform_metrics_jobs_v1 rows=999 size=30321
# 2025-07-09 11:37:06 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:08 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:08 [info     ] done writing 1.2Krows 35.6KB   filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-08/out.parquet' process=28478 root=platformmetrics/platform_metrics_jobs_v1 rows=1194 size=35621
# 2025-07-09 11:37:08 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:10 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:10 [info     ] done writing 287rows 11.9KB    filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_jobs_v1/dt=2025-07-09/out.parquet' process=28478 root=platformmetrics/platform_metrics_jobs_v1 rows=287 size=11865
# 2025-07-09 11:37:10 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:12 [debug    ] done writing platformmetrics/platform_metrics_jobs_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_jobs_v1
# 2025-07-09 11:37:12 [info     ] done writing 1rows 2.6KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-03/out.parquet' process=28478 root=platformmetrics/platform_metrics_pipelines_v1 rows=1 size=2623
# 2025-07-09 11:37:12 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:13 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:13 [info     ] done writing 1rows 2.6KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-04/out.parquet' process=28478 root=platformmetrics/platform_metrics_pipelines_v1 rows=1 size=2605
# 2025-07-09 11:37:13 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:15 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:15 [info     ] done writing 5rows 2.5KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-06/out.parquet' process=28478 root=platformmetrics/platform_metrics_pipelines_v1 rows=5 size=2480
# 2025-07-09 11:37:15 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:17 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:17 [info     ] done writing 20rows 3.4KB      filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-07/out.parquet' process=28478 root=platformmetrics/platform_metrics_pipelines_v1 rows=20 size=3410
# 2025-07-09 11:37:17 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:19 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:19 [info     ] done writing 25rows 3.8KB      filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-08/out.parquet' process=28478 root=platformmetrics/platform_metrics_pipelines_v1 rows=25 size=3838
# 2025-07-09 11:37:19 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:20 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:20 [info     ] done writing 6rows 2.7KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_pipelines_v1/dt=2025-07-09/out.parquet' process=28478 root=platformmetrics/platform_metrics_pipelines_v1 rows=6 size=2678
# 2025-07-09 11:37:20 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:22 [debug    ] done writing platformmetrics/platform_metrics_pipelines_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_pipelines_v1
# 2025-07-09 11:37:22 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-03/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:22 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:24 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:24 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-04/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:24 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:25 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:25 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-05/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:25 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:27 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:27 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-06/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:27 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:29 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:29 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-07/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:29 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:31 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:31 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-08/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:31 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:32 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:32 [info     ] done writing 1rows 1.2KB       filename=gcs_parquet.py lineno=57 maxrss=849575936 path='oplabs-tools-data-sink/platformmetrics/platform_metrics_prometheus_metrics_v1/dt=2025-07-09/out.parquet' process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1 rows=1 size=1190
# 2025-07-09 11:37:32 [info     ] memory usage                   filename=gcs_parquet.py lineno=65 max_rss=849.58 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
# 2025-07-09 11:37:34 [debug    ] done writing platformmetrics/platform_metrics_prometheus_metrics_v1 to GCS filename=writemanager.py lineno=131 process=28478 root=platformmetrics/platform_metrics_prometheus_metrics_v1
