# %%
import pandas as pd
import sys
import numpy as np
sys.path.append("../helper_functions")
import defillama_utils as dfl
sys.path.pop()
# Out:
# '../helper_functions'

# %%
df = dfl.get_todays_tvl()
df = df[df['chainTVL'] > 0] # Pull > 0 TVL
df = df[~df['chain'].str.contains('-')] # Filter out all pool2, borrows, staking, etc
df['chain_map'] = np.where(df['chain']=='Optimism','optimism','other chains')
df.to_csv('csv_outputs/dfl_data.csv',index=False)

# %%
display(df[df['name'].str.contains('AAVE')])
# Out:
#                name parentProtocol   category           slug  \
# 0       Binance CEX                       CEX    binance-cex
# 1       Binance CEX                       CEX    binance-cex
# 2       Binance CEX                       CEX    binance-cex
# 3       Binance CEX                       CEX    binance-cex
# 4       Binance CEX                       CEX    binance-cex
# ...             ...            ...        ...            ...
# 9001   Snark Launch                 Launchpad   snark-launch
# 9004  SuperLauncher                 Launchpad  superlauncher
# 9007        FunBear                  Services        funbear
# 9010    Kei Finance                     Yield    kei-finance
# 9027         Nutbox                  Services         nutbox
#
#                                url  \
# 0          https://www.binance.com
# 1          https://www.binance.com
# 2          https://www.binance.com
# 3          https://www.binance.com
# 4          https://www.binance.com
# ...                            ...
# 9001  https://app.snarklaunch.com/
# 9004      https://superlauncher.io
# 9007           https://funbear.net
# 9010                https://kei.fi
# 9027         https://app.nutbox.io
#
#                                             description         twitter  \
# 0     Binance is a cryptocurrency exchange which is ...         binance
# 1     Binance is a cryptocurrency exchange which is ...         binance
# 2     Binance is a cryptocurrency exchange which is ...         binance
# 3     Binance is a cryptocurrency exchange which is ...         binance
# 4     Binance is a cryptocurrency exchange which is ...         binance
# ...                                                 ...             ...
# 9001  Snark Launch is a decentralized launchpad on t...     SnarkLaunch
# 9004  SuperLauncher is an investment DAO facilitatin...  Super_Launcher
# 9007  Funbear is a community-oriented DeFi protocol ...       funbeario
# 9010  Kei Finance's the future of DeFi! Solves tradi...      KeiFinance
# 9027  Nutbox is a staking DAO platform for everyon. ...       NutboxDao
#
#      forkedFrom oracles           tvl      chain      chainTVL parent_slug  \
# 0            []      []  6.407331e+10   Optimism  2.589488e+08
# 1            []      []  6.407331e+10   Litecoin  5.428508e+08
# 2            []      []  6.407331e+10    Binance  9.828567e+09
# 3            []      []  6.407331e+10   Ethereum  1.612365e+10
# 4            []      []  6.407331e+10  Avalanche  6.250336e+08
# ...         ...     ...           ...        ...           ...         ...
# 9001         []      []  0.000000e+00    staking  5.281764e+04
# 9004         []      []  0.000000e+00    staking  3.024120e+05
# 9007         []      []  0.000000e+00    staking  2.080759e+07
# 9010         []      []  0.000000e+00    staking  3.066848e+05
# 9027         []      []  0.000000e+00    staking  3.356717e+04
#
#         parent_name     chain_map
# 0       Binance CEX      optimism
# 1       Binance CEX  other chains
# 2       Binance CEX  other chains
# 3       Binance CEX  other chains
# 4       Binance CEX  other chains
# ...             ...           ...
# 9001   Snark Launch  other chains
# 9004  SuperLauncher  other chains
# 9007        FunBear  other chains
# 9010    Kei Finance  other chains
# 9027         Nutbox  other chains
#
# [5626 rows x 15 columns]
