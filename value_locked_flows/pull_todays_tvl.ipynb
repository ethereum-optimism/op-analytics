# %%
import pandas as pd
import sys
sys.path.append("../helper_functions")
import defillama_utils as dfl
sys.path.pop()
# Out:
# '../helper_functions'

# %%
df = dfl.get_todays_tvl()
df = df[df['chainTVL'] > 0] # Pull > 0 TVL
df.to_csv('csv_outputs/dfl_data.csv',index=False)
# Out:
#              name  category         slug                      url  \
# 0     Binance CEX       CEX  binance-cex  https://www.binance.com
# 1     Binance CEX       CEX  binance-cex  https://www.binance.com
# 2     Binance CEX       CEX  binance-cex  https://www.binance.com
# 3     Binance CEX       CEX  binance-cex  https://www.binance.com
# 4     Binance CEX       CEX  binance-cex  https://www.binance.com
# ...           ...       ...          ...                      ...
# 9007      FunBear  Services      funbear      https://funbear.net
# 9009  Kei Finance     Yield  kei-finance           https://kei.fi
# 9010  Kei Finance     Yield  kei-finance           https://kei.fi
# 9024       Nutbox  Services       nutbox    https://app.nutbox.io
# 9027       Nutbox  Services       nutbox    https://app.nutbox.io
#
#                                             description     twitter  \
# 0     Binance is a cryptocurrency exchange which is ...     binance
# 1     Binance is a cryptocurrency exchange which is ...     binance
# 2     Binance is a cryptocurrency exchange which is ...     binance
# 3     Binance is a cryptocurrency exchange which is ...     binance
# 4     Binance is a cryptocurrency exchange which is ...     binance
# ...                                                 ...         ...
# 9007  Funbear is a community-oriented DeFi protocol ...   funbeario
# 9009  Kei Finance's the future of DeFi! Solves tradi...  KeiFinance
# 9010  Kei Finance's the future of DeFi! Solves tradi...  KeiFinance
# 9024  Nutbox is a staking DAO platform for everyon. ...   NutboxDao
# 9027  Nutbox is a staking DAO platform for everyon. ...   NutboxDao
#
#      forkedFrom oracles           tvl             chain      chainTVL
# 0            []      []  6.418972e+10          Optimism  2.600928e+08
# 1            []      []  6.418972e+10          Litecoin  5.476917e+08
# 2            []      []  6.418972e+10           Binance  9.859231e+09
# 3            []      []  6.418972e+10          Ethereum  1.615131e+10
# 4            []      []  6.418972e+10         Avalanche  6.250440e+08
# ...         ...     ...           ...               ...           ...
# 9007         []      []  0.000000e+00           staking  2.080255e+07
# 9009         []      []  0.000000e+00  Ethereum-staking  3.066848e+05
# 9010         []      []  0.000000e+00           staking  3.066848e+05
# 9024         []      []  0.000000e+00   Binance-staking  3.363355e+04
# 9027         []      []  0.000000e+00           staking  3.363355e+04
#
# [7590 rows x 11 columns]
